# %%
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import *
import seaborn as sns
import seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from pathlib import Path
import os.path
import random

# %%
writer = SummaryWriter()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# from google.colab import drive
# drive.mount('/content/gdrive/');

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# cuda

# %% [markdown]
# **Visualize images from Dataset:**

# %%
def load_Data():
    train_dataset = datasets.ImageFolder("Final_Dataset/dataset3/train", transform=transform)
    val_dataset = datasets.ImageFolder("Final_Dataset/dataset3/val", transform=test_transform)
    test_dataset = datasets.ImageFolder("Final_Dataset/dataset3/test", transform=test_transform)

    print(train_dataset.class_to_idx)
    #print(test_dataset.class_to_idx)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    return train_loader,val_loader,test_loader
load_Data()
# Out:
# {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
# (<torch.utils.data.dataloader.DataLoader at 0x7f57b1759640>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f56e378b0d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f56e378bb80>)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Model(nn.Module):
  def __init__(self,input) -> None:
      super(Model,self).__init__()
      self.model = torchvision.models.mobilenet_v2(pretrained=False)
      #self.num_ftrs = self.model.classifier[1].in_features
      #print(num_ftrs)
      self.fc_layer = nn.Sequential(
      nn.Linear(1280,640),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      
      nn.Linear(640,320),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      
      nn.Linear(320,160),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      nn.Linear(160, 12)
    )
      
      self.model.classifier = self.fc_layer
      self.features = {}
      self.model.classifier.register_forward_pre_hook(self.get_features("embeddings"))
      
  def get_features(self,name):
      def hook(model, input):
          self.features[name] = input[0].detach().cpu().numpy()
      return hook
  def forward(self, x):
        x = self.model(x)
        return x
model = Model((224,224))
print(model)
# Out:
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /anaconda/envs/jupyter_env/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Save checkpoint 
def save_checkpoint(state, filename):
    torch.save(state, filename)

# %%
# datastructure to store all the training testing and validation results.
y_train = []
y_expected_train = []
y_val = []
y_expected_val = []
y_test = []
y_expected_test = []
trainloss = []
valloss =[]
epochnum = []

# %%
print(torch.cuda.is_available())
def train(model, train_loader, criterion, optimizer, epoch, step=5):
    
    model.train()
    loss_list = AverageMeter()
    for i, (images, labels) in enumerate(train_loader):
        #print(torch.cuda.is_available())
        total =0
        correct = 0
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        #print(predicted,type(predicted))
        #print(labels,type(labels))
        output = model(images)
        loss = criterion(output,labels)
        loss_list.update(loss.data, images.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        y_train.extend(predicted.to(torch.device('cpu')))
        y_expected_train.extend(labels.to(torch.device('cpu')))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        #print( f'Training Accuracy: {accuracy:.2f}%')
            
        if i%step==0:
            print('EPOCH {} | ITER {} | AVG_LOSS {} | Train_ACC {}'.format(epoch, i, loss_list.avg,accuracy))
        writer.add_scalar('TRAIN_LOSS', loss, epoch)
        writer.add_scalar('TRAIN_ACC', accuracy, epoch)
        
    return loss ,accuracy
# Out:
# True

# %%
def val(model, val_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    loss_list = AverageMeter()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            #print("Inside validation");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            loss = criterion(outputs,labels)
            loss_list.update(loss.data, inputs.size(0))
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #print("CORRECT",correct)
            #print("Total",total)
        accuracy = 100 * correct / total
        print(f'Val Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('Validation_LOSS', loss, epoch)
        writer.add_scalar('Validation_ACCURACY', accuracy, epoch)
        return loss,accuracy

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    print("Best Model: ",epoch)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('_LOSS', loss, epoch)
        # writer.add_scalar('TEST_ACC', accuracy, epoch)
        return accuracy

# %%
def visualize(model , data_loader):
    class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
    idx2class = { value : key for key,value in  class2idx.items() }
    embeddings = np.array([])
    labels = np.array([])
    model.eval()
    out_features = 1280
    num_categories = 12
    with torch.no_grad(): 
        for i,data in enumerate(data_loader):
            images, labs = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            embeds = model.features["embeddings"].reshape(-1, 1280)
            embeddings = np.append(embeddings , embeds)
            labels = np.append(labels,labs.cpu())
  
    embeddings = embeddings.reshape(-1, 1280)
    
    c_labels = labels.reshape(-1 , 1).ravel()
    tsne = TSNE(n_components=2,perplexity=2).fit_transform(embeddings)
    labels = np.array([ idx2class[ele] for ele in c_labels])
    
    cmap = cm.get_cmap('tab20')
    
    for lab in range(num_categories):
        indices = (c_labels == lab)
        plt.scatter(tsne[indices, 0],tsne[indices, 1],c=np.array(cmap(lab)).reshape(1, 4),label=lab,alpha=1)
        plt.legend(fontsize='large', markerscale=2)
    plt.show()
  
# model = Model((224,224))
# train_loader, val_loader ,test_loader = load_Data()
# visualize(model,test_loader)

# %%
def plotloss():
  plt.figure(figsize=(20,10))
  plt.plot(epochnum, trainloss)
  plt.plot(epochnum, valloss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
idx2class = { value : key  for key , value in class2idx.items() }

def plot_confusion_matrix(data, labels, metrics ,output_filename=None):

    [macro_precision , micro_precision , macro_recall , micro_recall] = metrics

    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(10,10))
 
    plt.suptitle("Confusion Matrix")
    plt.title(f"(Macro/Micro) Precision : {round(macro_precision,2)}/{round(micro_precision,2)}   :::::   (Macro/Micro) Recall : {round(macro_recall,2)}/{round(micro_recall,2)}")
 
    seaborn.set(font_scale=1)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu",linewidths=2 , fmt='d' ,cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# %%
def main():
    model = Model((224,224));
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        model = model.cuda()
        print("using gpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    epochs = 30
    train_loader, val_loader ,test_loader = load_Data()
 
    history = open("Results/dataset3_MB_history.csv",'w')
    history.write('epochs , trainloss , Train-acc,val_acc , test_acc \n')
    max_accuracy = 0 
    finalepoch  = 0 
    for epoch in range(0,epochs):
        start = time.time()
        train_loss,accuracy = train(model, train_loader, criterion, optimizer, epoch)
        vallosss,val_loss = val(model, val_loader, criterion, optimizer, epoch)
        
        trainloss.append(train_loss.cpu().detach().numpy())
        valloss.append(vallosss.cpu().detach().numpy())
        epochnum.append(epoch)
        print()
        print('-' * 50)
        print('EPOCH {} | LOSS {} | TIME {}'.format(epoch, train_loss, time.time() - start))
        print('-' * 50)
        print()

        if(val_loss > max_accuracy):
          max_accuracy = val_loss
          finalepoch  = epoch
          save_checkpoint({'epoch': epoch,'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),'loss' : train_loss}, "Checkpoints/dataset3_mb_checkpoint.ckpt")

        history.write('{},{},{},{}\n'.format(epoch, train_loss,accuracy, val_loss ))
    test_loss = test(model, test_loader, criterion, optimizer, finalepoch)    
    history.close()
    visualize(model,train_loader)

# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    main()
# Out:
# True
# using gpu
# {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
# EPOCH 0 | ITER 0 | AVG_LOSS 2.48020601272583 | Train_ACC 18.75
# EPOCH 0 | ITER 5 | AVG_LOSS 2.506096124649048 | Train_ACC 9.375
# EPOCH 0 | ITER 10 | AVG_LOSS 2.4911956787109375 | Train_ACC 6.25
# EPOCH 0 | ITER 15 | AVG_LOSS 2.491790294647217 | Train_ACC 6.25
# EPOCH 0 | ITER 20 | AVG_LOSS 2.487537384033203 | Train_ACC 3.125
# EPOCH 0 | ITER 25 | AVG_LOSS 2.47713041305542 | Train_ACC 6.25
# EPOCH 0 | ITER 30 | AVG_LOSS 2.468277931213379 | Train_ACC 3.125
# EPOCH 0 | ITER 35 | AVG_LOSS 2.462378740310669 | Train_ACC 9.375
# EPOCH 0 | ITER 40 | AVG_LOSS 2.4545724391937256 | Train_ACC 18.75
# EPOCH 0 | ITER 45 | AVG_LOSS 2.442408323287964 | Train_ACC 15.625
# EPOCH 0 | ITER 50 | AVG_LOSS 2.4421536922454834 | Train_ACC 18.75
# EPOCH 0 | ITER 55 | AVG_LOSS 2.437715530395508 | Train_ACC 15.625
# EPOCH 0 | ITER 60 | AVG_LOSS 2.426755666732788 | Train_ACC 15.625
# EPOCH 0 | ITER 65 | AVG_LOSS 2.428778648376465 | Train_ACC 25.0
# EPOCH 0 | ITER 70 | AVG_LOSS 2.428227186203003 | Train_ACC 6.25
# EPOCH 0 | ITER 75 | AVG_LOSS 2.423755168914795 | Train_ACC 25.0
# EPOCH 0 | ITER 80 | AVG_LOSS 2.4171676635742188 | Train_ACC 21.875
# EPOCH 0 | ITER 85 | AVG_LOSS 2.4125750064849854 | Train_ACC 25.0
# EPOCH 0 | ITER 90 | AVG_LOSS 2.4089016914367676 | Train_ACC 9.375
# EPOCH 0 | ITER 95 | AVG_LOSS 2.4035112857818604 | Train_ACC 21.875
# EPOCH 0 | ITER 100 | AVG_LOSS 2.4015426635742188 | Train_ACC 12.5
# EPOCH 0 | ITER 105 | AVG_LOSS 2.398554801940918 | Train_ACC 18.75
# EPOCH 0 | ITER 110 | AVG_LOSS 2.3960564136505127 | Train_ACC 6.25
# EPOCH 0 | ITER 115 | AVG_LOSS 2.3895132541656494 | Train_ACC 28.125
# EPOCH 0 | ITER 120 | AVG_LOSS 2.3890881538391113 | Train_ACC 25.0
# EPOCH 0 | ITER 125 | AVG_LOSS 2.390815258026123 | Train_ACC 18.75
# EPOCH 0 | ITER 130 | AVG_LOSS 2.3907699584960938 | Train_ACC 21.875
# EPOCH 0 | ITER 135 | AVG_LOSS 2.389697551727295 | Train_ACC 21.875
# EPOCH 0 | ITER 140 | AVG_LOSS 2.3891124725341797 | Train_ACC 9.375
# EPOCH 0 | ITER 145 | AVG_LOSS 2.389808177947998 | Train_ACC 18.75
# EPOCH 0 | ITER 150 | AVG_LOSS 2.3872694969177246 | Train_ACC 18.75
# EPOCH 0 | ITER 155 | AVG_LOSS 2.383809804916382 | Train_ACC 21.875
# EPOCH 0 | ITER 160 | AVG_LOSS 2.38116455078125 | Train_ACC 21.875
# EPOCH 0 | ITER 165 | AVG_LOSS 2.3782804012298584 | Train_ACC 12.5
# EPOCH 0 | ITER 170 | AVG_LOSS 2.3747987747192383 | Train_ACC 12.5
# EPOCH 0 | ITER 175 | AVG_LOSS 2.371277332305908 | Train_ACC 15.625
# EPOCH 0 | ITER 180 | AVG_LOSS 2.3677978515625 | Train_ACC 25.0
# EPOCH 0 | ITER 185 | AVG_LOSS 2.3640596866607666 | Train_ACC 28.125
# EPOCH 0 | ITER 190 | AVG_LOSS 2.3597419261932373 | Train_ACC 31.25
# EPOCH 0 | ITER 195 | AVG_LOSS 2.356750965118408 | Train_ACC 28.125
# EPOCH 0 | ITER 200 | AVG_LOSS 2.351742744445801 | Train_ACC 21.875
# EPOCH 0 | ITER 205 | AVG_LOSS 2.3492486476898193 | Train_ACC 15.625
# EPOCH 0 | ITER 210 | AVG_LOSS 2.346280813217163 | Train_ACC 12.5
# EPOCH 0 | ITER 215 | AVG_LOSS 2.3438923358917236 | Train_ACC 18.75
# EPOCH 0 | ITER 220 | AVG_LOSS 2.3410770893096924 | Train_ACC 28.125
# EPOCH 0 | ITER 225 | AVG_LOSS 2.33986496925354 | Train_ACC 28.125
# EPOCH 0 | ITER 230 | AVG_LOSS 2.3355581760406494 | Train_ACC 18.75
# EPOCH 0 | ITER 235 | AVG_LOSS 2.3332371711730957 | Train_ACC 9.375
# EPOCH 0 | ITER 240 | AVG_LOSS 2.3300669193267822 | Train_ACC 15.625
# EPOCH 0 | ITER 245 | AVG_LOSS 2.3302979469299316 | Train_ACC 15.625
# EPOCH 0 | ITER 250 | AVG_LOSS 2.3289363384246826 | Train_ACC 28.125
# EPOCH 0 | ITER 255 | AVG_LOSS 2.3277359008789062 | Train_ACC 21.875
# EPOCH 0 | ITER 260 | AVG_LOSS 2.325770854949951 | Train_ACC 15.625
# EPOCH 0 | ITER 265 | AVG_LOSS 2.3229660987854004 | Train_ACC 34.375
# EPOCH 0 | ITER 270 | AVG_LOSS 2.320539951324463 | Train_ACC 28.125
# EPOCH 0 | ITER 275 | AVG_LOSS 2.3194239139556885 | Train_ACC 15.625
# EPOCH 0 | ITER 280 | AVG_LOSS 2.3185007572174072 | Train_ACC 21.875
# EPOCH 0 | ITER 285 | AVG_LOSS 2.31728458404541 | Train_ACC 31.25
# EPOCH 0 | ITER 290 | AVG_LOSS 2.315035581588745 | Train_ACC 12.5
# EPOCH 0 | ITER 295 | AVG_LOSS 2.3121721744537354 | Train_ACC 12.5
# EPOCH 0 | ITER 300 | AVG_LOSS 2.3117802143096924 | Train_ACC 6.25
# EPOCH 0 | ITER 305 | AVG_LOSS 2.3106632232666016 | Train_ACC 21.875
# EPOCH 0 | ITER 310 | AVG_LOSS 2.309030771255493 | Train_ACC 21.875
# EPOCH 0 | ITER 315 | AVG_LOSS 2.305729389190674 | Train_ACC 25.0
# EPOCH 0 | ITER 320 | AVG_LOSS 2.303791046142578 | Train_ACC 12.5
# EPOCH 0 | ITER 325 | AVG_LOSS 2.3009767532348633 | Train_ACC 9.375
# EPOCH 0 | ITER 330 | AVG_LOSS 2.2995100021362305 | Train_ACC 12.5
# EPOCH 0 | ITER 335 | AVG_LOSS 2.296505928039551 | Train_ACC 37.5
# EPOCH 0 | ITER 340 | AVG_LOSS 2.2944302558898926 | Train_ACC 18.75
# EPOCH 0 | ITER 345 | AVG_LOSS 2.291412591934204 | Train_ACC 18.75
# EPOCH 0 | ITER 350 | AVG_LOSS 2.287811756134033 | Train_ACC 28.125
# EPOCH 0 | ITER 355 | AVG_LOSS 2.285173177719116 | Train_ACC 21.875
# EPOCH 0 | ITER 360 | AVG_LOSS 2.2812139987945557 | Train_ACC 15.625
# EPOCH 0 | ITER 365 | AVG_LOSS 2.2797675132751465 | Train_ACC 18.75
# EPOCH 0 | ITER 370 | AVG_LOSS 2.275986671447754 | Train_ACC 37.5
# Val Accuracy: 15.21%
#
# --------------------------------------------------
# EPOCH 0 | LOSS 2.046323537826538 | TIME 626.1157593727112
# --------------------------------------------------
#
# EPOCH 1 | ITER 0 | AVG_LOSS 2.157058000564575 | Train_ACC 25.0
# EPOCH 1 | ITER 5 | AVG_LOSS 2.1953887939453125 | Train_ACC 15.625
# EPOCH 1 | ITER 10 | AVG_LOSS 2.1755313873291016 | Train_ACC 21.875
# EPOCH 1 | ITER 15 | AVG_LOSS 2.1371302604675293 | Train_ACC 25.0
# EPOCH 1 | ITER 20 | AVG_LOSS 2.135781764984131 | Train_ACC 21.875
# EPOCH 1 | ITER 25 | AVG_LOSS 2.1252434253692627 | Train_ACC 34.375
# EPOCH 1 | ITER 30 | AVG_LOSS 2.125075340270996 | Train_ACC 18.75
# EPOCH 1 | ITER 35 | AVG_LOSS 2.1299095153808594 | Train_ACC 21.875
# EPOCH 1 | ITER 40 | AVG_LOSS 2.109551429748535 | Train_ACC 31.25
# EPOCH 1 | ITER 45 | AVG_LOSS 2.105661630630493 | Train_ACC 21.875
# EPOCH 1 | ITER 50 | AVG_LOSS 2.1035513877868652 | Train_ACC 37.5
# EPOCH 1 | ITER 55 | AVG_LOSS 2.101778030395508 | Train_ACC 28.125
# EPOCH 1 | ITER 60 | AVG_LOSS 2.1025137901306152 | Train_ACC 21.875
# EPOCH 1 | ITER 65 | AVG_LOSS 2.093182325363159 | Train_ACC 25.0
# EPOCH 1 | ITER 70 | AVG_LOSS 2.086376667022705 | Train_ACC 34.375
# EPOCH 1 | ITER 75 | AVG_LOSS 2.0853309631347656 | Train_ACC 28.125
# EPOCH 1 | ITER 80 | AVG_LOSS 2.085419178009033 | Train_ACC 25.0
# EPOCH 1 | ITER 85 | AVG_LOSS 2.085477352142334 | Train_ACC 18.75
# EPOCH 1 | ITER 90 | AVG_LOSS 2.0814478397369385 | Train_ACC 37.5
# EPOCH 1 | ITER 95 | AVG_LOSS 2.0816190242767334 | Train_ACC 34.375
# EPOCH 1 | ITER 100 | AVG_LOSS 2.073493003845215 | Train_ACC 28.125
# EPOCH 1 | ITER 105 | AVG_LOSS 2.0723040103912354 | Train_ACC 34.375
# EPOCH 1 | ITER 110 | AVG_LOSS 2.0674688816070557 | Train_ACC 18.75
# EPOCH 1 | ITER 115 | AVG_LOSS 2.0635178089141846 | Train_ACC 31.25
# EPOCH 1 | ITER 120 | AVG_LOSS 2.063854455947876 | Train_ACC 15.625
# EPOCH 1 | ITER 125 | AVG_LOSS 2.0646183490753174 | Train_ACC 21.875
# EPOCH 1 | ITER 130 | AVG_LOSS 2.0626983642578125 | Train_ACC 34.375
# EPOCH 1 | ITER 135 | AVG_LOSS 2.0666182041168213 | Train_ACC 18.75
# EPOCH 1 | ITER 140 | AVG_LOSS 2.065359354019165 | Train_ACC 25.0
# EPOCH 1 | ITER 145 | AVG_LOSS 2.0640485286712646 | Train_ACC 25.0
# EPOCH 1 | ITER 150 | AVG_LOSS 2.065657377243042 | Train_ACC 15.625
# EPOCH 1 | ITER 155 | AVG_LOSS 2.0623116493225098 | Train_ACC 21.875
# EPOCH 1 | ITER 160 | AVG_LOSS 2.0585570335388184 | Train_ACC 25.0
# EPOCH 1 | ITER 165 | AVG_LOSS 2.056928873062134 | Train_ACC 21.875
# EPOCH 1 | ITER 170 | AVG_LOSS 2.053795099258423 | Train_ACC 12.5
# EPOCH 1 | ITER 175 | AVG_LOSS 2.052208185195923 | Train_ACC 28.125
# EPOCH 1 | ITER 180 | AVG_LOSS 2.0502419471740723 | Train_ACC 25.0
# EPOCH 1 | ITER 185 | AVG_LOSS 2.0496621131896973 | Train_ACC 34.375
# EPOCH 1 | ITER 190 | AVG_LOSS 2.0508368015289307 | Train_ACC 9.375
# EPOCH 1 | ITER 195 | AVG_LOSS 2.048091411590576 | Train_ACC 18.75
# EPOCH 1 | ITER 200 | AVG_LOSS 2.04422664642334 | Train_ACC 21.875
# EPOCH 1 | ITER 205 | AVG_LOSS 2.040900945663452 | Train_ACC 18.75
# EPOCH 1 | ITER 210 | AVG_LOSS 2.040583610534668 | Train_ACC 34.375
# EPOCH 1 | ITER 215 | AVG_LOSS 2.0407886505126953 | Train_ACC 25.0
# EPOCH 1 | ITER 220 | AVG_LOSS 2.0393099784851074 | Train_ACC 18.75
# EPOCH 1 | ITER 225 | AVG_LOSS 2.037961483001709 | Train_ACC 31.25
# EPOCH 1 | ITER 230 | AVG_LOSS 2.0377750396728516 | Train_ACC 46.875
# EPOCH 1 | ITER 235 | AVG_LOSS 2.0370090007781982 | Train_ACC 21.875
# EPOCH 1 | ITER 240 | AVG_LOSS 2.03403902053833 | Train_ACC 28.125
# EPOCH 1 | ITER 245 | AVG_LOSS 2.0316720008850098 | Train_ACC 43.75
# EPOCH 1 | ITER 250 | AVG_LOSS 2.0292954444885254 | Train_ACC 40.625
# EPOCH 1 | ITER 255 | AVG_LOSS 2.0280251502990723 | Train_ACC 25.0
# EPOCH 1 | ITER 260 | AVG_LOSS 2.026334047317505 | Train_ACC 12.5
# EPOCH 1 | ITER 265 | AVG_LOSS 2.020921230316162 | Train_ACC 40.625
# EPOCH 1 | ITER 270 | AVG_LOSS 2.02148699760437 | Train_ACC 28.125
# EPOCH 1 | ITER 275 | AVG_LOSS 2.02065110206604 | Train_ACC 21.875
# EPOCH 1 | ITER 280 | AVG_LOSS 2.0185484886169434 | Train_ACC 28.125
# EPOCH 1 | ITER 285 | AVG_LOSS 2.0168159008026123 | Train_ACC 40.625
# EPOCH 1 | ITER 290 | AVG_LOSS 2.01741886138916 | Train_ACC 28.125
# EPOCH 1 | ITER 295 | AVG_LOSS 2.015848159790039 | Train_ACC 50.0
# EPOCH 1 | ITER 300 | AVG_LOSS 2.015723466873169 | Train_ACC 15.625
# EPOCH 1 | ITER 305 | AVG_LOSS 2.016587734222412 | Train_ACC 25.0
# EPOCH 1 | ITER 310 | AVG_LOSS 2.0144617557525635 | Train_ACC 28.125
# EPOCH 1 | ITER 315 | AVG_LOSS 2.014423370361328 | Train_ACC 18.75
# EPOCH 1 | ITER 320 | AVG_LOSS 2.012565851211548 | Train_ACC 25.0
# EPOCH 1 | ITER 325 | AVG_LOSS 2.0110244750976562 | Train_ACC 31.25
# EPOCH 1 | ITER 330 | AVG_LOSS 2.0099101066589355 | Train_ACC 40.625
# EPOCH 1 | ITER 335 | AVG_LOSS 2.0095906257629395 | Train_ACC 40.625
# EPOCH 1 | ITER 340 | AVG_LOSS 2.011946439743042 | Train_ACC 28.125
# EPOCH 1 | ITER 345 | AVG_LOSS 2.0094642639160156 | Train_ACC 37.5
# EPOCH 1 | ITER 350 | AVG_LOSS 2.0088090896606445 | Train_ACC 46.875
# EPOCH 1 | ITER 355 | AVG_LOSS 2.0099711418151855 | Train_ACC 25.0
# EPOCH 1 | ITER 360 | AVG_LOSS 2.009305953979492 | Train_ACC 15.625
# EPOCH 1 | ITER 365 | AVG_LOSS 2.0072293281555176 | Train_ACC 34.375
# EPOCH 1 | ITER 370 | AVG_LOSS 2.00791335105896 | Train_ACC 50.0
# Val Accuracy: 28.75%
#
# --------------------------------------------------
# EPOCH 1 | LOSS 1.654001235961914 | TIME 617.7946650981903
# --------------------------------------------------
#
# EPOCH 2 | ITER 0 | AVG_LOSS 1.9304767847061157 | Train_ACC 37.5
# EPOCH 2 | ITER 5 | AVG_LOSS 1.8906145095825195 | Train_ACC 37.5
# EPOCH 2 | ITER 10 | AVG_LOSS 1.9093255996704102 | Train_ACC 31.25
# EPOCH 2 | ITER 15 | AVG_LOSS 1.9353688955307007 | Train_ACC 15.625
# EPOCH 2 | ITER 20 | AVG_LOSS 1.9082385301589966 | Train_ACC 31.25
# EPOCH 2 | ITER 25 | AVG_LOSS 1.9059749841690063 | Train_ACC 40.625
# EPOCH 2 | ITER 30 | AVG_LOSS 1.924161434173584 | Train_ACC 25.0
# EPOCH 2 | ITER 35 | AVG_LOSS 1.9325264692306519 | Train_ACC 34.375
# EPOCH 2 | ITER 40 | AVG_LOSS 1.9320324659347534 | Train_ACC 40.625
# EPOCH 2 | ITER 45 | AVG_LOSS 1.9299845695495605 | Train_ACC 34.375
# EPOCH 2 | ITER 50 | AVG_LOSS 1.8972928524017334 | Train_ACC 34.375
# EPOCH 2 | ITER 55 | AVG_LOSS 1.8971586227416992 | Train_ACC 28.125
# EPOCH 2 | ITER 60 | AVG_LOSS 1.8918335437774658 | Train_ACC 43.75
# EPOCH 2 | ITER 65 | AVG_LOSS 1.8923990726470947 | Train_ACC 31.25
# EPOCH 2 | ITER 70 | AVG_LOSS 1.899279236793518 | Train_ACC 28.125
# EPOCH 2 | ITER 75 | AVG_LOSS 1.8943551778793335 | Train_ACC 34.375
# EPOCH 2 | ITER 80 | AVG_LOSS 1.8931909799575806 | Train_ACC 43.75
# EPOCH 2 | ITER 85 | AVG_LOSS 1.8938195705413818 | Train_ACC 31.25
# EPOCH 2 | ITER 90 | AVG_LOSS 1.896332025527954 | Train_ACC 18.75
# EPOCH 2 | ITER 95 | AVG_LOSS 1.899616003036499 | Train_ACC 25.0
# EPOCH 2 | ITER 100 | AVG_LOSS 1.899880290031433 | Train_ACC 18.75
# EPOCH 2 | ITER 105 | AVG_LOSS 1.8898550271987915 | Train_ACC 46.875
# EPOCH 2 | ITER 110 | AVG_LOSS 1.8890272378921509 | Train_ACC 40.625
# EPOCH 2 | ITER 115 | AVG_LOSS 1.8821452856063843 | Train_ACC 40.625
# EPOCH 2 | ITER 120 | AVG_LOSS 1.8803784847259521 | Train_ACC 43.75
# EPOCH 2 | ITER 125 | AVG_LOSS 1.873828649520874 | Train_ACC 46.875
# EPOCH 2 | ITER 130 | AVG_LOSS 1.8740359544754028 | Train_ACC 34.375
# EPOCH 2 | ITER 135 | AVG_LOSS 1.8766252994537354 | Train_ACC 31.25
# EPOCH 2 | ITER 140 | AVG_LOSS 1.8739393949508667 | Train_ACC 21.875
# EPOCH 2 | ITER 145 | AVG_LOSS 1.8711953163146973 | Train_ACC 50.0
# EPOCH 2 | ITER 150 | AVG_LOSS 1.872780680656433 | Train_ACC 40.625
# EPOCH 2 | ITER 155 | AVG_LOSS 1.8661754131317139 | Train_ACC 40.625
# EPOCH 2 | ITER 160 | AVG_LOSS 1.8646056652069092 | Train_ACC 34.375
# EPOCH 2 | ITER 165 | AVG_LOSS 1.8638584613800049 | Train_ACC 31.25
# EPOCH 2 | ITER 170 | AVG_LOSS 1.862215518951416 | Train_ACC 18.75
# EPOCH 2 | ITER 175 | AVG_LOSS 1.860733985900879 | Train_ACC 43.75
# EPOCH 2 | ITER 180 | AVG_LOSS 1.862913966178894 | Train_ACC 15.625
# EPOCH 2 | ITER 185 | AVG_LOSS 1.8627681732177734 | Train_ACC 28.125
# EPOCH 2 | ITER 190 | AVG_LOSS 1.8650686740875244 | Train_ACC 34.375
# EPOCH 2 | ITER 195 | AVG_LOSS 1.863420844078064 | Train_ACC 34.375
# EPOCH 2 | ITER 200 | AVG_LOSS 1.864221453666687 | Train_ACC 40.625
# EPOCH 2 | ITER 205 | AVG_LOSS 1.8640021085739136 | Train_ACC 40.625
# EPOCH 2 | ITER 210 | AVG_LOSS 1.864668369293213 | Train_ACC 25.0
# EPOCH 2 | ITER 215 | AVG_LOSS 1.8642064332962036 | Train_ACC 15.625
# EPOCH 2 | ITER 220 | AVG_LOSS 1.8632173538208008 | Train_ACC 28.125
# EPOCH 2 | ITER 225 | AVG_LOSS 1.8652628660202026 | Train_ACC 25.0
# EPOCH 2 | ITER 230 | AVG_LOSS 1.8627734184265137 | Train_ACC 50.0
# EPOCH 2 | ITER 235 | AVG_LOSS 1.8628283739089966 | Train_ACC 37.5
# EPOCH 2 | ITER 240 | AVG_LOSS 1.8632973432540894 | Train_ACC 31.25
# EPOCH 2 | ITER 245 | AVG_LOSS 1.8637536764144897 | Train_ACC 31.25
# EPOCH 2 | ITER 250 | AVG_LOSS 1.8598560094833374 | Train_ACC 50.0
# EPOCH 2 | ITER 255 | AVG_LOSS 1.8564531803131104 | Train_ACC 37.5
# EPOCH 2 | ITER 260 | AVG_LOSS 1.8534824848175049 | Train_ACC 50.0
# EPOCH 2 | ITER 265 | AVG_LOSS 1.8532695770263672 | Train_ACC 31.25
# EPOCH 2 | ITER 270 | AVG_LOSS 1.8522676229476929 | Train_ACC 34.375
# EPOCH 2 | ITER 275 | AVG_LOSS 1.8514041900634766 | Train_ACC 34.375
# EPOCH 2 | ITER 280 | AVG_LOSS 1.8497108221054077 | Train_ACC 40.625
# EPOCH 2 | ITER 285 | AVG_LOSS 1.8485275506973267 | Train_ACC 37.5
# EPOCH 2 | ITER 290 | AVG_LOSS 1.8485625982284546 | Train_ACC 31.25
# EPOCH 2 | ITER 295 | AVG_LOSS 1.848512887954712 | Train_ACC 34.375
# EPOCH 2 | ITER 300 | AVG_LOSS 1.8465969562530518 | Train_ACC 18.75
# EPOCH 2 | ITER 305 | AVG_LOSS 1.8447294235229492 | Train_ACC 37.5
# EPOCH 2 | ITER 310 | AVG_LOSS 1.8441587686538696 | Train_ACC 40.625
# EPOCH 2 | ITER 315 | AVG_LOSS 1.8428548574447632 | Train_ACC 21.875
# EPOCH 2 | ITER 320 | AVG_LOSS 1.8449972867965698 | Train_ACC 25.0
# EPOCH 2 | ITER 325 | AVG_LOSS 1.8443541526794434 | Train_ACC 40.625
# EPOCH 2 | ITER 330 | AVG_LOSS 1.8438022136688232 | Train_ACC 40.625
# EPOCH 2 | ITER 335 | AVG_LOSS 1.8427445888519287 | Train_ACC 53.125
# EPOCH 2 | ITER 340 | AVG_LOSS 1.8409740924835205 | Train_ACC 37.5
# EPOCH 2 | ITER 345 | AVG_LOSS 1.8397228717803955 | Train_ACC 37.5
# EPOCH 2 | ITER 350 | AVG_LOSS 1.8392910957336426 | Train_ACC 34.375
# EPOCH 2 | ITER 355 | AVG_LOSS 1.8407284021377563 | Train_ACC 31.25
# EPOCH 2 | ITER 360 | AVG_LOSS 1.8407881259918213 | Train_ACC 31.25
# EPOCH 2 | ITER 365 | AVG_LOSS 1.8408697843551636 | Train_ACC 25.0
# EPOCH 2 | ITER 370 | AVG_LOSS 1.8406519889831543 | Train_ACC 34.375
# Val Accuracy: 36.22%
#
# --------------------------------------------------
# EPOCH 2 | LOSS 1.5702083110809326 | TIME 574.4144003391266
# --------------------------------------------------
#
# EPOCH 3 | ITER 0 | AVG_LOSS 1.9518660306930542 | Train_ACC 31.25
# EPOCH 3 | ITER 5 | AVG_LOSS 1.809609293937683 | Train_ACC 37.5
# EPOCH 3 | ITER 10 | AVG_LOSS 1.7541685104370117 | Train_ACC 40.625
# EPOCH 3 | ITER 15 | AVG_LOSS 1.7293864488601685 | Train_ACC 40.625
# EPOCH 3 | ITER 20 | AVG_LOSS 1.7353461980819702 | Train_ACC 28.125
# EPOCH 3 | ITER 25 | AVG_LOSS 1.7309880256652832 | Train_ACC 34.375
# EPOCH 3 | ITER 30 | AVG_LOSS 1.7308399677276611 | Train_ACC 40.625
# EPOCH 3 | ITER 35 | AVG_LOSS 1.7315170764923096 | Train_ACC 53.125
# EPOCH 3 | ITER 40 | AVG_LOSS 1.742743968963623 | Train_ACC 21.875
# EPOCH 3 | ITER 45 | AVG_LOSS 1.7568546533584595 | Train_ACC 21.875
# EPOCH 3 | ITER 50 | AVG_LOSS 1.7555040121078491 | Train_ACC 40.625
# EPOCH 3 | ITER 55 | AVG_LOSS 1.74246084690094 | Train_ACC 28.125
# EPOCH 3 | ITER 60 | AVG_LOSS 1.7394994497299194 | Train_ACC 43.75
# EPOCH 3 | ITER 65 | AVG_LOSS 1.7325060367584229 | Train_ACC 43.75
# EPOCH 3 | ITER 70 | AVG_LOSS 1.732485294342041 | Train_ACC 46.875
# EPOCH 3 | ITER 75 | AVG_LOSS 1.7343101501464844 | Train_ACC 43.75
# EPOCH 3 | ITER 80 | AVG_LOSS 1.7286945581436157 | Train_ACC 37.5
# EPOCH 3 | ITER 85 | AVG_LOSS 1.7305065393447876 | Train_ACC 37.5
# EPOCH 3 | ITER 90 | AVG_LOSS 1.734692096710205 | Train_ACC 34.375
# EPOCH 3 | ITER 95 | AVG_LOSS 1.7358074188232422 | Train_ACC 34.375
# EPOCH 3 | ITER 100 | AVG_LOSS 1.7439689636230469 | Train_ACC 31.25
# EPOCH 3 | ITER 105 | AVG_LOSS 1.7491447925567627 | Train_ACC 46.875
# EPOCH 3 | ITER 110 | AVG_LOSS 1.747226357460022 | Train_ACC 40.625
# EPOCH 3 | ITER 115 | AVG_LOSS 1.7462856769561768 | Train_ACC 28.125
# EPOCH 3 | ITER 120 | AVG_LOSS 1.7391116619110107 | Train_ACC 46.875
# EPOCH 3 | ITER 125 | AVG_LOSS 1.7399965524673462 | Train_ACC 34.375
# EPOCH 3 | ITER 130 | AVG_LOSS 1.7398360967636108 | Train_ACC 28.125
# EPOCH 3 | ITER 135 | AVG_LOSS 1.733937382698059 | Train_ACC 59.375
# EPOCH 3 | ITER 140 | AVG_LOSS 1.7337323427200317 | Train_ACC 31.25
# EPOCH 3 | ITER 145 | AVG_LOSS 1.730897307395935 | Train_ACC 31.25
# EPOCH 3 | ITER 150 | AVG_LOSS 1.7301815748214722 | Train_ACC 34.375
# EPOCH 3 | ITER 155 | AVG_LOSS 1.7283297777175903 | Train_ACC 43.75
# EPOCH 3 | ITER 160 | AVG_LOSS 1.7289260625839233 | Train_ACC 37.5
# EPOCH 3 | ITER 165 | AVG_LOSS 1.729215383529663 | Train_ACC 28.125
# EPOCH 3 | ITER 170 | AVG_LOSS 1.7297312021255493 | Train_ACC 25.0
# EPOCH 3 | ITER 175 | AVG_LOSS 1.7245417833328247 | Train_ACC 40.625
# EPOCH 3 | ITER 180 | AVG_LOSS 1.7288252115249634 | Train_ACC 31.25
# EPOCH 3 | ITER 185 | AVG_LOSS 1.7251719236373901 | Train_ACC 46.875
# EPOCH 3 | ITER 190 | AVG_LOSS 1.7267146110534668 | Train_ACC 25.0
# EPOCH 3 | ITER 195 | AVG_LOSS 1.7273396253585815 | Train_ACC 28.125
# EPOCH 3 | ITER 200 | AVG_LOSS 1.7285467386245728 | Train_ACC 34.375
# EPOCH 3 | ITER 205 | AVG_LOSS 1.7317699193954468 | Train_ACC 31.25
# EPOCH 3 | ITER 210 | AVG_LOSS 1.7358996868133545 | Train_ACC 40.625
# EPOCH 3 | ITER 215 | AVG_LOSS 1.7354562282562256 | Train_ACC 43.75
# EPOCH 3 | ITER 220 | AVG_LOSS 1.736159086227417 | Train_ACC 34.375
# EPOCH 3 | ITER 225 | AVG_LOSS 1.7321337461471558 | Train_ACC 53.125
# EPOCH 3 | ITER 230 | AVG_LOSS 1.7325471639633179 | Train_ACC 25.0
# EPOCH 3 | ITER 235 | AVG_LOSS 1.7298526763916016 | Train_ACC 50.0
# EPOCH 3 | ITER 240 | AVG_LOSS 1.7301310300827026 | Train_ACC 34.375
# EPOCH 3 | ITER 245 | AVG_LOSS 1.7265920639038086 | Train_ACC 40.625
# EPOCH 3 | ITER 250 | AVG_LOSS 1.7274318933486938 | Train_ACC 43.75
# EPOCH 3 | ITER 255 | AVG_LOSS 1.7259492874145508 | Train_ACC 46.875
# EPOCH 3 | ITER 260 | AVG_LOSS 1.7263004779815674 | Train_ACC 46.875
# EPOCH 3 | ITER 265 | AVG_LOSS 1.725517749786377 | Train_ACC 37.5
# EPOCH 3 | ITER 270 | AVG_LOSS 1.7259846925735474 | Train_ACC 37.5
# EPOCH 3 | ITER 275 | AVG_LOSS 1.7240360975265503 | Train_ACC 46.875
# EPOCH 3 | ITER 280 | AVG_LOSS 1.7226451635360718 | Train_ACC 50.0
# EPOCH 3 | ITER 285 | AVG_LOSS 1.7187432050704956 | Train_ACC 62.5
# EPOCH 3 | ITER 290 | AVG_LOSS 1.7197091579437256 | Train_ACC 40.625
# EPOCH 3 | ITER 295 | AVG_LOSS 1.7193876504898071 | Train_ACC 40.625
# EPOCH 3 | ITER 300 | AVG_LOSS 1.7188876867294312 | Train_ACC 56.25
# EPOCH 3 | ITER 305 | AVG_LOSS 1.7205259799957275 | Train_ACC 34.375
# EPOCH 3 | ITER 310 | AVG_LOSS 1.7181603908538818 | Train_ACC 50.0
# EPOCH 3 | ITER 315 | AVG_LOSS 1.7167068719863892 | Train_ACC 40.625
# EPOCH 3 | ITER 320 | AVG_LOSS 1.7180496454238892 | Train_ACC 28.125
# EPOCH 3 | ITER 325 | AVG_LOSS 1.7170170545578003 | Train_ACC 43.75
# EPOCH 3 | ITER 330 | AVG_LOSS 1.716388463973999 | Train_ACC 28.125
# EPOCH 3 | ITER 335 | AVG_LOSS 1.7148724794387817 | Train_ACC 43.75
# EPOCH 3 | ITER 340 | AVG_LOSS 1.7132362127304077 | Train_ACC 37.5
# EPOCH 3 | ITER 345 | AVG_LOSS 1.711908221244812 | Train_ACC 34.375
# EPOCH 3 | ITER 350 | AVG_LOSS 1.7131153345108032 | Train_ACC 37.5
# EPOCH 3 | ITER 355 | AVG_LOSS 1.7113388776779175 | Train_ACC 50.0
# EPOCH 3 | ITER 360 | AVG_LOSS 1.7123733758926392 | Train_ACC 37.5
# EPOCH 3 | ITER 365 | AVG_LOSS 1.711881160736084 | Train_ACC 40.625
# EPOCH 3 | ITER 370 | AVG_LOSS 1.7129491567611694 | Train_ACC 34.375
# Val Accuracy: 38.96%
#
# --------------------------------------------------
# EPOCH 3 | LOSS 1.9270306825637817 | TIME 606.3821272850037
# --------------------------------------------------
#
# EPOCH 4 | ITER 0 | AVG_LOSS 1.72422456741333 | Train_ACC 53.125
# EPOCH 4 | ITER 5 | AVG_LOSS 1.7105306386947632 | Train_ACC 40.625
# EPOCH 4 | ITER 10 | AVG_LOSS 1.6835460662841797 | Train_ACC 53.125
# EPOCH 4 | ITER 15 | AVG_LOSS 1.6715565919876099 | Train_ACC 50.0
# EPOCH 4 | ITER 20 | AVG_LOSS 1.6691969633102417 | Train_ACC 50.0
# EPOCH 4 | ITER 25 | AVG_LOSS 1.6572684049606323 | Train_ACC 43.75
# EPOCH 4 | ITER 30 | AVG_LOSS 1.6559878587722778 | Train_ACC 43.75
# EPOCH 4 | ITER 35 | AVG_LOSS 1.636940598487854 | Train_ACC 46.875
# EPOCH 4 | ITER 40 | AVG_LOSS 1.631960153579712 | Train_ACC 43.75
# EPOCH 4 | ITER 45 | AVG_LOSS 1.6433075666427612 | Train_ACC 40.625
# EPOCH 4 | ITER 50 | AVG_LOSS 1.6447852849960327 | Train_ACC 37.5
# EPOCH 4 | ITER 55 | AVG_LOSS 1.655992865562439 | Train_ACC 43.75
# EPOCH 4 | ITER 60 | AVG_LOSS 1.6478136777877808 | Train_ACC 53.125
# EPOCH 4 | ITER 65 | AVG_LOSS 1.6542448997497559 | Train_ACC 56.25
# EPOCH 4 | ITER 70 | AVG_LOSS 1.6564666032791138 | Train_ACC 40.625
# EPOCH 4 | ITER 75 | AVG_LOSS 1.6577157974243164 | Train_ACC 34.375
# EPOCH 4 | ITER 80 | AVG_LOSS 1.656118392944336 | Train_ACC 34.375
# EPOCH 4 | ITER 85 | AVG_LOSS 1.6521004438400269 | Train_ACC 40.625
# EPOCH 4 | ITER 90 | AVG_LOSS 1.6506248712539673 | Train_ACC 40.625
# EPOCH 4 | ITER 95 | AVG_LOSS 1.6557250022888184 | Train_ACC 46.875
# EPOCH 4 | ITER 100 | AVG_LOSS 1.6524111032485962 | Train_ACC 46.875
# EPOCH 4 | ITER 105 | AVG_LOSS 1.6483640670776367 | Train_ACC 34.375
# EPOCH 4 | ITER 110 | AVG_LOSS 1.6500458717346191 | Train_ACC 40.625
# EPOCH 4 | ITER 115 | AVG_LOSS 1.6471604108810425 | Train_ACC 40.625
# EPOCH 4 | ITER 120 | AVG_LOSS 1.6474783420562744 | Train_ACC 37.5
# EPOCH 4 | ITER 125 | AVG_LOSS 1.6485705375671387 | Train_ACC 31.25
# EPOCH 4 | ITER 130 | AVG_LOSS 1.6473560333251953 | Train_ACC 53.125
# EPOCH 4 | ITER 135 | AVG_LOSS 1.6484544277191162 | Train_ACC 56.25
# EPOCH 4 | ITER 140 | AVG_LOSS 1.647231936454773 | Train_ACC 43.75
# EPOCH 4 | ITER 145 | AVG_LOSS 1.6478586196899414 | Train_ACC 40.625
# EPOCH 4 | ITER 150 | AVG_LOSS 1.6447458267211914 | Train_ACC 40.625
# EPOCH 4 | ITER 155 | AVG_LOSS 1.644028663635254 | Train_ACC 40.625
# EPOCH 4 | ITER 160 | AVG_LOSS 1.6448135375976562 | Train_ACC 37.5
# EPOCH 4 | ITER 165 | AVG_LOSS 1.641801118850708 | Train_ACC 40.625
# EPOCH 4 | ITER 170 | AVG_LOSS 1.6407943964004517 | Train_ACC 53.125
# EPOCH 4 | ITER 175 | AVG_LOSS 1.6372636556625366 | Train_ACC 56.25
# EPOCH 4 | ITER 180 | AVG_LOSS 1.6310395002365112 | Train_ACC 56.25
# EPOCH 4 | ITER 185 | AVG_LOSS 1.6281778812408447 | Train_ACC 34.375
# EPOCH 4 | ITER 190 | AVG_LOSS 1.6268656253814697 | Train_ACC 43.75
# EPOCH 4 | ITER 195 | AVG_LOSS 1.6263978481292725 | Train_ACC 34.375
# EPOCH 4 | ITER 200 | AVG_LOSS 1.6257598400115967 | Train_ACC 43.75
# EPOCH 4 | ITER 205 | AVG_LOSS 1.6236804723739624 | Train_ACC 46.875
# EPOCH 4 | ITER 210 | AVG_LOSS 1.6223092079162598 | Train_ACC 53.125
# EPOCH 4 | ITER 215 | AVG_LOSS 1.6195648908615112 | Train_ACC 46.875
# EPOCH 4 | ITER 220 | AVG_LOSS 1.6202903985977173 | Train_ACC 31.25
# EPOCH 4 | ITER 225 | AVG_LOSS 1.6191433668136597 | Train_ACC 50.0
# EPOCH 4 | ITER 230 | AVG_LOSS 1.6147781610488892 | Train_ACC 43.75
# EPOCH 4 | ITER 235 | AVG_LOSS 1.6169252395629883 | Train_ACC 40.625
# EPOCH 4 | ITER 240 | AVG_LOSS 1.6153241395950317 | Train_ACC 53.125
# EPOCH 4 | ITER 245 | AVG_LOSS 1.6152622699737549 | Train_ACC 53.125
# EPOCH 4 | ITER 250 | AVG_LOSS 1.6145119667053223 | Train_ACC 53.125
# EPOCH 4 | ITER 255 | AVG_LOSS 1.6174525022506714 | Train_ACC 21.875
# EPOCH 4 | ITER 260 | AVG_LOSS 1.6166366338729858 | Train_ACC 53.125
# EPOCH 4 | ITER 265 | AVG_LOSS 1.6192071437835693 | Train_ACC 21.875
# EPOCH 4 | ITER 270 | AVG_LOSS 1.6198512315750122 | Train_ACC 28.125
# EPOCH 4 | ITER 275 | AVG_LOSS 1.6197501420974731 | Train_ACC 31.25
# EPOCH 4 | ITER 280 | AVG_LOSS 1.6182126998901367 | Train_ACC 53.125
# EPOCH 4 | ITER 285 | AVG_LOSS 1.6174523830413818 | Train_ACC 53.125
# EPOCH 4 | ITER 290 | AVG_LOSS 1.6177278757095337 | Train_ACC 50.0
# EPOCH 4 | ITER 295 | AVG_LOSS 1.6192443370819092 | Train_ACC 37.5
# EPOCH 4 | ITER 300 | AVG_LOSS 1.6205888986587524 | Train_ACC 46.875
# EPOCH 4 | ITER 305 | AVG_LOSS 1.6205538511276245 | Train_ACC 31.25
# EPOCH 4 | ITER 310 | AVG_LOSS 1.6203720569610596 | Train_ACC 59.375
# EPOCH 4 | ITER 315 | AVG_LOSS 1.6211057901382446 | Train_ACC 40.625
# EPOCH 4 | ITER 320 | AVG_LOSS 1.618074655532837 | Train_ACC 53.125
# EPOCH 4 | ITER 325 | AVG_LOSS 1.616810917854309 | Train_ACC 50.0
# EPOCH 4 | ITER 330 | AVG_LOSS 1.6169706583023071 | Train_ACC 46.875
# EPOCH 4 | ITER 335 | AVG_LOSS 1.6153390407562256 | Train_ACC 46.875
# EPOCH 4 | ITER 340 | AVG_LOSS 1.6147810220718384 | Train_ACC 40.625
# EPOCH 4 | ITER 345 | AVG_LOSS 1.6141473054885864 | Train_ACC 34.375
# EPOCH 4 | ITER 350 | AVG_LOSS 1.6168557405471802 | Train_ACC 50.0
# EPOCH 4 | ITER 355 | AVG_LOSS 1.6155726909637451 | Train_ACC 50.0
# EPOCH 4 | ITER 360 | AVG_LOSS 1.6175570487976074 | Train_ACC 43.75
# EPOCH 4 | ITER 365 | AVG_LOSS 1.6134014129638672 | Train_ACC 59.375
# EPOCH 4 | ITER 370 | AVG_LOSS 1.613904356956482 | Train_ACC 37.5
# Val Accuracy: 49.77%
#
# --------------------------------------------------
# EPOCH 4 | LOSS 1.967481255531311 | TIME 596.360612154007
# --------------------------------------------------
#
# EPOCH 5 | ITER 0 | AVG_LOSS 1.2790414094924927 | Train_ACC 53.125
# EPOCH 5 | ITER 5 | AVG_LOSS 1.469468116760254 | Train_ACC 31.25
# EPOCH 5 | ITER 10 | AVG_LOSS 1.529714822769165 | Train_ACC 59.375
# EPOCH 5 | ITER 15 | AVG_LOSS 1.5435973405838013 | Train_ACC 37.5
# EPOCH 5 | ITER 20 | AVG_LOSS 1.4916911125183105 | Train_ACC 71.875
# EPOCH 5 | ITER 25 | AVG_LOSS 1.4765106439590454 | Train_ACC 50.0
# EPOCH 5 | ITER 30 | AVG_LOSS 1.4985982179641724 | Train_ACC 53.125
# EPOCH 5 | ITER 35 | AVG_LOSS 1.4842649698257446 | Train_ACC 56.25
# EPOCH 5 | ITER 40 | AVG_LOSS 1.4937289953231812 | Train_ACC 28.125
# EPOCH 5 | ITER 45 | AVG_LOSS 1.488748550415039 | Train_ACC 46.875
# EPOCH 5 | ITER 50 | AVG_LOSS 1.4851610660552979 | Train_ACC 50.0
# EPOCH 5 | ITER 55 | AVG_LOSS 1.4865628480911255 | Train_ACC 37.5
# EPOCH 5 | ITER 60 | AVG_LOSS 1.491929054260254 | Train_ACC 46.875
# EPOCH 5 | ITER 65 | AVG_LOSS 1.497219443321228 | Train_ACC 37.5
# EPOCH 5 | ITER 70 | AVG_LOSS 1.500533103942871 | Train_ACC 53.125
# EPOCH 5 | ITER 75 | AVG_LOSS 1.494136929512024 | Train_ACC 40.625
# EPOCH 5 | ITER 80 | AVG_LOSS 1.4944416284561157 | Train_ACC 34.375
# EPOCH 5 | ITER 85 | AVG_LOSS 1.4884037971496582 | Train_ACC 50.0
# EPOCH 5 | ITER 90 | AVG_LOSS 1.498003363609314 | Train_ACC 37.5
# EPOCH 5 | ITER 95 | AVG_LOSS 1.493862509727478 | Train_ACC 56.25
# EPOCH 5 | ITER 100 | AVG_LOSS 1.4983776807785034 | Train_ACC 62.5
# EPOCH 5 | ITER 105 | AVG_LOSS 1.4970216751098633 | Train_ACC 50.0
# EPOCH 5 | ITER 110 | AVG_LOSS 1.498165488243103 | Train_ACC 46.875
# EPOCH 5 | ITER 115 | AVG_LOSS 1.4965519905090332 | Train_ACC 25.0
# EPOCH 5 | ITER 120 | AVG_LOSS 1.4951119422912598 | Train_ACC 46.875
# EPOCH 5 | ITER 125 | AVG_LOSS 1.5010262727737427 | Train_ACC 28.125
# EPOCH 5 | ITER 130 | AVG_LOSS 1.49917733669281 | Train_ACC 50.0
# EPOCH 5 | ITER 135 | AVG_LOSS 1.5005542039871216 | Train_ACC 50.0
# EPOCH 5 | ITER 140 | AVG_LOSS 1.5049623250961304 | Train_ACC 46.875
# EPOCH 5 | ITER 145 | AVG_LOSS 1.5069117546081543 | Train_ACC 46.875
# EPOCH 5 | ITER 150 | AVG_LOSS 1.508925437927246 | Train_ACC 46.875
# EPOCH 5 | ITER 155 | AVG_LOSS 1.5114089250564575 | Train_ACC 40.625
# EPOCH 5 | ITER 160 | AVG_LOSS 1.5118588209152222 | Train_ACC 37.5
# EPOCH 5 | ITER 165 | AVG_LOSS 1.5067657232284546 | Train_ACC 59.375
# EPOCH 5 | ITER 170 | AVG_LOSS 1.5071282386779785 | Train_ACC 40.625
# EPOCH 5 | ITER 175 | AVG_LOSS 1.5040671825408936 | Train_ACC 50.0
# EPOCH 5 | ITER 180 | AVG_LOSS 1.5065193176269531 | Train_ACC 34.375
# EPOCH 5 | ITER 185 | AVG_LOSS 1.506056785583496 | Train_ACC 53.125
# EPOCH 5 | ITER 190 | AVG_LOSS 1.5055737495422363 | Train_ACC 46.875
# EPOCH 5 | ITER 195 | AVG_LOSS 1.5050997734069824 | Train_ACC 50.0
# EPOCH 5 | ITER 200 | AVG_LOSS 1.50349760055542 | Train_ACC 62.5
# EPOCH 5 | ITER 205 | AVG_LOSS 1.4997714757919312 | Train_ACC 46.875
# EPOCH 5 | ITER 210 | AVG_LOSS 1.505804181098938 | Train_ACC 40.625
# EPOCH 5 | ITER 215 | AVG_LOSS 1.5068050622940063 | Train_ACC 43.75
# EPOCH 5 | ITER 220 | AVG_LOSS 1.5100042819976807 | Train_ACC 40.625
# EPOCH 5 | ITER 225 | AVG_LOSS 1.5119264125823975 | Train_ACC 50.0
# EPOCH 5 | ITER 230 | AVG_LOSS 1.5141007900238037 | Train_ACC 25.0
# EPOCH 5 | ITER 235 | AVG_LOSS 1.514954686164856 | Train_ACC 43.75
# EPOCH 5 | ITER 240 | AVG_LOSS 1.51302170753479 | Train_ACC 40.625
# EPOCH 5 | ITER 245 | AVG_LOSS 1.5103853940963745 | Train_ACC 56.25
# EPOCH 5 | ITER 250 | AVG_LOSS 1.5098127126693726 | Train_ACC 46.875
# EPOCH 5 | ITER 255 | AVG_LOSS 1.51121985912323 | Train_ACC 43.75
# EPOCH 5 | ITER 260 | AVG_LOSS 1.5118390321731567 | Train_ACC 40.625
# EPOCH 5 | ITER 265 | AVG_LOSS 1.5136042833328247 | Train_ACC 40.625
# EPOCH 5 | ITER 270 | AVG_LOSS 1.5143282413482666 | Train_ACC 40.625
# EPOCH 5 | ITER 275 | AVG_LOSS 1.5140347480773926 | Train_ACC 46.875
# EPOCH 5 | ITER 280 | AVG_LOSS 1.5116151571273804 | Train_ACC 53.125
# EPOCH 5 | ITER 285 | AVG_LOSS 1.5098905563354492 | Train_ACC 56.25
# EPOCH 5 | ITER 290 | AVG_LOSS 1.5095008611679077 | Train_ACC 40.625
# EPOCH 5 | ITER 295 | AVG_LOSS 1.5109862089157104 | Train_ACC 46.875
# EPOCH 5 | ITER 300 | AVG_LOSS 1.5132324695587158 | Train_ACC 53.125
# EPOCH 5 | ITER 305 | AVG_LOSS 1.512326717376709 | Train_ACC 59.375
# EPOCH 5 | ITER 310 | AVG_LOSS 1.5124080181121826 | Train_ACC 62.5
# EPOCH 5 | ITER 315 | AVG_LOSS 1.5122359991073608 | Train_ACC 50.0
# EPOCH 5 | ITER 320 | AVG_LOSS 1.5124350786209106 | Train_ACC 43.75
# EPOCH 5 | ITER 325 | AVG_LOSS 1.509133219718933 | Train_ACC 46.875
# EPOCH 5 | ITER 330 | AVG_LOSS 1.509531021118164 | Train_ACC 40.625
# EPOCH 5 | ITER 335 | AVG_LOSS 1.5096405744552612 | Train_ACC 50.0
# EPOCH 5 | ITER 340 | AVG_LOSS 1.5081322193145752 | Train_ACC 56.25
# EPOCH 5 | ITER 345 | AVG_LOSS 1.5094560384750366 | Train_ACC 37.5
# EPOCH 5 | ITER 350 | AVG_LOSS 1.5083975791931152 | Train_ACC 53.125
# EPOCH 5 | ITER 355 | AVG_LOSS 1.509492039680481 | Train_ACC 40.625
# EPOCH 5 | ITER 360 | AVG_LOSS 1.5086346864700317 | Train_ACC 50.0
# EPOCH 5 | ITER 365 | AVG_LOSS 1.5065325498580933 | Train_ACC 37.5
# EPOCH 5 | ITER 370 | AVG_LOSS 1.5053586959838867 | Train_ACC 37.5
# Val Accuracy: 52.84%
#
# --------------------------------------------------
# EPOCH 5 | LOSS 1.4435735940933228 | TIME 570.2415487766266
# --------------------------------------------------
#
# EPOCH 6 | ITER 0 | AVG_LOSS 1.1706156730651855 | Train_ACC 62.5
# EPOCH 6 | ITER 5 | AVG_LOSS 1.4382680654525757 | Train_ACC 40.625
# EPOCH 6 | ITER 10 | AVG_LOSS 1.3686034679412842 | Train_ACC 59.375
# EPOCH 6 | ITER 15 | AVG_LOSS 1.3793120384216309 | Train_ACC 53.125
# EPOCH 6 | ITER 20 | AVG_LOSS 1.3619303703308105 | Train_ACC 43.75
# EPOCH 6 | ITER 25 | AVG_LOSS 1.3780933618545532 | Train_ACC 56.25
# EPOCH 6 | ITER 30 | AVG_LOSS 1.3827400207519531 | Train_ACC 56.25
# EPOCH 6 | ITER 35 | AVG_LOSS 1.3908312320709229 | Train_ACC 43.75
# EPOCH 6 | ITER 40 | AVG_LOSS 1.4083178043365479 | Train_ACC 34.375
# EPOCH 6 | ITER 45 | AVG_LOSS 1.4221231937408447 | Train_ACC 56.25
# EPOCH 6 | ITER 50 | AVG_LOSS 1.4087239503860474 | Train_ACC 62.5
# EPOCH 6 | ITER 55 | AVG_LOSS 1.414517879486084 | Train_ACC 43.75
# EPOCH 6 | ITER 60 | AVG_LOSS 1.413963794708252 | Train_ACC 53.125
# EPOCH 6 | ITER 65 | AVG_LOSS 1.4167513847351074 | Train_ACC 34.375
# EPOCH 6 | ITER 70 | AVG_LOSS 1.4200986623764038 | Train_ACC 56.25
# EPOCH 6 | ITER 75 | AVG_LOSS 1.4231805801391602 | Train_ACC 37.5
# EPOCH 6 | ITER 80 | AVG_LOSS 1.4229427576065063 | Train_ACC 34.375
# EPOCH 6 | ITER 85 | AVG_LOSS 1.4132819175720215 | Train_ACC 43.75
# EPOCH 6 | ITER 90 | AVG_LOSS 1.412929892539978 | Train_ACC 59.375
# EPOCH 6 | ITER 95 | AVG_LOSS 1.4174894094467163 | Train_ACC 40.625
# EPOCH 6 | ITER 100 | AVG_LOSS 1.418839693069458 | Train_ACC 50.0
# EPOCH 6 | ITER 105 | AVG_LOSS 1.418386697769165 | Train_ACC 46.875
# EPOCH 6 | ITER 110 | AVG_LOSS 1.4147489070892334 | Train_ACC 59.375
# EPOCH 6 | ITER 115 | AVG_LOSS 1.4181896448135376 | Train_ACC 50.0
# EPOCH 6 | ITER 120 | AVG_LOSS 1.4162214994430542 | Train_ACC 59.375
# EPOCH 6 | ITER 125 | AVG_LOSS 1.409409761428833 | Train_ACC 62.5
# EPOCH 6 | ITER 130 | AVG_LOSS 1.4081499576568604 | Train_ACC 43.75
# EPOCH 6 | ITER 135 | AVG_LOSS 1.4068975448608398 | Train_ACC 50.0
# EPOCH 6 | ITER 140 | AVG_LOSS 1.408820629119873 | Train_ACC 50.0
# EPOCH 6 | ITER 145 | AVG_LOSS 1.4121955633163452 | Train_ACC 62.5
# EPOCH 6 | ITER 150 | AVG_LOSS 1.4160887002944946 | Train_ACC 56.25
# EPOCH 6 | ITER 155 | AVG_LOSS 1.4182963371276855 | Train_ACC 53.125
# EPOCH 6 | ITER 160 | AVG_LOSS 1.4182343482971191 | Train_ACC 50.0
# EPOCH 6 | ITER 165 | AVG_LOSS 1.418689250946045 | Train_ACC 53.125
# EPOCH 6 | ITER 170 | AVG_LOSS 1.4141979217529297 | Train_ACC 68.75
# EPOCH 6 | ITER 175 | AVG_LOSS 1.4121077060699463 | Train_ACC 65.625
# EPOCH 6 | ITER 180 | AVG_LOSS 1.4174519777297974 | Train_ACC 40.625
# EPOCH 6 | ITER 185 | AVG_LOSS 1.41410231590271 | Train_ACC 56.25
# EPOCH 6 | ITER 190 | AVG_LOSS 1.4101966619491577 | Train_ACC 75.0
# EPOCH 6 | ITER 195 | AVG_LOSS 1.4105976819992065 | Train_ACC 71.875
# EPOCH 6 | ITER 200 | AVG_LOSS 1.4125261306762695 | Train_ACC 43.75
# EPOCH 6 | ITER 205 | AVG_LOSS 1.4095964431762695 | Train_ACC 62.5
# EPOCH 6 | ITER 210 | AVG_LOSS 1.409470796585083 | Train_ACC 50.0
# EPOCH 6 | ITER 215 | AVG_LOSS 1.4067879915237427 | Train_ACC 68.75
# EPOCH 6 | ITER 220 | AVG_LOSS 1.4091451168060303 | Train_ACC 65.625
# EPOCH 6 | ITER 225 | AVG_LOSS 1.4094289541244507 | Train_ACC 43.75
# EPOCH 6 | ITER 230 | AVG_LOSS 1.4071636199951172 | Train_ACC 50.0
# EPOCH 6 | ITER 235 | AVG_LOSS 1.4068955183029175 | Train_ACC 53.125
# EPOCH 6 | ITER 240 | AVG_LOSS 1.4053447246551514 | Train_ACC 59.375
# EPOCH 6 | ITER 245 | AVG_LOSS 1.4063613414764404 | Train_ACC 56.25
# EPOCH 6 | ITER 250 | AVG_LOSS 1.4053637981414795 | Train_ACC 46.875
# EPOCH 6 | ITER 255 | AVG_LOSS 1.4048277139663696 | Train_ACC 53.125
# EPOCH 6 | ITER 260 | AVG_LOSS 1.4060230255126953 | Train_ACC 43.75
# EPOCH 6 | ITER 265 | AVG_LOSS 1.404461145401001 | Train_ACC 46.875
# EPOCH 6 | ITER 270 | AVG_LOSS 1.4042052030563354 | Train_ACC 46.875
# EPOCH 6 | ITER 275 | AVG_LOSS 1.4038845300674438 | Train_ACC 40.625
# EPOCH 6 | ITER 280 | AVG_LOSS 1.3998514413833618 | Train_ACC 56.25
# EPOCH 6 | ITER 285 | AVG_LOSS 1.398659586906433 | Train_ACC 50.0
# EPOCH 6 | ITER 290 | AVG_LOSS 1.400814414024353 | Train_ACC 50.0
# EPOCH 6 | ITER 295 | AVG_LOSS 1.4022269248962402 | Train_ACC 50.0
# EPOCH 6 | ITER 300 | AVG_LOSS 1.4018118381500244 | Train_ACC 59.375
# EPOCH 6 | ITER 305 | AVG_LOSS 1.3993732929229736 | Train_ACC 46.875
# EPOCH 6 | ITER 310 | AVG_LOSS 1.399034023284912 | Train_ACC 50.0
# EPOCH 6 | ITER 315 | AVG_LOSS 1.3999830484390259 | Train_ACC 50.0
# EPOCH 6 | ITER 320 | AVG_LOSS 1.3983961343765259 | Train_ACC 56.25
# EPOCH 6 | ITER 325 | AVG_LOSS 1.3968316316604614 | Train_ACC 53.125
# EPOCH 6 | ITER 330 | AVG_LOSS 1.3944488763809204 | Train_ACC 65.625
# EPOCH 6 | ITER 335 | AVG_LOSS 1.3934800624847412 | Train_ACC 46.875
# EPOCH 6 | ITER 340 | AVG_LOSS 1.3929460048675537 | Train_ACC 53.125
# EPOCH 6 | ITER 345 | AVG_LOSS 1.3899204730987549 | Train_ACC 68.75
# EPOCH 6 | ITER 350 | AVG_LOSS 1.3893145322799683 | Train_ACC 68.75
# EPOCH 6 | ITER 355 | AVG_LOSS 1.3912780284881592 | Train_ACC 37.5
# EPOCH 6 | ITER 360 | AVG_LOSS 1.3907233476638794 | Train_ACC 56.25
# EPOCH 6 | ITER 365 | AVG_LOSS 1.389868140220642 | Train_ACC 46.875
# EPOCH 6 | ITER 370 | AVG_LOSS 1.392343521118164 | Train_ACC 56.25
# Val Accuracy: 44.63%
#
# --------------------------------------------------
# EPOCH 6 | LOSS 1.6088298559188843 | TIME 602.3958370685577
# --------------------------------------------------
#
# EPOCH 7 | ITER 0 | AVG_LOSS 1.3454959392547607 | Train_ACC 43.75
# EPOCH 7 | ITER 5 | AVG_LOSS 1.2822120189666748 | Train_ACC 56.25
# EPOCH 7 | ITER 10 | AVG_LOSS 1.2867422103881836 | Train_ACC 65.625
# EPOCH 7 | ITER 15 | AVG_LOSS 1.3625260591506958 | Train_ACC 28.125
# EPOCH 7 | ITER 20 | AVG_LOSS 1.3316843509674072 | Train_ACC 62.5
# EPOCH 7 | ITER 25 | AVG_LOSS 1.298051118850708 | Train_ACC 65.625
# EPOCH 7 | ITER 30 | AVG_LOSS 1.2971880435943604 | Train_ACC 68.75
# EPOCH 7 | ITER 35 | AVG_LOSS 1.3180996179580688 | Train_ACC 46.875
# EPOCH 7 | ITER 40 | AVG_LOSS 1.3146319389343262 | Train_ACC 59.375
# EPOCH 7 | ITER 45 | AVG_LOSS 1.3281352519989014 | Train_ACC 56.25
# EPOCH 7 | ITER 50 | AVG_LOSS 1.328311562538147 | Train_ACC 53.125
# EPOCH 7 | ITER 55 | AVG_LOSS 1.322839379310608 | Train_ACC 56.25
# EPOCH 7 | ITER 60 | AVG_LOSS 1.31370210647583 | Train_ACC 59.375
# EPOCH 7 | ITER 65 | AVG_LOSS 1.313004493713379 | Train_ACC 65.625
# EPOCH 7 | ITER 70 | AVG_LOSS 1.3037559986114502 | Train_ACC 59.375
# EPOCH 7 | ITER 75 | AVG_LOSS 1.3069242238998413 | Train_ACC 59.375
# EPOCH 7 | ITER 80 | AVG_LOSS 1.3142200708389282 | Train_ACC 46.875
# EPOCH 7 | ITER 85 | AVG_LOSS 1.318909764289856 | Train_ACC 65.625
# EPOCH 7 | ITER 90 | AVG_LOSS 1.3117939233779907 | Train_ACC 65.625
# EPOCH 7 | ITER 95 | AVG_LOSS 1.3134979009628296 | Train_ACC 78.125
# EPOCH 7 | ITER 100 | AVG_LOSS 1.3129963874816895 | Train_ACC 56.25
# EPOCH 7 | ITER 105 | AVG_LOSS 1.311056137084961 | Train_ACC 56.25
# EPOCH 7 | ITER 110 | AVG_LOSS 1.3100764751434326 | Train_ACC 46.875
# EPOCH 7 | ITER 115 | AVG_LOSS 1.3192216157913208 | Train_ACC 46.875
# EPOCH 7 | ITER 120 | AVG_LOSS 1.3171755075454712 | Train_ACC 46.875
# EPOCH 7 | ITER 125 | AVG_LOSS 1.3151763677597046 | Train_ACC 71.875
# EPOCH 7 | ITER 130 | AVG_LOSS 1.312199592590332 | Train_ACC 59.375
# EPOCH 7 | ITER 135 | AVG_LOSS 1.303515076637268 | Train_ACC 78.125
# EPOCH 7 | ITER 140 | AVG_LOSS 1.3013606071472168 | Train_ACC 59.375
# EPOCH 7 | ITER 145 | AVG_LOSS 1.2953028678894043 | Train_ACC 56.25
# EPOCH 7 | ITER 150 | AVG_LOSS 1.2895822525024414 | Train_ACC 62.5
# EPOCH 7 | ITER 155 | AVG_LOSS 1.2921409606933594 | Train_ACC 59.375
# EPOCH 7 | ITER 160 | AVG_LOSS 1.291435956954956 | Train_ACC 53.125
# EPOCH 7 | ITER 165 | AVG_LOSS 1.29486083984375 | Train_ACC 37.5
# EPOCH 7 | ITER 170 | AVG_LOSS 1.2956897020339966 | Train_ACC 59.375
# EPOCH 7 | ITER 175 | AVG_LOSS 1.2951841354370117 | Train_ACC 53.125
# EPOCH 7 | ITER 180 | AVG_LOSS 1.293005108833313 | Train_ACC 56.25
# EPOCH 7 | ITER 185 | AVG_LOSS 1.2923572063446045 | Train_ACC 56.25
# EPOCH 7 | ITER 190 | AVG_LOSS 1.2950005531311035 | Train_ACC 31.25
# EPOCH 7 | ITER 195 | AVG_LOSS 1.2964619398117065 | Train_ACC 71.875
# EPOCH 7 | ITER 200 | AVG_LOSS 1.2964328527450562 | Train_ACC 71.875
# EPOCH 7 | ITER 205 | AVG_LOSS 1.292960286140442 | Train_ACC 62.5
# EPOCH 7 | ITER 210 | AVG_LOSS 1.2928218841552734 | Train_ACC 68.75
# EPOCH 7 | ITER 215 | AVG_LOSS 1.2931767702102661 | Train_ACC 75.0
# EPOCH 7 | ITER 220 | AVG_LOSS 1.2915902137756348 | Train_ACC 56.25
# EPOCH 7 | ITER 225 | AVG_LOSS 1.2933906316757202 | Train_ACC 62.5
# EPOCH 7 | ITER 230 | AVG_LOSS 1.2962110042572021 | Train_ACC 43.75
# EPOCH 7 | ITER 235 | AVG_LOSS 1.2970004081726074 | Train_ACC 65.625
# EPOCH 7 | ITER 240 | AVG_LOSS 1.2946611642837524 | Train_ACC 59.375
# EPOCH 7 | ITER 245 | AVG_LOSS 1.2921319007873535 | Train_ACC 62.5
# EPOCH 7 | ITER 250 | AVG_LOSS 1.2896125316619873 | Train_ACC 59.375
# EPOCH 7 | ITER 255 | AVG_LOSS 1.2870656251907349 | Train_ACC 56.25
# EPOCH 7 | ITER 260 | AVG_LOSS 1.287292242050171 | Train_ACC 59.375
# EPOCH 7 | ITER 265 | AVG_LOSS 1.2860112190246582 | Train_ACC 68.75
# EPOCH 7 | ITER 270 | AVG_LOSS 1.2833412885665894 | Train_ACC 62.5
# EPOCH 7 | ITER 275 | AVG_LOSS 1.2829196453094482 | Train_ACC 62.5
# EPOCH 7 | ITER 280 | AVG_LOSS 1.2828426361083984 | Train_ACC 62.5
# EPOCH 7 | ITER 285 | AVG_LOSS 1.2815008163452148 | Train_ACC 65.625
# EPOCH 7 | ITER 290 | AVG_LOSS 1.283365249633789 | Train_ACC 43.75
# EPOCH 7 | ITER 295 | AVG_LOSS 1.2828691005706787 | Train_ACC 56.25
# EPOCH 7 | ITER 300 | AVG_LOSS 1.285292625427246 | Train_ACC 46.875
# EPOCH 7 | ITER 305 | AVG_LOSS 1.28726065158844 | Train_ACC 46.875
# EPOCH 7 | ITER 310 | AVG_LOSS 1.2889002561569214 | Train_ACC 46.875
# EPOCH 7 | ITER 315 | AVG_LOSS 1.289467453956604 | Train_ACC 56.25
# EPOCH 7 | ITER 320 | AVG_LOSS 1.2903984785079956 | Train_ACC 53.125
# EPOCH 7 | ITER 325 | AVG_LOSS 1.2923980951309204 | Train_ACC 46.875
# EPOCH 7 | ITER 330 | AVG_LOSS 1.2931536436080933 | Train_ACC 59.375
# EPOCH 7 | ITER 335 | AVG_LOSS 1.2926057577133179 | Train_ACC 46.875
# EPOCH 7 | ITER 340 | AVG_LOSS 1.2910454273223877 | Train_ACC 59.375
# EPOCH 7 | ITER 345 | AVG_LOSS 1.2916568517684937 | Train_ACC 53.125
# EPOCH 7 | ITER 350 | AVG_LOSS 1.2917296886444092 | Train_ACC 56.25
# EPOCH 7 | ITER 355 | AVG_LOSS 1.2905021905899048 | Train_ACC 59.375
# EPOCH 7 | ITER 360 | AVG_LOSS 1.2939908504486084 | Train_ACC 59.375
# EPOCH 7 | ITER 365 | AVG_LOSS 1.2935744524002075 | Train_ACC 68.75
# EPOCH 7 | ITER 370 | AVG_LOSS 1.2939728498458862 | Train_ACC 65.625
# Val Accuracy: 56.37%
#
# --------------------------------------------------
# EPOCH 7 | LOSS 1.8582462072372437 | TIME 581.6847817897797
# --------------------------------------------------
#
# EPOCH 8 | ITER 0 | AVG_LOSS 0.9092371463775635 | Train_ACC 65.625
# EPOCH 8 | ITER 5 | AVG_LOSS 1.1951566934585571 | Train_ACC 40.625
# EPOCH 8 | ITER 10 | AVG_LOSS 1.2452293634414673 | Train_ACC 56.25
# EPOCH 8 | ITER 15 | AVG_LOSS 1.2293387651443481 | Train_ACC 56.25
# EPOCH 8 | ITER 20 | AVG_LOSS 1.1866846084594727 | Train_ACC 43.75
# EPOCH 8 | ITER 25 | AVG_LOSS 1.1748692989349365 | Train_ACC 50.0
# EPOCH 8 | ITER 30 | AVG_LOSS 1.1966873407363892 | Train_ACC 53.125
# EPOCH 8 | ITER 35 | AVG_LOSS 1.1831963062286377 | Train_ACC 68.75
# EPOCH 8 | ITER 40 | AVG_LOSS 1.1939806938171387 | Train_ACC 56.25
# EPOCH 8 | ITER 45 | AVG_LOSS 1.181949257850647 | Train_ACC 59.375
# EPOCH 8 | ITER 50 | AVG_LOSS 1.1996424198150635 | Train_ACC 59.375
# EPOCH 8 | ITER 55 | AVG_LOSS 1.1941800117492676 | Train_ACC 71.875
# EPOCH 8 | ITER 60 | AVG_LOSS 1.2025240659713745 | Train_ACC 71.875
# EPOCH 8 | ITER 65 | AVG_LOSS 1.209834337234497 | Train_ACC 68.75
# EPOCH 8 | ITER 70 | AVG_LOSS 1.2078640460968018 | Train_ACC 53.125
# EPOCH 8 | ITER 75 | AVG_LOSS 1.208091139793396 | Train_ACC 53.125
# EPOCH 8 | ITER 80 | AVG_LOSS 1.2091118097305298 | Train_ACC 56.25
# EPOCH 8 | ITER 85 | AVG_LOSS 1.2024037837982178 | Train_ACC 59.375
# EPOCH 8 | ITER 90 | AVG_LOSS 1.219617486000061 | Train_ACC 43.75
# EPOCH 8 | ITER 95 | AVG_LOSS 1.224705457687378 | Train_ACC 50.0
# EPOCH 8 | ITER 100 | AVG_LOSS 1.2256393432617188 | Train_ACC 56.25
# EPOCH 8 | ITER 105 | AVG_LOSS 1.2300816774368286 | Train_ACC 56.25
# EPOCH 8 | ITER 110 | AVG_LOSS 1.2321498394012451 | Train_ACC 59.375
# EPOCH 8 | ITER 115 | AVG_LOSS 1.230599284172058 | Train_ACC 59.375
# EPOCH 8 | ITER 120 | AVG_LOSS 1.2345436811447144 | Train_ACC 50.0
# EPOCH 8 | ITER 125 | AVG_LOSS 1.240097999572754 | Train_ACC 65.625
# EPOCH 8 | ITER 130 | AVG_LOSS 1.2366454601287842 | Train_ACC 68.75
# EPOCH 8 | ITER 135 | AVG_LOSS 1.2337539196014404 | Train_ACC 56.25
# EPOCH 8 | ITER 140 | AVG_LOSS 1.2326542139053345 | Train_ACC 59.375
# EPOCH 8 | ITER 145 | AVG_LOSS 1.2278339862823486 | Train_ACC 62.5
# EPOCH 8 | ITER 150 | AVG_LOSS 1.221473217010498 | Train_ACC 75.0
# EPOCH 8 | ITER 155 | AVG_LOSS 1.222957968711853 | Train_ACC 71.875
# EPOCH 8 | ITER 160 | AVG_LOSS 1.225974440574646 | Train_ACC 59.375
# EPOCH 8 | ITER 165 | AVG_LOSS 1.2245664596557617 | Train_ACC 75.0
# EPOCH 8 | ITER 170 | AVG_LOSS 1.232214093208313 | Train_ACC 53.125
# EPOCH 8 | ITER 175 | AVG_LOSS 1.2323185205459595 | Train_ACC 50.0
# EPOCH 8 | ITER 180 | AVG_LOSS 1.2355846166610718 | Train_ACC 59.375
# EPOCH 8 | ITER 185 | AVG_LOSS 1.2362806797027588 | Train_ACC 50.0
# EPOCH 8 | ITER 190 | AVG_LOSS 1.237989068031311 | Train_ACC 46.875
# EPOCH 8 | ITER 195 | AVG_LOSS 1.23507821559906 | Train_ACC 56.25
# EPOCH 8 | ITER 200 | AVG_LOSS 1.240028738975525 | Train_ACC 62.5
# EPOCH 8 | ITER 205 | AVG_LOSS 1.2392927408218384 | Train_ACC 53.125
# EPOCH 8 | ITER 210 | AVG_LOSS 1.2380398511886597 | Train_ACC 75.0
# EPOCH 8 | ITER 215 | AVG_LOSS 1.237945795059204 | Train_ACC 62.5
# EPOCH 8 | ITER 220 | AVG_LOSS 1.2360782623291016 | Train_ACC 59.375
# EPOCH 8 | ITER 225 | AVG_LOSS 1.236820101737976 | Train_ACC 50.0
# EPOCH 8 | ITER 230 | AVG_LOSS 1.235565423965454 | Train_ACC 59.375
# EPOCH 8 | ITER 235 | AVG_LOSS 1.23543119430542 | Train_ACC 59.375
# EPOCH 8 | ITER 240 | AVG_LOSS 1.231943964958191 | Train_ACC 62.5
# EPOCH 8 | ITER 245 | AVG_LOSS 1.2305020093917847 | Train_ACC 71.875
# EPOCH 8 | ITER 250 | AVG_LOSS 1.23029363155365 | Train_ACC 50.0
# EPOCH 8 | ITER 255 | AVG_LOSS 1.2298511266708374 | Train_ACC 56.25
# EPOCH 8 | ITER 260 | AVG_LOSS 1.2286202907562256 | Train_ACC 65.625
# EPOCH 8 | ITER 265 | AVG_LOSS 1.2292091846466064 | Train_ACC 53.125
# EPOCH 8 | ITER 270 | AVG_LOSS 1.231640338897705 | Train_ACC 62.5
# EPOCH 8 | ITER 275 | AVG_LOSS 1.2278343439102173 | Train_ACC 56.25
# EPOCH 8 | ITER 280 | AVG_LOSS 1.2279001474380493 | Train_ACC 65.625
# EPOCH 8 | ITER 285 | AVG_LOSS 1.2269580364227295 | Train_ACC 50.0
# EPOCH 8 | ITER 290 | AVG_LOSS 1.2260500192642212 | Train_ACC 40.625
# EPOCH 8 | ITER 295 | AVG_LOSS 1.227800965309143 | Train_ACC 53.125
# EPOCH 8 | ITER 300 | AVG_LOSS 1.227039098739624 | Train_ACC 50.0
# EPOCH 8 | ITER 305 | AVG_LOSS 1.2277421951293945 | Train_ACC 62.5
# EPOCH 8 | ITER 310 | AVG_LOSS 1.2269458770751953 | Train_ACC 53.125
# EPOCH 8 | ITER 315 | AVG_LOSS 1.2278987169265747 | Train_ACC 68.75
# EPOCH 8 | ITER 320 | AVG_LOSS 1.2269039154052734 | Train_ACC 53.125
# EPOCH 8 | ITER 325 | AVG_LOSS 1.223893642425537 | Train_ACC 71.875
# EPOCH 8 | ITER 330 | AVG_LOSS 1.2247414588928223 | Train_ACC 31.25
# EPOCH 8 | ITER 335 | AVG_LOSS 1.2225428819656372 | Train_ACC 62.5
# EPOCH 8 | ITER 340 | AVG_LOSS 1.222387671470642 | Train_ACC 62.5
# EPOCH 8 | ITER 345 | AVG_LOSS 1.219374418258667 | Train_ACC 62.5
# EPOCH 8 | ITER 350 | AVG_LOSS 1.2174922227859497 | Train_ACC 46.875
# EPOCH 8 | ITER 355 | AVG_LOSS 1.2178252935409546 | Train_ACC 56.25
# EPOCH 8 | ITER 360 | AVG_LOSS 1.2158997058868408 | Train_ACC 62.5
# EPOCH 8 | ITER 365 | AVG_LOSS 1.2136313915252686 | Train_ACC 59.375
# EPOCH 8 | ITER 370 | AVG_LOSS 1.2134299278259277 | Train_ACC 56.25
# Val Accuracy: 57.37%
#
# --------------------------------------------------
# EPOCH 8 | LOSS 1.123350977897644 | TIME 572.9076459407806
# --------------------------------------------------
#
# EPOCH 9 | ITER 0 | AVG_LOSS 1.028789758682251 | Train_ACC 62.5
# EPOCH 9 | ITER 5 | AVG_LOSS 1.103205680847168 | Train_ACC 71.875
# EPOCH 9 | ITER 10 | AVG_LOSS 1.103119134902954 | Train_ACC 71.875
# EPOCH 9 | ITER 15 | AVG_LOSS 1.1270655393600464 | Train_ACC 59.375
# EPOCH 9 | ITER 20 | AVG_LOSS 1.1530731916427612 | Train_ACC 59.375
# EPOCH 9 | ITER 25 | AVG_LOSS 1.1329890489578247 | Train_ACC 62.5
# EPOCH 9 | ITER 30 | AVG_LOSS 1.146990418434143 | Train_ACC 59.375
# EPOCH 9 | ITER 35 | AVG_LOSS 1.138716459274292 | Train_ACC 59.375
# EPOCH 9 | ITER 40 | AVG_LOSS 1.1477618217468262 | Train_ACC 40.625
# EPOCH 9 | ITER 45 | AVG_LOSS 1.1478989124298096 | Train_ACC 59.375
# EPOCH 9 | ITER 50 | AVG_LOSS 1.1622146368026733 | Train_ACC 59.375
# EPOCH 9 | ITER 55 | AVG_LOSS 1.1541460752487183 | Train_ACC 68.75
# EPOCH 9 | ITER 60 | AVG_LOSS 1.1396632194519043 | Train_ACC 71.875
# EPOCH 9 | ITER 65 | AVG_LOSS 1.1468372344970703 | Train_ACC 53.125
# EPOCH 9 | ITER 70 | AVG_LOSS 1.1479252576828003 | Train_ACC 46.875
# EPOCH 9 | ITER 75 | AVG_LOSS 1.1535871028900146 | Train_ACC 75.0
# EPOCH 9 | ITER 80 | AVG_LOSS 1.160914421081543 | Train_ACC 59.375
# EPOCH 9 | ITER 85 | AVG_LOSS 1.163090467453003 | Train_ACC 71.875
# ...
# EPOCH 27 | ITER 15 | AVG_LOSS 0.5765882730484009 | Train_ACC 84.375
# EPOCH 27 | ITER 20 | AVG_LOSS 0.5522614121437073 | Train_ACC 90.625
# EPOCH 27 | ITER 25 | AVG_LOSS 0.5125505328178406 | Train_ACC 84.375
# EPOCH 27 | ITER 30 | AVG_LOSS 0.5361827611923218 | Train_ACC 71.875
# EPOCH 27 | ITER 35 | AVG_LOSS 0.5398131608963013 | Train_ACC 71.875
# EPOCH 27 | ITER 40 | AVG_LOSS 0.5306077003479004 | Train_ACC 87.5
# EPOCH 27 | ITER 45 | AVG_LOSS 0.5320817232131958 | Train_ACC 81.25
# EPOCH 27 | ITER 50 | AVG_LOSS 0.5305007100105286 | Train_ACC 81.25
# EPOCH 27 | ITER 55 | AVG_LOSS 0.5366860032081604 | Train_ACC 78.125
# EPOCH 27 | ITER 60 | AVG_LOSS 0.5440004467964172 | Train_ACC 84.375
# EPOCH 27 | ITER 65 | AVG_LOSS 0.5439074635505676 | Train_ACC 84.375
# EPOCH 27 | ITER 70 | AVG_LOSS 0.5455530881881714 | Train_ACC 84.375
# EPOCH 27 | ITER 75 | AVG_LOSS 0.5458472967147827 | Train_ACC 81.25
# EPOCH 27 | ITER 80 | AVG_LOSS 0.5544666051864624 | Train_ACC 81.25
# EPOCH 27 | ITER 85 | AVG_LOSS 0.5596445202827454 | Train_ACC 84.375
# EPOCH 27 | ITER 90 | AVG_LOSS 0.5564330816268921 | Train_ACC 75.0
# EPOCH 27 | ITER 95 | AVG_LOSS 0.5582407712936401 | Train_ACC 75.0
# EPOCH 27 | ITER 100 | AVG_LOSS 0.556167483329773 | Train_ACC 81.25
# EPOCH 27 | ITER 105 | AVG_LOSS 0.5596521496772766 | Train_ACC 81.25
# EPOCH 27 | ITER 110 | AVG_LOSS 0.5621829628944397 | Train_ACC 84.375
# EPOCH 27 | ITER 115 | AVG_LOSS 0.5652042031288147 | Train_ACC 68.75
# EPOCH 27 | ITER 120 | AVG_LOSS 0.5675205588340759 | Train_ACC 87.5
# EPOCH 27 | ITER 125 | AVG_LOSS 0.5652050375938416 | Train_ACC 84.375
# EPOCH 27 | ITER 130 | AVG_LOSS 0.561309814453125 | Train_ACC 87.5
# EPOCH 27 | ITER 135 | AVG_LOSS 0.5600175857543945 | Train_ACC 84.375
# EPOCH 27 | ITER 140 | AVG_LOSS 0.5615264773368835 | Train_ACC 75.0
# EPOCH 27 | ITER 145 | AVG_LOSS 0.5638880133628845 | Train_ACC 71.875
# EPOCH 27 | ITER 150 | AVG_LOSS 0.5606363415718079 | Train_ACC 78.125
# EPOCH 27 | ITER 155 | AVG_LOSS 0.5612682104110718 | Train_ACC 81.25
# EPOCH 27 | ITER 160 | AVG_LOSS 0.5583010911941528 | Train_ACC 78.125
# EPOCH 27 | ITER 165 | AVG_LOSS 0.5566613078117371 | Train_ACC 84.375
# EPOCH 27 | ITER 170 | AVG_LOSS 0.5634711980819702 | Train_ACC 84.375
# EPOCH 27 | ITER 175 | AVG_LOSS 0.5653829574584961 | Train_ACC 81.25
# EPOCH 27 | ITER 180 | AVG_LOSS 0.5693652629852295 | Train_ACC 65.625
# EPOCH 27 | ITER 185 | AVG_LOSS 0.567086935043335 | Train_ACC 81.25
# EPOCH 27 | ITER 190 | AVG_LOSS 0.569451093673706 | Train_ACC 75.0
# EPOCH 27 | ITER 195 | AVG_LOSS 0.5658552646636963 | Train_ACC 84.375
# EPOCH 27 | ITER 200 | AVG_LOSS 0.5679661631584167 | Train_ACC 75.0
# EPOCH 27 | ITER 205 | AVG_LOSS 0.5711241960525513 | Train_ACC 87.5
# EPOCH 27 | ITER 210 | AVG_LOSS 0.5693987607955933 | Train_ACC 78.125
# EPOCH 27 | ITER 215 | AVG_LOSS 0.5715375542640686 | Train_ACC 75.0
# EPOCH 27 | ITER 220 | AVG_LOSS 0.5702782273292542 | Train_ACC 75.0
# EPOCH 27 | ITER 225 | AVG_LOSS 0.5704259872436523 | Train_ACC 71.875
# EPOCH 27 | ITER 230 | AVG_LOSS 0.5728857517242432 | Train_ACC 84.375
# EPOCH 27 | ITER 235 | AVG_LOSS 0.5749363303184509 | Train_ACC 81.25
# EPOCH 27 | ITER 240 | AVG_LOSS 0.5747293829917908 | Train_ACC 84.375
# EPOCH 27 | ITER 245 | AVG_LOSS 0.5725379586219788 | Train_ACC 87.5
# EPOCH 27 | ITER 250 | AVG_LOSS 0.5751334428787231 | Train_ACC 81.25
# EPOCH 27 | ITER 255 | AVG_LOSS 0.5743301510810852 | Train_ACC 84.375
# EPOCH 27 | ITER 260 | AVG_LOSS 0.5709679126739502 | Train_ACC 81.25
# EPOCH 27 | ITER 265 | AVG_LOSS 0.5689154267311096 | Train_ACC 84.375
# EPOCH 27 | ITER 270 | AVG_LOSS 0.5692819356918335 | Train_ACC 84.375
# EPOCH 27 | ITER 275 | AVG_LOSS 0.5695151686668396 | Train_ACC 84.375
# EPOCH 27 | ITER 280 | AVG_LOSS 0.5686373114585876 | Train_ACC 96.875
# EPOCH 27 | ITER 285 | AVG_LOSS 0.5713290572166443 | Train_ACC 84.375
# EPOCH 27 | ITER 290 | AVG_LOSS 0.5744393467903137 | Train_ACC 87.5
# EPOCH 27 | ITER 295 | AVG_LOSS 0.5736382007598877 | Train_ACC 84.375
# EPOCH 27 | ITER 300 | AVG_LOSS 0.5759313702583313 | Train_ACC 68.75
# EPOCH 27 | ITER 305 | AVG_LOSS 0.574894368648529 | Train_ACC 81.25
# EPOCH 27 | ITER 310 | AVG_LOSS 0.5763269662857056 | Train_ACC 90.625
# EPOCH 27 | ITER 315 | AVG_LOSS 0.5745871067047119 | Train_ACC 87.5
# EPOCH 27 | ITER 320 | AVG_LOSS 0.5743762850761414 | Train_ACC 90.625
# EPOCH 27 | ITER 325 | AVG_LOSS 0.5721969604492188 | Train_ACC 81.25
# EPOCH 27 | ITER 330 | AVG_LOSS 0.5699736475944519 | Train_ACC 78.125
# EPOCH 27 | ITER 335 | AVG_LOSS 0.5710314512252808 | Train_ACC 87.5
# EPOCH 27 | ITER 340 | AVG_LOSS 0.5716752409934998 | Train_ACC 87.5
# EPOCH 27 | ITER 345 | AVG_LOSS 0.5725449919700623 | Train_ACC 84.375
# EPOCH 27 | ITER 350 | AVG_LOSS 0.5728084444999695 | Train_ACC 93.75
# EPOCH 27 | ITER 355 | AVG_LOSS 0.5720722079277039 | Train_ACC 78.125
# EPOCH 27 | ITER 360 | AVG_LOSS 0.5712908506393433 | Train_ACC 87.5
# EPOCH 27 | ITER 365 | AVG_LOSS 0.5699511170387268 | Train_ACC 84.375
# EPOCH 27 | ITER 370 | AVG_LOSS 0.5697515606880188 | Train_ACC 93.75
# Val Accuracy: 75.05%
#
# --------------------------------------------------
# EPOCH 27 | LOSS 0.3585473597049713 | TIME 531.1350047588348
# --------------------------------------------------
#
# EPOCH 28 | ITER 0 | AVG_LOSS 0.5001264214515686 | Train_ACC 81.25
# EPOCH 28 | ITER 5 | AVG_LOSS 0.47952109575271606 | Train_ACC 81.25
# EPOCH 28 | ITER 10 | AVG_LOSS 0.5219777226448059 | Train_ACC 68.75
# EPOCH 28 | ITER 15 | AVG_LOSS 0.513487696647644 | Train_ACC 84.375
# EPOCH 28 | ITER 20 | AVG_LOSS 0.5028058290481567 | Train_ACC 71.875
# EPOCH 28 | ITER 25 | AVG_LOSS 0.5027090907096863 | Train_ACC 87.5
# EPOCH 28 | ITER 30 | AVG_LOSS 0.5090692639350891 | Train_ACC 81.25
# EPOCH 28 | ITER 35 | AVG_LOSS 0.49599209427833557 | Train_ACC 84.375
# EPOCH 28 | ITER 40 | AVG_LOSS 0.4980514645576477 | Train_ACC 87.5
# EPOCH 28 | ITER 45 | AVG_LOSS 0.4979332387447357 | Train_ACC 90.625
# EPOCH 28 | ITER 50 | AVG_LOSS 0.4949137270450592 | Train_ACC 84.375
# EPOCH 28 | ITER 55 | AVG_LOSS 0.4898534119129181 | Train_ACC 84.375
# EPOCH 28 | ITER 60 | AVG_LOSS 0.4874996542930603 | Train_ACC 87.5
# EPOCH 28 | ITER 65 | AVG_LOSS 0.490660697221756 | Train_ACC 87.5
# EPOCH 28 | ITER 70 | AVG_LOSS 0.4988521337509155 | Train_ACC 84.375
# EPOCH 28 | ITER 75 | AVG_LOSS 0.5008382797241211 | Train_ACC 84.375
# EPOCH 28 | ITER 80 | AVG_LOSS 0.5017220377922058 | Train_ACC 81.25
# EPOCH 28 | ITER 85 | AVG_LOSS 0.5000706315040588 | Train_ACC 93.75
# EPOCH 28 | ITER 90 | AVG_LOSS 0.5090513229370117 | Train_ACC 78.125
# EPOCH 28 | ITER 95 | AVG_LOSS 0.5074993968009949 | Train_ACC 84.375
# EPOCH 28 | ITER 100 | AVG_LOSS 0.5084245204925537 | Train_ACC 78.125
# EPOCH 28 | ITER 105 | AVG_LOSS 0.514014720916748 | Train_ACC 87.5
# EPOCH 28 | ITER 110 | AVG_LOSS 0.5147917866706848 | Train_ACC 87.5
# EPOCH 28 | ITER 115 | AVG_LOSS 0.5150085687637329 | Train_ACC 81.25
# EPOCH 28 | ITER 120 | AVG_LOSS 0.5114222168922424 | Train_ACC 90.625
# EPOCH 28 | ITER 125 | AVG_LOSS 0.5115540623664856 | Train_ACC 84.375
# EPOCH 28 | ITER 130 | AVG_LOSS 0.5176894068717957 | Train_ACC 90.625
# EPOCH 28 | ITER 135 | AVG_LOSS 0.5185293555259705 | Train_ACC 81.25
# EPOCH 28 | ITER 140 | AVG_LOSS 0.5246056914329529 | Train_ACC 81.25
# EPOCH 28 | ITER 145 | AVG_LOSS 0.5241910815238953 | Train_ACC 81.25
# EPOCH 28 | ITER 150 | AVG_LOSS 0.52353435754776 | Train_ACC 78.125
# EPOCH 28 | ITER 155 | AVG_LOSS 0.522595226764679 | Train_ACC 87.5
# EPOCH 28 | ITER 160 | AVG_LOSS 0.5268664360046387 | Train_ACC 84.375
# EPOCH 28 | ITER 165 | AVG_LOSS 0.5325146913528442 | Train_ACC 75.0
# EPOCH 28 | ITER 170 | AVG_LOSS 0.5400865077972412 | Train_ACC 78.125
# EPOCH 28 | ITER 175 | AVG_LOSS 0.5371800661087036 | Train_ACC 81.25
# EPOCH 28 | ITER 180 | AVG_LOSS 0.5347477793693542 | Train_ACC 90.625
# EPOCH 28 | ITER 185 | AVG_LOSS 0.5318792462348938 | Train_ACC 93.75
# EPOCH 28 | ITER 190 | AVG_LOSS 0.5295268297195435 | Train_ACC 78.125
# EPOCH 28 | ITER 195 | AVG_LOSS 0.5284640789031982 | Train_ACC 71.875
# EPOCH 28 | ITER 200 | AVG_LOSS 0.5257051587104797 | Train_ACC 87.5
# EPOCH 28 | ITER 205 | AVG_LOSS 0.5286175012588501 | Train_ACC 78.125
# EPOCH 28 | ITER 210 | AVG_LOSS 0.5283499956130981 | Train_ACC 84.375
# EPOCH 28 | ITER 215 | AVG_LOSS 0.5254014134407043 | Train_ACC 81.25
# EPOCH 28 | ITER 220 | AVG_LOSS 0.5298358798027039 | Train_ACC 71.875
# EPOCH 28 | ITER 225 | AVG_LOSS 0.5339896082878113 | Train_ACC 68.75
# EPOCH 28 | ITER 230 | AVG_LOSS 0.5341393351554871 | Train_ACC 90.625
# EPOCH 28 | ITER 235 | AVG_LOSS 0.5372146368026733 | Train_ACC 71.875
# EPOCH 28 | ITER 240 | AVG_LOSS 0.5381662845611572 | Train_ACC 78.125
# EPOCH 28 | ITER 245 | AVG_LOSS 0.5381816029548645 | Train_ACC 84.375
# EPOCH 28 | ITER 250 | AVG_LOSS 0.5379139184951782 | Train_ACC 71.875
# EPOCH 28 | ITER 255 | AVG_LOSS 0.5378466844558716 | Train_ACC 78.125
# EPOCH 28 | ITER 260 | AVG_LOSS 0.5378179550170898 | Train_ACC 75.0
# EPOCH 28 | ITER 265 | AVG_LOSS 0.5409456491470337 | Train_ACC 87.5
# EPOCH 28 | ITER 270 | AVG_LOSS 0.5413550734519958 | Train_ACC 90.625
# EPOCH 28 | ITER 275 | AVG_LOSS 0.5394431948661804 | Train_ACC 84.375
# EPOCH 28 | ITER 280 | AVG_LOSS 0.538763701915741 | Train_ACC 78.125
# EPOCH 28 | ITER 285 | AVG_LOSS 0.5381467342376709 | Train_ACC 87.5
# EPOCH 28 | ITER 290 | AVG_LOSS 0.5391528606414795 | Train_ACC 78.125
# EPOCH 28 | ITER 295 | AVG_LOSS 0.5380848050117493 | Train_ACC 84.375
# EPOCH 28 | ITER 300 | AVG_LOSS 0.5395998954772949 | Train_ACC 75.0
# EPOCH 28 | ITER 305 | AVG_LOSS 0.5398381352424622 | Train_ACC 78.125
# EPOCH 28 | ITER 310 | AVG_LOSS 0.5416865944862366 | Train_ACC 65.625
# EPOCH 28 | ITER 315 | AVG_LOSS 0.5413835644721985 | Train_ACC 87.5
# EPOCH 28 | ITER 320 | AVG_LOSS 0.5423777103424072 | Train_ACC 81.25
# EPOCH 28 | ITER 325 | AVG_LOSS 0.5433711409568787 | Train_ACC 93.75
# EPOCH 28 | ITER 330 | AVG_LOSS 0.5419687032699585 | Train_ACC 90.625
# EPOCH 28 | ITER 335 | AVG_LOSS 0.5423508286476135 | Train_ACC 81.25
# EPOCH 28 | ITER 340 | AVG_LOSS 0.5439907908439636 | Train_ACC 81.25
# EPOCH 28 | ITER 345 | AVG_LOSS 0.5443940758705139 | Train_ACC 90.625
# EPOCH 28 | ITER 350 | AVG_LOSS 0.5450456142425537 | Train_ACC 59.375
# EPOCH 28 | ITER 355 | AVG_LOSS 0.5458438992500305 | Train_ACC 75.0
# EPOCH 28 | ITER 360 | AVG_LOSS 0.5478923916816711 | Train_ACC 71.875
# EPOCH 28 | ITER 365 | AVG_LOSS 0.5468103885650635 | Train_ACC 87.5
# EPOCH 28 | ITER 370 | AVG_LOSS 0.5459161400794983 | Train_ACC 75.0
# Val Accuracy: 72.31%
#
# --------------------------------------------------
# EPOCH 28 | LOSS 0.3685671389102936 | TIME 581.0939011573792
# --------------------------------------------------
#
# EPOCH 29 | ITER 0 | AVG_LOSS 0.37513467669487 | Train_ACC 87.5
# EPOCH 29 | ITER 5 | AVG_LOSS 0.5616813898086548 | Train_ACC 90.625
# EPOCH 29 | ITER 10 | AVG_LOSS 0.5768346786499023 | Train_ACC 81.25
# EPOCH 29 | ITER 15 | AVG_LOSS 0.5360857248306274 | Train_ACC 87.5
# EPOCH 29 | ITER 20 | AVG_LOSS 0.5178322196006775 | Train_ACC 78.125
# EPOCH 29 | ITER 25 | AVG_LOSS 0.48718830943107605 | Train_ACC 93.75
# EPOCH 29 | ITER 30 | AVG_LOSS 0.4912397265434265 | Train_ACC 78.125
# EPOCH 29 | ITER 35 | AVG_LOSS 0.4749782383441925 | Train_ACC 84.375
# EPOCH 29 | ITER 40 | AVG_LOSS 0.4755682051181793 | Train_ACC 75.0
# EPOCH 29 | ITER 45 | AVG_LOSS 0.4719650447368622 | Train_ACC 87.5
# EPOCH 29 | ITER 50 | AVG_LOSS 0.480912983417511 | Train_ACC 75.0
# EPOCH 29 | ITER 55 | AVG_LOSS 0.4823060929775238 | Train_ACC 90.625
# EPOCH 29 | ITER 60 | AVG_LOSS 0.48602747917175293 | Train_ACC 78.125
# EPOCH 29 | ITER 65 | AVG_LOSS 0.5049701929092407 | Train_ACC 87.5
# EPOCH 29 | ITER 70 | AVG_LOSS 0.5037533640861511 | Train_ACC 90.625
# EPOCH 29 | ITER 75 | AVG_LOSS 0.5040456652641296 | Train_ACC 78.125
# EPOCH 29 | ITER 80 | AVG_LOSS 0.5094674825668335 | Train_ACC 93.75
# EPOCH 29 | ITER 85 | AVG_LOSS 0.5142458081245422 | Train_ACC 78.125
# EPOCH 29 | ITER 90 | AVG_LOSS 0.5109055638313293 | Train_ACC 84.375
# EPOCH 29 | ITER 95 | AVG_LOSS 0.513484537601471 | Train_ACC 71.875
# EPOCH 29 | ITER 100 | AVG_LOSS 0.5175695419311523 | Train_ACC 84.375
# EPOCH 29 | ITER 105 | AVG_LOSS 0.5155454874038696 | Train_ACC 87.5
# EPOCH 29 | ITER 110 | AVG_LOSS 0.5178866386413574 | Train_ACC 68.75
# EPOCH 29 | ITER 115 | AVG_LOSS 0.514157235622406 | Train_ACC 90.625
# EPOCH 29 | ITER 120 | AVG_LOSS 0.5193207859992981 | Train_ACC 87.5
# EPOCH 29 | ITER 125 | AVG_LOSS 0.5171694755554199 | Train_ACC 93.75
# EPOCH 29 | ITER 130 | AVG_LOSS 0.5192078351974487 | Train_ACC 81.25
# EPOCH 29 | ITER 135 | AVG_LOSS 0.5151429772377014 | Train_ACC 87.5
# EPOCH 29 | ITER 140 | AVG_LOSS 0.5171893835067749 | Train_ACC 81.25
# EPOCH 29 | ITER 145 | AVG_LOSS 0.5209377408027649 | Train_ACC 84.375
# EPOCH 29 | ITER 150 | AVG_LOSS 0.5196377635002136 | Train_ACC 87.5
# EPOCH 29 | ITER 155 | AVG_LOSS 0.5223321914672852 | Train_ACC 81.25
# EPOCH 29 | ITER 160 | AVG_LOSS 0.5221339464187622 | Train_ACC 90.625
# EPOCH 29 | ITER 165 | AVG_LOSS 0.5207424163818359 | Train_ACC 68.75
# EPOCH 29 | ITER 170 | AVG_LOSS 0.5195920467376709 | Train_ACC 93.75
# EPOCH 29 | ITER 175 | AVG_LOSS 0.5196899175643921 | Train_ACC 84.375
# EPOCH 29 | ITER 180 | AVG_LOSS 0.5204929709434509 | Train_ACC 75.0
# EPOCH 29 | ITER 185 | AVG_LOSS 0.5226207971572876 | Train_ACC 81.25
# EPOCH 29 | ITER 190 | AVG_LOSS 0.5198854207992554 | Train_ACC 93.75
# EPOCH 29 | ITER 195 | AVG_LOSS 0.516874372959137 | Train_ACC 87.5
# EPOCH 29 | ITER 200 | AVG_LOSS 0.5134758353233337 | Train_ACC 78.125
# EPOCH 29 | ITER 205 | AVG_LOSS 0.5108944177627563 | Train_ACC 84.375
# EPOCH 29 | ITER 210 | AVG_LOSS 0.5099526643753052 | Train_ACC 65.625
# EPOCH 29 | ITER 215 | AVG_LOSS 0.5103268623352051 | Train_ACC 87.5
# EPOCH 29 | ITER 220 | AVG_LOSS 0.5129985809326172 | Train_ACC 90.625
# EPOCH 29 | ITER 225 | AVG_LOSS 0.5143653750419617 | Train_ACC 78.125
# EPOCH 29 | ITER 230 | AVG_LOSS 0.51747065782547 | Train_ACC 87.5
# EPOCH 29 | ITER 235 | AVG_LOSS 0.519801676273346 | Train_ACC 75.0
# EPOCH 29 | ITER 240 | AVG_LOSS 0.521496057510376 | Train_ACC 75.0
# EPOCH 29 | ITER 245 | AVG_LOSS 0.5222538113594055 | Train_ACC 87.5
# EPOCH 29 | ITER 250 | AVG_LOSS 0.5245839357376099 | Train_ACC 78.125
# EPOCH 29 | ITER 255 | AVG_LOSS 0.5236984491348267 | Train_ACC 78.125
# EPOCH 29 | ITER 260 | AVG_LOSS 0.5253667235374451 | Train_ACC 68.75
# EPOCH 29 | ITER 265 | AVG_LOSS 0.5260553956031799 | Train_ACC 81.25
# EPOCH 29 | ITER 270 | AVG_LOSS 0.5267364978790283 | Train_ACC 81.25
# EPOCH 29 | ITER 275 | AVG_LOSS 0.5245900750160217 | Train_ACC 84.375
# EPOCH 29 | ITER 280 | AVG_LOSS 0.5288729071617126 | Train_ACC 84.375
# EPOCH 29 | ITER 285 | AVG_LOSS 0.5276983976364136 | Train_ACC 93.75
# EPOCH 29 | ITER 290 | AVG_LOSS 0.5281468629837036 | Train_ACC 81.25
# EPOCH 29 | ITER 295 | AVG_LOSS 0.5284449458122253 | Train_ACC 81.25
# EPOCH 29 | ITER 300 | AVG_LOSS 0.5296014547348022 | Train_ACC 84.375
# EPOCH 29 | ITER 305 | AVG_LOSS 0.5280810594558716 | Train_ACC 81.25
# EPOCH 29 | ITER 310 | AVG_LOSS 0.5284407138824463 | Train_ACC 81.25
# EPOCH 29 | ITER 315 | AVG_LOSS 0.5272846817970276 | Train_ACC 78.125
# EPOCH 29 | ITER 320 | AVG_LOSS 0.5274651646614075 | Train_ACC 84.375
# EPOCH 29 | ITER 325 | AVG_LOSS 0.5273183584213257 | Train_ACC 93.75
# EPOCH 29 | ITER 330 | AVG_LOSS 0.5269823670387268 | Train_ACC 84.375
# EPOCH 29 | ITER 335 | AVG_LOSS 0.5291796922683716 | Train_ACC 84.375
# EPOCH 29 | ITER 340 | AVG_LOSS 0.5297569036483765 | Train_ACC 75.0
# EPOCH 29 | ITER 345 | AVG_LOSS 0.5293028354644775 | Train_ACC 90.625
# EPOCH 29 | ITER 350 | AVG_LOSS 0.5288521647453308 | Train_ACC 75.0
# EPOCH 29 | ITER 355 | AVG_LOSS 0.5298876166343689 | Train_ACC 78.125
# EPOCH 29 | ITER 360 | AVG_LOSS 0.5293152332305908 | Train_ACC 96.875
# EPOCH 29 | ITER 365 | AVG_LOSS 0.5270050168037415 | Train_ACC 87.5
# EPOCH 29 | ITER 370 | AVG_LOSS 0.5270610451698303 | Train_ACC 75.0
# Val Accuracy: 74.85%
#
# --------------------------------------------------
# EPOCH 29 | LOSS 0.6768102049827576 | TIME 582.796560049057
# --------------------------------------------------
#
# Best Model:  26
# ****************************************
# test Accuracy: 73.69%
# /tmp/ipykernel_5072/3382140826.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
plotloss()

# %%
class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}

idx2class = { value : key  for key , value in class2idx.items() }
y_true = [idx2class[val.item()] for val in y_expected_test ]
y_pred = [idx2class[val.item()] for val in y_test ]


macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")
f1_score = (2*micro_precision*micro_recall)/(micro_recall + micro_precision)
print("f1 - Score is :--- " ,f1_score)
cnf_matrix = confusion_matrix(y_true , y_pred , labels=['butterfly','cats','cow','dogs','elephant','hen','horse','monkey','panda','sheep', 'spider', 'squirrel'])
plot_confusion_matrix(cnf_matrix , class2idx.keys() , [macro_precision , micro_precision , macro_recall , micro_recall], output_filename = "cnf_mobilenet_Data3.png")
# Out:
# f1 - Score is :---  0.7368770764119601
