# %%
from google.colab import drive
drive.mount('/content/gdrive/');
import os

# folder path
dir_path =  '/content/gdrive/MyDrive/Final_Dataset/dataset1'

import os

count = 0
for root_dir, cur_dir, files in os.walk(r'/content/gdrive/MyDrive/Final_Dataset/dataset1'):
    count += len(files)
print('file count:', count)
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# file count: 5000

# %%
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import *
import seaborn as sns
import seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import os.path
import random
import cv2

# %%
writer = SummaryWriter()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
from google.colab import drive
drive.mount('/content/gdrive/');

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# cuda
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# **Visualize images from Dataset:**

# %%
dataset =  "/content/gdrive/MyDrive/Final_Dataset/dataset1/train/Cat"
list = []
for image in os.listdir(dataset):
  list.append(os.path.join(dataset,image))
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(list[i]))
    ax.set_title("Cat")

plt.tight_layout()
plt.show()

dataset ="/content/gdrive/MyDrive/Final_Dataset/dataset1/train/Dog/"
list = []
for image in os.listdir(dataset):
  list.append(os.path.join(dataset,image))
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(list[i]))
    ax.set_title("Dog")

plt.tight_layout()
plt.show()

# %%
def load_Data():
    train_dataset = datasets.ImageFolder("/content/gdrive/MyDrive/Final_Dataset/dataset1/train", transform=transform)
    val_dataset = datasets.ImageFolder("/content/gdrive/MyDrive/Final_Dataset/dataset1/val", transform=test_transform)
    test_dataset = datasets.ImageFolder("/content/gdrive/MyDrive/Final_Dataset/dataset1/test", transform=test_transform)

    print(train_dataset.class_to_idx)
    #print(test_dataset.class_to_idx)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    return train_loader,val_loader,test_loader

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Model(nn.Module):
  def __init__(self,input) -> None:
      super(Model,self).__init__()
      self.model = torchvision.models.mobilenet_v2(pretrained=True)
      #self.num_ftrs = self.model.classifier[1].in_features
      #print(num_ftrs)
      self.fc_layer = nn.Sequential(
      nn.Linear(1280,640),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      
      nn.Linear(640,320),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      
      nn.Linear(320,160),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      nn.Linear(160, 2)
    )
      
      self.model.classifier = self.fc_layer
      self.features = {}
      self.model.classifier.register_forward_pre_hook(self.get_features("embeddings"))
  def get_features(self,name):
      def hook(model, input):
          self.features[name] = input[0].detach().cpu().numpy()
      return hook
  def forward(self, x):
        x = self.model(x)
        return x
model = Model((224,224))
print(model)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 126MB/s]
# Model(
#   (model): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=1280, out_features=640, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=640, out_features=320, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=320, out_features=160, bias=True)
#       (7): ReLU(inplace=True)
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=160, out_features=2, bias=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=1280, out_features=640, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=640, out_features=320, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=320, out_features=160, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=160, out_features=2, bias=True)
#   )
# )

# %%
# Save checkpoint 
def save_checkpoint(state, filename):
    torch.save(state, filename)

# %%
# datastructure to store all the training testing and validation results.
y_train = []
y_expected_train = []
y_val = []
y_expected_val = []
y_test = []
y_expected_test = []
trainloss = []
valloss =[]
epochnum = []

# %%
print(torch.cuda.is_available())
def train(model, train_loader, criterion, optimizer, epoch, step=5):
    
    model.train()
    loss_list = AverageMeter()
    for i, (images, labels) in enumerate(train_loader):
        #print(torch.cuda.is_available())
        total =0
        correct = 0
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        #print(predicted,type(predicted))
        #print(labels,type(labels))
        output = model(images)
        loss = criterion(output,labels)
        loss_list.update(loss.data, images.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        y_train.extend(predicted.to(torch.device('cpu')))
        y_expected_train.extend(labels.to(torch.device('cpu')))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        #print( f'Training Accuracy: {accuracy:.2f}%')
            
        if i%step==0:
            print('EPOCH {} | ITER {} | AVG_LOSS {} | Train_ACC {}'.format(epoch, i, loss_list.avg,accuracy))
        writer.add_scalar('TRAIN_LOSS', loss, epoch)
        writer.add_scalar('TRAIN_ACC', accuracy, epoch)
        
    return loss ,accuracy
# Out:
# True

# %%
def val(model, val_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    loss_list = AverageMeter()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            #print("Inside validation");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            loss = criterion(outputs,labels)
            loss_list.update(loss.data, inputs.size(0))
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #print("CORRECT",correct)
            #print("Total",total)
        accuracy = 100 * correct / total
        print(f'Val Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('Validation_LOSS', loss, epoch)
        writer.add_scalar('Validation_ACCURACY', accuracy, epoch)
        return loss,accuracy

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    print("Best Model: ",epoch)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('_LOSS', loss, epoch)
        # writer.add_scalar('TEST_ACC', accuracy, epoch)
        return accuracy

# %%
def visualize(model , data_loader):
    class2idx = {'Cat': 0, 'Dog': 1}
    idx2class = { value : key for key,value in  class2idx.items() }
    embeddings = np.array([])
    labels = np.array([])
    model.eval()
    out_features = 1280
    num_categories = 2
    with torch.no_grad(): 
        for i,data in enumerate(data_loader):
            images, labs = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            embeds = model.features["embeddings"].reshape(-1, 1280)
            embeddings = np.append(embeddings , embeds)
            labels = np.append(labels,labs.cpu())
  
    embeddings = embeddings.reshape(-1, 1280)
    
    c_labels = labels.reshape(-1 , 1).ravel()
    tsne = TSNE(n_components=2,perplexity=2).fit_transform(embeddings)
    labels = np.array([ idx2class[ele] for ele in c_labels])
    
    cmap = cm.get_cmap('tab20')
    
    for lab in range(num_categories):
        indices = (c_labels == lab)
        plt.scatter(tsne[indices, 0],tsne[indices, 1],c=np.array(cmap(lab)).reshape(1, 4),label=lab,alpha=1)
        plt.legend(fontsize='large', markerscale=2)
    plt.show()
  
# model = Model((224,224))
# train_loader, val_loader ,test_loader = load_Data()
# visualize(model,test_loader)

# %%
def plotloss():
  plt.figure(figsize=(20,10))
  plt.plot(epochnum, trainloss)
  plt.plot(epochnum, valloss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
class2idx = {'Cat':0,'Dog':1}
idx2class = { value : key  for key , value in class2idx.items() }

def plot_confusion_matrix(data, labels, metrics ,output_filename=None):

    [macro_precision , micro_precision , macro_recall , micro_recall] = metrics

    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(10,10))
 
    plt.suptitle("Confusion Matrix")
    plt.title(f"(Macro/Micro) Precision : {round(macro_precision,2)}/{round(micro_precision,2)}   :::::   (Macro/Micro) Recall : {round(macro_recall,2)}/{round(micro_recall,2)}")
 
    seaborn.set(font_scale=1)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu",linewidths=2 , fmt='d' ,cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# %%
def main():
    model = Model((224,224));
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        model = model.cuda()
        print("using gpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    epochs = 30
    train_loader, val_loader ,test_loader = load_Data()
 
    history = open("/content/gdrive/MyDrive/Results/finetunedataset1_Mobilenet_history.csv",'w')
    history.write('epochs , trainloss , Train-acc,val_acc , test_acc \n')
    max_accuracy = 0 
    finalepoch  = 0 
    for epoch in range(0,epochs):
        start = time.time()
        train_loss,accuracy = train(model, train_loader, criterion, optimizer, epoch)
        vallosss,val_loss = val(model, val_loader, criterion, optimizer, epoch)
        
        trainloss.append(train_loss.cpu().detach().numpy())
        valloss.append(vallosss.cpu().detach().numpy())
        epochnum.append(epoch)
        print()
        print('-' * 50)
        print('EPOCH {} | LOSS {} | TIME {}'.format(epoch, train_loss, time.time() - start))
        print('-' * 50)
        print()

        if(val_loss > max_accuracy):
          max_accuracy = val_loss
          finalepoch  = epoch
          save_checkpoint({'epoch': epoch,'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),'loss' : train_loss}, "/content/gdrive/MyDrive/Checkpoints/finetunedataset1_Mobilenetv2_checkpoint.ckpt")

        history.write('{},{},{},{}\n'.format(epoch, train_loss,accuracy, val_loss ))
    test_loss = test(model, test_loader, criterion, optimizer, finalepoch)    
    history.close()
    visualize(model,train_loader)
# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    main()
# Out:
# True
# using gpu
# {'Cat': 0, 'Dog': 1}
# EPOCH 0 | ITER 0 | AVG_LOSS 0.6994498372077942 | Train_ACC 46.875
# EPOCH 0 | ITER 5 | AVG_LOSS 0.4416337013244629 | Train_ACC 90.625
# EPOCH 0 | ITER 10 | AVG_LOSS 0.39021241664886475 | Train_ACC 100.0
# EPOCH 0 | ITER 15 | AVG_LOSS 0.35992518067359924 | Train_ACC 90.625
# EPOCH 0 | ITER 20 | AVG_LOSS 0.33173152804374695 | Train_ACC 90.625
# EPOCH 0 | ITER 25 | AVG_LOSS 0.30063536763191223 | Train_ACC 90.625
# EPOCH 0 | ITER 30 | AVG_LOSS 0.3067418038845062 | Train_ACC 93.75
# EPOCH 0 | ITER 35 | AVG_LOSS 0.29343557357788086 | Train_ACC 90.625
# EPOCH 0 | ITER 40 | AVG_LOSS 0.281280517578125 | Train_ACC 87.5
# EPOCH 0 | ITER 45 | AVG_LOSS 0.26936766505241394 | Train_ACC 96.875
# EPOCH 0 | ITER 50 | AVG_LOSS 0.2701628506183624 | Train_ACC 81.25
# EPOCH 0 | ITER 55 | AVG_LOSS 0.2642761468887329 | Train_ACC 87.5
# EPOCH 0 | ITER 60 | AVG_LOSS 0.2526271641254425 | Train_ACC 96.875
# EPOCH 0 | ITER 65 | AVG_LOSS 0.2431710958480835 | Train_ACC 96.875
# EPOCH 0 | ITER 70 | AVG_LOSS 0.2442595213651657 | Train_ACC 87.5
# EPOCH 0 | ITER 75 | AVG_LOSS 0.2363298088312149 | Train_ACC 96.875
# EPOCH 0 | ITER 80 | AVG_LOSS 0.23342160880565643 | Train_ACC 87.5
# EPOCH 0 | ITER 85 | AVG_LOSS 0.23551735281944275 | Train_ACC 81.25
# EPOCH 0 | ITER 90 | AVG_LOSS 0.23790811002254486 | Train_ACC 90.625
# EPOCH 0 | ITER 95 | AVG_LOSS 0.23485665023326874 | Train_ACC 93.75
# EPOCH 0 | ITER 100 | AVG_LOSS 0.23227262496948242 | Train_ACC 96.875
# EPOCH 0 | ITER 105 | AVG_LOSS 0.22602666914463043 | Train_ACC 96.875
# EPOCH 0 | ITER 110 | AVG_LOSS 0.22307325899600983 | Train_ACC 93.75
# EPOCH 0 | ITER 115 | AVG_LOSS 0.22035855054855347 | Train_ACC 87.5
# EPOCH 0 | ITER 120 | AVG_LOSS 0.21697652339935303 | Train_ACC 93.75
# Val Accuracy: 91.40%
#
# --------------------------------------------------
# EPOCH 0 | LOSS 0.10132743418216705 | TIME 609.5050458908081
# --------------------------------------------------
#
# EPOCH 1 | ITER 0 | AVG_LOSS 0.10689588636159897 | Train_ACC 93.75
# EPOCH 1 | ITER 5 | AVG_LOSS 0.17788098752498627 | Train_ACC 96.875
# EPOCH 1 | ITER 10 | AVG_LOSS 0.19004230201244354 | Train_ACC 96.875
# EPOCH 1 | ITER 15 | AVG_LOSS 0.18022122979164124 | Train_ACC 90.625
# EPOCH 1 | ITER 20 | AVG_LOSS 0.1790926605463028 | Train_ACC 90.625
# EPOCH 1 | ITER 25 | AVG_LOSS 0.16048045456409454 | Train_ACC 96.875
# EPOCH 1 | ITER 30 | AVG_LOSS 0.15172412991523743 | Train_ACC 96.875
# EPOCH 1 | ITER 35 | AVG_LOSS 0.16128985583782196 | Train_ACC 90.625
# EPOCH 1 | ITER 40 | AVG_LOSS 0.15796534717082977 | Train_ACC 96.875
# EPOCH 1 | ITER 45 | AVG_LOSS 0.15686087310314178 | Train_ACC 90.625
# EPOCH 1 | ITER 50 | AVG_LOSS 0.1538418084383011 | Train_ACC 93.75
# EPOCH 1 | ITER 55 | AVG_LOSS 0.1486991047859192 | Train_ACC 100.0
# EPOCH 1 | ITER 60 | AVG_LOSS 0.14555317163467407 | Train_ACC 93.75
# EPOCH 1 | ITER 65 | AVG_LOSS 0.16317299008369446 | Train_ACC 87.5
# EPOCH 1 | ITER 70 | AVG_LOSS 0.16302281618118286 | Train_ACC 81.25
# EPOCH 1 | ITER 75 | AVG_LOSS 0.16477835178375244 | Train_ACC 96.875
# EPOCH 1 | ITER 80 | AVG_LOSS 0.16432155668735504 | Train_ACC 96.875
# EPOCH 1 | ITER 85 | AVG_LOSS 0.16233181953430176 | Train_ACC 96.875
# EPOCH 1 | ITER 90 | AVG_LOSS 0.15908759832382202 | Train_ACC 96.875
# EPOCH 1 | ITER 95 | AVG_LOSS 0.15446238219738007 | Train_ACC 100.0
# EPOCH 1 | ITER 100 | AVG_LOSS 0.15106312930583954 | Train_ACC 100.0
# EPOCH 1 | ITER 105 | AVG_LOSS 0.1516122668981552 | Train_ACC 100.0
# EPOCH 1 | ITER 110 | AVG_LOSS 0.15218865871429443 | Train_ACC 93.75
# EPOCH 1 | ITER 115 | AVG_LOSS 0.15115346014499664 | Train_ACC 93.75
# EPOCH 1 | ITER 120 | AVG_LOSS 0.1509350836277008 | Train_ACC 93.75
# Val Accuracy: 97.80%
#
# --------------------------------------------------
# EPOCH 1 | LOSS 0.04299396276473999 | TIME 48.832754611968994
# --------------------------------------------------
#
# EPOCH 2 | ITER 0 | AVG_LOSS 0.08041976392269135 | Train_ACC 96.875
# EPOCH 2 | ITER 5 | AVG_LOSS 0.09981196373701096 | Train_ACC 93.75
# EPOCH 2 | ITER 10 | AVG_LOSS 0.08034143596887589 | Train_ACC 96.875
# EPOCH 2 | ITER 15 | AVG_LOSS 0.08347408473491669 | Train_ACC 96.875
# EPOCH 2 | ITER 20 | AVG_LOSS 0.07485444098711014 | Train_ACC 96.875
# EPOCH 2 | ITER 25 | AVG_LOSS 0.08683612942695618 | Train_ACC 96.875
# EPOCH 2 | ITER 30 | AVG_LOSS 0.0984565019607544 | Train_ACC 100.0
# EPOCH 2 | ITER 35 | AVG_LOSS 0.09851012378931046 | Train_ACC 96.875
# EPOCH 2 | ITER 40 | AVG_LOSS 0.10128511488437653 | Train_ACC 90.625
# EPOCH 2 | ITER 45 | AVG_LOSS 0.10025869309902191 | Train_ACC 96.875
# EPOCH 2 | ITER 50 | AVG_LOSS 0.09522219002246857 | Train_ACC 96.875
# EPOCH 2 | ITER 55 | AVG_LOSS 0.09898258000612259 | Train_ACC 90.625
# EPOCH 2 | ITER 60 | AVG_LOSS 0.09648220986127853 | Train_ACC 87.5
# EPOCH 2 | ITER 65 | AVG_LOSS 0.09590879082679749 | Train_ACC 96.875
# EPOCH 2 | ITER 70 | AVG_LOSS 0.10240951925516129 | Train_ACC 96.875
# EPOCH 2 | ITER 75 | AVG_LOSS 0.10345616936683655 | Train_ACC 100.0
# EPOCH 2 | ITER 80 | AVG_LOSS 0.10476327687501907 | Train_ACC 93.75
# EPOCH 2 | ITER 85 | AVG_LOSS 0.10393846035003662 | Train_ACC 96.875
# EPOCH 2 | ITER 90 | AVG_LOSS 0.10475905239582062 | Train_ACC 100.0
# EPOCH 2 | ITER 95 | AVG_LOSS 0.10333749651908875 | Train_ACC 100.0
# EPOCH 2 | ITER 100 | AVG_LOSS 0.10283445566892624 | Train_ACC 93.75
# EPOCH 2 | ITER 105 | AVG_LOSS 0.10426204651594162 | Train_ACC 93.75
# EPOCH 2 | ITER 110 | AVG_LOSS 0.1034010648727417 | Train_ACC 93.75
# EPOCH 2 | ITER 115 | AVG_LOSS 0.10406523942947388 | Train_ACC 100.0
# EPOCH 2 | ITER 120 | AVG_LOSS 0.1037948802113533 | Train_ACC 90.625
# Val Accuracy: 96.80%
#
# --------------------------------------------------
# EPOCH 2 | LOSS 0.029831621795892715 | TIME 47.03528714179993
# --------------------------------------------------
#
# EPOCH 3 | ITER 0 | AVG_LOSS 0.076799675822258 | Train_ACC 96.875
# EPOCH 3 | ITER 5 | AVG_LOSS 0.07439052313566208 | Train_ACC 93.75
# EPOCH 3 | ITER 10 | AVG_LOSS 0.06861473619937897 | Train_ACC 96.875
# EPOCH 3 | ITER 15 | AVG_LOSS 0.10735111683607101 | Train_ACC 100.0
# EPOCH 3 | ITER 20 | AVG_LOSS 0.1266057789325714 | Train_ACC 87.5
# EPOCH 3 | ITER 25 | AVG_LOSS 0.14130432903766632 | Train_ACC 84.375
# EPOCH 3 | ITER 30 | AVG_LOSS 0.15243437886238098 | Train_ACC 90.625
# EPOCH 3 | ITER 35 | AVG_LOSS 0.15509183704853058 | Train_ACC 90.625
# EPOCH 3 | ITER 40 | AVG_LOSS 0.154537171125412 | Train_ACC 96.875
# EPOCH 3 | ITER 45 | AVG_LOSS 0.15194565057754517 | Train_ACC 93.75
# EPOCH 3 | ITER 50 | AVG_LOSS 0.14700636267662048 | Train_ACC 100.0
# EPOCH 3 | ITER 55 | AVG_LOSS 0.146637424826622 | Train_ACC 93.75
# EPOCH 3 | ITER 60 | AVG_LOSS 0.13771536946296692 | Train_ACC 100.0
# EPOCH 3 | ITER 65 | AVG_LOSS 0.1346110850572586 | Train_ACC 90.625
# EPOCH 3 | ITER 70 | AVG_LOSS 0.13372235000133514 | Train_ACC 93.75
# EPOCH 3 | ITER 75 | AVG_LOSS 0.13134847581386566 | Train_ACC 100.0
# EPOCH 3 | ITER 80 | AVG_LOSS 0.12828104197978973 | Train_ACC 93.75
# EPOCH 3 | ITER 85 | AVG_LOSS 0.12651674449443817 | Train_ACC 96.875
# EPOCH 3 | ITER 90 | AVG_LOSS 0.1263134628534317 | Train_ACC 96.875
# EPOCH 3 | ITER 95 | AVG_LOSS 0.1240411251783371 | Train_ACC 93.75
# EPOCH 3 | ITER 100 | AVG_LOSS 0.12724335491657257 | Train_ACC 93.75
# EPOCH 3 | ITER 105 | AVG_LOSS 0.12762856483459473 | Train_ACC 93.75
# EPOCH 3 | ITER 110 | AVG_LOSS 0.12597711384296417 | Train_ACC 96.875
# EPOCH 3 | ITER 115 | AVG_LOSS 0.1225099116563797 | Train_ACC 100.0
# EPOCH 3 | ITER 120 | AVG_LOSS 0.11950267851352692 | Train_ACC 100.0
# Val Accuracy: 97.60%
#
# --------------------------------------------------
# EPOCH 3 | LOSS 0.048634640872478485 | TIME 48.64520978927612
# --------------------------------------------------
#
# EPOCH 4 | ITER 0 | AVG_LOSS 0.10939835011959076 | Train_ACC 93.75
# EPOCH 4 | ITER 5 | AVG_LOSS 0.07807871699333191 | Train_ACC 96.875
# EPOCH 4 | ITER 10 | AVG_LOSS 0.09044954925775528 | Train_ACC 90.625
# EPOCH 4 | ITER 15 | AVG_LOSS 0.0769973024725914 | Train_ACC 100.0
# EPOCH 4 | ITER 20 | AVG_LOSS 0.09025085717439651 | Train_ACC 90.625
# EPOCH 4 | ITER 25 | AVG_LOSS 0.08082417398691177 | Train_ACC 96.875
# EPOCH 4 | ITER 30 | AVG_LOSS 0.07934180647134781 | Train_ACC 100.0
# EPOCH 4 | ITER 35 | AVG_LOSS 0.09421465545892715 | Train_ACC 90.625
# EPOCH 4 | ITER 40 | AVG_LOSS 0.09084518998861313 | Train_ACC 96.875
# EPOCH 4 | ITER 45 | AVG_LOSS 0.0950818881392479 | Train_ACC 93.75
# EPOCH 4 | ITER 50 | AVG_LOSS 0.09702951461076736 | Train_ACC 96.875
# EPOCH 4 | ITER 55 | AVG_LOSS 0.09674723446369171 | Train_ACC 93.75
# EPOCH 4 | ITER 60 | AVG_LOSS 0.09475340694189072 | Train_ACC 96.875
# EPOCH 4 | ITER 65 | AVG_LOSS 0.09522629529237747 | Train_ACC 96.875
# EPOCH 4 | ITER 70 | AVG_LOSS 0.09212509542703629 | Train_ACC 93.75
# EPOCH 4 | ITER 75 | AVG_LOSS 0.09227411448955536 | Train_ACC 100.0
# EPOCH 4 | ITER 80 | AVG_LOSS 0.09812511503696442 | Train_ACC 87.5
# EPOCH 4 | ITER 85 | AVG_LOSS 0.09739750623703003 | Train_ACC 100.0
# EPOCH 4 | ITER 90 | AVG_LOSS 0.0943620428442955 | Train_ACC 100.0
# EPOCH 4 | ITER 95 | AVG_LOSS 0.0987093597650528 | Train_ACC 87.5
# EPOCH 4 | ITER 100 | AVG_LOSS 0.09663040935993195 | Train_ACC 93.75
# EPOCH 4 | ITER 105 | AVG_LOSS 0.09550207853317261 | Train_ACC 100.0
# EPOCH 4 | ITER 110 | AVG_LOSS 0.09486909210681915 | Train_ACC 100.0
# EPOCH 4 | ITER 115 | AVG_LOSS 0.09687033295631409 | Train_ACC 93.75
# EPOCH 4 | ITER 120 | AVG_LOSS 0.09721972048282623 | Train_ACC 100.0
# Val Accuracy: 97.00%
#
# --------------------------------------------------
# EPOCH 4 | LOSS 0.024895576760172844 | TIME 47.49726343154907
# --------------------------------------------------
#
# EPOCH 5 | ITER 0 | AVG_LOSS 0.11585996299982071 | Train_ACC 96.875
# EPOCH 5 | ITER 5 | AVG_LOSS 0.06839185953140259 | Train_ACC 96.875
# EPOCH 5 | ITER 10 | AVG_LOSS 0.06402061879634857 | Train_ACC 100.0
# EPOCH 5 | ITER 15 | AVG_LOSS 0.05055723711848259 | Train_ACC 100.0
# EPOCH 5 | ITER 20 | AVG_LOSS 0.05463317036628723 | Train_ACC 96.875
# EPOCH 5 | ITER 25 | AVG_LOSS 0.04769560694694519 | Train_ACC 100.0
# EPOCH 5 | ITER 30 | AVG_LOSS 0.045442525297403336 | Train_ACC 100.0
# EPOCH 5 | ITER 35 | AVG_LOSS 0.04729017987847328 | Train_ACC 96.875
# EPOCH 5 | ITER 40 | AVG_LOSS 0.060264039784669876 | Train_ACC 93.75
# EPOCH 5 | ITER 45 | AVG_LOSS 0.06338878720998764 | Train_ACC 96.875
# EPOCH 5 | ITER 50 | AVG_LOSS 0.06586885452270508 | Train_ACC 96.875
# EPOCH 5 | ITER 55 | AVG_LOSS 0.06445560604333878 | Train_ACC 96.875
# EPOCH 5 | ITER 60 | AVG_LOSS 0.06290914118289948 | Train_ACC 100.0
# EPOCH 5 | ITER 65 | AVG_LOSS 0.06090060994029045 | Train_ACC 96.875
# EPOCH 5 | ITER 70 | AVG_LOSS 0.061080850660800934 | Train_ACC 96.875
# EPOCH 5 | ITER 75 | AVG_LOSS 0.058755289763212204 | Train_ACC 96.875
# EPOCH 5 | ITER 80 | AVG_LOSS 0.05786016955971718 | Train_ACC 96.875
# EPOCH 5 | ITER 85 | AVG_LOSS 0.06043320894241333 | Train_ACC 100.0
# EPOCH 5 | ITER 90 | AVG_LOSS 0.05964581295847893 | Train_ACC 100.0
# EPOCH 5 | ITER 95 | AVG_LOSS 0.0641433373093605 | Train_ACC 90.625
# EPOCH 5 | ITER 100 | AVG_LOSS 0.06621701270341873 | Train_ACC 96.875
# EPOCH 5 | ITER 105 | AVG_LOSS 0.06717420369386673 | Train_ACC 93.75
# EPOCH 5 | ITER 110 | AVG_LOSS 0.06640668213367462 | Train_ACC 100.0
# EPOCH 5 | ITER 115 | AVG_LOSS 0.06692519783973694 | Train_ACC 90.625
# EPOCH 5 | ITER 120 | AVG_LOSS 0.06685113906860352 | Train_ACC 100.0
# Val Accuracy: 96.60%
#
# --------------------------------------------------
# EPOCH 5 | LOSS 0.10976352542638779 | TIME 48.90627694129944
# --------------------------------------------------
#
# EPOCH 6 | ITER 0 | AVG_LOSS 0.1243368610739708 | Train_ACC 93.75
# EPOCH 6 | ITER 5 | AVG_LOSS 0.14685045182704926 | Train_ACC 96.875
# EPOCH 6 | ITER 10 | AVG_LOSS 0.11427730321884155 | Train_ACC 96.875
# EPOCH 6 | ITER 15 | AVG_LOSS 0.11592328548431396 | Train_ACC 93.75
# EPOCH 6 | ITER 20 | AVG_LOSS 0.10114747285842896 | Train_ACC 100.0
# EPOCH 6 | ITER 25 | AVG_LOSS 0.10045713186264038 | Train_ACC 93.75
# EPOCH 6 | ITER 30 | AVG_LOSS 0.11009812355041504 | Train_ACC 96.875
# EPOCH 6 | ITER 35 | AVG_LOSS 0.10031869262456894 | Train_ACC 96.875
# EPOCH 6 | ITER 40 | AVG_LOSS 0.10022945702075958 | Train_ACC 96.875
# EPOCH 6 | ITER 45 | AVG_LOSS 0.09287115931510925 | Train_ACC 100.0
# EPOCH 6 | ITER 50 | AVG_LOSS 0.09138412773609161 | Train_ACC 96.875
# EPOCH 6 | ITER 55 | AVG_LOSS 0.08517400175333023 | Train_ACC 100.0
# EPOCH 6 | ITER 60 | AVG_LOSS 0.08523951470851898 | Train_ACC 100.0
# EPOCH 6 | ITER 65 | AVG_LOSS 0.08732044696807861 | Train_ACC 96.875
# EPOCH 6 | ITER 70 | AVG_LOSS 0.08448272198438644 | Train_ACC 93.75
# EPOCH 6 | ITER 75 | AVG_LOSS 0.08447850495576859 | Train_ACC 93.75
# EPOCH 6 | ITER 80 | AVG_LOSS 0.08341193199157715 | Train_ACC 96.875
# EPOCH 6 | ITER 85 | AVG_LOSS 0.08230427652597427 | Train_ACC 100.0
# EPOCH 6 | ITER 90 | AVG_LOSS 0.08252625167369843 | Train_ACC 100.0
# EPOCH 6 | ITER 95 | AVG_LOSS 0.07995955646038055 | Train_ACC 100.0
# EPOCH 6 | ITER 100 | AVG_LOSS 0.07969004660844803 | Train_ACC 96.875
# EPOCH 6 | ITER 105 | AVG_LOSS 0.0806969702243805 | Train_ACC 96.875
# EPOCH 6 | ITER 110 | AVG_LOSS 0.082618847489357 | Train_ACC 93.75
# EPOCH 6 | ITER 115 | AVG_LOSS 0.08132471889257431 | Train_ACC 100.0
# EPOCH 6 | ITER 120 | AVG_LOSS 0.08519455790519714 | Train_ACC 96.875
# Val Accuracy: 95.40%
#
# --------------------------------------------------
# EPOCH 6 | LOSS 0.0704021155834198 | TIME 47.232558727264404
# --------------------------------------------------
#
# EPOCH 7 | ITER 0 | AVG_LOSS 0.1038847267627716 | Train_ACC 96.875
# EPOCH 7 | ITER 5 | AVG_LOSS 0.09119950234889984 | Train_ACC 90.625
# EPOCH 7 | ITER 10 | AVG_LOSS 0.07186742126941681 | Train_ACC 100.0
# EPOCH 7 | ITER 15 | AVG_LOSS 0.05494912341237068 | Train_ACC 100.0
# EPOCH 7 | ITER 20 | AVG_LOSS 0.050283268094062805 | Train_ACC 96.875
# EPOCH 7 | ITER 25 | AVG_LOSS 0.042820919305086136 | Train_ACC 100.0
# EPOCH 7 | ITER 30 | AVG_LOSS 0.038841843605041504 | Train_ACC 100.0
# EPOCH 7 | ITER 35 | AVG_LOSS 0.042238086462020874 | Train_ACC 100.0
# EPOCH 7 | ITER 40 | AVG_LOSS 0.04081026464700699 | Train_ACC 100.0
# EPOCH 7 | ITER 45 | AVG_LOSS 0.04160327464342117 | Train_ACC 100.0
# EPOCH 7 | ITER 50 | AVG_LOSS 0.04211021214723587 | Train_ACC 96.875
# EPOCH 7 | ITER 55 | AVG_LOSS 0.04630640521645546 | Train_ACC 100.0
# EPOCH 7 | ITER 60 | AVG_LOSS 0.05080454796552658 | Train_ACC 100.0
# EPOCH 7 | ITER 65 | AVG_LOSS 0.052031613886356354 | Train_ACC 93.75
# EPOCH 7 | ITER 70 | AVG_LOSS 0.05250421538949013 | Train_ACC 96.875
# EPOCH 7 | ITER 75 | AVG_LOSS 0.05677426606416702 | Train_ACC 100.0
# EPOCH 7 | ITER 80 | AVG_LOSS 0.058211781084537506 | Train_ACC 100.0
# EPOCH 7 | ITER 85 | AVG_LOSS 0.059528566896915436 | Train_ACC 100.0
# EPOCH 7 | ITER 90 | AVG_LOSS 0.06113912910223007 | Train_ACC 96.875
# EPOCH 7 | ITER 95 | AVG_LOSS 0.06077377125620842 | Train_ACC 100.0
# EPOCH 7 | ITER 100 | AVG_LOSS 0.060517776757478714 | Train_ACC 100.0
# EPOCH 7 | ITER 105 | AVG_LOSS 0.059392910450696945 | Train_ACC 100.0
# EPOCH 7 | ITER 110 | AVG_LOSS 0.05898566171526909 | Train_ACC 96.875
# EPOCH 7 | ITER 115 | AVG_LOSS 0.06154435873031616 | Train_ACC 100.0
# EPOCH 7 | ITER 120 | AVG_LOSS 0.06284890323877335 | Train_ACC 96.875
# Val Accuracy: 96.60%
#
# --------------------------------------------------
# EPOCH 7 | LOSS 0.015202331356704235 | TIME 48.90984129905701
# --------------------------------------------------
#
# EPOCH 8 | ITER 0 | AVG_LOSS 0.07427430897951126 | Train_ACC 93.75
# EPOCH 8 | ITER 5 | AVG_LOSS 0.03950085863471031 | Train_ACC 96.875
# EPOCH 8 | ITER 10 | AVG_LOSS 0.03196104243397713 | Train_ACC 100.0
# EPOCH 8 | ITER 15 | AVG_LOSS 0.03334033489227295 | Train_ACC 100.0
# EPOCH 8 | ITER 20 | AVG_LOSS 0.04145108163356781 | Train_ACC 96.875
# EPOCH 8 | ITER 25 | AVG_LOSS 0.045529697090387344 | Train_ACC 96.875
# EPOCH 8 | ITER 30 | AVG_LOSS 0.045369952917099 | Train_ACC 96.875
# EPOCH 8 | ITER 35 | AVG_LOSS 0.0443279966711998 | Train_ACC 100.0
# EPOCH 8 | ITER 40 | AVG_LOSS 0.04710175842046738 | Train_ACC 93.75
# EPOCH 8 | ITER 45 | AVG_LOSS 0.056973569095134735 | Train_ACC 96.875
# EPOCH 8 | ITER 50 | AVG_LOSS 0.06262148916721344 | Train_ACC 96.875
# EPOCH 8 | ITER 55 | AVG_LOSS 0.061027705669403076 | Train_ACC 96.875
# EPOCH 8 | ITER 60 | AVG_LOSS 0.06353196501731873 | Train_ACC 96.875
# EPOCH 8 | ITER 65 | AVG_LOSS 0.064085952937603 | Train_ACC 96.875
# EPOCH 8 | ITER 70 | AVG_LOSS 0.0669490322470665 | Train_ACC 100.0
# EPOCH 8 | ITER 75 | AVG_LOSS 0.07112210243940353 | Train_ACC 93.75
# EPOCH 8 | ITER 80 | AVG_LOSS 0.07206094264984131 | Train_ACC 100.0
# EPOCH 8 | ITER 85 | AVG_LOSS 0.07139984518289566 | Train_ACC 100.0
# EPOCH 8 | ITER 90 | AVG_LOSS 0.07205594331026077 | Train_ACC 96.875
# EPOCH 8 | ITER 95 | AVG_LOSS 0.07376758754253387 | Train_ACC 93.75
# EPOCH 8 | ITER 100 | AVG_LOSS 0.07306927442550659 | Train_ACC 100.0
# EPOCH 8 | ITER 105 | AVG_LOSS 0.070693239569664 | Train_ACC 100.0
# EPOCH 8 | ITER 110 | AVG_LOSS 0.07031315565109253 | Train_ACC 100.0
# EPOCH 8 | ITER 115 | AVG_LOSS 0.06998290866613388 | Train_ACC 93.75
# EPOCH 8 | ITER 120 | AVG_LOSS 0.0675937682390213 | Train_ACC 100.0
# Val Accuracy: 97.00%
#
# --------------------------------------------------
# EPOCH 8 | LOSS 0.014804905280470848 | TIME 48.474990129470825
# --------------------------------------------------
#
# EPOCH 9 | ITER 0 | AVG_LOSS 0.013162788935005665 | Train_ACC 100.0
# EPOCH 9 | ITER 5 | AVG_LOSS 0.025170840322971344 | Train_ACC 100.0
# EPOCH 9 | ITER 10 | AVG_LOSS 0.018937960267066956 | Train_ACC 100.0
# EPOCH 9 | ITER 15 | AVG_LOSS 0.021096769720315933 | Train_ACC 96.875
# EPOCH 9 | ITER 20 | AVG_LOSS 0.021945174783468246 | Train_ACC 100.0
# EPOCH 9 | ITER 25 | AVG_LOSS 0.018838893622159958 | Train_ACC 100.0
# EPOCH 9 | ITER 30 | AVG_LOSS 0.022597594186663628 | Train_ACC 100.0
# EPOCH 9 | ITER 35 | AVG_LOSS 0.030897919088602066 | Train_ACC 100.0
# EPOCH 9 | ITER 40 | AVG_LOSS 0.031841132789850235 | Train_ACC 100.0
# EPOCH 9 | ITER 45 | AVG_LOSS 0.032582927495241165 | Train_ACC 100.0
# EPOCH 9 | ITER 50 | AVG_LOSS 0.0349058173596859 | Train_ACC 93.75
# EPOCH 9 | ITER 55 | AVG_LOSS 0.04271480813622475 | Train_ACC 90.625
# EPOCH 9 | ITER 60 | AVG_LOSS 0.04367223009467125 | Train_ACC 96.875
# EPOCH 9 | ITER 65 | AVG_LOSS 0.047997161746025085 | Train_ACC 96.875
# EPOCH 9 | ITER 70 | AVG_LOSS 0.05116063356399536 | Train_ACC 100.0
# EPOCH 9 | ITER 75 | AVG_LOSS 0.05299299210309982 | Train_ACC 96.875
# EPOCH 9 | ITER 80 | AVG_LOSS 0.055831510573625565 | Train_ACC 100.0
# EPOCH 9 | ITER 85 | AVG_LOSS 0.055055201053619385 | Train_ACC 100.0
# EPOCH 9 | ITER 90 | AVG_LOSS 0.05673278123140335 | Train_ACC 93.75
# EPOCH 9 | ITER 95 | AVG_LOSS 0.05769989639520645 | Train_ACC 96.875
# EPOCH 9 | ITER 100 | AVG_LOSS 0.05736544355750084 | Train_ACC 96.875
# EPOCH 9 | ITER 105 | AVG_LOSS 0.0600576288998127 | Train_ACC 90.625
# EPOCH 9 | ITER 110 | AVG_LOSS 0.062485676258802414 | Train_ACC 90.625
# EPOCH 9 | ITER 115 | AVG_LOSS 0.06269802898168564 | Train_ACC 96.875
# EPOCH 9 | ITER 120 | AVG_LOSS 0.0614318773150444 | Train_ACC 100.0
# Val Accuracy: 97.40%
#
# --------------------------------------------------
# EPOCH 9 | LOSS 0.03976421803236008 | TIME 48.2668821811676
# --------------------------------------------------
#
# EPOCH 10 | ITER 0 | AVG_LOSS 0.02711830474436283 | Train_ACC 100.0
# EPOCH 10 | ITER 5 | AVG_LOSS 0.019597526639699936 | Train_ACC 100.0
# EPOCH 10 | ITER 10 | AVG_LOSS 0.021783476695418358 | Train_ACC 100.0
# EPOCH 10 | ITER 15 | AVG_LOSS 0.026497410610318184 | Train_ACC 100.0
# EPOCH 10 | ITER 20 | AVG_LOSS 0.02740892954170704 | Train_ACC 100.0
# EPOCH 10 | ITER 25 | AVG_LOSS 0.029896073043346405 | Train_ACC 100.0
# EPOCH 10 | ITER 30 | AVG_LOSS 0.033782511949539185 | Train_ACC 96.875
# EPOCH 10 | ITER 35 | AVG_LOSS 0.03769586980342865 | Train_ACC 96.875
# EPOCH 10 | ITER 40 | AVG_LOSS 0.03849583491683006 | Train_ACC 96.875
# EPOCH 10 | ITER 45 | AVG_LOSS 0.039981625974178314 | Train_ACC 90.625
# EPOCH 10 | ITER 50 | AVG_LOSS 0.0391647033393383 | Train_ACC 100.0
# EPOCH 10 | ITER 55 | AVG_LOSS 0.04018722474575043 | Train_ACC 96.875
# EPOCH 10 | ITER 60 | AVG_LOSS 0.04059719294309616 | Train_ACC 93.75
# EPOCH 10 | ITER 65 | AVG_LOSS 0.039842281490564346 | Train_ACC 93.75
# EPOCH 10 | ITER 70 | AVG_LOSS 0.03889698535203934 | Train_ACC 100.0
# EPOCH 10 | ITER 75 | AVG_LOSS 0.03809582442045212 | Train_ACC 100.0
# EPOCH 10 | ITER 80 | AVG_LOSS 0.03713202849030495 | Train_ACC 96.875
# EPOCH 10 | ITER 85 | AVG_LOSS 0.0356530100107193 | Train_ACC 100.0
# EPOCH 10 | ITER 90 | AVG_LOSS 0.03694133087992668 | Train_ACC 100.0
# EPOCH 10 | ITER 95 | AVG_LOSS 0.03743928670883179 | Train_ACC 100.0
# EPOCH 10 | ITER 100 | AVG_LOSS 0.03739278018474579 | Train_ACC 100.0
# EPOCH 10 | ITER 105 | AVG_LOSS 0.03637870028614998 | Train_ACC 100.0
# EPOCH 10 | ITER 110 | AVG_LOSS 0.03872087225317955 | Train_ACC 100.0
# EPOCH 10 | ITER 115 | AVG_LOSS 0.03809303417801857 | Train_ACC 100.0
# EPOCH 10 | ITER 120 | AVG_LOSS 0.039891477674245834 | Train_ACC 96.875
# Val Accuracy: 95.20%
#
# --------------------------------------------------
# EPOCH 10 | LOSS 0.09557730704545975 | TIME 48.24860215187073
# --------------------------------------------------
#
# EPOCH 11 | ITER 0 | AVG_LOSS 0.07294077426195145 | Train_ACC 93.75
# EPOCH 11 | ITER 5 | AVG_LOSS 0.04062121361494064 | Train_ACC 100.0
# EPOCH 11 | ITER 10 | AVG_LOSS 0.05019455775618553 | Train_ACC 100.0
# EPOCH 11 | ITER 15 | AVG_LOSS 0.061915118247270584 | Train_ACC 100.0
# EPOCH 11 | ITER 20 | AVG_LOSS 0.07253700494766235 | Train_ACC 93.75
# EPOCH 11 | ITER 25 | AVG_LOSS 0.06652385741472244 | Train_ACC 100.0
# EPOCH 11 | ITER 30 | AVG_LOSS 0.06719514727592468 | Train_ACC 100.0
# EPOCH 11 | ITER 35 | AVG_LOSS 0.07499728351831436 | Train_ACC 87.5
# EPOCH 11 | ITER 40 | AVG_LOSS 0.07065936177968979 | Train_ACC 96.875
# EPOCH 11 | ITER 45 | AVG_LOSS 0.06537434458732605 | Train_ACC 96.875
# EPOCH 11 | ITER 50 | AVG_LOSS 0.07189306616783142 | Train_ACC 93.75
# EPOCH 11 | ITER 55 | AVG_LOSS 0.07154854387044907 | Train_ACC 93.75
# EPOCH 11 | ITER 60 | AVG_LOSS 0.07236801087856293 | Train_ACC 93.75
# EPOCH 11 | ITER 65 | AVG_LOSS 0.07518082112073898 | Train_ACC 100.0
# EPOCH 11 | ITER 70 | AVG_LOSS 0.07317022979259491 | Train_ACC 100.0
# EPOCH 11 | ITER 75 | AVG_LOSS 0.07674933224916458 | Train_ACC 93.75
# EPOCH 11 | ITER 80 | AVG_LOSS 0.07937569171190262 | Train_ACC 100.0
# EPOCH 11 | ITER 85 | AVG_LOSS 0.07817215472459793 | Train_ACC 100.0
# EPOCH 11 | ITER 90 | AVG_LOSS 0.0804300457239151 | Train_ACC 93.75
# EPOCH 11 | ITER 95 | AVG_LOSS 0.08576582372188568 | Train_ACC 93.75
# EPOCH 11 | ITER 100 | AVG_LOSS 0.0849652886390686 | Train_ACC 100.0
# EPOCH 11 | ITER 105 | AVG_LOSS 0.08353995531797409 | Train_ACC 100.0
# EPOCH 11 | ITER 110 | AVG_LOSS 0.08235866576433182 | Train_ACC 96.875
# EPOCH 11 | ITER 115 | AVG_LOSS 0.08005388081073761 | Train_ACC 100.0
# EPOCH 11 | ITER 120 | AVG_LOSS 0.07840767502784729 | Train_ACC 100.0
# Val Accuracy: 97.40%
#
# --------------------------------------------------
# EPOCH 11 | LOSS 0.006814913358539343 | TIME 47.93299698829651
# --------------------------------------------------
#
# EPOCH 12 | ITER 0 | AVG_LOSS 0.008130441419780254 | Train_ACC 100.0
# EPOCH 12 | ITER 5 | AVG_LOSS 0.043220411986112595 | Train_ACC 96.875
# EPOCH 12 | ITER 10 | AVG_LOSS 0.05224756896495819 | Train_ACC 96.875
# EPOCH 12 | ITER 15 | AVG_LOSS 0.07518893480300903 | Train_ACC 100.0
# EPOCH 12 | ITER 20 | AVG_LOSS 0.06107773259282112 | Train_ACC 100.0
# EPOCH 12 | ITER 25 | AVG_LOSS 0.06598737090826035 | Train_ACC 100.0
# EPOCH 12 | ITER 30 | AVG_LOSS 0.0656064972281456 | Train_ACC 100.0
# EPOCH 12 | ITER 35 | AVG_LOSS 0.07473067194223404 | Train_ACC 93.75
# EPOCH 12 | ITER 40 | AVG_LOSS 0.07243140786886215 | Train_ACC 100.0
# EPOCH 12 | ITER 45 | AVG_LOSS 0.07933463901281357 | Train_ACC 90.625
# EPOCH 12 | ITER 50 | AVG_LOSS 0.08175885677337646 | Train_ACC 93.75
# EPOCH 12 | ITER 55 | AVG_LOSS 0.07908277958631516 | Train_ACC 96.875
# EPOCH 12 | ITER 60 | AVG_LOSS 0.07616281509399414 | Train_ACC 100.0
# EPOCH 12 | ITER 65 | AVG_LOSS 0.07297298312187195 | Train_ACC 100.0
# EPOCH 12 | ITER 70 | AVG_LOSS 0.07154501974582672 | Train_ACC 100.0
# EPOCH 12 | ITER 75 | AVG_LOSS 0.07084478437900543 | Train_ACC 96.875
# EPOCH 12 | ITER 80 | AVG_LOSS 0.06834609806537628 | Train_ACC 100.0
# EPOCH 12 | ITER 85 | AVG_LOSS 0.06602703779935837 | Train_ACC 100.0
# EPOCH 12 | ITER 90 | AVG_LOSS 0.06300615519285202 | Train_ACC 96.875
# EPOCH 12 | ITER 95 | AVG_LOSS 0.06112908944487572 | Train_ACC 100.0
# EPOCH 12 | ITER 100 | AVG_LOSS 0.059465523809194565 | Train_ACC 96.875
# EPOCH 12 | ITER 105 | AVG_LOSS 0.058030419051647186 | Train_ACC 100.0
# EPOCH 12 | ITER 110 | AVG_LOSS 0.057107213884592056 | Train_ACC 96.875
# EPOCH 12 | ITER 115 | AVG_LOSS 0.0556991770863533 | Train_ACC 96.875
# EPOCH 12 | ITER 120 | AVG_LOSS 0.056120049208402634 | Train_ACC 100.0
# Val Accuracy: 96.60%
#
# --------------------------------------------------
# EPOCH 12 | LOSS 0.15262389183044434 | TIME 48.168129205703735
# --------------------------------------------------
#
# EPOCH 13 | ITER 0 | AVG_LOSS 0.05294777452945709 | Train_ACC 96.875
# EPOCH 13 | ITER 5 | AVG_LOSS 0.06396752595901489 | Train_ACC 96.875
# EPOCH 13 | ITER 10 | AVG_LOSS 0.07973327487707138 | Train_ACC 100.0
# EPOCH 13 | ITER 15 | AVG_LOSS 0.0887364074587822 | Train_ACC 96.875
# EPOCH 13 | ITER 20 | AVG_LOSS 0.08373180776834488 | Train_ACC 100.0
# EPOCH 13 | ITER 25 | AVG_LOSS 0.08156118541955948 | Train_ACC 100.0
# EPOCH 13 | ITER 30 | AVG_LOSS 0.0771067813038826 | Train_ACC 96.875
# EPOCH 13 | ITER 35 | AVG_LOSS 0.08122584223747253 | Train_ACC 100.0
# EPOCH 13 | ITER 40 | AVG_LOSS 0.08385579288005829 | Train_ACC 96.875
# EPOCH 13 | ITER 45 | AVG_LOSS 0.0807448998093605 | Train_ACC 96.875
# EPOCH 13 | ITER 50 | AVG_LOSS 0.07708624750375748 | Train_ACC 100.0
# EPOCH 13 | ITER 55 | AVG_LOSS 0.07405846565961838 | Train_ACC 96.875
# EPOCH 13 | ITER 60 | AVG_LOSS 0.0722150057554245 | Train_ACC 100.0
# EPOCH 13 | ITER 65 | AVG_LOSS 0.07700248062610626 | Train_ACC 100.0
# EPOCH 13 | ITER 70 | AVG_LOSS 0.07538850605487823 | Train_ACC 93.75
# EPOCH 13 | ITER 75 | AVG_LOSS 0.07352520525455475 | Train_ACC 93.75
# EPOCH 13 | ITER 80 | AVG_LOSS 0.07065477222204208 | Train_ACC 100.0
# EPOCH 13 | ITER 85 | AVG_LOSS 0.07148880511522293 | Train_ACC 93.75
# EPOCH 13 | ITER 90 | AVG_LOSS 0.06952416151762009 | Train_ACC 100.0
# EPOCH 13 | ITER 95 | AVG_LOSS 0.06748165190219879 | Train_ACC 96.875
# EPOCH 13 | ITER 100 | AVG_LOSS 0.06792707741260529 | Train_ACC 100.0
# EPOCH 13 | ITER 105 | AVG_LOSS 0.06661233305931091 | Train_ACC 100.0
# EPOCH 13 | ITER 110 | AVG_LOSS 0.06627321988344193 | Train_ACC 96.875
# EPOCH 13 | ITER 115 | AVG_LOSS 0.06397674977779388 | Train_ACC 100.0
# EPOCH 13 | ITER 120 | AVG_LOSS 0.0640457272529602 | Train_ACC 93.75
# Val Accuracy: 96.60%
#
# --------------------------------------------------
# EPOCH 13 | LOSS 0.015890944749116898 | TIME 47.77119040489197
# --------------------------------------------------
#
# EPOCH 14 | ITER 0 | AVG_LOSS 0.05464906245470047 | Train_ACC 96.875
# EPOCH 14 | ITER 5 | AVG_LOSS 0.08569540083408356 | Train_ACC 100.0
# EPOCH 14 | ITER 10 | AVG_LOSS 0.0660577192902565 | Train_ACC 96.875
# EPOCH 14 | ITER 15 | AVG_LOSS 0.0701342299580574 | Train_ACC 96.875
# EPOCH 14 | ITER 20 | AVG_LOSS 0.06368338316679001 | Train_ACC 100.0
# EPOCH 14 | ITER 25 | AVG_LOSS 0.06733731180429459 | Train_ACC 96.875
# EPOCH 14 | ITER 30 | AVG_LOSS 0.07505905628204346 | Train_ACC 93.75
# EPOCH 14 | ITER 35 | AVG_LOSS 0.07408875226974487 | Train_ACC 100.0
# EPOCH 14 | ITER 40 | AVG_LOSS 0.06766484677791595 | Train_ACC 100.0
# EPOCH 14 | ITER 45 | AVG_LOSS 0.06805688142776489 | Train_ACC 96.875
# EPOCH 14 | ITER 50 | AVG_LOSS 0.06440140306949615 | Train_ACC 100.0
# EPOCH 14 | ITER 55 | AVG_LOSS 0.06027737259864807 | Train_ACC 100.0
# EPOCH 14 | ITER 60 | AVG_LOSS 0.05749966576695442 | Train_ACC 100.0
# EPOCH 14 | ITER 65 | AVG_LOSS 0.05882567539811134 | Train_ACC 100.0
# EPOCH 14 | ITER 70 | AVG_LOSS 0.06572061032056808 | Train_ACC 93.75
# EPOCH 14 | ITER 75 | AVG_LOSS 0.06334681808948517 | Train_ACC 96.875
# EPOCH 14 | ITER 80 | AVG_LOSS 0.0629185140132904 | Train_ACC 96.875
# EPOCH 14 | ITER 85 | AVG_LOSS 0.06257572025060654 | Train_ACC 100.0
# EPOCH 14 | ITER 90 | AVG_LOSS 0.06324061006307602 | Train_ACC 93.75
# EPOCH 14 | ITER 95 | AVG_LOSS 0.06203664094209671 | Train_ACC 96.875
# EPOCH 14 | ITER 100 | AVG_LOSS 0.061043694615364075 | Train_ACC 100.0
# EPOCH 14 | ITER 105 | AVG_LOSS 0.059251569211483 | Train_ACC 100.0
# EPOCH 14 | ITER 110 | AVG_LOSS 0.05710273236036301 | Train_ACC 100.0
# EPOCH 14 | ITER 115 | AVG_LOSS 0.05511287972331047 | Train_ACC 100.0
# EPOCH 14 | ITER 120 | AVG_LOSS 0.053050633519887924 | Train_ACC 100.0
# Val Accuracy: 97.40%
#
# --------------------------------------------------
# EPOCH 14 | LOSS 0.0008367568952962756 | TIME 48.825244426727295
# --------------------------------------------------
#
# EPOCH 15 | ITER 0 | AVG_LOSS 1.1524498404469341e-05 | Train_ACC 100.0
# EPOCH 15 | ITER 5 | AVG_LOSS 0.06733949482440948 | Train_ACC 100.0
# EPOCH 15 | ITER 10 | AVG_LOSS 0.03789987042546272 | Train_ACC 100.0
# EPOCH 15 | ITER 15 | AVG_LOSS 0.03265010192990303 | Train_ACC 96.875
# EPOCH 15 | ITER 20 | AVG_LOSS 0.03309420123696327 | Train_ACC 100.0
# EPOCH 15 | ITER 25 | AVG_LOSS 0.038240402936935425 | Train_ACC 96.875
# EPOCH 15 | ITER 30 | AVG_LOSS 0.034558650106191635 | Train_ACC 96.875
# EPOCH 15 | ITER 35 | AVG_LOSS 0.03361653536558151 | Train_ACC 93.75
# EPOCH 15 | ITER 40 | AVG_LOSS 0.03202002868056297 | Train_ACC 96.875
# EPOCH 15 | ITER 45 | AVG_LOSS 0.03121035359799862 | Train_ACC 100.0
# EPOCH 15 | ITER 50 | AVG_LOSS 0.02919004112482071 | Train_ACC 100.0
# EPOCH 15 | ITER 55 | AVG_LOSS 0.028595637530088425 | Train_ACC 100.0
# EPOCH 15 | ITER 60 | AVG_LOSS 0.027846379205584526 | Train_ACC 100.0
# EPOCH 15 | ITER 65 | AVG_LOSS 0.02859223261475563 | Train_ACC 100.0
# EPOCH 15 | ITER 70 | AVG_LOSS 0.02986149676144123 | Train_ACC 96.875
# EPOCH 15 | ITER 75 | AVG_LOSS 0.030164141207933426 | Train_ACC 100.0
# EPOCH 15 | ITER 80 | AVG_LOSS 0.03238082677125931 | Train_ACC 96.875
# EPOCH 15 | ITER 85 | AVG_LOSS 0.03745954483747482 | Train_ACC 96.875
# EPOCH 15 | ITER 90 | AVG_LOSS 0.0421442911028862 | Train_ACC 96.875
# EPOCH 15 | ITER 95 | AVG_LOSS 0.04648405313491821 | Train_ACC 100.0
# EPOCH 15 | ITER 100 | AVG_LOSS 0.04920949414372444 | Train_ACC 100.0
# EPOCH 15 | ITER 105 | AVG_LOSS 0.05019323527812958 | Train_ACC 100.0
# EPOCH 15 | ITER 110 | AVG_LOSS 0.0536908283829689 | Train_ACC 100.0
# EPOCH 15 | ITER 115 | AVG_LOSS 0.053238946944475174 | Train_ACC 96.875
# EPOCH 15 | ITER 120 | AVG_LOSS 0.05465845763683319 | Train_ACC 96.875
# Val Accuracy: 94.80%
#
# --------------------------------------------------
# EPOCH 15 | LOSS 0.02503017522394657 | TIME 47.78055119514465
# --------------------------------------------------
#
# EPOCH 16 | ITER 0 | AVG_LOSS 0.03810377046465874 | Train_ACC 100.0
# EPOCH 16 | ITER 5 | AVG_LOSS 0.05455175042152405 | Train_ACC 100.0
# EPOCH 16 | ITER 10 | AVG_LOSS 0.061548225581645966 | Train_ACC 93.75
# EPOCH 16 | ITER 15 | AVG_LOSS 0.05919438973069191 | Train_ACC 100.0
# EPOCH 16 | ITER 20 | AVG_LOSS 0.05654019117355347 | Train_ACC 100.0
# EPOCH 16 | ITER 25 | AVG_LOSS 0.06254701316356659 | Train_ACC 100.0
# EPOCH 16 | ITER 30 | AVG_LOSS 0.06472422182559967 | Train_ACC 100.0
# EPOCH 16 | ITER 35 | AVG_LOSS 0.06420949101448059 | Train_ACC 100.0
# EPOCH 16 | ITER 40 | AVG_LOSS 0.06634008884429932 | Train_ACC 100.0
# EPOCH 16 | ITER 45 | AVG_LOSS 0.06494511663913727 | Train_ACC 100.0
# EPOCH 16 | ITER 50 | AVG_LOSS 0.06498362123966217 | Train_ACC 96.875
# EPOCH 16 | ITER 55 | AVG_LOSS 0.06214551627635956 | Train_ACC 100.0
# EPOCH 16 | ITER 60 | AVG_LOSS 0.06142214685678482 | Train_ACC 100.0
# EPOCH 16 | ITER 65 | AVG_LOSS 0.06041764095425606 | Train_ACC 100.0
# EPOCH 16 | ITER 70 | AVG_LOSS 0.05872131884098053 | Train_ACC 93.75
# EPOCH 16 | ITER 75 | AVG_LOSS 0.05797697976231575 | Train_ACC 93.75
# EPOCH 16 | ITER 80 | AVG_LOSS 0.05628436431288719 | Train_ACC 100.0
# EPOCH 16 | ITER 85 | AVG_LOSS 0.05574240908026695 | Train_ACC 100.0
# EPOCH 16 | ITER 90 | AVG_LOSS 0.053776878863573074 | Train_ACC 100.0
# EPOCH 16 | ITER 95 | AVG_LOSS 0.05203842744231224 | Train_ACC 100.0
# EPOCH 16 | ITER 100 | AVG_LOSS 0.050619520246982574 | Train_ACC 96.875
# EPOCH 16 | ITER 105 | AVG_LOSS 0.054472774267196655 | Train_ACC 100.0
# EPOCH 16 | ITER 110 | AVG_LOSS 0.05312632769346237 | Train_ACC 100.0
# EPOCH 16 | ITER 115 | AVG_LOSS 0.054313547909259796 | Train_ACC 100.0
# EPOCH 16 | ITER 120 | AVG_LOSS 0.0558248832821846 | Train_ACC 100.0
# Val Accuracy: 93.60%
#
# --------------------------------------------------
# EPOCH 16 | LOSS 0.061345137655735016 | TIME 47.436169385910034
# --------------------------------------------------
#
# EPOCH 17 | ITER 0 | AVG_LOSS 0.007346720434725285 | Train_ACC 100.0
# EPOCH 17 | ITER 5 | AVG_LOSS 0.05138701945543289 | Train_ACC 100.0
# EPOCH 17 | ITER 10 | AVG_LOSS 0.044816914945840836 | Train_ACC 100.0
# EPOCH 17 | ITER 15 | AVG_LOSS 0.0376393161714077 | Train_ACC 100.0
# EPOCH 17 | ITER 20 | AVG_LOSS 0.036832116544246674 | Train_ACC 100.0
# EPOCH 17 | ITER 25 | AVG_LOSS 0.04526382312178612 | Train_ACC 93.75
# EPOCH 17 | ITER 30 | AVG_LOSS 0.04814644530415535 | Train_ACC 100.0
# EPOCH 17 | ITER 35 | AVG_LOSS 0.046137768775224686 | Train_ACC 100.0
# EPOCH 17 | ITER 40 | AVG_LOSS 0.04223335161805153 | Train_ACC 100.0
# EPOCH 17 | ITER 45 | AVG_LOSS 0.03951627016067505 | Train_ACC 100.0
# EPOCH 17 | ITER 50 | AVG_LOSS 0.04523185268044472 | Train_ACC 96.875
# EPOCH 17 | ITER 55 | AVG_LOSS 0.042415425181388855 | Train_ACC 100.0
# EPOCH 17 | ITER 60 | AVG_LOSS 0.04283025488257408 | Train_ACC 100.0
# EPOCH 17 | ITER 65 | AVG_LOSS 0.04717959091067314 | Train_ACC 100.0
# EPOCH 17 | ITER 70 | AVG_LOSS 0.04905295372009277 | Train_ACC 96.875
# EPOCH 17 | ITER 75 | AVG_LOSS 0.051272712647914886 | Train_ACC 93.75
# EPOCH 17 | ITER 80 | AVG_LOSS 0.05128875747323036 | Train_ACC 100.0
# EPOCH 17 | ITER 85 | AVG_LOSS 0.04969996586441994 | Train_ACC 100.0
# EPOCH 17 | ITER 90 | AVG_LOSS 0.04851746931672096 | Train_ACC 100.0
# EPOCH 17 | ITER 95 | AVG_LOSS 0.046344876289367676 | Train_ACC 100.0
# EPOCH 17 | ITER 100 | AVG_LOSS 0.04888219013810158 | Train_ACC 90.625
# EPOCH 17 | ITER 105 | AVG_LOSS 0.05016389861702919 | Train_ACC 96.875
# EPOCH 17 | ITER 110 | AVG_LOSS 0.06541714817285538 | Train_ACC 96.875
# EPOCH 17 | ITER 115 | AVG_LOSS 0.06869343668222427 | Train_ACC 93.75
# EPOCH 17 | ITER 120 | AVG_LOSS 0.07563755661249161 | Train_ACC 90.625
# Val Accuracy: 90.60%
#
# --------------------------------------------------
# EPOCH 17 | LOSS 0.10634047538042068 | TIME 47.58847260475159
# --------------------------------------------------
#
# EPOCH 18 | ITER 0 | AVG_LOSS 0.17101715505123138 | Train_ACC 93.75
# EPOCH 18 | ITER 5 | AVG_LOSS 0.11040918529033661 | Train_ACC 100.0
# EPOCH 18 | ITER 10 | AVG_LOSS 0.14388532936573029 | Train_ACC 90.625
# EPOCH 18 | ITER 15 | AVG_LOSS 0.11739832907915115 | Train_ACC 100.0
# EPOCH 18 | ITER 20 | AVG_LOSS 0.10182341188192368 | Train_ACC 96.875
# EPOCH 18 | ITER 25 | AVG_LOSS 0.10381370782852173 | Train_ACC 96.875
# EPOCH 18 | ITER 30 | AVG_LOSS 0.09891436994075775 | Train_ACC 100.0
# EPOCH 18 | ITER 35 | AVG_LOSS 0.09739182144403458 | Train_ACC 90.625
# EPOCH 18 | ITER 40 | AVG_LOSS 0.09272751212120056 | Train_ACC 93.75
# EPOCH 18 | ITER 45 | AVG_LOSS 0.09514196962118149 | Train_ACC 96.875
# EPOCH 18 | ITER 50 | AVG_LOSS 0.08982307463884354 | Train_ACC 96.875
# EPOCH 18 | ITER 55 | AVG_LOSS 0.08803137391805649 | Train_ACC 96.875
# EPOCH 18 | ITER 60 | AVG_LOSS 0.09273892641067505 | Train_ACC 90.625
# EPOCH 18 | ITER 65 | AVG_LOSS 0.09238407760858536 | Train_ACC 93.75
# EPOCH 18 | ITER 70 | AVG_LOSS 0.09056920558214188 | Train_ACC 100.0
# EPOCH 18 | ITER 75 | AVG_LOSS 0.08950509876012802 | Train_ACC 96.875
# EPOCH 18 | ITER 80 | AVG_LOSS 0.08718108385801315 | Train_ACC 100.0
# EPOCH 18 | ITER 85 | AVG_LOSS 0.0840424969792366 | Train_ACC 96.875
# EPOCH 18 | ITER 90 | AVG_LOSS 0.08454423397779465 | Train_ACC 96.875
# EPOCH 18 | ITER 95 | AVG_LOSS 0.08425052464008331 | Train_ACC 96.875
# EPOCH 18 | ITER 100 | AVG_LOSS 0.08301664143800735 | Train_ACC 96.875
# EPOCH 18 | ITER 105 | AVG_LOSS 0.08297007530927658 | Train_ACC 100.0
# EPOCH 18 | ITER 110 | AVG_LOSS 0.08298105746507645 | Train_ACC 96.875
# EPOCH 18 | ITER 115 | AVG_LOSS 0.08241686969995499 | Train_ACC 100.0
# EPOCH 18 | ITER 120 | AVG_LOSS 0.07989103347063065 | Train_ACC 96.875
# Val Accuracy: 95.80%
#
# --------------------------------------------------
# EPOCH 18 | LOSS 0.04007844626903534 | TIME 47.69853615760803
# --------------------------------------------------
#
# EPOCH 19 | ITER 0 | AVG_LOSS 0.21082615852355957 | Train_ACC 96.875
# EPOCH 19 | ITER 5 | AVG_LOSS 0.059090565890073776 | Train_ACC 100.0
# EPOCH 19 | ITER 10 | AVG_LOSS 0.04201778024435043 | Train_ACC 100.0
# EPOCH 19 | ITER 15 | AVG_LOSS 0.03437220677733421 | Train_ACC 100.0
# EPOCH 19 | ITER 20 | AVG_LOSS 0.028263546526432037 | Train_ACC 100.0
# EPOCH 19 | ITER 25 | AVG_LOSS 0.02677193656563759 | Train_ACC 100.0
# EPOCH 19 | ITER 30 | AVG_LOSS 0.032298870384693146 | Train_ACC 96.875
# EPOCH 19 | ITER 35 | AVG_LOSS 0.030725516378879547 | Train_ACC 100.0
# EPOCH 19 | ITER 40 | AVG_LOSS 0.03883358836174011 | Train_ACC 100.0
# EPOCH 19 | ITER 45 | AVG_LOSS 0.04034700244665146 | Train_ACC 93.75
# EPOCH 19 | ITER 50 | AVG_LOSS 0.048290498554706573 | Train_ACC 96.875
# EPOCH 19 | ITER 55 | AVG_LOSS 0.048365041613578796 | Train_ACC 93.75
# EPOCH 19 | ITER 60 | AVG_LOSS 0.05381813645362854 | Train_ACC 90.625
# EPOCH 19 | ITER 65 | AVG_LOSS 0.05374946817755699 | Train_ACC 96.875
# EPOCH 19 | ITER 70 | AVG_LOSS 0.05485982820391655 | Train_ACC 100.0
# EPOCH 19 | ITER 75 | AVG_LOSS 0.05257821083068848 | Train_ACC 100.0
# EPOCH 19 | ITER 80 | AVG_LOSS 0.052436769008636475 | Train_ACC 100.0
# EPOCH 19 | ITER 85 | AVG_LOSS 0.05145341902971268 | Train_ACC 100.0
# EPOCH 19 | ITER 90 | AVG_LOSS 0.05192051827907562 | Train_ACC 100.0
# EPOCH 19 | ITER 95 | AVG_LOSS 0.051429957151412964 | Train_ACC 93.75
# EPOCH 19 | ITER 100 | AVG_LOSS 0.049740057438611984 | Train_ACC 100.0
# EPOCH 19 | ITER 105 | AVG_LOSS 0.04958977922797203 | Train_ACC 100.0
# EPOCH 19 | ITER 110 | AVG_LOSS 0.04924054816365242 | Train_ACC 100.0
# EPOCH 19 | ITER 115 | AVG_LOSS 0.04787787050008774 | Train_ACC 100.0
# EPOCH 19 | ITER 120 | AVG_LOSS 0.04871562868356705 | Train_ACC 100.0
# Val Accuracy: 96.20%
#
# --------------------------------------------------
# EPOCH 19 | LOSS 0.046245500445365906 | TIME 48.12998175621033
# --------------------------------------------------
#
# EPOCH 20 | ITER 0 | AVG_LOSS 0.001284634810872376 | Train_ACC 100.0
# EPOCH 20 | ITER 5 | AVG_LOSS 0.014497309923171997 | Train_ACC 100.0
# EPOCH 20 | ITER 10 | AVG_LOSS 0.05219167098402977 | Train_ACC 100.0
# EPOCH 20 | ITER 15 | AVG_LOSS 0.04168089106678963 | Train_ACC 100.0
# EPOCH 20 | ITER 20 | AVG_LOSS 0.04139777645468712 | Train_ACC 96.875
# EPOCH 20 | ITER 25 | AVG_LOSS 0.04586845263838768 | Train_ACC 100.0
# EPOCH 20 | ITER 30 | AVG_LOSS 0.040754400193691254 | Train_ACC 100.0
# EPOCH 20 | ITER 35 | AVG_LOSS 0.038722097873687744 | Train_ACC 100.0
# EPOCH 20 | ITER 40 | AVG_LOSS 0.03899321332573891 | Train_ACC 100.0
# EPOCH 20 | ITER 45 | AVG_LOSS 0.039590366184711456 | Train_ACC 100.0
# EPOCH 20 | ITER 50 | AVG_LOSS 0.03984355553984642 | Train_ACC 96.875
# EPOCH 20 | ITER 55 | AVG_LOSS 0.040648773312568665 | Train_ACC 100.0
# EPOCH 20 | ITER 60 | AVG_LOSS 0.03922811523079872 | Train_ACC 100.0
# EPOCH 20 | ITER 65 | AVG_LOSS 0.04010754078626633 | Train_ACC 96.875
# EPOCH 20 | ITER 70 | AVG_LOSS 0.04902669042348862 | Train_ACC 100.0
# EPOCH 20 | ITER 75 | AVG_LOSS 0.049233127385377884 | Train_ACC 93.75
# EPOCH 20 | ITER 80 | AVG_LOSS 0.05064280331134796 | Train_ACC 96.875
# EPOCH 20 | ITER 85 | AVG_LOSS 0.052244458347558975 | Train_ACC 90.625
# EPOCH 20 | ITER 90 | AVG_LOSS 0.054010551422834396 | Train_ACC 100.0
# EPOCH 20 | ITER 95 | AVG_LOSS 0.05409770831465721 | Train_ACC 93.75
# EPOCH 20 | ITER 100 | AVG_LOSS 0.052690546959638596 | Train_ACC 100.0
# EPOCH 20 | ITER 105 | AVG_LOSS 0.0514732226729393 | Train_ACC 100.0
# EPOCH 20 | ITER 110 | AVG_LOSS 0.05186552181839943 | Train_ACC 100.0
# EPOCH 20 | ITER 115 | AVG_LOSS 0.05190722271800041 | Train_ACC 100.0
# EPOCH 20 | ITER 120 | AVG_LOSS 0.050897225737571716 | Train_ACC 96.875
# Val Accuracy: 94.40%
#
# --------------------------------------------------
# EPOCH 20 | LOSS 0.006468168459832668 | TIME 47.288448333740234
# --------------------------------------------------
#
# EPOCH 21 | ITER 0 | AVG_LOSS 0.04995477572083473 | Train_ACC 96.875
# EPOCH 21 | ITER 5 | AVG_LOSS 0.032414648681879044 | Train_ACC 96.875
# EPOCH 21 | ITER 10 | AVG_LOSS 0.030515853315591812 | Train_ACC 100.0
# EPOCH 21 | ITER 15 | AVG_LOSS 0.02514049783349037 | Train_ACC 100.0
# EPOCH 21 | ITER 20 | AVG_LOSS 0.027664292603731155 | Train_ACC 93.75
# EPOCH 21 | ITER 25 | AVG_LOSS 0.026213141158223152 | Train_ACC 100.0
# EPOCH 21 | ITER 30 | AVG_LOSS 0.026991643011569977 | Train_ACC 100.0
# EPOCH 21 | ITER 35 | AVG_LOSS 0.03012526035308838 | Train_ACC 96.875
# EPOCH 21 | ITER 40 | AVG_LOSS 0.027728646993637085 | Train_ACC 96.875
# EPOCH 21 | ITER 45 | AVG_LOSS 0.02614137902855873 | Train_ACC 100.0
# EPOCH 21 | ITER 50 | AVG_LOSS 0.024977747350931168 | Train_ACC 100.0
# EPOCH 21 | ITER 55 | AVG_LOSS 0.02621244080364704 | Train_ACC 96.875
# EPOCH 21 | ITER 60 | AVG_LOSS 0.0274887103587389 | Train_ACC 100.0
# EPOCH 21 | ITER 65 | AVG_LOSS 0.028001517057418823 | Train_ACC 96.875
# EPOCH 21 | ITER 70 | AVG_LOSS 0.03246620297431946 | Train_ACC 100.0
# EPOCH 21 | ITER 75 | AVG_LOSS 0.034150850027799606 | Train_ACC 100.0
# EPOCH 21 | ITER 80 | AVG_LOSS 0.03525914251804352 | Train_ACC 100.0
# EPOCH 21 | ITER 85 | AVG_LOSS 0.035565219819545746 | Train_ACC 100.0
# EPOCH 21 | ITER 90 | AVG_LOSS 0.03769661486148834 | Train_ACC 96.875
# EPOCH 21 | ITER 95 | AVG_LOSS 0.037045665085315704 | Train_ACC 100.0
# EPOCH 21 | ITER 100 | AVG_LOSS 0.0357099249958992 | Train_ACC 100.0
# EPOCH 21 | ITER 105 | AVG_LOSS 0.03513696789741516 | Train_ACC 100.0
# EPOCH 21 | ITER 110 | AVG_LOSS 0.035121235996484756 | Train_ACC 100.0
# EPOCH 21 | ITER 115 | AVG_LOSS 0.03529708459973335 | Train_ACC 96.875
# EPOCH 21 | ITER 120 | AVG_LOSS 0.0341750793159008 | Train_ACC 96.875
# Val Accuracy: 95.20%
#
# --------------------------------------------------
# EPOCH 21 | LOSS 0.02181931957602501 | TIME 48.547000885009766
# --------------------------------------------------
#
# EPOCH 22 | ITER 0 | AVG_LOSS 7.381546311080456e-05 | Train_ACC 100.0
# EPOCH 22 | ITER 5 | AVG_LOSS 0.010543972253799438 | Train_ACC 100.0
# EPOCH 22 | ITER 10 | AVG_LOSS 0.025392351672053337 | Train_ACC 96.875
# EPOCH 22 | ITER 15 | AVG_LOSS 0.03225962072610855 | Train_ACC 100.0
# EPOCH 22 | ITER 20 | AVG_LOSS 0.0320361964404583 | Train_ACC 100.0
# EPOCH 22 | ITER 25 | AVG_LOSS 0.03415723890066147 | Train_ACC 100.0
# EPOCH 22 | ITER 30 | AVG_LOSS 0.03447866439819336 | Train_ACC 100.0
# EPOCH 22 | ITER 35 | AVG_LOSS 0.030398057773709297 | Train_ACC 100.0
# EPOCH 22 | ITER 40 | AVG_LOSS 0.030057739466428757 | Train_ACC 100.0
# EPOCH 22 | ITER 45 | AVG_LOSS 0.032165274024009705 | Train_ACC 100.0
# EPOCH 22 | ITER 50 | AVG_LOSS 0.03021278604865074 | Train_ACC 100.0
# EPOCH 22 | ITER 55 | AVG_LOSS 0.028776973485946655 | Train_ACC 100.0
# EPOCH 22 | ITER 60 | AVG_LOSS 0.028462817892432213 | Train_ACC 96.875
# EPOCH 22 | ITER 65 | AVG_LOSS 0.031439922749996185 | Train_ACC 96.875
# EPOCH 22 | ITER 70 | AVG_LOSS 0.03181692957878113 | Train_ACC 93.75
# EPOCH 22 | ITER 75 | AVG_LOSS 0.03461270034313202 | Train_ACC 100.0
# EPOCH 22 | ITER 80 | AVG_LOSS 0.03318118676543236 | Train_ACC 100.0
# EPOCH 22 | ITER 85 | AVG_LOSS 0.033082976937294006 | Train_ACC 100.0
# EPOCH 22 | ITER 90 | AVG_LOSS 0.03450501337647438 | Train_ACC 100.0
# EPOCH 22 | ITER 95 | AVG_LOSS 0.03459995239973068 | Train_ACC 100.0
# EPOCH 22 | ITER 100 | AVG_LOSS 0.03401132673025131 | Train_ACC 100.0
# EPOCH 22 | ITER 105 | AVG_LOSS 0.032864272594451904 | Train_ACC 100.0
# EPOCH 22 | ITER 110 | AVG_LOSS 0.03261286020278931 | Train_ACC 96.875
# EPOCH 22 | ITER 115 | AVG_LOSS 0.03316154703497887 | Train_ACC 100.0
# EPOCH 22 | ITER 120 | AVG_LOSS 0.03316744789481163 | Train_ACC 100.0
# Val Accuracy: 95.60%
#
# --------------------------------------------------
# EPOCH 22 | LOSS 0.038227662444114685 | TIME 46.725120067596436
# --------------------------------------------------
#
# EPOCH 23 | ITER 0 | AVG_LOSS 0.005155680235475302 | Train_ACC 100.0
# EPOCH 23 | ITER 5 | AVG_LOSS 0.015611059963703156 | Train_ACC 100.0
# EPOCH 23 | ITER 10 | AVG_LOSS 0.04167202115058899 | Train_ACC 96.875
# EPOCH 23 | ITER 15 | AVG_LOSS 0.03286875784397125 | Train_ACC 96.875
# EPOCH 23 | ITER 20 | AVG_LOSS 0.029527341946959496 | Train_ACC 100.0
# EPOCH 23 | ITER 25 | AVG_LOSS 0.03149469569325447 | Train_ACC 100.0
# EPOCH 23 | ITER 30 | AVG_LOSS 0.029291365295648575 | Train_ACC 96.875
# EPOCH 23 | ITER 35 | AVG_LOSS 0.03557254746556282 | Train_ACC 100.0
# EPOCH 23 | ITER 40 | AVG_LOSS 0.0338142104446888 | Train_ACC 96.875
# EPOCH 23 | ITER 45 | AVG_LOSS 0.03620002046227455 | Train_ACC 100.0
# EPOCH 23 | ITER 50 | AVG_LOSS 0.038141123950481415 | Train_ACC 96.875
# EPOCH 23 | ITER 55 | AVG_LOSS 0.035963404923677444 | Train_ACC 100.0
# EPOCH 23 | ITER 60 | AVG_LOSS 0.03409365564584732 | Train_ACC 100.0
# EPOCH 23 | ITER 65 | AVG_LOSS 0.03582426533102989 | Train_ACC 96.875
# EPOCH 23 | ITER 70 | AVG_LOSS 0.03777405247092247 | Train_ACC 100.0
# EPOCH 23 | ITER 75 | AVG_LOSS 0.04302102327346802 | Train_ACC 100.0
# EPOCH 23 | ITER 80 | AVG_LOSS 0.04153149947524071 | Train_ACC 100.0
# EPOCH 23 | ITER 85 | AVG_LOSS 0.041974712163209915 | Train_ACC 96.875
# EPOCH 23 | ITER 90 | AVG_LOSS 0.04185505583882332 | Train_ACC 100.0
# EPOCH 23 | ITER 95 | AVG_LOSS 0.04280820116400719 | Train_ACC 100.0
# EPOCH 23 | ITER 100 | AVG_LOSS 0.044519830495119095 | Train_ACC 100.0
# EPOCH 23 | ITER 105 | AVG_LOSS 0.043117523193359375 | Train_ACC 100.0
# EPOCH 23 | ITER 110 | AVG_LOSS 0.04269009456038475 | Train_ACC 100.0
# EPOCH 23 | ITER 115 | AVG_LOSS 0.042269907891750336 | Train_ACC 96.875
# EPOCH 23 | ITER 120 | AVG_LOSS 0.04150563105940819 | Train_ACC 96.875
# Val Accuracy: 96.00%
#
# --------------------------------------------------
# EPOCH 23 | LOSS 0.005142671056091785 | TIME 48.463595151901245
# --------------------------------------------------
#
# EPOCH 24 | ITER 0 | AVG_LOSS 0.011484265327453613 | Train_ACC 100.0
# EPOCH 24 | ITER 5 | AVG_LOSS 0.02476387284696102 | Train_ACC 96.875
# EPOCH 24 | ITER 10 | AVG_LOSS 0.051772329956293106 | Train_ACC 100.0
# EPOCH 24 | ITER 15 | AVG_LOSS 0.044731397181749344 | Train_ACC 100.0
# EPOCH 24 | ITER 20 | AVG_LOSS 0.06088576093316078 | Train_ACC 93.75
# EPOCH 24 | ITER 25 | AVG_LOSS 0.06576025485992432 | Train_ACC 93.75
# EPOCH 24 | ITER 30 | AVG_LOSS 0.06263916939496994 | Train_ACC 96.875
# EPOCH 24 | ITER 35 | AVG_LOSS 0.0634102150797844 | Train_ACC 100.0
# EPOCH 24 | ITER 40 | AVG_LOSS 0.06492836028337479 | Train_ACC 90.625
# EPOCH 24 | ITER 45 | AVG_LOSS 0.06290128082036972 | Train_ACC 100.0
# EPOCH 24 | ITER 50 | AVG_LOSS 0.06487848609685898 | Train_ACC 96.875
# EPOCH 24 | ITER 55 | AVG_LOSS 0.06616538763046265 | Train_ACC 100.0
# EPOCH 24 | ITER 60 | AVG_LOSS 0.06409579515457153 | Train_ACC 96.875
# EPOCH 24 | ITER 65 | AVG_LOSS 0.06096833571791649 | Train_ACC 100.0
# EPOCH 24 | ITER 70 | AVG_LOSS 0.060132529586553574 | Train_ACC 100.0
# EPOCH 24 | ITER 75 | AVG_LOSS 0.0584271214902401 | Train_ACC 96.875
# EPOCH 24 | ITER 80 | AVG_LOSS 0.05719144269824028 | Train_ACC 96.875
# EPOCH 24 | ITER 85 | AVG_LOSS 0.0570884570479393 | Train_ACC 100.0
# EPOCH 24 | ITER 90 | AVG_LOSS 0.05453983321785927 | Train_ACC 100.0
# EPOCH 24 | ITER 95 | AVG_LOSS 0.0527166947722435 | Train_ACC 100.0
# EPOCH 24 | ITER 100 | AVG_LOSS 0.05197427049279213 | Train_ACC 100.0
# EPOCH 24 | ITER 105 | AVG_LOSS 0.053743649274110794 | Train_ACC 100.0
# EPOCH 24 | ITER 110 | AVG_LOSS 0.05329068750143051 | Train_ACC 96.875
# EPOCH 24 | ITER 115 | AVG_LOSS 0.05341723933815956 | Train_ACC 93.75
# EPOCH 24 | ITER 120 | AVG_LOSS 0.05316561460494995 | Train_ACC 100.0
# Val Accuracy: 96.40%
#
# --------------------------------------------------
# EPOCH 24 | LOSS 0.05308908596634865 | TIME 46.64620566368103
# --------------------------------------------------
#
# EPOCH 25 | ITER 0 | AVG_LOSS 0.008865851908922195 | Train_ACC 100.0
# EPOCH 25 | ITER 5 | AVG_LOSS 0.04626704379916191 | Train_ACC 93.75
# EPOCH 25 | ITER 10 | AVG_LOSS 0.04895047843456268 | Train_ACC 100.0
# EPOCH 25 | ITER 15 | AVG_LOSS 0.055443841964006424 | Train_ACC 93.75
# EPOCH 25 | ITER 20 | AVG_LOSS 0.05076828598976135 | Train_ACC 96.875
# EPOCH 25 | ITER 25 | AVG_LOSS 0.051051314920186996 | Train_ACC 100.0
# EPOCH 25 | ITER 30 | AVG_LOSS 0.04765477403998375 | Train_ACC 100.0
# EPOCH 25 | ITER 35 | AVG_LOSS 0.05278189852833748 | Train_ACC 93.75
# EPOCH 25 | ITER 40 | AVG_LOSS 0.051279257982969284 | Train_ACC 100.0
# EPOCH 25 | ITER 45 | AVG_LOSS 0.0486435741186142 | Train_ACC 100.0
# EPOCH 25 | ITER 50 | AVG_LOSS 0.04650263860821724 | Train_ACC 100.0
# EPOCH 25 | ITER 55 | AVG_LOSS 0.045260775834321976 | Train_ACC 96.875
# EPOCH 25 | ITER 60 | AVG_LOSS 0.04264172166585922 | Train_ACC 100.0
# EPOCH 25 | ITER 65 | AVG_LOSS 0.04190771281719208 | Train_ACC 100.0
# EPOCH 25 | ITER 70 | AVG_LOSS 0.04008854925632477 | Train_ACC 100.0
# EPOCH 25 | ITER 75 | AVG_LOSS 0.03822759538888931 | Train_ACC 96.875
# EPOCH 25 | ITER 80 | AVG_LOSS 0.03604026511311531 | Train_ACC 100.0
# EPOCH 25 | ITER 85 | AVG_LOSS 0.03796951472759247 | Train_ACC 100.0
# EPOCH 25 | ITER 90 | AVG_LOSS 0.03661264851689339 | Train_ACC 100.0
# EPOCH 25 | ITER 95 | AVG_LOSS 0.037097420543432236 | Train_ACC 96.875
# EPOCH 25 | ITER 100 | AVG_LOSS 0.03596226125955582 | Train_ACC 100.0
# EPOCH 25 | ITER 105 | AVG_LOSS 0.03890392556786537 | Train_ACC 100.0
# EPOCH 25 | ITER 110 | AVG_LOSS 0.03937437757849693 | Train_ACC 100.0
# EPOCH 25 | ITER 115 | AVG_LOSS 0.03888458386063576 | Train_ACC 100.0
# EPOCH 25 | ITER 120 | AVG_LOSS 0.040176164358854294 | Train_ACC 90.625
# Val Accuracy: 95.80%
#
# --------------------------------------------------
# EPOCH 25 | LOSS 0.013722872361540794 | TIME 48.642645835876465
# --------------------------------------------------
#
# EPOCH 26 | ITER 0 | AVG_LOSS 0.005166730377823114 | Train_ACC 100.0
# EPOCH 26 | ITER 5 | AVG_LOSS 0.04460592195391655 | Train_ACC 100.0
# EPOCH 26 | ITER 10 | AVG_LOSS 0.0312618762254715 | Train_ACC 100.0
# EPOCH 26 | ITER 15 | AVG_LOSS 0.031700652092695236 | Train_ACC 96.875
# EPOCH 26 | ITER 20 | AVG_LOSS 0.041428934782743454 | Train_ACC 90.625
# EPOCH 26 | ITER 25 | AVG_LOSS 0.03524994105100632 | Train_ACC 100.0
# EPOCH 26 | ITER 30 | AVG_LOSS 0.039150986820459366 | Train_ACC 96.875
# EPOCH 26 | ITER 35 | AVG_LOSS 0.037406016141176224 | Train_ACC 100.0
# EPOCH 26 | ITER 40 | AVG_LOSS 0.05114525929093361 | Train_ACC 96.875
# EPOCH 26 | ITER 45 | AVG_LOSS 0.049358487129211426 | Train_ACC 100.0
# EPOCH 26 | ITER 50 | AVG_LOSS 0.049559663981199265 | Train_ACC 100.0
# EPOCH 26 | ITER 55 | AVG_LOSS 0.04767141491174698 | Train_ACC 100.0
# EPOCH 26 | ITER 60 | AVG_LOSS 0.04590495675802231 | Train_ACC 100.0
# EPOCH 26 | ITER 65 | AVG_LOSS 0.045585133135318756 | Train_ACC 100.0
# EPOCH 26 | ITER 70 | AVG_LOSS 0.04412032291293144 | Train_ACC 100.0
# EPOCH 26 | ITER 75 | AVG_LOSS 0.04153761267662048 | Train_ACC 100.0
# EPOCH 26 | ITER 80 | AVG_LOSS 0.03912929445505142 | Train_ACC 100.0
# EPOCH 26 | ITER 85 | AVG_LOSS 0.04055594652891159 | Train_ACC 100.0
# EPOCH 26 | ITER 90 | AVG_LOSS 0.03979584574699402 | Train_ACC 100.0
# EPOCH 26 | ITER 95 | AVG_LOSS 0.040915749967098236 | Train_ACC 100.0
# EPOCH 26 | ITER 100 | AVG_LOSS 0.04346304386854172 | Train_ACC 96.875
# EPOCH 26 | ITER 105 | AVG_LOSS 0.04848068207502365 | Train_ACC 90.625
# EPOCH 26 | ITER 110 | AVG_LOSS 0.04775825887918472 | Train_ACC 100.0
# EPOCH 26 | ITER 115 | AVG_LOSS 0.04784369841217995 | Train_ACC 100.0
# EPOCH 26 | ITER 120 | AVG_LOSS 0.049022261053323746 | Train_ACC 96.875
# Val Accuracy: 95.40%
#
# --------------------------------------------------
# EPOCH 26 | LOSS 0.04413999617099762 | TIME 46.858492851257324
# --------------------------------------------------
#
# EPOCH 27 | ITER 0 | AVG_LOSS 0.008455788716673851 | Train_ACC 100.0
# EPOCH 27 | ITER 5 | AVG_LOSS 0.03523436188697815 | Train_ACC 100.0
# EPOCH 27 | ITER 10 | AVG_LOSS 0.09446458518505096 | Train_ACC 96.875
# EPOCH 27 | ITER 15 | AVG_LOSS 0.07395405322313309 | Train_ACC 100.0
# EPOCH 27 | ITER 20 | AVG_LOSS 0.06586097180843353 | Train_ACC 100.0
# EPOCH 27 | ITER 25 | AVG_LOSS 0.06505586206912994 | Train_ACC 93.75
# EPOCH 27 | ITER 30 | AVG_LOSS 0.05606567859649658 | Train_ACC 100.0
# EPOCH 27 | ITER 35 | AVG_LOSS 0.05623753368854523 | Train_ACC 96.875
# EPOCH 27 | ITER 40 | AVG_LOSS 0.050827089697122574 | Train_ACC 100.0
# EPOCH 27 | ITER 45 | AVG_LOSS 0.05493141710758209 | Train_ACC 100.0
# EPOCH 27 | ITER 50 | AVG_LOSS 0.05138719081878662 | Train_ACC 100.0
# EPOCH 27 | ITER 55 | AVG_LOSS 0.04788118973374367 | Train_ACC 100.0
# EPOCH 27 | ITER 60 | AVG_LOSS 0.05079171061515808 | Train_ACC 100.0
# EPOCH 27 | ITER 65 | AVG_LOSS 0.048494864255189896 | Train_ACC 100.0
# EPOCH 27 | ITER 70 | AVG_LOSS 0.04637223109602928 | Train_ACC 96.875
# EPOCH 27 | ITER 75 | AVG_LOSS 0.047002729028463364 | Train_ACC 96.875
# EPOCH 27 | ITER 80 | AVG_LOSS 0.04611135274171829 | Train_ACC 96.875
# EPOCH 27 | ITER 85 | AVG_LOSS 0.0450664646923542 | Train_ACC 96.875
# EPOCH 27 | ITER 90 | AVG_LOSS 0.04397156089544296 | Train_ACC 100.0
# EPOCH 27 | ITER 95 | AVG_LOSS 0.042889248579740524 | Train_ACC 100.0
# EPOCH 27 | ITER 100 | AVG_LOSS 0.04160463809967041 | Train_ACC 100.0
# EPOCH 27 | ITER 105 | AVG_LOSS 0.04145362228155136 | Train_ACC 100.0
# EPOCH 27 | ITER 110 | AVG_LOSS 0.04013470560312271 | Train_ACC 100.0
# EPOCH 27 | ITER 115 | AVG_LOSS 0.03873414918780327 | Train_ACC 100.0
# EPOCH 27 | ITER 120 | AVG_LOSS 0.037904273718595505 | Train_ACC 100.0
# Val Accuracy: 97.20%
#
# --------------------------------------------------
# EPOCH 27 | LOSS 0.055529072880744934 | TIME 48.95100736618042
# --------------------------------------------------
#
# EPOCH 28 | ITER 0 | AVG_LOSS 0.03037581406533718 | Train_ACC 100.0
# EPOCH 28 | ITER 5 | AVG_LOSS 0.019344758242368698 | Train_ACC 100.0
# EPOCH 28 | ITER 10 | AVG_LOSS 0.01552797481417656 | Train_ACC 100.0
# EPOCH 28 | ITER 15 | AVG_LOSS 0.020623842254281044 | Train_ACC 100.0
# EPOCH 28 | ITER 20 | AVG_LOSS 0.01961313933134079 | Train_ACC 100.0
# EPOCH 28 | ITER 25 | AVG_LOSS 0.019155647605657578 | Train_ACC 100.0
# EPOCH 28 | ITER 30 | AVG_LOSS 0.020125389099121094 | Train_ACC 96.875
# EPOCH 28 | ITER 35 | AVG_LOSS 0.01832265593111515 | Train_ACC 100.0
# EPOCH 28 | ITER 40 | AVG_LOSS 0.02162049524486065 | Train_ACC 96.875
# EPOCH 28 | ITER 45 | AVG_LOSS 0.019922319799661636 | Train_ACC 100.0
# EPOCH 28 | ITER 50 | AVG_LOSS 0.03954707086086273 | Train_ACC 100.0
# EPOCH 28 | ITER 55 | AVG_LOSS 0.04202062264084816 | Train_ACC 93.75
# EPOCH 28 | ITER 60 | AVG_LOSS 0.04944337531924248 | Train_ACC 96.875
# EPOCH 28 | ITER 65 | AVG_LOSS 0.05227435380220413 | Train_ACC 96.875
# EPOCH 28 | ITER 70 | AVG_LOSS 0.05376003682613373 | Train_ACC 96.875
# EPOCH 28 | ITER 75 | AVG_LOSS 0.05281239002943039 | Train_ACC 96.875
# EPOCH 28 | ITER 80 | AVG_LOSS 0.05315033718943596 | Train_ACC 100.0
# EPOCH 28 | ITER 85 | AVG_LOSS 0.05267515406012535 | Train_ACC 93.75
# EPOCH 28 | ITER 90 | AVG_LOSS 0.052091315388679504 | Train_ACC 96.875
# EPOCH 28 | ITER 95 | AVG_LOSS 0.05052877590060234 | Train_ACC 96.875
# EPOCH 28 | ITER 100 | AVG_LOSS 0.05242833495140076 | Train_ACC 93.75
# EPOCH 28 | ITER 105 | AVG_LOSS 0.05169195309281349 | Train_ACC 96.875
# EPOCH 28 | ITER 110 | AVG_LOSS 0.05052657425403595 | Train_ACC 100.0
# EPOCH 28 | ITER 115 | AVG_LOSS 0.0508694089949131 | Train_ACC 100.0
# EPOCH 28 | ITER 120 | AVG_LOSS 0.05041177570819855 | Train_ACC 100.0
# Val Accuracy: 97.80%
#
# --------------------------------------------------
# EPOCH 28 | LOSS 0.004923767875880003 | TIME 46.72433662414551
# --------------------------------------------------
#
# EPOCH 29 | ITER 0 | AVG_LOSS 0.004605234134942293 | Train_ACC 100.0
# EPOCH 29 | ITER 5 | AVG_LOSS 0.021336201578378677 | Train_ACC 96.875
# EPOCH 29 | ITER 10 | AVG_LOSS 0.03232797235250473 | Train_ACC 100.0
# EPOCH 29 | ITER 15 | AVG_LOSS 0.027387384325265884 | Train_ACC 100.0
# EPOCH 29 | ITER 20 | AVG_LOSS 0.04161727428436279 | Train_ACC 93.75
# EPOCH 29 | ITER 25 | AVG_LOSS 0.0434090755879879 | Train_ACC 100.0
# EPOCH 29 | ITER 30 | AVG_LOSS 0.040966060012578964 | Train_ACC 96.875
# EPOCH 29 | ITER 35 | AVG_LOSS 0.04819266498088837 | Train_ACC 93.75
# EPOCH 29 | ITER 40 | AVG_LOSS 0.04345110058784485 | Train_ACC 100.0
# EPOCH 29 | ITER 45 | AVG_LOSS 0.04236817732453346 | Train_ACC 100.0
# EPOCH 29 | ITER 50 | AVG_LOSS 0.04146513715386391 | Train_ACC 96.875
# EPOCH 29 | ITER 55 | AVG_LOSS 0.041220538318157196 | Train_ACC 100.0
# EPOCH 29 | ITER 60 | AVG_LOSS 0.04213990271091461 | Train_ACC 87.5
# EPOCH 29 | ITER 65 | AVG_LOSS 0.040689773857593536 | Train_ACC 100.0
# EPOCH 29 | ITER 70 | AVG_LOSS 0.04288385808467865 | Train_ACC 100.0
# EPOCH 29 | ITER 75 | AVG_LOSS 0.04059639945626259 | Train_ACC 100.0
# EPOCH 29 | ITER 80 | AVG_LOSS 0.03839702531695366 | Train_ACC 100.0
# EPOCH 29 | ITER 85 | AVG_LOSS 0.03920658677816391 | Train_ACC 100.0
# EPOCH 29 | ITER 90 | AVG_LOSS 0.03933163359761238 | Train_ACC 100.0
# EPOCH 29 | ITER 95 | AVG_LOSS 0.0385514572262764 | Train_ACC 96.875
# EPOCH 29 | ITER 100 | AVG_LOSS 0.03891252353787422 | Train_ACC 100.0
# EPOCH 29 | ITER 105 | AVG_LOSS 0.039733413606882095 | Train_ACC 96.875
# EPOCH 29 | ITER 110 | AVG_LOSS 0.03899245336651802 | Train_ACC 100.0
# EPOCH 29 | ITER 115 | AVG_LOSS 0.03783099353313446 | Train_ACC 100.0
# EPOCH 29 | ITER 120 | AVG_LOSS 0.03677808493375778 | Train_ACC 100.0
# Val Accuracy: 97.80%
#
# --------------------------------------------------
# EPOCH 29 | LOSS 0.034999195486307144 | TIME 48.473347425460815
# --------------------------------------------------
#
# Best Model:  1
# ****************************************
# test Accuracy: 96.60%
# <ipython-input-14-6cbf595d9b3d>:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
plotloss()

# %%
class2idx = {'Cat': 0, 'Dog': 1}

idx2class = { value : key  for key , value in class2idx.items() }
y_true = [idx2class[val.item()] for val in y_expected_test ]
y_pred = [idx2class[val.item()] for val in y_test ]
#print(y_true)
#print(y_pred)

macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")
f1_score = (2*micro_precision*micro_recall)/(micro_recall + micro_precision)

print("f1 - Score is :--- " ,f1_score)
cnf_matrix = confusion_matrix(y_true , y_pred , labels=['Cat','Dog'])
plot_confusion_matrix(cnf_matrix , class2idx.keys() , [macro_precision , micro_precision , macro_recall , micro_recall], output_filename = "cnf_mobilenet_Data1.png")
# Out:
# f1 - Score is :---  0.966
