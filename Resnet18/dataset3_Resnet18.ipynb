# %%
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
import torchvision.models as models
from torchvision.models import resnet18, ResNet18_Weights
from sklearn.metrics import *
import seaborn as sns
import seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import os.path
import random
import cv2

# %%
writer = SummaryWriter()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from google.colab import drive
drive.mount('/content/gdrive/');

transforms_train = transforms.Compose([
    transforms.Resize((256, 256)),   #must same as here
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(), # data augmentation
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalization
])
transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),   #must same as here
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# Out:
# Mounted at /content/gdrive/

# %%
def load_Data():
  train_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset3/train"
  test_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset3/test"
  val_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset3/val"
  # train_dir = "/content/gdrive/MyDrive/test/dataset1/train"
  # test_dir = "/content/gdrive/MyDrive/test/dataset1/test"
  # val_dir = "/content/gdrive/MyDrive/test/dataset1/val"
  trainset = datasets.ImageFolder(train_dir, transforms_train)
  testset = datasets.ImageFolder(test_dir, transforms_test)
  valset = datasets.ImageFolder(val_dir, transforms_test)
  trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=8)
  testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=8)
  valloader = torch.utils.data.DataLoader(valset, batch_size=32, shuffle=False, num_workers=8)
  return trainloader,testloader,valloader
load_Data()
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# (<torch.utils.data.dataloader.DataLoader at 0x7f9b7ce6fa90>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f9b7ce6f910>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f9b7ce6fc10>)

# %%
# def Model():
#   # Define the ResNet-18 model
#   resnet = 
#   # Replace the last fully connected layer with a new one
#   num_ftrs = resnet.fc.in_features
#   print(num_ftrs)
#   resnet.fc = nn.Linear(num_ftrs,2)

#   # Define the loss function and optimizer
#   return resnet
# Model()

# %%
class Resnet18(nn.Module):
    def __init__(self,inputDims) -> None:
        super(Resnet18 , self).__init__()

        self.model = torchvision.models.resnet18(pretrained=False)

        self.fc_layer = nn.Sequential(
            
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(32, 12)
        )
        
        self.model.fc = self.fc_layer
        self.features = {}
        self.model.avgpool.register_forward_hook(self.get_features("embeddings"))

    def get_features(self,name):
        def hook(model, input, output):
            self.features[name] = output.detach().cpu().numpy()
        return hook

    def forward(self, x):
          x = self.model(x)
          return x
model2 = Resnet18((224,224))
print(model2)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Resnet18(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.2, inplace=False)
#       (6): Linear(in_features=128, out_features=64, bias=True)
#       (7): ReLU(inplace=True)
#       (8): Dropout(p=0.2, inplace=False)
#       (9): Linear(in_features=64, out_features=32, bias=True)
#       (10): ReLU(inplace=True)
#       (11): Dropout(p=0.2, inplace=False)
#       (12): Linear(in_features=32, out_features=12, bias=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=64, out_features=32, bias=True)
#     (10): ReLU(inplace=True)
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=32, out_features=12, bias=True)
#   )
# )

# %%
def save_checkpoint(state, filename):
  torch.save(state, filename)

# %%
# datastructure to store all the training testing and validation results.
y_train = []
y_expected_train = []
y_val = []
y_expected_val = []
y_test = []
y_expected_test = []
trainloss = []
valloss =[]
epochnum = []

# %%
print(torch.cuda.is_available())
def train(model, train_loader, criterion, optimizer, epoch, step=5):
    
    model.train()
    for i, (images, labels) in enumerate(train_loader):
        #print(torch.cuda.is_available())
        total =0
        correct = 0
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        #print(predicted,type(predicted))
        #print(labels,type(labels))
        output = model(images)
        loss = criterion(output,labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        y_train.extend(predicted.to(torch.device('cpu')))
        y_expected_train.extend(labels.to(torch.device('cpu')))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        #print( f'Training Accuracy: {accuracy:.2f}%')
            
        if i%step==0:
            print('EPOCH {} | ITER {} | AVG_LOSS {} | Train_ACC {}'.format(epoch, i, loss,accuracy))
        writer.add_scalar('TRAIN_LOSS', loss, epoch)
        
    return loss ,accuracy
# Out:
# True

# %%
def test(resnet, testloader, criterion, optimizer, epoch,step=5):
  with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in testloader:
            inputs = inputs.to(device)
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = resnet(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            accuracy = 100 * correct / total
            print(f'Test Accuracy: {accuracy:.2f}%')
            return accuracy

# %%
def val(model, val_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            #print("Inside validation");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            loss = criterion(outputs,labels)
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #print("CORRECT",correct)
            #print("Total",total)
        accuracy = 100 * correct / total
        print(f'Val Accuracy: {accuracy:.2f}%')
        return loss,accuracy

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        return accuracy

# %%
def visualize(model , data_loader):
    class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
    idx2class = { value : key for key,value in  class2idx.items() }
    embeddings = np.array([])
    labels = np.array([])
    model.eval()
    out_features = 512
    num_categories = 12
    with torch.no_grad(): 
        for i,data in enumerate(data_loader):
            images, labs = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            embeds = model.features["embeddings"].reshape(-1, 1024)
            embeddings = np.append(embeddings , embeds)
            labels = np.append(labels,labs.cpu())
  
    embeddings = embeddings.reshape(-1, 512)
    
    c_labels = labels.reshape(-1 , 1).ravel()
    tsne = TSNE(n_components=2,perplexity=2).fit_transform(embeddings)
    labels = np.array([ idx2class[ele] for ele in c_labels])
    
    cmap = cm.get_cmap('tab20')
    
    for lab in range(num_categories):
        indices = (c_labels == lab)
        plt.scatter(tsne[indices, 0],tsne[indices, 1],c=np.array(cmap(lab)).reshape(1, 4),label=lab,alpha=1)
        plt.legend(fontsize='large', markerscale=2)
    plt.show()
  
# model = Model((224,224))
# train_loader, val_loader ,test_loader = load_Data()
# visualize(model,test_loader)

# %%
def plotloss():
  plt.figure(figsize=(20,10))
  plt.plot(epochnum, trainloss)
  plt.plot(epochnum, valloss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
idx2class = { value : key  for key , value in class2idx.items() }

def plot_confusion_matrix(data, labels, metrics ,output_filename=None):

    [macro_precision , micro_precision , macro_recall , micro_recall] = metrics

    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(10,10))
 
    plt.suptitle("Confusion Matrix")
    plt.title(f"(Macro/Micro) Precision : {round(macro_precision,2)}/{round(micro_precision,2)}   :::::   (Macro/Micro) Recall : {round(macro_recall,2)}/{round(micro_recall,2)}")
 
    seaborn.set(font_scale=1)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu",linewidths=2 , fmt='d' ,cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# %%
def main():
    model = Resnet18((224,224));
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        model = model.cuda()
        print("using gpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    epochs = 30
    train_loader, val_loader ,test_loader = load_Data()
 
    history = open("/content/gdrive/MyDrive/Results/dataset3_Resnet18_history.csv",'w')
    history.write('epochs , trainloss , Train-acc,val_acc , test_acc \n')
    max_accuracy = 0 
    for epoch in range(0,epochs):
        start = time.time()
        train_loss,accuracy = train(model, train_loader, criterion, optimizer, epoch)
        vallosss,val_loss = val(model, val_loader, criterion, optimizer, epoch)
        test_loss = test(model, test_loader, criterion, optimizer, epoch)
        trainloss.append(train_loss.cpu().detach().numpy())
        valloss.append(vallosss.cpu().detach().numpy())
        epochnum.append(epoch)
        print()
        print('-' * 50)
        print('EPOCH {} | LOSS {} | TIME {}'.format(epoch, train_loss, time.time() - start))
        print('-' * 50)
        print()

        if(val_loss > max_accuracy):
          max_accuracy = val_loss
          save_checkpoint({'epoch': epoch,'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),'loss' : train_loss}, "/content/gdrive/MyDrive/Checkpoints/dataset3_Resnet18.ckpt")

        history.write('{},{},{},{},{}\n'.format(epoch, train_loss,accuracy, val_loss , test_loss))
        
    history.close()
    visualize(model,train_loader)
# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    main()
# Out:
# True
# using gpu
# EPOCH 0 | ITER 0 | AVG_LOSS 2.4591479301452637 | Train_ACC 12.5
# EPOCH 0 | ITER 5 | AVG_LOSS 2.46974778175354 | Train_ACC 15.625
# EPOCH 0 | ITER 10 | AVG_LOSS 2.381991386413574 | Train_ACC 15.625
# EPOCH 0 | ITER 15 | AVG_LOSS 2.3602874279022217 | Train_ACC 15.625
# EPOCH 0 | ITER 20 | AVG_LOSS 2.38634991645813 | Train_ACC 6.25
# EPOCH 0 | ITER 25 | AVG_LOSS 2.42728853225708 | Train_ACC 12.5
# EPOCH 0 | ITER 30 | AVG_LOSS 2.409067153930664 | Train_ACC 15.625
# EPOCH 0 | ITER 35 | AVG_LOSS 2.6436712741851807 | Train_ACC 6.25
# EPOCH 0 | ITER 40 | AVG_LOSS 2.3904879093170166 | Train_ACC 18.75
# EPOCH 0 | ITER 45 | AVG_LOSS 2.4040207862854004 | Train_ACC 6.25
# EPOCH 0 | ITER 50 | AVG_LOSS 2.4076335430145264 | Train_ACC 9.375
# EPOCH 0 | ITER 55 | AVG_LOSS 2.4665820598602295 | Train_ACC 12.5
# EPOCH 0 | ITER 60 | AVG_LOSS 2.4104650020599365 | Train_ACC 12.5
# EPOCH 0 | ITER 65 | AVG_LOSS 2.4329910278320312 | Train_ACC 12.5
# EPOCH 0 | ITER 70 | AVG_LOSS 2.402564764022827 | Train_ACC 18.75
# EPOCH 0 | ITER 75 | AVG_LOSS 2.423868179321289 | Train_ACC 12.5
# EPOCH 0 | ITER 80 | AVG_LOSS 2.400974988937378 | Train_ACC 12.5
# EPOCH 0 | ITER 85 | AVG_LOSS 2.3516976833343506 | Train_ACC 15.625
# EPOCH 0 | ITER 90 | AVG_LOSS 2.417742967605591 | Train_ACC 18.75
# EPOCH 0 | ITER 95 | AVG_LOSS 2.5128488540649414 | Train_ACC 15.625
# EPOCH 0 | ITER 100 | AVG_LOSS 2.4249637126922607 | Train_ACC 12.5
# EPOCH 0 | ITER 105 | AVG_LOSS 2.4430270195007324 | Train_ACC 15.625
# EPOCH 0 | ITER 110 | AVG_LOSS 2.178281545639038 | Train_ACC 25.0
# EPOCH 0 | ITER 115 | AVG_LOSS 2.2553093433380127 | Train_ACC 15.625
# EPOCH 0 | ITER 120 | AVG_LOSS 2.4813807010650635 | Train_ACC 6.25
# EPOCH 0 | ITER 125 | AVG_LOSS 2.396292209625244 | Train_ACC 12.5
# EPOCH 0 | ITER 130 | AVG_LOSS 2.352846384048462 | Train_ACC 9.375
# EPOCH 0 | ITER 135 | AVG_LOSS 2.534599542617798 | Train_ACC 18.75
# EPOCH 0 | ITER 140 | AVG_LOSS 2.4211490154266357 | Train_ACC 9.375
# EPOCH 0 | ITER 145 | AVG_LOSS 2.368234872817993 | Train_ACC 18.75
# EPOCH 0 | ITER 150 | AVG_LOSS 2.461772918701172 | Train_ACC 12.5
# EPOCH 0 | ITER 155 | AVG_LOSS 2.4666049480438232 | Train_ACC 15.625
# EPOCH 0 | ITER 160 | AVG_LOSS 2.361438512802124 | Train_ACC 18.75
# EPOCH 0 | ITER 165 | AVG_LOSS 2.3503799438476562 | Train_ACC 15.625
# EPOCH 0 | ITER 170 | AVG_LOSS 2.463798761367798 | Train_ACC 9.375
# EPOCH 0 | ITER 175 | AVG_LOSS 2.417428493499756 | Train_ACC 12.5
# EPOCH 0 | ITER 180 | AVG_LOSS 2.4892783164978027 | Train_ACC 12.5
# EPOCH 0 | ITER 185 | AVG_LOSS 2.499027729034424 | Train_ACC 9.375
# EPOCH 0 | ITER 190 | AVG_LOSS 2.478640556335449 | Train_ACC 15.625
# EPOCH 0 | ITER 195 | AVG_LOSS 2.425957679748535 | Train_ACC 15.625
# EPOCH 0 | ITER 200 | AVG_LOSS 2.3630406856536865 | Train_ACC 15.625
# EPOCH 0 | ITER 205 | AVG_LOSS 2.351200819015503 | Train_ACC 18.75
# EPOCH 0 | ITER 210 | AVG_LOSS 2.469195604324341 | Train_ACC 6.25
# EPOCH 0 | ITER 215 | AVG_LOSS 2.3471317291259766 | Train_ACC 21.875
# EPOCH 0 | ITER 220 | AVG_LOSS 2.3992323875427246 | Train_ACC 6.25
# EPOCH 0 | ITER 225 | AVG_LOSS 2.526036500930786 | Train_ACC 0.0
# EPOCH 0 | ITER 230 | AVG_LOSS 2.420177459716797 | Train_ACC 3.125
# EPOCH 0 | ITER 235 | AVG_LOSS 2.3935821056365967 | Train_ACC 12.5
# EPOCH 0 | ITER 240 | AVG_LOSS 2.4856767654418945 | Train_ACC 6.25
# EPOCH 0 | ITER 245 | AVG_LOSS 2.3057258129119873 | Train_ACC 21.875
# EPOCH 0 | ITER 250 | AVG_LOSS 2.4272451400756836 | Train_ACC 15.625
# EPOCH 0 | ITER 255 | AVG_LOSS 2.7119076251983643 | Train_ACC 6.25
# EPOCH 0 | ITER 260 | AVG_LOSS 2.4138317108154297 | Train_ACC 21.875
# EPOCH 0 | ITER 265 | AVG_LOSS 2.4278321266174316 | Train_ACC 12.5
# EPOCH 0 | ITER 270 | AVG_LOSS 2.337791681289673 | Train_ACC 15.625
# EPOCH 0 | ITER 275 | AVG_LOSS 2.309041976928711 | Train_ACC 12.5
# EPOCH 0 | ITER 280 | AVG_LOSS 2.3365118503570557 | Train_ACC 18.75
# EPOCH 0 | ITER 285 | AVG_LOSS 2.3112387657165527 | Train_ACC 12.5
# EPOCH 0 | ITER 290 | AVG_LOSS 2.4012370109558105 | Train_ACC 15.625
# EPOCH 0 | ITER 295 | AVG_LOSS 2.509148120880127 | Train_ACC 12.5
# EPOCH 0 | ITER 300 | AVG_LOSS 2.443767547607422 | Train_ACC 15.625
# EPOCH 0 | ITER 305 | AVG_LOSS 2.3768861293792725 | Train_ACC 18.75
# EPOCH 0 | ITER 310 | AVG_LOSS 2.429685354232788 | Train_ACC 18.75
# EPOCH 0 | ITER 315 | AVG_LOSS 2.4756956100463867 | Train_ACC 12.5
# EPOCH 0 | ITER 320 | AVG_LOSS 2.3264105319976807 | Train_ACC 15.625
# EPOCH 0 | ITER 325 | AVG_LOSS 2.2942311763763428 | Train_ACC 6.25
# EPOCH 0 | ITER 330 | AVG_LOSS 2.3563785552978516 | Train_ACC 12.5
# EPOCH 0 | ITER 335 | AVG_LOSS 2.42726993560791 | Train_ACC 9.375
# EPOCH 0 | ITER 340 | AVG_LOSS 2.1977427005767822 | Train_ACC 34.375
# EPOCH 0 | ITER 345 | AVG_LOSS 2.514657497406006 | Train_ACC 15.625
# EPOCH 0 | ITER 350 | AVG_LOSS 2.4758808612823486 | Train_ACC 9.375
# EPOCH 0 | ITER 355 | AVG_LOSS 2.428040027618408 | Train_ACC 12.5
# EPOCH 0 | ITER 360 | AVG_LOSS 2.393592596054077 | Train_ACC 12.5
# EPOCH 0 | ITER 365 | AVG_LOSS 2.633327007293701 | Train_ACC 9.375
# EPOCH 0 | ITER 370 | AVG_LOSS 2.445291757583618 | Train_ACC 12.5
# Val Accuracy: 16.68%
# ****************************************
# test Accuracy: 15.94%
#
# --------------------------------------------------
# EPOCH 0 | LOSS 2.3297250270843506 | TIME 836.4755721092224
# --------------------------------------------------
#
# EPOCH 1 | ITER 0 | AVG_LOSS 2.4022316932678223 | Train_ACC 15.625
# EPOCH 1 | ITER 5 | AVG_LOSS 2.351529836654663 | Train_ACC 21.875
# EPOCH 1 | ITER 10 | AVG_LOSS 2.357325792312622 | Train_ACC 9.375
# EPOCH 1 | ITER 15 | AVG_LOSS 2.442072868347168 | Train_ACC 15.625
# EPOCH 1 | ITER 20 | AVG_LOSS 2.4157114028930664 | Train_ACC 18.75
# EPOCH 1 | ITER 25 | AVG_LOSS 2.2956624031066895 | Train_ACC 25.0
# EPOCH 1 | ITER 30 | AVG_LOSS 2.4193336963653564 | Train_ACC 28.125
# EPOCH 1 | ITER 35 | AVG_LOSS 2.421727180480957 | Train_ACC 18.75
# EPOCH 1 | ITER 40 | AVG_LOSS 2.4188344478607178 | Train_ACC 21.875
# EPOCH 1 | ITER 45 | AVG_LOSS 2.5213844776153564 | Train_ACC 15.625
# EPOCH 1 | ITER 50 | AVG_LOSS 2.4509215354919434 | Train_ACC 21.875
# EPOCH 1 | ITER 55 | AVG_LOSS 2.462407350540161 | Train_ACC 12.5
# EPOCH 1 | ITER 60 | AVG_LOSS 2.3184316158294678 | Train_ACC 21.875
# EPOCH 1 | ITER 65 | AVG_LOSS 2.2930798530578613 | Train_ACC 21.875
# EPOCH 1 | ITER 70 | AVG_LOSS 2.2874937057495117 | Train_ACC 18.75
# EPOCH 1 | ITER 75 | AVG_LOSS 2.3141260147094727 | Train_ACC 12.5
# EPOCH 1 | ITER 80 | AVG_LOSS 2.3608005046844482 | Train_ACC 6.25
# EPOCH 1 | ITER 85 | AVG_LOSS 2.4326233863830566 | Train_ACC 6.25
# EPOCH 1 | ITER 90 | AVG_LOSS 2.449098825454712 | Train_ACC 21.875
# EPOCH 1 | ITER 95 | AVG_LOSS 2.4283101558685303 | Train_ACC 15.625
# EPOCH 1 | ITER 100 | AVG_LOSS 2.5131216049194336 | Train_ACC 15.625
# EPOCH 1 | ITER 105 | AVG_LOSS 2.5213096141815186 | Train_ACC 15.625
# EPOCH 1 | ITER 110 | AVG_LOSS 2.3876266479492188 | Train_ACC 25.0
# EPOCH 1 | ITER 115 | AVG_LOSS 2.385456085205078 | Train_ACC 12.5
# EPOCH 1 | ITER 120 | AVG_LOSS 2.383528709411621 | Train_ACC 9.375
# EPOCH 1 | ITER 125 | AVG_LOSS 2.4052062034606934 | Train_ACC 12.5
# EPOCH 1 | ITER 130 | AVG_LOSS 2.2855842113494873 | Train_ACC 18.75
# EPOCH 1 | ITER 135 | AVG_LOSS 2.284114122390747 | Train_ACC 25.0
# EPOCH 1 | ITER 140 | AVG_LOSS 2.491558074951172 | Train_ACC 9.375
# EPOCH 1 | ITER 145 | AVG_LOSS 2.289238929748535 | Train_ACC 25.0
# EPOCH 1 | ITER 150 | AVG_LOSS 2.3993871212005615 | Train_ACC 12.5
# EPOCH 1 | ITER 155 | AVG_LOSS 2.3255717754364014 | Train_ACC 15.625
# EPOCH 1 | ITER 160 | AVG_LOSS 2.3581950664520264 | Train_ACC 21.875
# EPOCH 1 | ITER 165 | AVG_LOSS 2.34281849861145 | Train_ACC 9.375
# EPOCH 1 | ITER 170 | AVG_LOSS 2.3469772338867188 | Train_ACC 18.75
# EPOCH 1 | ITER 175 | AVG_LOSS 2.2060399055480957 | Train_ACC 21.875
# EPOCH 1 | ITER 180 | AVG_LOSS 2.263528823852539 | Train_ACC 12.5
# EPOCH 1 | ITER 185 | AVG_LOSS 2.0913169384002686 | Train_ACC 31.25
# EPOCH 1 | ITER 190 | AVG_LOSS 2.3969247341156006 | Train_ACC 15.625
# EPOCH 1 | ITER 195 | AVG_LOSS 2.299933671951294 | Train_ACC 25.0
# EPOCH 1 | ITER 200 | AVG_LOSS 2.3176498413085938 | Train_ACC 18.75
# EPOCH 1 | ITER 205 | AVG_LOSS 2.38905930519104 | Train_ACC 21.875
# EPOCH 1 | ITER 210 | AVG_LOSS 2.3001654148101807 | Train_ACC 28.125
# EPOCH 1 | ITER 215 | AVG_LOSS 2.2976431846618652 | Train_ACC 18.75
# EPOCH 1 | ITER 220 | AVG_LOSS 2.298001527786255 | Train_ACC 18.75
# EPOCH 1 | ITER 225 | AVG_LOSS 2.0838561058044434 | Train_ACC 25.0
# EPOCH 1 | ITER 230 | AVG_LOSS 2.6264171600341797 | Train_ACC 9.375
# EPOCH 1 | ITER 235 | AVG_LOSS 2.37709641456604 | Train_ACC 15.625
# EPOCH 1 | ITER 240 | AVG_LOSS 2.3256430625915527 | Train_ACC 18.75
# EPOCH 1 | ITER 245 | AVG_LOSS 2.462064743041992 | Train_ACC 12.5
# EPOCH 1 | ITER 250 | AVG_LOSS 2.6690313816070557 | Train_ACC 3.125
# EPOCH 1 | ITER 255 | AVG_LOSS 2.257154703140259 | Train_ACC 15.625
# EPOCH 1 | ITER 260 | AVG_LOSS 2.250434398651123 | Train_ACC 12.5
# EPOCH 1 | ITER 265 | AVG_LOSS 2.2239012718200684 | Train_ACC 25.0
# EPOCH 1 | ITER 270 | AVG_LOSS 2.45356822013855 | Train_ACC 9.375
# EPOCH 1 | ITER 275 | AVG_LOSS 2.2948179244995117 | Train_ACC 18.75
# EPOCH 1 | ITER 280 | AVG_LOSS 2.2902519702911377 | Train_ACC 21.875
# EPOCH 1 | ITER 285 | AVG_LOSS 2.4198899269104004 | Train_ACC 18.75
# EPOCH 1 | ITER 290 | AVG_LOSS 2.18168568611145 | Train_ACC 34.375
# EPOCH 1 | ITER 295 | AVG_LOSS 2.249896287918091 | Train_ACC 25.0
# EPOCH 1 | ITER 300 | AVG_LOSS 2.286008834838867 | Train_ACC 12.5
# EPOCH 1 | ITER 305 | AVG_LOSS 2.4407858848571777 | Train_ACC 18.75
# EPOCH 1 | ITER 310 | AVG_LOSS 2.239575147628784 | Train_ACC 15.625
# EPOCH 1 | ITER 315 | AVG_LOSS 2.419506788253784 | Train_ACC 9.375
# EPOCH 1 | ITER 320 | AVG_LOSS 2.21931791305542 | Train_ACC 21.875
# EPOCH 1 | ITER 325 | AVG_LOSS 2.2965965270996094 | Train_ACC 21.875
# EPOCH 1 | ITER 330 | AVG_LOSS 2.1172149181365967 | Train_ACC 25.0
# EPOCH 1 | ITER 335 | AVG_LOSS 2.402785539627075 | Train_ACC 21.875
# EPOCH 1 | ITER 340 | AVG_LOSS 2.374127149581909 | Train_ACC 18.75
# EPOCH 1 | ITER 345 | AVG_LOSS 2.3162732124328613 | Train_ACC 18.75
# EPOCH 1 | ITER 350 | AVG_LOSS 2.448964834213257 | Train_ACC 9.375
# EPOCH 1 | ITER 355 | AVG_LOSS 2.2100441455841064 | Train_ACC 25.0
# EPOCH 1 | ITER 360 | AVG_LOSS 2.477978229522705 | Train_ACC 15.625
# EPOCH 1 | ITER 365 | AVG_LOSS 2.213970184326172 | Train_ACC 40.625
# EPOCH 1 | ITER 370 | AVG_LOSS 2.276686191558838 | Train_ACC 18.75
# Val Accuracy: 17.67%
# ****************************************
# test Accuracy: 16.74%
#
# --------------------------------------------------
# EPOCH 1 | LOSS 2.2580502033233643 | TIME 175.15128564834595
# --------------------------------------------------
#
# EPOCH 2 | ITER 0 | AVG_LOSS 2.229322910308838 | Train_ACC 31.25
# EPOCH 2 | ITER 5 | AVG_LOSS 2.246379852294922 | Train_ACC 12.5
# EPOCH 2 | ITER 10 | AVG_LOSS 2.3491454124450684 | Train_ACC 25.0
# EPOCH 2 | ITER 15 | AVG_LOSS 2.2724077701568604 | Train_ACC 12.5
# EPOCH 2 | ITER 20 | AVG_LOSS 2.39670991897583 | Train_ACC 15.625
# EPOCH 2 | ITER 25 | AVG_LOSS 2.2998123168945312 | Train_ACC 18.75
# EPOCH 2 | ITER 30 | AVG_LOSS 2.3184633255004883 | Train_ACC 15.625
# EPOCH 2 | ITER 35 | AVG_LOSS 2.3215811252593994 | Train_ACC 12.5
# EPOCH 2 | ITER 40 | AVG_LOSS 2.362635612487793 | Train_ACC 12.5
# EPOCH 2 | ITER 45 | AVG_LOSS 2.3376026153564453 | Train_ACC 21.875
# EPOCH 2 | ITER 50 | AVG_LOSS 2.349379777908325 | Train_ACC 12.5
# EPOCH 2 | ITER 55 | AVG_LOSS 2.356539487838745 | Train_ACC 18.75
# EPOCH 2 | ITER 60 | AVG_LOSS 2.543212652206421 | Train_ACC 3.125
# EPOCH 2 | ITER 65 | AVG_LOSS 2.6427407264709473 | Train_ACC 15.625
# EPOCH 2 | ITER 70 | AVG_LOSS 2.308851957321167 | Train_ACC 34.375
# EPOCH 2 | ITER 75 | AVG_LOSS 2.27199387550354 | Train_ACC 28.125
# EPOCH 2 | ITER 80 | AVG_LOSS 2.6903276443481445 | Train_ACC 0.0
# EPOCH 2 | ITER 85 | AVG_LOSS 2.1549346446990967 | Train_ACC 18.75
# EPOCH 2 | ITER 90 | AVG_LOSS 2.3033885955810547 | Train_ACC 15.625
# EPOCH 2 | ITER 95 | AVG_LOSS 2.234438896179199 | Train_ACC 25.0
# EPOCH 2 | ITER 100 | AVG_LOSS 2.2914366722106934 | Train_ACC 21.875
# EPOCH 2 | ITER 105 | AVG_LOSS 2.361077070236206 | Train_ACC 12.5
# EPOCH 2 | ITER 110 | AVG_LOSS 2.2224111557006836 | Train_ACC 21.875
# EPOCH 2 | ITER 115 | AVG_LOSS 2.3561837673187256 | Train_ACC 18.75
# EPOCH 2 | ITER 120 | AVG_LOSS 2.4154574871063232 | Train_ACC 18.75
# EPOCH 2 | ITER 125 | AVG_LOSS 2.4468801021575928 | Train_ACC 12.5
# EPOCH 2 | ITER 130 | AVG_LOSS 2.2262792587280273 | Train_ACC 21.875
# EPOCH 2 | ITER 135 | AVG_LOSS 2.2425029277801514 | Train_ACC 37.5
# EPOCH 2 | ITER 140 | AVG_LOSS 2.3318002223968506 | Train_ACC 21.875
# EPOCH 2 | ITER 145 | AVG_LOSS 2.4784839153289795 | Train_ACC 9.375
# EPOCH 2 | ITER 150 | AVG_LOSS 2.513279676437378 | Train_ACC 3.125
# EPOCH 2 | ITER 155 | AVG_LOSS 2.282994508743286 | Train_ACC 25.0
# EPOCH 2 | ITER 160 | AVG_LOSS 2.2413344383239746 | Train_ACC 21.875
# EPOCH 2 | ITER 165 | AVG_LOSS 2.3700356483459473 | Train_ACC 15.625
# EPOCH 2 | ITER 170 | AVG_LOSS 2.183384656906128 | Train_ACC 15.625
# EPOCH 2 | ITER 175 | AVG_LOSS 2.002441644668579 | Train_ACC 28.125
# EPOCH 2 | ITER 180 | AVG_LOSS 2.478745460510254 | Train_ACC 9.375
# EPOCH 2 | ITER 185 | AVG_LOSS 2.323606252670288 | Train_ACC 18.75
# EPOCH 2 | ITER 190 | AVG_LOSS 2.225430488586426 | Train_ACC 18.75
# EPOCH 2 | ITER 195 | AVG_LOSS 2.4098217487335205 | Train_ACC 9.375
# EPOCH 2 | ITER 200 | AVG_LOSS 2.477092742919922 | Train_ACC 18.75
# EPOCH 2 | ITER 205 | AVG_LOSS 2.3232150077819824 | Train_ACC 15.625
# EPOCH 2 | ITER 210 | AVG_LOSS 2.2984304428100586 | Train_ACC 25.0
# EPOCH 2 | ITER 215 | AVG_LOSS 2.1370460987091064 | Train_ACC 21.875
# EPOCH 2 | ITER 220 | AVG_LOSS 2.169064521789551 | Train_ACC 31.25
# EPOCH 2 | ITER 225 | AVG_LOSS 2.3001208305358887 | Train_ACC 18.75
# EPOCH 2 | ITER 230 | AVG_LOSS 2.272246837615967 | Train_ACC 21.875
# EPOCH 2 | ITER 235 | AVG_LOSS 2.232553720474243 | Train_ACC 21.875
# EPOCH 2 | ITER 240 | AVG_LOSS 2.1879782676696777 | Train_ACC 28.125
# EPOCH 2 | ITER 245 | AVG_LOSS 2.443042039871216 | Train_ACC 12.5
# EPOCH 2 | ITER 250 | AVG_LOSS 2.1585748195648193 | Train_ACC 28.125
# EPOCH 2 | ITER 255 | AVG_LOSS 2.126674175262451 | Train_ACC 25.0
# EPOCH 2 | ITER 260 | AVG_LOSS 2.554041862487793 | Train_ACC 15.625
# EPOCH 2 | ITER 265 | AVG_LOSS 2.193002939224243 | Train_ACC 18.75
# EPOCH 2 | ITER 270 | AVG_LOSS 2.313369035720825 | Train_ACC 9.375
# EPOCH 2 | ITER 275 | AVG_LOSS 2.297244071960449 | Train_ACC 12.5
# EPOCH 2 | ITER 280 | AVG_LOSS 2.3137903213500977 | Train_ACC 18.75
# EPOCH 2 | ITER 285 | AVG_LOSS 2.335542917251587 | Train_ACC 15.625
# EPOCH 2 | ITER 290 | AVG_LOSS 2.3835771083831787 | Train_ACC 15.625
# EPOCH 2 | ITER 295 | AVG_LOSS 2.3546221256256104 | Train_ACC 9.375
# EPOCH 2 | ITER 300 | AVG_LOSS 2.3027284145355225 | Train_ACC 18.75
# EPOCH 2 | ITER 305 | AVG_LOSS 2.2789576053619385 | Train_ACC 21.875
# EPOCH 2 | ITER 310 | AVG_LOSS 2.426055908203125 | Train_ACC 6.25
# EPOCH 2 | ITER 315 | AVG_LOSS 2.3700265884399414 | Train_ACC 15.625
# EPOCH 2 | ITER 320 | AVG_LOSS 2.154238700866699 | Train_ACC 31.25
# EPOCH 2 | ITER 325 | AVG_LOSS 2.3455798625946045 | Train_ACC 18.75
# EPOCH 2 | ITER 330 | AVG_LOSS 2.152897596359253 | Train_ACC 21.875
# EPOCH 2 | ITER 335 | AVG_LOSS 2.330099582672119 | Train_ACC 18.75
# EPOCH 2 | ITER 340 | AVG_LOSS 2.3576571941375732 | Train_ACC 9.375
# EPOCH 2 | ITER 345 | AVG_LOSS 2.2373838424682617 | Train_ACC 18.75
# EPOCH 2 | ITER 350 | AVG_LOSS 2.3447728157043457 | Train_ACC 6.25
# EPOCH 2 | ITER 355 | AVG_LOSS 2.2583861351013184 | Train_ACC 28.125
# EPOCH 2 | ITER 360 | AVG_LOSS 2.2962820529937744 | Train_ACC 18.75
# EPOCH 2 | ITER 365 | AVG_LOSS 2.2547895908355713 | Train_ACC 18.75
# EPOCH 2 | ITER 370 | AVG_LOSS 2.3436689376831055 | Train_ACC 6.25
# Val Accuracy: 23.79%
# ****************************************
# test Accuracy: 21.75%
#
# --------------------------------------------------
# EPOCH 2 | LOSS 2.2302610874176025 | TIME 174.87672114372253
# --------------------------------------------------
#
# EPOCH 3 | ITER 0 | AVG_LOSS 2.4272608757019043 | Train_ACC 9.375
# EPOCH 3 | ITER 5 | AVG_LOSS 2.412675380706787 | Train_ACC 25.0
# EPOCH 3 | ITER 10 | AVG_LOSS 2.2918288707733154 | Train_ACC 25.0
# EPOCH 3 | ITER 15 | AVG_LOSS 2.287015438079834 | Train_ACC 15.625
# EPOCH 3 | ITER 20 | AVG_LOSS 2.216062307357788 | Train_ACC 21.875
# EPOCH 3 | ITER 25 | AVG_LOSS 2.067064046859741 | Train_ACC 31.25
# EPOCH 3 | ITER 30 | AVG_LOSS 2.1872472763061523 | Train_ACC 18.75
# EPOCH 3 | ITER 35 | AVG_LOSS 2.2723708152770996 | Train_ACC 28.125
# EPOCH 3 | ITER 40 | AVG_LOSS 2.346127510070801 | Train_ACC 15.625
# EPOCH 3 | ITER 45 | AVG_LOSS 2.330049753189087 | Train_ACC 21.875
# EPOCH 3 | ITER 50 | AVG_LOSS 2.3582682609558105 | Train_ACC 15.625
# EPOCH 3 | ITER 55 | AVG_LOSS 2.3814048767089844 | Train_ACC 12.5
# EPOCH 3 | ITER 60 | AVG_LOSS 2.3205370903015137 | Train_ACC 12.5
# EPOCH 3 | ITER 65 | AVG_LOSS 2.109215497970581 | Train_ACC 31.25
# EPOCH 3 | ITER 70 | AVG_LOSS 2.132936954498291 | Train_ACC 21.875
# EPOCH 3 | ITER 75 | AVG_LOSS 2.1813297271728516 | Train_ACC 28.125
# EPOCH 3 | ITER 80 | AVG_LOSS 2.195307493209839 | Train_ACC 21.875
# EPOCH 3 | ITER 85 | AVG_LOSS 2.2871041297912598 | Train_ACC 15.625
# EPOCH 3 | ITER 90 | AVG_LOSS 2.2422420978546143 | Train_ACC 12.5
# EPOCH 3 | ITER 95 | AVG_LOSS 2.3240230083465576 | Train_ACC 12.5
# EPOCH 3 | ITER 100 | AVG_LOSS 2.297034740447998 | Train_ACC 21.875
# EPOCH 3 | ITER 105 | AVG_LOSS 2.1289780139923096 | Train_ACC 28.125
# EPOCH 3 | ITER 110 | AVG_LOSS 2.313830852508545 | Train_ACC 18.75
# EPOCH 3 | ITER 115 | AVG_LOSS 2.5270121097564697 | Train_ACC 12.5
# EPOCH 3 | ITER 120 | AVG_LOSS 2.307453155517578 | Train_ACC 21.875
# EPOCH 3 | ITER 125 | AVG_LOSS 2.422135591506958 | Train_ACC 15.625
# EPOCH 3 | ITER 130 | AVG_LOSS 2.123533010482788 | Train_ACC 21.875
# EPOCH 3 | ITER 135 | AVG_LOSS 2.416248083114624 | Train_ACC 18.75
# EPOCH 3 | ITER 140 | AVG_LOSS 2.243786573410034 | Train_ACC 21.875
# EPOCH 3 | ITER 145 | AVG_LOSS 2.3150055408477783 | Train_ACC 18.75
# EPOCH 3 | ITER 150 | AVG_LOSS 2.308889150619507 | Train_ACC 31.25
# EPOCH 3 | ITER 155 | AVG_LOSS 2.1530749797821045 | Train_ACC 28.125
# EPOCH 3 | ITER 160 | AVG_LOSS 2.018972158432007 | Train_ACC 25.0
# EPOCH 3 | ITER 165 | AVG_LOSS 2.4481048583984375 | Train_ACC 9.375
# EPOCH 3 | ITER 170 | AVG_LOSS 2.146395206451416 | Train_ACC 18.75
# EPOCH 3 | ITER 175 | AVG_LOSS 2.3359506130218506 | Train_ACC 18.75
# EPOCH 3 | ITER 180 | AVG_LOSS 2.247852087020874 | Train_ACC 6.25
# EPOCH 3 | ITER 185 | AVG_LOSS 2.0352416038513184 | Train_ACC 34.375
# EPOCH 3 | ITER 190 | AVG_LOSS 2.1241440773010254 | Train_ACC 28.125
# EPOCH 3 | ITER 195 | AVG_LOSS 2.2911195755004883 | Train_ACC 12.5
# EPOCH 3 | ITER 200 | AVG_LOSS 2.2210633754730225 | Train_ACC 18.75
# EPOCH 3 | ITER 205 | AVG_LOSS 2.3594586849212646 | Train_ACC 25.0
# EPOCH 3 | ITER 210 | AVG_LOSS 2.380765438079834 | Train_ACC 9.375
# EPOCH 3 | ITER 215 | AVG_LOSS 2.415618658065796 | Train_ACC 15.625
# EPOCH 3 | ITER 220 | AVG_LOSS 2.1504573822021484 | Train_ACC 21.875
# EPOCH 3 | ITER 225 | AVG_LOSS 2.250230550765991 | Train_ACC 18.75
# EPOCH 3 | ITER 230 | AVG_LOSS 2.2046947479248047 | Train_ACC 15.625
# EPOCH 3 | ITER 235 | AVG_LOSS 2.3994247913360596 | Train_ACC 6.25
# EPOCH 3 | ITER 240 | AVG_LOSS 2.0999057292938232 | Train_ACC 25.0
# EPOCH 3 | ITER 245 | AVG_LOSS 2.180811882019043 | Train_ACC 18.75
# EPOCH 3 | ITER 250 | AVG_LOSS 2.272764205932617 | Train_ACC 21.875
# EPOCH 3 | ITER 255 | AVG_LOSS 2.1358470916748047 | Train_ACC 18.75
# EPOCH 3 | ITER 260 | AVG_LOSS 2.2329413890838623 | Train_ACC 18.75
# EPOCH 3 | ITER 265 | AVG_LOSS 2.2703359127044678 | Train_ACC 21.875
# EPOCH 3 | ITER 270 | AVG_LOSS 2.4078328609466553 | Train_ACC 9.375
# EPOCH 3 | ITER 275 | AVG_LOSS 2.301387071609497 | Train_ACC 6.25
# EPOCH 3 | ITER 280 | AVG_LOSS 2.149228096008301 | Train_ACC 31.25
# EPOCH 3 | ITER 285 | AVG_LOSS 2.1785919666290283 | Train_ACC 18.75
# EPOCH 3 | ITER 290 | AVG_LOSS 2.198673725128174 | Train_ACC 25.0
# EPOCH 3 | ITER 295 | AVG_LOSS 2.267470359802246 | Train_ACC 31.25
# EPOCH 3 | ITER 300 | AVG_LOSS 2.3712594509124756 | Train_ACC 15.625
# EPOCH 3 | ITER 305 | AVG_LOSS 2.2337801456451416 | Train_ACC 28.125
# EPOCH 3 | ITER 310 | AVG_LOSS 2.1914045810699463 | Train_ACC 18.75
# EPOCH 3 | ITER 315 | AVG_LOSS 2.1392054557800293 | Train_ACC 28.125
# EPOCH 3 | ITER 320 | AVG_LOSS 2.248642683029175 | Train_ACC 12.5
# EPOCH 3 | ITER 325 | AVG_LOSS 2.195772171020508 | Train_ACC 28.125
# EPOCH 3 | ITER 330 | AVG_LOSS 2.135310173034668 | Train_ACC 31.25
# EPOCH 3 | ITER 335 | AVG_LOSS 2.4146628379821777 | Train_ACC 18.75
# EPOCH 3 | ITER 340 | AVG_LOSS 2.184749126434326 | Train_ACC 28.125
# EPOCH 3 | ITER 345 | AVG_LOSS 2.254582405090332 | Train_ACC 18.75
# EPOCH 3 | ITER 350 | AVG_LOSS 2.3882980346679688 | Train_ACC 15.625
# EPOCH 3 | ITER 355 | AVG_LOSS 2.3418500423431396 | Train_ACC 12.5
# EPOCH 3 | ITER 360 | AVG_LOSS 2.2363603115081787 | Train_ACC 15.625
# EPOCH 3 | ITER 365 | AVG_LOSS 2.405519485473633 | Train_ACC 12.5
# EPOCH 3 | ITER 370 | AVG_LOSS 2.1958298683166504 | Train_ACC 18.75
# Val Accuracy: 24.39%
# ****************************************
# test Accuracy: 22.35%
#
# --------------------------------------------------
# EPOCH 3 | LOSS 2.25883412361145 | TIME 174.68310952186584
# --------------------------------------------------
#
# EPOCH 4 | ITER 0 | AVG_LOSS 2.172973871231079 | Train_ACC 25.0
# EPOCH 4 | ITER 5 | AVG_LOSS 2.1655948162078857 | Train_ACC 25.0
# EPOCH 4 | ITER 10 | AVG_LOSS 2.2585012912750244 | Train_ACC 21.875
# EPOCH 4 | ITER 15 | AVG_LOSS 1.889260172843933 | Train_ACC 40.625
# EPOCH 4 | ITER 20 | AVG_LOSS 2.3623440265655518 | Train_ACC 9.375
# EPOCH 4 | ITER 25 | AVG_LOSS 2.256756544113159 | Train_ACC 28.125
# EPOCH 4 | ITER 30 | AVG_LOSS 2.0857653617858887 | Train_ACC 25.0
# EPOCH 4 | ITER 35 | AVG_LOSS 2.42258358001709 | Train_ACC 18.75
# EPOCH 4 | ITER 40 | AVG_LOSS 2.2666187286376953 | Train_ACC 15.625
# EPOCH 4 | ITER 45 | AVG_LOSS 2.3487954139709473 | Train_ACC 18.75
# EPOCH 4 | ITER 50 | AVG_LOSS 2.353738307952881 | Train_ACC 18.75
# EPOCH 4 | ITER 55 | AVG_LOSS 2.7638909816741943 | Train_ACC 12.5
# EPOCH 4 | ITER 60 | AVG_LOSS 2.0442886352539062 | Train_ACC 31.25
# EPOCH 4 | ITER 65 | AVG_LOSS 2.252455472946167 | Train_ACC 21.875
# EPOCH 4 | ITER 70 | AVG_LOSS 2.11856746673584 | Train_ACC 28.125
# EPOCH 4 | ITER 75 | AVG_LOSS 2.373061418533325 | Train_ACC 9.375
# EPOCH 4 | ITER 80 | AVG_LOSS 2.397772789001465 | Train_ACC 9.375
# EPOCH 4 | ITER 85 | AVG_LOSS 2.217226982116699 | Train_ACC 25.0
# EPOCH 4 | ITER 90 | AVG_LOSS 2.017585515975952 | Train_ACC 28.125
# EPOCH 4 | ITER 95 | AVG_LOSS 2.1670780181884766 | Train_ACC 18.75
# EPOCH 4 | ITER 100 | AVG_LOSS 2.206068754196167 | Train_ACC 12.5
# EPOCH 4 | ITER 105 | AVG_LOSS 2.3276207447052 | Train_ACC 28.125
# EPOCH 4 | ITER 110 | AVG_LOSS 2.421203136444092 | Train_ACC 21.875
# EPOCH 4 | ITER 115 | AVG_LOSS 2.207331418991089 | Train_ACC 25.0
# EPOCH 4 | ITER 120 | AVG_LOSS 2.366410970687866 | Train_ACC 25.0
# EPOCH 4 | ITER 125 | AVG_LOSS 2.2268753051757812 | Train_ACC 18.75
# EPOCH 4 | ITER 130 | AVG_LOSS 2.2392070293426514 | Train_ACC 31.25
# EPOCH 4 | ITER 135 | AVG_LOSS 2.290956735610962 | Train_ACC 18.75
# EPOCH 4 | ITER 140 | AVG_LOSS 2.1446471214294434 | Train_ACC 28.125
# EPOCH 4 | ITER 145 | AVG_LOSS 2.3590519428253174 | Train_ACC 12.5
# EPOCH 4 | ITER 150 | AVG_LOSS 2.302973985671997 | Train_ACC 15.625
# EPOCH 4 | ITER 155 | AVG_LOSS 2.195286989212036 | Train_ACC 28.125
# EPOCH 4 | ITER 160 | AVG_LOSS 2.025238513946533 | Train_ACC 34.375
# EPOCH 4 | ITER 165 | AVG_LOSS 2.3745460510253906 | Train_ACC 15.625
# EPOCH 4 | ITER 170 | AVG_LOSS 2.1474051475524902 | Train_ACC 31.25
# EPOCH 4 | ITER 175 | AVG_LOSS 2.059149742126465 | Train_ACC 34.375
# EPOCH 4 | ITER 180 | AVG_LOSS 1.9905966520309448 | Train_ACC 34.375
# EPOCH 4 | ITER 185 | AVG_LOSS 2.4650604724884033 | Train_ACC 15.625
# EPOCH 4 | ITER 190 | AVG_LOSS 2.158385753631592 | Train_ACC 25.0
# EPOCH 4 | ITER 195 | AVG_LOSS 2.2821805477142334 | Train_ACC 21.875
# EPOCH 4 | ITER 200 | AVG_LOSS 2.346757411956787 | Train_ACC 21.875
# EPOCH 4 | ITER 205 | AVG_LOSS 2.139380931854248 | Train_ACC 34.375
# EPOCH 4 | ITER 210 | AVG_LOSS 2.227766752243042 | Train_ACC 15.625
# EPOCH 4 | ITER 215 | AVG_LOSS 2.3761839866638184 | Train_ACC 25.0
# EPOCH 4 | ITER 220 | AVG_LOSS 2.327387809753418 | Train_ACC 12.5
# EPOCH 4 | ITER 225 | AVG_LOSS 2.2278366088867188 | Train_ACC 15.625
# EPOCH 4 | ITER 230 | AVG_LOSS 2.2072558403015137 | Train_ACC 18.75
# EPOCH 4 | ITER 235 | AVG_LOSS 2.110790252685547 | Train_ACC 25.0
# EPOCH 4 | ITER 240 | AVG_LOSS 2.234126091003418 | Train_ACC 21.875
# EPOCH 4 | ITER 245 | AVG_LOSS 2.2463467121124268 | Train_ACC 25.0
# EPOCH 4 | ITER 250 | AVG_LOSS 2.495765447616577 | Train_ACC 3.125
# EPOCH 4 | ITER 255 | AVG_LOSS 2.347935914993286 | Train_ACC 6.25
# EPOCH 4 | ITER 260 | AVG_LOSS 2.1033825874328613 | Train_ACC 18.75
# EPOCH 4 | ITER 265 | AVG_LOSS 2.24017071723938 | Train_ACC 31.25
# EPOCH 4 | ITER 270 | AVG_LOSS 2.1432747840881348 | Train_ACC 34.375
# EPOCH 4 | ITER 275 | AVG_LOSS 2.1872103214263916 | Train_ACC 31.25
# EPOCH 4 | ITER 280 | AVG_LOSS 2.112363815307617 | Train_ACC 25.0
# EPOCH 4 | ITER 285 | AVG_LOSS 2.1350185871124268 | Train_ACC 15.625
# EPOCH 4 | ITER 290 | AVG_LOSS 2.310452461242676 | Train_ACC 12.5
# EPOCH 4 | ITER 295 | AVG_LOSS 2.179652452468872 | Train_ACC 28.125
# EPOCH 4 | ITER 300 | AVG_LOSS 2.282060146331787 | Train_ACC 9.375
# EPOCH 4 | ITER 305 | AVG_LOSS 2.299337387084961 | Train_ACC 18.75
# EPOCH 4 | ITER 310 | AVG_LOSS 2.2083702087402344 | Train_ACC 18.75
# EPOCH 4 | ITER 315 | AVG_LOSS 2.015871047973633 | Train_ACC 25.0
# EPOCH 4 | ITER 320 | AVG_LOSS 2.380875825881958 | Train_ACC 15.625
# EPOCH 4 | ITER 325 | AVG_LOSS 2.279822587966919 | Train_ACC 18.75
# EPOCH 4 | ITER 330 | AVG_LOSS 2.2653841972351074 | Train_ACC 9.375
# EPOCH 4 | ITER 335 | AVG_LOSS 2.3695008754730225 | Train_ACC 9.375
# EPOCH 4 | ITER 340 | AVG_LOSS 2.2608802318573 | Train_ACC 21.875
# EPOCH 4 | ITER 345 | AVG_LOSS 2.255382537841797 | Train_ACC 21.875
# EPOCH 4 | ITER 350 | AVG_LOSS 2.2963459491729736 | Train_ACC 21.875
# EPOCH 4 | ITER 355 | AVG_LOSS 2.479520559310913 | Train_ACC 6.25
# EPOCH 4 | ITER 360 | AVG_LOSS 2.5381810665130615 | Train_ACC 9.375
# EPOCH 4 | ITER 365 | AVG_LOSS 2.1804559230804443 | Train_ACC 28.125
# EPOCH 4 | ITER 370 | AVG_LOSS 2.2453720569610596 | Train_ACC 25.0
# Val Accuracy: 21.99%
# ****************************************
# test Accuracy: 21.28%
#
# --------------------------------------------------
# EPOCH 4 | LOSS 2.136561393737793 | TIME 175.54514026641846
# --------------------------------------------------
#
# EPOCH 5 | ITER 0 | AVG_LOSS 2.095411539077759 | Train_ACC 28.125
# EPOCH 5 | ITER 5 | AVG_LOSS 2.2155988216400146 | Train_ACC 18.75
# EPOCH 5 | ITER 10 | AVG_LOSS 2.2115378379821777 | Train_ACC 15.625
# EPOCH 5 | ITER 15 | AVG_LOSS 2.340118408203125 | Train_ACC 15.625
# EPOCH 5 | ITER 20 | AVG_LOSS 2.1377644538879395 | Train_ACC 18.75
# EPOCH 5 | ITER 25 | AVG_LOSS 2.200209140777588 | Train_ACC 28.125
# EPOCH 5 | ITER 30 | AVG_LOSS 2.2258572578430176 | Train_ACC 31.25
# EPOCH 5 | ITER 35 | AVG_LOSS 2.1438241004943848 | Train_ACC 18.75
# EPOCH 5 | ITER 40 | AVG_LOSS 2.2700836658477783 | Train_ACC 12.5
# EPOCH 5 | ITER 45 | AVG_LOSS 2.292109489440918 | Train_ACC 21.875
# EPOCH 5 | ITER 50 | AVG_LOSS 2.4375975131988525 | Train_ACC 21.875
# EPOCH 5 | ITER 55 | AVG_LOSS 2.1725704669952393 | Train_ACC 18.75
# EPOCH 5 | ITER 60 | AVG_LOSS 2.065152406692505 | Train_ACC 28.125
# EPOCH 5 | ITER 65 | AVG_LOSS 2.5167930126190186 | Train_ACC 3.125
# EPOCH 5 | ITER 70 | AVG_LOSS 2.2527968883514404 | Train_ACC 28.125
# EPOCH 5 | ITER 75 | AVG_LOSS 2.0799756050109863 | Train_ACC 21.875
# EPOCH 5 | ITER 80 | AVG_LOSS 2.323775053024292 | Train_ACC 12.5
# EPOCH 5 | ITER 85 | AVG_LOSS 2.0791468620300293 | Train_ACC 21.875
# EPOCH 5 | ITER 90 | AVG_LOSS 2.3638503551483154 | Train_ACC 18.75
# EPOCH 5 | ITER 95 | AVG_LOSS 2.192516565322876 | Train_ACC 31.25
# EPOCH 5 | ITER 100 | AVG_LOSS 2.242459297180176 | Train_ACC 18.75
# EPOCH 5 | ITER 105 | AVG_LOSS 2.206556558609009 | Train_ACC 25.0
# EPOCH 5 | ITER 110 | AVG_LOSS 2.1640772819519043 | Train_ACC 12.5
# EPOCH 5 | ITER 115 | AVG_LOSS 2.3518025875091553 | Train_ACC 21.875
# EPOCH 5 | ITER 120 | AVG_LOSS 2.3604087829589844 | Train_ACC 12.5
# EPOCH 5 | ITER 125 | AVG_LOSS 2.063443660736084 | Train_ACC 21.875
# EPOCH 5 | ITER 130 | AVG_LOSS 2.206817150115967 | Train_ACC 15.625
# EPOCH 5 | ITER 135 | AVG_LOSS 2.4896254539489746 | Train_ACC 18.75
# EPOCH 5 | ITER 140 | AVG_LOSS 1.942466378211975 | Train_ACC 31.25
# EPOCH 5 | ITER 145 | AVG_LOSS 2.092273473739624 | Train_ACC 34.375
# EPOCH 5 | ITER 150 | AVG_LOSS 2.1131229400634766 | Train_ACC 21.875
# EPOCH 5 | ITER 155 | AVG_LOSS 2.2303898334503174 | Train_ACC 15.625
# EPOCH 5 | ITER 160 | AVG_LOSS 2.1892664432525635 | Train_ACC 21.875
# EPOCH 5 | ITER 165 | AVG_LOSS 2.0893123149871826 | Train_ACC 34.375
# EPOCH 5 | ITER 170 | AVG_LOSS 2.307523250579834 | Train_ACC 15.625
# EPOCH 5 | ITER 175 | AVG_LOSS 2.2882637977600098 | Train_ACC 9.375
# EPOCH 5 | ITER 180 | AVG_LOSS 2.2862510681152344 | Train_ACC 21.875
# EPOCH 5 | ITER 185 | AVG_LOSS 2.0810258388519287 | Train_ACC 34.375
# EPOCH 5 | ITER 190 | AVG_LOSS 2.0673484802246094 | Train_ACC 34.375
# EPOCH 5 | ITER 195 | AVG_LOSS 1.977530598640442 | Train_ACC 31.25
# EPOCH 5 | ITER 200 | AVG_LOSS 2.3674280643463135 | Train_ACC 21.875
# EPOCH 5 | ITER 205 | AVG_LOSS 2.120105028152466 | Train_ACC 34.375
# EPOCH 5 | ITER 210 | AVG_LOSS 2.4357550144195557 | Train_ACC 12.5
# EPOCH 5 | ITER 215 | AVG_LOSS 2.093292236328125 | Train_ACC 28.125
# EPOCH 5 | ITER 220 | AVG_LOSS 2.21585750579834 | Train_ACC 28.125
# EPOCH 5 | ITER 225 | AVG_LOSS 2.0584053993225098 | Train_ACC 31.25
# EPOCH 5 | ITER 230 | AVG_LOSS 2.1356258392333984 | Train_ACC 28.125
# EPOCH 5 | ITER 235 | AVG_LOSS 2.1571717262268066 | Train_ACC 21.875
# EPOCH 5 | ITER 240 | AVG_LOSS 2.145693063735962 | Train_ACC 12.5
# EPOCH 5 | ITER 245 | AVG_LOSS 2.100924015045166 | Train_ACC 21.875
# EPOCH 5 | ITER 250 | AVG_LOSS 2.095486879348755 | Train_ACC 18.75
# EPOCH 5 | ITER 255 | AVG_LOSS 2.175736427307129 | Train_ACC 25.0
# EPOCH 5 | ITER 260 | AVG_LOSS 2.266425609588623 | Train_ACC 18.75
# EPOCH 5 | ITER 265 | AVG_LOSS 2.193524122238159 | Train_ACC 25.0
# EPOCH 5 | ITER 270 | AVG_LOSS 2.105214834213257 | Train_ACC 18.75
# EPOCH 5 | ITER 275 | AVG_LOSS 2.2305407524108887 | Train_ACC 28.125
# EPOCH 5 | ITER 280 | AVG_LOSS 2.1714365482330322 | Train_ACC 25.0
# EPOCH 5 | ITER 285 | AVG_LOSS 2.155264377593994 | Train_ACC 21.875
# EPOCH 5 | ITER 290 | AVG_LOSS 2.0548579692840576 | Train_ACC 25.0
# EPOCH 5 | ITER 295 | AVG_LOSS 2.211604118347168 | Train_ACC 15.625
# EPOCH 5 | ITER 300 | AVG_LOSS 2.2343790531158447 | Train_ACC 34.375
# EPOCH 5 | ITER 305 | AVG_LOSS 2.4164183139801025 | Train_ACC 18.75
# EPOCH 5 | ITER 310 | AVG_LOSS 2.029613971710205 | Train_ACC 28.125
# EPOCH 5 | ITER 315 | AVG_LOSS 2.1781017780303955 | Train_ACC 25.0
# EPOCH 5 | ITER 320 | AVG_LOSS 2.186603307723999 | Train_ACC 18.75
# EPOCH 5 | ITER 325 | AVG_LOSS 2.1838719844818115 | Train_ACC 25.0
# EPOCH 5 | ITER 330 | AVG_LOSS 2.1984832286834717 | Train_ACC 21.875
# EPOCH 5 | ITER 335 | AVG_LOSS 2.043565273284912 | Train_ACC 28.125
# EPOCH 5 | ITER 340 | AVG_LOSS 2.245786666870117 | Train_ACC 9.375
# EPOCH 5 | ITER 345 | AVG_LOSS 2.3239023685455322 | Train_ACC 21.875
# EPOCH 5 | ITER 350 | AVG_LOSS 2.3355977535247803 | Train_ACC 21.875
# EPOCH 5 | ITER 355 | AVG_LOSS 2.1316065788269043 | Train_ACC 25.0
# EPOCH 5 | ITER 360 | AVG_LOSS 2.169776201248169 | Train_ACC 31.25
# EPOCH 5 | ITER 365 | AVG_LOSS 2.312976360321045 | Train_ACC 9.375
# EPOCH 5 | ITER 370 | AVG_LOSS 2.2009735107421875 | Train_ACC 25.0
# Val Accuracy: 25.05%
# ****************************************
# test Accuracy: 23.02%
#
# --------------------------------------------------
# EPOCH 5 | LOSS 2.3745453357696533 | TIME 177.87241530418396
# --------------------------------------------------
#
# EPOCH 6 | ITER 0 | AVG_LOSS 2.1682381629943848 | Train_ACC 21.875
# EPOCH 6 | ITER 5 | AVG_LOSS 2.2073092460632324 | Train_ACC 18.75
# EPOCH 6 | ITER 10 | AVG_LOSS 2.2289884090423584 | Train_ACC 12.5
# EPOCH 6 | ITER 15 | AVG_LOSS 2.2729227542877197 | Train_ACC 18.75
# EPOCH 6 | ITER 20 | AVG_LOSS 2.2222182750701904 | Train_ACC 31.25
# EPOCH 6 | ITER 25 | AVG_LOSS 2.2031443119049072 | Train_ACC 18.75
# EPOCH 6 | ITER 30 | AVG_LOSS 2.2497377395629883 | Train_ACC 9.375
# EPOCH 6 | ITER 35 | AVG_LOSS 2.222642421722412 | Train_ACC 18.75
# EPOCH 6 | ITER 40 | AVG_LOSS 2.1799657344818115 | Train_ACC 9.375
# EPOCH 6 | ITER 45 | AVG_LOSS 2.016669511795044 | Train_ACC 21.875
# EPOCH 6 | ITER 50 | AVG_LOSS 2.101743698120117 | Train_ACC 34.375
# EPOCH 6 | ITER 55 | AVG_LOSS 2.008465528488159 | Train_ACC 21.875
# EPOCH 6 | ITER 60 | AVG_LOSS 2.1591320037841797 | Train_ACC 15.625
# EPOCH 6 | ITER 65 | AVG_LOSS 1.9666658639907837 | Train_ACC 37.5
# EPOCH 6 | ITER 70 | AVG_LOSS 2.272871255874634 | Train_ACC 31.25
# EPOCH 6 | ITER 75 | AVG_LOSS 2.1299822330474854 | Train_ACC 12.5
# EPOCH 6 | ITER 80 | AVG_LOSS 2.141507863998413 | Train_ACC 21.875
# EPOCH 6 | ITER 85 | AVG_LOSS 2.101062774658203 | Train_ACC 18.75
# EPOCH 6 | ITER 90 | AVG_LOSS 2.0402286052703857 | Train_ACC 37.5
# EPOCH 6 | ITER 95 | AVG_LOSS 2.238767147064209 | Train_ACC 15.625
# EPOCH 6 | ITER 100 | AVG_LOSS 2.1559016704559326 | Train_ACC 25.0
# EPOCH 6 | ITER 105 | AVG_LOSS 1.9746787548065186 | Train_ACC 18.75
# EPOCH 6 | ITER 110 | AVG_LOSS 2.3629534244537354 | Train_ACC 12.5
# EPOCH 6 | ITER 115 | AVG_LOSS 2.3098604679107666 | Train_ACC 18.75
# EPOCH 6 | ITER 120 | AVG_LOSS 2.2413437366485596 | Train_ACC 15.625
# EPOCH 6 | ITER 125 | AVG_LOSS 2.197929859161377 | Train_ACC 18.75
# EPOCH 6 | ITER 130 | AVG_LOSS 2.0877504348754883 | Train_ACC 25.0
# EPOCH 6 | ITER 135 | AVG_LOSS 2.0229809284210205 | Train_ACC 25.0
# EPOCH 6 | ITER 140 | AVG_LOSS 2.161098003387451 | Train_ACC 40.625
# EPOCH 6 | ITER 145 | AVG_LOSS 2.1283695697784424 | Train_ACC 25.0
# EPOCH 6 | ITER 150 | AVG_LOSS 1.9917768239974976 | Train_ACC 21.875
# EPOCH 6 | ITER 155 | AVG_LOSS 2.106259346008301 | Train_ACC 9.375
# EPOCH 6 | ITER 160 | AVG_LOSS 2.1750762462615967 | Train_ACC 15.625
# EPOCH 6 | ITER 165 | AVG_LOSS 2.0581560134887695 | Train_ACC 25.0
# EPOCH 6 | ITER 170 | AVG_LOSS 2.100611686706543 | Train_ACC 34.375
# EPOCH 6 | ITER 175 | AVG_LOSS 2.2984912395477295 | Train_ACC 12.5
# EPOCH 6 | ITER 180 | AVG_LOSS 2.233274459838867 | Train_ACC 12.5
# EPOCH 6 | ITER 185 | AVG_LOSS 2.285031795501709 | Train_ACC 21.875
# EPOCH 6 | ITER 190 | AVG_LOSS 2.3636560440063477 | Train_ACC 6.25
# EPOCH 6 | ITER 195 | AVG_LOSS 2.1572957038879395 | Train_ACC 28.125
# EPOCH 6 | ITER 200 | AVG_LOSS 2.0186116695404053 | Train_ACC 31.25
# EPOCH 6 | ITER 205 | AVG_LOSS 2.2564594745635986 | Train_ACC 28.125
# EPOCH 6 | ITER 210 | AVG_LOSS 2.0006251335144043 | Train_ACC 21.875
# EPOCH 6 | ITER 215 | AVG_LOSS 2.1245059967041016 | Train_ACC 25.0
# EPOCH 6 | ITER 220 | AVG_LOSS 2.0521280765533447 | Train_ACC 31.25
# EPOCH 6 | ITER 225 | AVG_LOSS 2.0398387908935547 | Train_ACC 28.125
# EPOCH 6 | ITER 230 | AVG_LOSS 1.8726811408996582 | Train_ACC 28.125
# EPOCH 6 | ITER 235 | AVG_LOSS 2.058590888977051 | Train_ACC 21.875
# EPOCH 6 | ITER 240 | AVG_LOSS 1.9411529302597046 | Train_ACC 25.0
# EPOCH 6 | ITER 245 | AVG_LOSS 2.2930068969726562 | Train_ACC 31.25
# EPOCH 6 | ITER 250 | AVG_LOSS 2.3660032749176025 | Train_ACC 6.25
# EPOCH 6 | ITER 255 | AVG_LOSS 2.139133930206299 | Train_ACC 31.25
# EPOCH 6 | ITER 260 | AVG_LOSS 2.2672486305236816 | Train_ACC 18.75
# EPOCH 6 | ITER 265 | AVG_LOSS 2.370899200439453 | Train_ACC 6.25
# EPOCH 6 | ITER 270 | AVG_LOSS 2.2383034229278564 | Train_ACC 15.625
# EPOCH 6 | ITER 275 | AVG_LOSS 1.9989451169967651 | Train_ACC 21.875
# EPOCH 6 | ITER 280 | AVG_LOSS 1.906853199005127 | Train_ACC 37.5
# EPOCH 6 | ITER 285 | AVG_LOSS 2.003019094467163 | Train_ACC 12.5
# EPOCH 6 | ITER 290 | AVG_LOSS 2.0710816383361816 | Train_ACC 18.75
# EPOCH 6 | ITER 295 | AVG_LOSS 2.222271680831909 | Train_ACC 18.75
# EPOCH 6 | ITER 300 | AVG_LOSS 2.3020503520965576 | Train_ACC 18.75
# EPOCH 6 | ITER 305 | AVG_LOSS 2.295485019683838 | Train_ACC 18.75
# EPOCH 6 | ITER 310 | AVG_LOSS 2.3452703952789307 | Train_ACC 18.75
# EPOCH 6 | ITER 315 | AVG_LOSS 2.206233263015747 | Train_ACC 18.75
# EPOCH 6 | ITER 320 | AVG_LOSS 2.311938762664795 | Train_ACC 31.25
# EPOCH 6 | ITER 325 | AVG_LOSS 2.111774444580078 | Train_ACC 28.125
# EPOCH 6 | ITER 330 | AVG_LOSS 2.289369821548462 | Train_ACC 12.5
# EPOCH 6 | ITER 335 | AVG_LOSS 1.9352080821990967 | Train_ACC 28.125
# EPOCH 6 | ITER 340 | AVG_LOSS 1.9672974348068237 | Train_ACC 25.0
# EPOCH 6 | ITER 345 | AVG_LOSS 2.3257670402526855 | Train_ACC 18.75
# EPOCH 6 | ITER 350 | AVG_LOSS 1.9968218803405762 | Train_ACC 34.375
# EPOCH 6 | ITER 355 | AVG_LOSS 2.3702869415283203 | Train_ACC 21.875
# EPOCH 6 | ITER 360 | AVG_LOSS 1.9874591827392578 | Train_ACC 34.375
# EPOCH 6 | ITER 365 | AVG_LOSS 1.9995265007019043 | Train_ACC 25.0
# EPOCH 6 | ITER 370 | AVG_LOSS 2.2030842304229736 | Train_ACC 12.5
# Val Accuracy: 23.92%
# ****************************************
# test Accuracy: 23.68%
#
# --------------------------------------------------
# EPOCH 6 | LOSS 2.245811939239502 | TIME 178.4754831790924
# --------------------------------------------------
#
# EPOCH 7 | ITER 0 | AVG_LOSS 2.3603804111480713 | Train_ACC 12.5
# EPOCH 7 | ITER 5 | AVG_LOSS 1.9766353368759155 | Train_ACC 31.25
# EPOCH 7 | ITER 10 | AVG_LOSS 2.2773077487945557 | Train_ACC 25.0
# EPOCH 7 | ITER 15 | AVG_LOSS 2.165992259979248 | Train_ACC 34.375
# EPOCH 7 | ITER 20 | AVG_LOSS 2.2362747192382812 | Train_ACC 18.75
# EPOCH 7 | ITER 25 | AVG_LOSS 2.115166664123535 | Train_ACC 18.75
# EPOCH 7 | ITER 30 | AVG_LOSS 1.9878535270690918 | Train_ACC 34.375
# EPOCH 7 | ITER 35 | AVG_LOSS 2.042851209640503 | Train_ACC 31.25
# EPOCH 7 | ITER 40 | AVG_LOSS 2.4703946113586426 | Train_ACC 15.625
# EPOCH 7 | ITER 45 | AVG_LOSS 2.3072500228881836 | Train_ACC 18.75
# EPOCH 7 | ITER 50 | AVG_LOSS 2.0367040634155273 | Train_ACC 28.125
# EPOCH 7 | ITER 55 | AVG_LOSS 2.0136003494262695 | Train_ACC 31.25
# EPOCH 7 | ITER 60 | AVG_LOSS 2.01987886428833 | Train_ACC 25.0
# EPOCH 7 | ITER 65 | AVG_LOSS 2.371156692504883 | Train_ACC 21.875
# EPOCH 7 | ITER 70 | AVG_LOSS 2.326179265975952 | Train_ACC 15.625
# EPOCH 7 | ITER 75 | AVG_LOSS 2.150956153869629 | Train_ACC 34.375
# EPOCH 7 | ITER 80 | AVG_LOSS 2.2300822734832764 | Train_ACC 15.625
# EPOCH 7 | ITER 85 | AVG_LOSS 1.9800946712493896 | Train_ACC 25.0
# EPOCH 7 | ITER 90 | AVG_LOSS 2.117182731628418 | Train_ACC 15.625
# EPOCH 7 | ITER 95 | AVG_LOSS 2.1791834831237793 | Train_ACC 25.0
# EPOCH 7 | ITER 100 | AVG_LOSS 2.0895040035247803 | Train_ACC 37.5
# EPOCH 7 | ITER 105 | AVG_LOSS 1.9707574844360352 | Train_ACC 25.0
# EPOCH 7 | ITER 110 | AVG_LOSS 2.1408398151397705 | Train_ACC 25.0
# EPOCH 7 | ITER 115 | AVG_LOSS 2.281834125518799 | Train_ACC 25.0
# EPOCH 7 | ITER 120 | AVG_LOSS 1.8366565704345703 | Train_ACC 28.125
# EPOCH 7 | ITER 125 | AVG_LOSS 1.9833945035934448 | Train_ACC 43.75
# EPOCH 7 | ITER 130 | AVG_LOSS 1.9361647367477417 | Train_ACC 31.25
# EPOCH 7 | ITER 135 | AVG_LOSS 1.9896279573440552 | Train_ACC 18.75
# EPOCH 7 | ITER 140 | AVG_LOSS 2.172440767288208 | Train_ACC 21.875
# EPOCH 7 | ITER 145 | AVG_LOSS 2.1829543113708496 | Train_ACC 28.125
# EPOCH 7 | ITER 150 | AVG_LOSS 2.046691656112671 | Train_ACC 25.0
# EPOCH 7 | ITER 155 | AVG_LOSS 2.522212266921997 | Train_ACC 25.0
# EPOCH 7 | ITER 160 | AVG_LOSS 2.1936838626861572 | Train_ACC 18.75
# EPOCH 7 | ITER 165 | AVG_LOSS 2.1854844093322754 | Train_ACC 18.75
# EPOCH 7 | ITER 170 | AVG_LOSS 2.0734806060791016 | Train_ACC 28.125
# EPOCH 7 | ITER 175 | AVG_LOSS 2.111124277114868 | Train_ACC 25.0
# EPOCH 7 | ITER 180 | AVG_LOSS 2.3088159561157227 | Train_ACC 18.75
# EPOCH 7 | ITER 185 | AVG_LOSS 1.8674895763397217 | Train_ACC 34.375
# EPOCH 7 | ITER 190 | AVG_LOSS 2.288301706314087 | Train_ACC 15.625
# EPOCH 7 | ITER 195 | AVG_LOSS 2.403900384902954 | Train_ACC 18.75
# EPOCH 7 | ITER 200 | AVG_LOSS 1.9120968580245972 | Train_ACC 25.0
# EPOCH 7 | ITER 205 | AVG_LOSS 2.32712984085083 | Train_ACC 21.875
# EPOCH 7 | ITER 210 | AVG_LOSS 2.042823314666748 | Train_ACC 28.125
# EPOCH 7 | ITER 215 | AVG_LOSS 2.189159631729126 | Train_ACC 21.875
# EPOCH 7 | ITER 220 | AVG_LOSS 1.9641023874282837 | Train_ACC 28.125
# EPOCH 7 | ITER 225 | AVG_LOSS 2.1064634323120117 | Train_ACC 18.75
# EPOCH 7 | ITER 230 | AVG_LOSS 2.004098415374756 | Train_ACC 21.875
# EPOCH 7 | ITER 235 | AVG_LOSS 2.2815442085266113 | Train_ACC 15.625
# EPOCH 7 | ITER 240 | AVG_LOSS 2.125535726547241 | Train_ACC 18.75
# EPOCH 7 | ITER 245 | AVG_LOSS 2.11665940284729 | Train_ACC 15.625
# EPOCH 7 | ITER 250 | AVG_LOSS 2.0255115032196045 | Train_ACC 34.375
# EPOCH 7 | ITER 255 | AVG_LOSS 2.2402849197387695 | Train_ACC 18.75
# EPOCH 7 | ITER 260 | AVG_LOSS 2.0453941822052 | Train_ACC 25.0
# EPOCH 7 | ITER 265 | AVG_LOSS 1.9275808334350586 | Train_ACC 25.0
# EPOCH 7 | ITER 270 | AVG_LOSS 2.024137496948242 | Train_ACC 21.875
# EPOCH 7 | ITER 275 | AVG_LOSS 2.018362522125244 | Train_ACC 28.125
# EPOCH 7 | ITER 280 | AVG_LOSS 2.0644209384918213 | Train_ACC 34.375
# EPOCH 7 | ITER 285 | AVG_LOSS 2.380408525466919 | Train_ACC 18.75
# EPOCH 7 | ITER 290 | AVG_LOSS 2.127444267272949 | Train_ACC 34.375
# EPOCH 7 | ITER 295 | AVG_LOSS 2.0372238159179688 | Train_ACC 28.125
# EPOCH 7 | ITER 300 | AVG_LOSS 2.0560576915740967 | Train_ACC 28.125
# EPOCH 7 | ITER 305 | AVG_LOSS 2.0602192878723145 | Train_ACC 31.25
# EPOCH 7 | ITER 310 | AVG_LOSS 2.309462308883667 | Train_ACC 28.125
# EPOCH 7 | ITER 315 | AVG_LOSS 2.1923606395721436 | Train_ACC 37.5
# EPOCH 7 | ITER 320 | AVG_LOSS 1.8829467296600342 | Train_ACC 37.5
# EPOCH 7 | ITER 325 | AVG_LOSS 2.2948572635650635 | Train_ACC 9.375
# EPOCH 7 | ITER 330 | AVG_LOSS 2.1448495388031006 | Train_ACC 34.375
# EPOCH 7 | ITER 335 | AVG_LOSS 1.988323450088501 | Train_ACC 25.0
# EPOCH 7 | ITER 340 | AVG_LOSS 2.1274197101593018 | Train_ACC 15.625
# EPOCH 7 | ITER 345 | AVG_LOSS 2.2152297496795654 | Train_ACC 15.625
# EPOCH 7 | ITER 350 | AVG_LOSS 2.034264087677002 | Train_ACC 25.0
# EPOCH 7 | ITER 355 | AVG_LOSS 2.077533721923828 | Train_ACC 21.875
# EPOCH 7 | ITER 360 | AVG_LOSS 2.3497207164764404 | Train_ACC 21.875
# EPOCH 7 | ITER 365 | AVG_LOSS 1.871378779411316 | Train_ACC 28.125
# EPOCH 7 | ITER 370 | AVG_LOSS 2.1515119075775146 | Train_ACC 25.0
# Val Accuracy: 29.63%
# ****************************************
# test Accuracy: 28.75%
#
# --------------------------------------------------
# EPOCH 7 | LOSS 2.1746976375579834 | TIME 177.84597754478455
# --------------------------------------------------
#
# EPOCH 8 | ITER 0 | AVG_LOSS 2.133582353591919 | Train_ACC 28.125
# EPOCH 8 | ITER 5 | AVG_LOSS 2.258918046951294 | Train_ACC 28.125
# EPOCH 8 | ITER 10 | AVG_LOSS 2.074605941772461 | Train_ACC 18.75
# EPOCH 8 | ITER 15 | AVG_LOSS 2.294111490249634 | Train_ACC 12.5
# EPOCH 8 | ITER 20 | AVG_LOSS 2.2062172889709473 | Train_ACC 21.875
# EPOCH 8 | ITER 25 | AVG_LOSS 2.065080404281616 | Train_ACC 21.875
# EPOCH 8 | ITER 30 | AVG_LOSS 2.0602121353149414 | Train_ACC 31.25
# EPOCH 8 | ITER 35 | AVG_LOSS 2.318890333175659 | Train_ACC 21.875
# EPOCH 8 | ITER 40 | AVG_LOSS 2.1804721355438232 | Train_ACC 25.0
# EPOCH 8 | ITER 45 | AVG_LOSS 2.058260917663574 | Train_ACC 15.625
# EPOCH 8 | ITER 50 | AVG_LOSS 2.045213222503662 | Train_ACC 37.5
# EPOCH 8 | ITER 55 | AVG_LOSS 2.1897201538085938 | Train_ACC 31.25
# EPOCH 8 | ITER 60 | AVG_LOSS 2.0857532024383545 | Train_ACC 15.625
# EPOCH 8 | ITER 65 | AVG_LOSS 2.0775020122528076 | Train_ACC 28.125
# EPOCH 8 | ITER 70 | AVG_LOSS 2.146899938583374 | Train_ACC 21.875
# EPOCH 8 | ITER 75 | AVG_LOSS 2.134932279586792 | Train_ACC 18.75
# EPOCH 8 | ITER 80 | AVG_LOSS 1.8904389142990112 | Train_ACC 28.125
# EPOCH 8 | ITER 85 | AVG_LOSS 2.046630620956421 | Train_ACC 28.125
# EPOCH 8 | ITER 90 | AVG_LOSS 1.968637228012085 | Train_ACC 31.25
# EPOCH 8 | ITER 95 | AVG_LOSS 2.052929639816284 | Train_ACC 28.125
# EPOCH 8 | ITER 100 | AVG_LOSS 2.1810927391052246 | Train_ACC 25.0
# EPOCH 8 | ITER 105 | AVG_LOSS 2.088876247406006 | Train_ACC 34.375
# EPOCH 8 | ITER 110 | AVG_LOSS 2.025235176086426 | Train_ACC 25.0
# EPOCH 8 | ITER 115 | AVG_LOSS 1.9546329975128174 | Train_ACC 31.25
# EPOCH 8 | ITER 120 | AVG_LOSS 1.9791264533996582 | Train_ACC 37.5
# EPOCH 8 | ITER 125 | AVG_LOSS 2.08215069770813 | Train_ACC 21.875
# EPOCH 8 | ITER 130 | AVG_LOSS 2.2660162448883057 | Train_ACC 15.625
# EPOCH 8 | ITER 135 | AVG_LOSS 2.210557460784912 | Train_ACC 18.75
# EPOCH 8 | ITER 140 | AVG_LOSS 2.2395589351654053 | Train_ACC 21.875
# EPOCH 8 | ITER 145 | AVG_LOSS 1.9441107511520386 | Train_ACC 28.125
# EPOCH 8 | ITER 150 | AVG_LOSS 2.0227010250091553 | Train_ACC 25.0
# EPOCH 8 | ITER 155 | AVG_LOSS 2.0838019847869873 | Train_ACC 21.875
# EPOCH 8 | ITER 160 | AVG_LOSS 2.010960102081299 | Train_ACC 37.5
# EPOCH 8 | ITER 165 | AVG_LOSS 1.8784416913986206 | Train_ACC 34.375
# EPOCH 8 | ITER 170 | AVG_LOSS 1.9574918746948242 | Train_ACC 25.0
# EPOCH 8 | ITER 175 | AVG_LOSS 2.0787625312805176 | Train_ACC 31.25
# EPOCH 8 | ITER 180 | AVG_LOSS 1.9801017045974731 | Train_ACC 31.25
# EPOCH 8 | ITER 185 | AVG_LOSS 1.7946308851242065 | Train_ACC 34.375
# EPOCH 8 | ITER 190 | AVG_LOSS 2.2508251667022705 | Train_ACC 34.375
# EPOCH 8 | ITER 195 | AVG_LOSS 1.8966683149337769 | Train_ACC 31.25
# EPOCH 8 | ITER 200 | AVG_LOSS 1.9975287914276123 | Train_ACC 25.0
# EPOCH 8 | ITER 205 | AVG_LOSS 1.8349651098251343 | Train_ACC 31.25
# EPOCH 8 | ITER 210 | AVG_LOSS 1.8356152772903442 | Train_ACC 25.0
# EPOCH 8 | ITER 215 | AVG_LOSS 2.0709640979766846 | Train_ACC 21.875
# EPOCH 8 | ITER 220 | AVG_LOSS 2.1319313049316406 | Train_ACC 28.125
# EPOCH 8 | ITER 225 | AVG_LOSS 2.0719950199127197 | Train_ACC 28.125
# EPOCH 8 | ITER 230 | AVG_LOSS 2.1128089427948 | Train_ACC 28.125
# EPOCH 8 | ITER 235 | AVG_LOSS 2.2841379642486572 | Train_ACC 28.125
# EPOCH 8 | ITER 240 | AVG_LOSS 1.722221851348877 | Train_ACC 37.5
# EPOCH 8 | ITER 245 | AVG_LOSS 2.170658826828003 | Train_ACC 15.625
# EPOCH 8 | ITER 250 | AVG_LOSS 1.956626057624817 | Train_ACC 31.25
# EPOCH 8 | ITER 255 | AVG_LOSS 2.014723777770996 | Train_ACC 28.125
# EPOCH 8 | ITER 260 | AVG_LOSS 1.7757047414779663 | Train_ACC 46.875
# EPOCH 8 | ITER 265 | AVG_LOSS 2.1275622844696045 | Train_ACC 21.875
# EPOCH 8 | ITER 270 | AVG_LOSS 1.8650426864624023 | Train_ACC 43.75
# EPOCH 8 | ITER 275 | AVG_LOSS 2.397318124771118 | Train_ACC 15.625
# EPOCH 8 | ITER 280 | AVG_LOSS 1.861972451210022 | Train_ACC 43.75
# EPOCH 8 | ITER 285 | AVG_LOSS 2.024200201034546 | Train_ACC 25.0
# EPOCH 8 | ITER 290 | AVG_LOSS 1.8048540353775024 | Train_ACC 46.875
# EPOCH 8 | ITER 295 | AVG_LOSS 1.992763876914978 | Train_ACC 34.375
# EPOCH 8 | ITER 300 | AVG_LOSS 2.1238603591918945 | Train_ACC 18.75
# EPOCH 8 | ITER 305 | AVG_LOSS 1.930955410003662 | Train_ACC 25.0
# EPOCH 8 | ITER 310 | AVG_LOSS 1.9792534112930298 | Train_ACC 21.875
# EPOCH 8 | ITER 315 | AVG_LOSS 2.0717523097991943 | Train_ACC 21.875
# EPOCH 8 | ITER 320 | AVG_LOSS 1.7337979078292847 | Train_ACC 28.125
# EPOCH 8 | ITER 325 | AVG_LOSS 2.189675807952881 | Train_ACC 21.875
# EPOCH 8 | ITER 330 | AVG_LOSS 2.0198683738708496 | Train_ACC 31.25
# EPOCH 8 | ITER 335 | AVG_LOSS 2.1054329872131348 | Train_ACC 31.25
# EPOCH 8 | ITER 340 | AVG_LOSS 1.9509763717651367 | Train_ACC 40.625
# EPOCH 8 | ITER 345 | AVG_LOSS 1.8951727151870728 | Train_ACC 21.875
# EPOCH 8 | ITER 350 | AVG_LOSS 1.7448354959487915 | Train_ACC 43.75
# EPOCH 8 | ITER 355 | AVG_LOSS 1.8953560590744019 | Train_ACC 34.375
# EPOCH 8 | ITER 360 | AVG_LOSS 2.1262290477752686 | Train_ACC 21.875
# EPOCH 8 | ITER 365 | AVG_LOSS 1.9785908460617065 | Train_ACC 34.375
# EPOCH 8 | ITER 370 | AVG_LOSS 2.074641704559326 | Train_ACC 21.875
# Val Accuracy: 29.10%
# ****************************************
# test Accuracy: 29.02%
#
# --------------------------------------------------
# EPOCH 8 | LOSS 2.1145503520965576 | TIME 179.27262139320374
# --------------------------------------------------
#
# EPOCH 9 | ITER 0 | AVG_LOSS 2.1831185817718506 | Train_ACC 31.25
# EPOCH 9 | ITER 5 | AVG_LOSS 1.9508992433547974 | Train_ACC 34.375
# EPOCH 9 | ITER 10 | AVG_LOSS 2.1885323524475098 | Train_ACC 25.0
# EPOCH 9 | ITER 15 | AVG_LOSS 2.0128865242004395 | Train_ACC 34.375
# EPOCH 9 | ITER 20 | AVG_LOSS 2.0134291648864746 | Train_ACC 25.0
# EPOCH 9 | ITER 25 | AVG_LOSS 1.9836525917053223 | Train_ACC 28.125
# EPOCH 9 | ITER 30 | AVG_LOSS 1.8388276100158691 | Train_ACC 31.25
# EPOCH 9 | ITER 35 | AVG_LOSS 2.074103355407715 | Train_ACC 18.75
# EPOCH 9 | ITER 40 | AVG_LOSS 1.900943398475647 | Train_ACC 34.375
# EPOCH 9 | ITER 45 | AVG_LOSS 1.9742884635925293 | Train_ACC 34.375
# EPOCH 9 | ITER 50 | AVG_LOSS 1.947582483291626 | Train_ACC 34.375
# EPOCH 9 | ITER 55 | AVG_LOSS 2.108333110809326 | Train_ACC 15.625
# EPOCH 9 | ITER 60 | AVG_LOSS 2.089262008666992 | Train_ACC 25.0
# EPOCH 9 | ITER 65 | AVG_LOSS 2.1069631576538086 | Train_ACC 37.5
# ...
# EPOCH 27 | ITER 20 | AVG_LOSS 1.462808609008789 | Train_ACC 56.25
# EPOCH 27 | ITER 25 | AVG_LOSS 1.5161099433898926 | Train_ACC 40.625
# EPOCH 27 | ITER 30 | AVG_LOSS 1.0447759628295898 | Train_ACC 65.625
# EPOCH 27 | ITER 35 | AVG_LOSS 1.3133063316345215 | Train_ACC 59.375
# EPOCH 27 | ITER 40 | AVG_LOSS 1.026326060295105 | Train_ACC 65.625
# EPOCH 27 | ITER 45 | AVG_LOSS 1.2298823595046997 | Train_ACC 53.125
# EPOCH 27 | ITER 50 | AVG_LOSS 1.962110161781311 | Train_ACC 56.25
# EPOCH 27 | ITER 55 | AVG_LOSS 1.3458638191223145 | Train_ACC 50.0
# EPOCH 27 | ITER 60 | AVG_LOSS 1.393717646598816 | Train_ACC 62.5
# EPOCH 27 | ITER 65 | AVG_LOSS 1.2397825717926025 | Train_ACC 62.5
# EPOCH 27 | ITER 70 | AVG_LOSS 1.3650566339492798 | Train_ACC 53.125
# EPOCH 27 | ITER 75 | AVG_LOSS 1.4956004619598389 | Train_ACC 56.25
# EPOCH 27 | ITER 80 | AVG_LOSS 1.4721078872680664 | Train_ACC 59.375
# EPOCH 27 | ITER 85 | AVG_LOSS 1.4410388469696045 | Train_ACC 56.25
# EPOCH 27 | ITER 90 | AVG_LOSS 1.6233011484146118 | Train_ACC 46.875
# EPOCH 27 | ITER 95 | AVG_LOSS 1.3642035722732544 | Train_ACC 53.125
# EPOCH 27 | ITER 100 | AVG_LOSS 2.1906979084014893 | Train_ACC 37.5
# EPOCH 27 | ITER 105 | AVG_LOSS 1.5485013723373413 | Train_ACC 43.75
# EPOCH 27 | ITER 110 | AVG_LOSS 1.3482846021652222 | Train_ACC 56.25
# EPOCH 27 | ITER 115 | AVG_LOSS 1.3707917928695679 | Train_ACC 65.625
# EPOCH 27 | ITER 120 | AVG_LOSS 1.815885066986084 | Train_ACC 50.0
# EPOCH 27 | ITER 125 | AVG_LOSS 1.5476815700531006 | Train_ACC 53.125
# EPOCH 27 | ITER 130 | AVG_LOSS 1.567401647567749 | Train_ACC 40.625
# EPOCH 27 | ITER 135 | AVG_LOSS 1.5310252904891968 | Train_ACC 50.0
# EPOCH 27 | ITER 140 | AVG_LOSS 1.2325897216796875 | Train_ACC 56.25
# EPOCH 27 | ITER 145 | AVG_LOSS 1.2291548252105713 | Train_ACC 50.0
# EPOCH 27 | ITER 150 | AVG_LOSS 1.1422929763793945 | Train_ACC 65.625
# EPOCH 27 | ITER 155 | AVG_LOSS 1.3937262296676636 | Train_ACC 43.75
# EPOCH 27 | ITER 160 | AVG_LOSS 1.1385637521743774 | Train_ACC 59.375
# EPOCH 27 | ITER 165 | AVG_LOSS 1.9628392457962036 | Train_ACC 31.25
# EPOCH 27 | ITER 170 | AVG_LOSS 1.460762858390808 | Train_ACC 43.75
# EPOCH 27 | ITER 175 | AVG_LOSS 1.4484803676605225 | Train_ACC 50.0
# EPOCH 27 | ITER 180 | AVG_LOSS 1.5309134721755981 | Train_ACC 43.75
# EPOCH 27 | ITER 185 | AVG_LOSS 1.876572847366333 | Train_ACC 34.375
# EPOCH 27 | ITER 190 | AVG_LOSS 1.1517276763916016 | Train_ACC 68.75
# EPOCH 27 | ITER 195 | AVG_LOSS 1.3167250156402588 | Train_ACC 40.625
# EPOCH 27 | ITER 200 | AVG_LOSS 1.3113125562667847 | Train_ACC 50.0
# EPOCH 27 | ITER 205 | AVG_LOSS 1.1711394786834717 | Train_ACC 62.5
# EPOCH 27 | ITER 210 | AVG_LOSS 1.35304594039917 | Train_ACC 53.125
# EPOCH 27 | ITER 215 | AVG_LOSS 1.5938501358032227 | Train_ACC 31.25
# EPOCH 27 | ITER 220 | AVG_LOSS 1.915419578552246 | Train_ACC 40.625
# EPOCH 27 | ITER 225 | AVG_LOSS 1.5893375873565674 | Train_ACC 46.875
# EPOCH 27 | ITER 230 | AVG_LOSS 1.159735918045044 | Train_ACC 62.5
# EPOCH 27 | ITER 235 | AVG_LOSS 1.4523109197616577 | Train_ACC 59.375
# EPOCH 27 | ITER 240 | AVG_LOSS 1.5827256441116333 | Train_ACC 53.125
# EPOCH 27 | ITER 245 | AVG_LOSS 1.3021154403686523 | Train_ACC 59.375
# EPOCH 27 | ITER 250 | AVG_LOSS 1.196751594543457 | Train_ACC 65.625
# EPOCH 27 | ITER 255 | AVG_LOSS 1.5845057964324951 | Train_ACC 53.125
# EPOCH 27 | ITER 260 | AVG_LOSS 1.405809998512268 | Train_ACC 50.0
# EPOCH 27 | ITER 265 | AVG_LOSS 1.3681490421295166 | Train_ACC 56.25
# EPOCH 27 | ITER 270 | AVG_LOSS 1.1392217874526978 | Train_ACC 68.75
# EPOCH 27 | ITER 275 | AVG_LOSS 1.3357869386672974 | Train_ACC 50.0
# EPOCH 27 | ITER 280 | AVG_LOSS 1.384108543395996 | Train_ACC 43.75
# EPOCH 27 | ITER 285 | AVG_LOSS 1.4638653993606567 | Train_ACC 43.75
# EPOCH 27 | ITER 290 | AVG_LOSS 1.5289123058319092 | Train_ACC 53.125
# EPOCH 27 | ITER 295 | AVG_LOSS 1.0664160251617432 | Train_ACC 68.75
# EPOCH 27 | ITER 300 | AVG_LOSS 1.5088138580322266 | Train_ACC 56.25
# EPOCH 27 | ITER 305 | AVG_LOSS 1.6284103393554688 | Train_ACC 50.0
# EPOCH 27 | ITER 310 | AVG_LOSS 1.7453210353851318 | Train_ACC 46.875
# EPOCH 27 | ITER 315 | AVG_LOSS 1.4983899593353271 | Train_ACC 50.0
# EPOCH 27 | ITER 320 | AVG_LOSS 1.4200594425201416 | Train_ACC 59.375
# EPOCH 27 | ITER 325 | AVG_LOSS 1.6579784154891968 | Train_ACC 34.375
# EPOCH 27 | ITER 330 | AVG_LOSS 1.5162125825881958 | Train_ACC 53.125
# EPOCH 27 | ITER 335 | AVG_LOSS 1.7854773998260498 | Train_ACC 37.5
# EPOCH 27 | ITER 340 | AVG_LOSS 1.7754861116409302 | Train_ACC 53.125
# EPOCH 27 | ITER 345 | AVG_LOSS 1.1858388185501099 | Train_ACC 59.375
# EPOCH 27 | ITER 350 | AVG_LOSS 1.2379206418991089 | Train_ACC 59.375
# EPOCH 27 | ITER 355 | AVG_LOSS 1.7171199321746826 | Train_ACC 53.125
# EPOCH 27 | ITER 360 | AVG_LOSS 1.5438783168792725 | Train_ACC 53.125
# EPOCH 27 | ITER 365 | AVG_LOSS 1.1148163080215454 | Train_ACC 68.75
# EPOCH 27 | ITER 370 | AVG_LOSS 1.3365144729614258 | Train_ACC 50.0
# Val Accuracy: 54.15%
# ****************************************
# test Accuracy: 57.17%
#
# --------------------------------------------------
# EPOCH 27 | LOSS 1.4490127563476562 | TIME 177.5544924736023
# --------------------------------------------------
#
# EPOCH 28 | ITER 0 | AVG_LOSS 1.4540605545043945 | Train_ACC 46.875
# EPOCH 28 | ITER 5 | AVG_LOSS 1.332671046257019 | Train_ACC 62.5
# EPOCH 28 | ITER 10 | AVG_LOSS 1.8126474618911743 | Train_ACC 34.375
# EPOCH 28 | ITER 15 | AVG_LOSS 1.5470359325408936 | Train_ACC 43.75
# EPOCH 28 | ITER 20 | AVG_LOSS 0.970374584197998 | Train_ACC 68.75
# EPOCH 28 | ITER 25 | AVG_LOSS 1.2705000638961792 | Train_ACC 59.375
# EPOCH 28 | ITER 30 | AVG_LOSS 1.383862018585205 | Train_ACC 56.25
# EPOCH 28 | ITER 35 | AVG_LOSS 1.4516160488128662 | Train_ACC 50.0
# EPOCH 28 | ITER 40 | AVG_LOSS 1.4663934707641602 | Train_ACC 53.125
# EPOCH 28 | ITER 45 | AVG_LOSS 1.5153294801712036 | Train_ACC 43.75
# EPOCH 28 | ITER 50 | AVG_LOSS 1.535753607749939 | Train_ACC 46.875
# EPOCH 28 | ITER 55 | AVG_LOSS 1.4925644397735596 | Train_ACC 46.875
# EPOCH 28 | ITER 60 | AVG_LOSS 1.3406269550323486 | Train_ACC 56.25
# EPOCH 28 | ITER 65 | AVG_LOSS 1.4891364574432373 | Train_ACC 50.0
# EPOCH 28 | ITER 70 | AVG_LOSS 1.407043218612671 | Train_ACC 50.0
# EPOCH 28 | ITER 75 | AVG_LOSS 1.4073877334594727 | Train_ACC 46.875
# EPOCH 28 | ITER 80 | AVG_LOSS 1.7203147411346436 | Train_ACC 50.0
# EPOCH 28 | ITER 85 | AVG_LOSS 1.2122783660888672 | Train_ACC 62.5
# EPOCH 28 | ITER 90 | AVG_LOSS 1.4437458515167236 | Train_ACC 50.0
# EPOCH 28 | ITER 95 | AVG_LOSS 1.0880966186523438 | Train_ACC 68.75
# EPOCH 28 | ITER 100 | AVG_LOSS 1.4862045049667358 | Train_ACC 46.875
# EPOCH 28 | ITER 105 | AVG_LOSS 1.4433543682098389 | Train_ACC 50.0
# EPOCH 28 | ITER 110 | AVG_LOSS 1.5403374433517456 | Train_ACC 46.875
# EPOCH 28 | ITER 115 | AVG_LOSS 1.2628284692764282 | Train_ACC 65.625
# EPOCH 28 | ITER 120 | AVG_LOSS 1.1740105152130127 | Train_ACC 59.375
# EPOCH 28 | ITER 125 | AVG_LOSS 1.156187891960144 | Train_ACC 65.625
# EPOCH 28 | ITER 130 | AVG_LOSS 1.5461900234222412 | Train_ACC 46.875
# EPOCH 28 | ITER 135 | AVG_LOSS 1.694448709487915 | Train_ACC 46.875
# EPOCH 28 | ITER 140 | AVG_LOSS 1.1478193998336792 | Train_ACC 62.5
# EPOCH 28 | ITER 145 | AVG_LOSS 1.49263334274292 | Train_ACC 56.25
# EPOCH 28 | ITER 150 | AVG_LOSS 1.2177183628082275 | Train_ACC 62.5
# EPOCH 28 | ITER 155 | AVG_LOSS 1.7376240491867065 | Train_ACC 43.75
# EPOCH 28 | ITER 160 | AVG_LOSS 1.4985172748565674 | Train_ACC 59.375
# EPOCH 28 | ITER 165 | AVG_LOSS 1.6494935750961304 | Train_ACC 40.625
# EPOCH 28 | ITER 170 | AVG_LOSS 0.9751535058021545 | Train_ACC 71.875
# EPOCH 28 | ITER 175 | AVG_LOSS 1.4413557052612305 | Train_ACC 65.625
# EPOCH 28 | ITER 180 | AVG_LOSS 1.346124291419983 | Train_ACC 59.375
# EPOCH 28 | ITER 185 | AVG_LOSS 1.5767744779586792 | Train_ACC 46.875
# EPOCH 28 | ITER 190 | AVG_LOSS 1.3048697710037231 | Train_ACC 56.25
# EPOCH 28 | ITER 195 | AVG_LOSS 1.1535300016403198 | Train_ACC 56.25
# EPOCH 28 | ITER 200 | AVG_LOSS 1.6962777376174927 | Train_ACC 43.75
# EPOCH 28 | ITER 205 | AVG_LOSS 1.614769697189331 | Train_ACC 53.125
# EPOCH 28 | ITER 210 | AVG_LOSS 1.452258825302124 | Train_ACC 50.0
# EPOCH 28 | ITER 215 | AVG_LOSS 1.4293758869171143 | Train_ACC 53.125
# EPOCH 28 | ITER 220 | AVG_LOSS 1.3945248126983643 | Train_ACC 53.125
# EPOCH 28 | ITER 225 | AVG_LOSS 1.1994346380233765 | Train_ACC 62.5
# EPOCH 28 | ITER 230 | AVG_LOSS 1.3585336208343506 | Train_ACC 50.0
# EPOCH 28 | ITER 235 | AVG_LOSS 1.4506994485855103 | Train_ACC 53.125
# EPOCH 28 | ITER 240 | AVG_LOSS 1.5541998147964478 | Train_ACC 46.875
# EPOCH 28 | ITER 245 | AVG_LOSS 1.6251298189163208 | Train_ACC 59.375
# EPOCH 28 | ITER 250 | AVG_LOSS 1.2966452836990356 | Train_ACC 62.5
# EPOCH 28 | ITER 255 | AVG_LOSS 1.455083966255188 | Train_ACC 53.125
# EPOCH 28 | ITER 260 | AVG_LOSS 1.368769645690918 | Train_ACC 56.25
# EPOCH 28 | ITER 265 | AVG_LOSS 1.2323005199432373 | Train_ACC 59.375
# EPOCH 28 | ITER 270 | AVG_LOSS 1.633350133895874 | Train_ACC 43.75
# EPOCH 28 | ITER 275 | AVG_LOSS 1.5426595211029053 | Train_ACC 50.0
# EPOCH 28 | ITER 280 | AVG_LOSS 1.2514575719833374 | Train_ACC 53.125
# EPOCH 28 | ITER 285 | AVG_LOSS 1.9106911420822144 | Train_ACC 40.625
# EPOCH 28 | ITER 290 | AVG_LOSS 1.4352915287017822 | Train_ACC 37.5
# EPOCH 28 | ITER 295 | AVG_LOSS 1.5274300575256348 | Train_ACC 65.625
# EPOCH 28 | ITER 300 | AVG_LOSS 1.9786349534988403 | Train_ACC 46.875
# EPOCH 28 | ITER 305 | AVG_LOSS 1.0584272146224976 | Train_ACC 56.25
# EPOCH 28 | ITER 310 | AVG_LOSS 1.50689697265625 | Train_ACC 43.75
# EPOCH 28 | ITER 315 | AVG_LOSS 1.5117944478988647 | Train_ACC 37.5
# EPOCH 28 | ITER 320 | AVG_LOSS 1.0944749116897583 | Train_ACC 62.5
# EPOCH 28 | ITER 325 | AVG_LOSS 0.9967930912971497 | Train_ACC 71.875
# EPOCH 28 | ITER 330 | AVG_LOSS 1.8560190200805664 | Train_ACC 28.125
# EPOCH 28 | ITER 335 | AVG_LOSS 1.9761128425598145 | Train_ACC 43.75
# EPOCH 28 | ITER 340 | AVG_LOSS 1.4936541318893433 | Train_ACC 50.0
# EPOCH 28 | ITER 345 | AVG_LOSS 1.8892086744308472 | Train_ACC 40.625
# EPOCH 28 | ITER 350 | AVG_LOSS 1.3267419338226318 | Train_ACC 65.625
# EPOCH 28 | ITER 355 | AVG_LOSS 1.4069254398345947 | Train_ACC 46.875
# EPOCH 28 | ITER 360 | AVG_LOSS 1.3712573051452637 | Train_ACC 53.125
# EPOCH 28 | ITER 365 | AVG_LOSS 1.2982914447784424 | Train_ACC 56.25
# EPOCH 28 | ITER 370 | AVG_LOSS 1.2185347080230713 | Train_ACC 56.25
# Val Accuracy: 59.14%
# ****************************************
# test Accuracy: 60.57%
#
# --------------------------------------------------
# EPOCH 28 | LOSS 1.379888892173767 | TIME 181.9544336795807
# --------------------------------------------------
#
# EPOCH 29 | ITER 0 | AVG_LOSS 1.3774534463882446 | Train_ACC 59.375
# EPOCH 29 | ITER 5 | AVG_LOSS 1.1878888607025146 | Train_ACC 65.625
# EPOCH 29 | ITER 10 | AVG_LOSS 1.3537774085998535 | Train_ACC 34.375
# EPOCH 29 | ITER 15 | AVG_LOSS 1.6337212324142456 | Train_ACC 43.75
# EPOCH 29 | ITER 20 | AVG_LOSS 1.2423866987228394 | Train_ACC 68.75
# EPOCH 29 | ITER 25 | AVG_LOSS 1.2795157432556152 | Train_ACC 53.125
# EPOCH 29 | ITER 30 | AVG_LOSS 1.758579134941101 | Train_ACC 46.875
# EPOCH 29 | ITER 35 | AVG_LOSS 1.4442905187606812 | Train_ACC 46.875
# EPOCH 29 | ITER 40 | AVG_LOSS 1.3550159931182861 | Train_ACC 50.0
# EPOCH 29 | ITER 45 | AVG_LOSS 1.5493556261062622 | Train_ACC 56.25
# EPOCH 29 | ITER 50 | AVG_LOSS 1.316348910331726 | Train_ACC 56.25
# EPOCH 29 | ITER 55 | AVG_LOSS 1.7094579935073853 | Train_ACC 56.25
# EPOCH 29 | ITER 60 | AVG_LOSS 1.300956130027771 | Train_ACC 65.625
# EPOCH 29 | ITER 65 | AVG_LOSS 1.258102297782898 | Train_ACC 65.625
# EPOCH 29 | ITER 70 | AVG_LOSS 1.278172254562378 | Train_ACC 50.0
# EPOCH 29 | ITER 75 | AVG_LOSS 1.008901834487915 | Train_ACC 65.625
# EPOCH 29 | ITER 80 | AVG_LOSS 1.423779010772705 | Train_ACC 43.75
# EPOCH 29 | ITER 85 | AVG_LOSS 1.3093477487564087 | Train_ACC 53.125
# EPOCH 29 | ITER 90 | AVG_LOSS 1.2806180715560913 | Train_ACC 56.25
# EPOCH 29 | ITER 95 | AVG_LOSS 1.3505810499191284 | Train_ACC 50.0
# EPOCH 29 | ITER 100 | AVG_LOSS 1.4218254089355469 | Train_ACC 53.125
# EPOCH 29 | ITER 105 | AVG_LOSS 1.314980387687683 | Train_ACC 56.25
# EPOCH 29 | ITER 110 | AVG_LOSS 1.5522396564483643 | Train_ACC 56.25
# EPOCH 29 | ITER 115 | AVG_LOSS 1.3536980152130127 | Train_ACC 62.5
# EPOCH 29 | ITER 120 | AVG_LOSS 1.0000956058502197 | Train_ACC 71.875
# EPOCH 29 | ITER 125 | AVG_LOSS 1.5900115966796875 | Train_ACC 40.625
# EPOCH 29 | ITER 130 | AVG_LOSS 1.320160150527954 | Train_ACC 62.5
# EPOCH 29 | ITER 135 | AVG_LOSS 1.6658071279525757 | Train_ACC 50.0
# EPOCH 29 | ITER 140 | AVG_LOSS 1.3087222576141357 | Train_ACC 56.25
# EPOCH 29 | ITER 145 | AVG_LOSS 1.5938918590545654 | Train_ACC 43.75
# EPOCH 29 | ITER 150 | AVG_LOSS 1.2008131742477417 | Train_ACC 62.5
# EPOCH 29 | ITER 155 | AVG_LOSS 1.7395638227462769 | Train_ACC 37.5
# EPOCH 29 | ITER 160 | AVG_LOSS 1.966495156288147 | Train_ACC 40.625
# EPOCH 29 | ITER 165 | AVG_LOSS 1.3900867700576782 | Train_ACC 65.625
# EPOCH 29 | ITER 170 | AVG_LOSS 1.5186313390731812 | Train_ACC 43.75
# EPOCH 29 | ITER 175 | AVG_LOSS 1.372413158416748 | Train_ACC 59.375
# EPOCH 29 | ITER 180 | AVG_LOSS 1.5266640186309814 | Train_ACC 43.75
# EPOCH 29 | ITER 185 | AVG_LOSS 1.4749531745910645 | Train_ACC 46.875
# EPOCH 29 | ITER 190 | AVG_LOSS 1.3601967096328735 | Train_ACC 46.875
# EPOCH 29 | ITER 195 | AVG_LOSS 1.181203007698059 | Train_ACC 53.125
# EPOCH 29 | ITER 200 | AVG_LOSS 1.2542058229446411 | Train_ACC 56.25
# EPOCH 29 | ITER 205 | AVG_LOSS 2.038479804992676 | Train_ACC 40.625
# EPOCH 29 | ITER 210 | AVG_LOSS 1.0331178903579712 | Train_ACC 75.0
# EPOCH 29 | ITER 215 | AVG_LOSS 1.6783803701400757 | Train_ACC 53.125
# EPOCH 29 | ITER 220 | AVG_LOSS 1.7592694759368896 | Train_ACC 53.125
# EPOCH 29 | ITER 225 | AVG_LOSS 1.0524827241897583 | Train_ACC 62.5
# EPOCH 29 | ITER 230 | AVG_LOSS 1.5182267427444458 | Train_ACC 53.125
# EPOCH 29 | ITER 235 | AVG_LOSS 1.3195054531097412 | Train_ACC 65.625
# EPOCH 29 | ITER 240 | AVG_LOSS 1.352251648902893 | Train_ACC 53.125
# EPOCH 29 | ITER 245 | AVG_LOSS 1.420467495918274 | Train_ACC 56.25
# EPOCH 29 | ITER 250 | AVG_LOSS 1.2682150602340698 | Train_ACC 53.125
# EPOCH 29 | ITER 255 | AVG_LOSS 1.0705446004867554 | Train_ACC 65.625
# EPOCH 29 | ITER 260 | AVG_LOSS 1.740965485572815 | Train_ACC 37.5
# EPOCH 29 | ITER 265 | AVG_LOSS 1.0580321550369263 | Train_ACC 68.75
# EPOCH 29 | ITER 270 | AVG_LOSS 1.7111668586730957 | Train_ACC 28.125
# EPOCH 29 | ITER 275 | AVG_LOSS 1.2086941003799438 | Train_ACC 65.625
# EPOCH 29 | ITER 280 | AVG_LOSS 1.6692248582839966 | Train_ACC 43.75
# EPOCH 29 | ITER 285 | AVG_LOSS 1.769188642501831 | Train_ACC 59.375
# EPOCH 29 | ITER 290 | AVG_LOSS 1.6212158203125 | Train_ACC 46.875
# EPOCH 29 | ITER 295 | AVG_LOSS 1.5876671075820923 | Train_ACC 46.875
# EPOCH 29 | ITER 300 | AVG_LOSS 1.4811882972717285 | Train_ACC 50.0
# EPOCH 29 | ITER 305 | AVG_LOSS 1.5520626306533813 | Train_ACC 50.0
# EPOCH 29 | ITER 310 | AVG_LOSS 1.738076090812683 | Train_ACC 34.375
# EPOCH 29 | ITER 315 | AVG_LOSS 1.9174253940582275 | Train_ACC 40.625
# EPOCH 29 | ITER 320 | AVG_LOSS 1.0458027124404907 | Train_ACC 65.625
# EPOCH 29 | ITER 325 | AVG_LOSS 1.2601978778839111 | Train_ACC 50.0
# EPOCH 29 | ITER 330 | AVG_LOSS 1.5156173706054688 | Train_ACC 43.75
# EPOCH 29 | ITER 335 | AVG_LOSS 1.0602896213531494 | Train_ACC 56.25
# EPOCH 29 | ITER 340 | AVG_LOSS 1.263061285018921 | Train_ACC 53.125
# EPOCH 29 | ITER 345 | AVG_LOSS 1.1465072631835938 | Train_ACC 59.375
# EPOCH 29 | ITER 350 | AVG_LOSS 1.276841640472412 | Train_ACC 50.0
# EPOCH 29 | ITER 355 | AVG_LOSS 1.7102787494659424 | Train_ACC 46.875
# EPOCH 29 | ITER 360 | AVG_LOSS 1.3340047597885132 | Train_ACC 50.0
# EPOCH 29 | ITER 365 | AVG_LOSS 1.8570400476455688 | Train_ACC 34.375
# EPOCH 29 | ITER 370 | AVG_LOSS 1.6512762308120728 | Train_ACC 43.75
# Val Accuracy: 58.41%
# ****************************************
# test Accuracy: 57.91%
#
# --------------------------------------------------
# EPOCH 29 | LOSS 1.3760435581207275 | TIME 188.03524708747864
# --------------------------------------------------
# <ipython-input-12-35ad287684ad>:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
plotloss()

# %%
class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}

idx2class = { value : key  for key , value in class2idx.items() }
y_true = [idx2class[val.item()] for val in y_expected_test ]
y_pred = [idx2class[val.item()] for val in y_test ]
print(y_true)
print(y_pred)

macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")
f1_score = (2*micro_precision*micro_recall)/(micro_recall + micro_precision)

print("f1 - Score is :--- " ,f1_score)
cnf_matrix = confusion_matrix(y_true , y_pred , labels=['butterfly','cats','cow','dogs','elephant','hen','horse','monkey','panda','sheep', 'spider', 'squirrel'])
plot_confusion_matrix(cnf_matrix , class2idx.keys() , [macro_precision , micro_precision , macro_recall , micro_recall], output_filename = "cnf_resnet_Data3.png")
# Out:
# ['butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', 'dogs', ...
# ['butterfly', 'butterfly', 'butterfly', 'butterfly', 'elephant', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cats', 'butterfly', 'cats', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cow', 'cats', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cats', 'cats', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'spider', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'panda', 'spider', 'butterfly', 'cow', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'elephant', 'butterfly', 'butterfly', 'butterfly', 'monkey', 'butterfly', 'cats', 'butterfly', 'butterfly', 'butterfly', 'cats', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cow', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cow', 'butterfly', 'cow', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'monkey', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'spider', 'butterfly', 'butterfly', 'butterfly', 'spider', 'cats', 'monkey', 'cats', 'cats', 'cow', 'butterfly', 'cats', 'butterfly', 'butterfly', 'cats', 'cow', 'cats', 'cow', 'butterfly', 'cats', 'butterfly', 'butterfly', 'spider', 'butterfly', 'cow', 'monkey', 'cats', 'butterfly', 'cow', 'cats', 'cow', 'spider', 'butterfly', 'cats', 'cats', 'cats', 'cow', 'butterfly', 'elephant', 'spider', 'butterfly', 'cats', 'cats', 'monkey', 'cats', 'elephant', 'cats', 'cats', 'butterfly', 'cow', 'cats', 'cats', 'elephant', 'cats', 'elephant', 'spider', 'butterfly', 'cats', 'butterfly', 'cats', 'cats', 'butterfly', 'butterfly', 'elephant', 'butterfly', 'cats', 'cats', 'butterfly', 'cats', 'cats', 'cats', 'cow', 'butterfly', 'cats', 'spider', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'butterfly', 'cats', 'cats', 'cats', 'cats', 'cats', 'butterfly', 'butterfly', 'butterfly', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cow', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cats', 'cow', 'butterfly', 'spider', 'spider', 'cow', 'butterfly', 'cats', 'cats', 'butterfly', 'cats', 'cats', 'cats', 'cow', 'butterfly', 'cats', 'butterfly', 'cow', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cow', 'panda', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cow', 'spider', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'spider', 'butterfly', 'butterfly', 'spider', 'cow', 'butterfly', 'butterfly', 'monkey', 'elephant', 'butterfly', 'butterfly', 'cow', 'spider', 'butterfly', 'butterfly', 'cats', 'monkey', 'butterfly', 'elephant', 'butterfly', 'butterfly', 'butterfly', 'elephant', 'monkey', 'cats', 'butterfly', 'cow', 'cats', 'butterfly', 'butterfly', 'monkey', 'cow', 'butterfly', 'butterfly', 'butterfly', 'cow', 'cow', 'butterfly', 'cow', 'butterfly', 'elephant', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'monkey', 'butterfly', 'cow', 'butterfly', 'monkey', 'butterfly', 'cow', 'butterfly', 'butterfly', 'butterfly', 'monkey', 'butterfly', 'butterfly', 'cow', 'butterfly', 'monkey', 'cow', 'cats', 'cats', 'butterfly', 'cats', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'panda', 'butterfly', 'butterfly', 'elephant', 'elephant', 'panda', 'cow', 'cats', 'butterfly', 'cow', 'butterfly', 'butterfly', 'cow', 'horse', 'butterfly', 'butterfly', 'butterfly', 'butterfly', 'cow', 'butterfly', 'cow', 'cow', 'cow', 'butterfly' ...
# f1 - Score is :---  0.38908160996219704
