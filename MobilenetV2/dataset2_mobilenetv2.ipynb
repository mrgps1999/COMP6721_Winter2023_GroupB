# %%
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import *
import seaborn as sns
import seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from pathlib import Path
import os.path
import random
import cv2

# %%
writer = SummaryWriter()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
from google.colab import drive
drive.mount('/content/gdrive/');

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# cuda
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# **Visualize images from Dataset:**

# %%
dataset = "/content/gdrive/MyDrive/Final_Dataset/dataset2/train/cow/"
list = []
for image in os.listdir(dataset):
  list.append(os.path.join(dataset,image))
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(list[i]))
    ax.set_title("Cow")

plt.tight_layout()
plt.show()

dataset = "/content/gdrive/MyDrive/Final_Dataset/dataset2/train/elephant/"
list = []
for image in os.listdir(dataset):
  list.append(os.path.join(dataset,image))
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(list[i]))
    ax.set_title("Elephant")

plt.tight_layout()
plt.show()

# %%
def load_Data():
    train_dataset = datasets.ImageFolder("/content/gdrive/MyDrive/Final_Dataset/dataset2/train", transform=transform)
    val_dataset = datasets.ImageFolder("/content/gdrive/MyDrive/Final_Dataset/dataset2/val", transform=test_transform)
    test_dataset = datasets.ImageFolder("/content/gdrive/MyDrive/Final_Dataset/dataset2/test", transform=test_transform)

    print(train_dataset.class_to_idx)
    #print(test_dataset.class_to_idx)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    return train_loader,val_loader,test_loader
load_Data()
# Out:
# {'cat': 0, 'cow': 1, 'dog': 2, 'elephant': 3, 'horse': 4}
# (<torch.utils.data.dataloader.DataLoader at 0x7f3f882fef70>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f3f882fefa0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f3f9b4d3be0>)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class Model(nn.Module):
  def __init__(self,input) -> None:
      super(Model,self).__init__()
      self.model = torchvision.models.mobilenet_v2(pretrained=False)
      #self.num_ftrs = self.model.classifier[1].in_features
      #print(num_ftrs)
      self.fc_layer = nn.Sequential(
      nn.Linear(1280,640),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      
      nn.Linear(640,320),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      
      nn.Linear(320,160),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.1),
      nn.Linear(160, 5)
    )
      
      self.model.classifier = self.fc_layer
      self.features = {}
      self.model.classifier.register_forward_pre_hook(self.get_features("embeddings"))
  def get_features(self,name):
      def hook(model, input):
          self.features[name] = input[0].detach().cpu().numpy()
      return hook
  def forward(self, x):
        x = self.model(x)
        return x
model = Model((224,224))
print(model)
# Out:
# Model(
#   (model): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=1280, out_features=640, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=640, out_features=320, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=320, out_features=160, bias=True)
#       (7): ReLU(inplace=True)
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=160, out_features=5, bias=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=1280, out_features=640, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=640, out_features=320, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=320, out_features=160, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=160, out_features=5, bias=True)
#   )
# )

# %%
# Save checkpoint 
def save_checkpoint(state, filename):
    torch.save(state, filename)

# %%
# datastructure to store all the training testing and validation results.
y_train = []
y_expected_train = []
y_val = []
y_expected_val = []
y_test = []
y_expected_test = []
trainloss = []
valloss =[]
epochnum = []

# %%
print(torch.cuda.is_available())
def train(model, train_loader, criterion, optimizer, epoch, step=5):
    
    model.train()
    loss_list = AverageMeter()
    for i, (images, labels) in enumerate(train_loader):
        #print(torch.cuda.is_available())
        total =0
        correct = 0
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        #print(predicted,type(predicted))
        #print(labels,type(labels))
        output = model(images)
        loss = criterion(output,labels)
        loss_list.update(loss.data, images.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        y_train.extend(predicted.to(torch.device('cpu')))
        y_expected_train.extend(labels.to(torch.device('cpu')))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        #print( f'Training Accuracy: {accuracy:.2f}%')
            
        if i%step==0:
            print('EPOCH {} | ITER {} | AVG_LOSS {} | Train_ACC {}'.format(epoch, i, loss_list.avg,accuracy))
        writer.add_scalar('TRAIN_LOSS', loss, epoch)
        writer.add_scalar('TRAIN_ACC', accuracy, epoch)
        
    return loss ,accuracy
# Out:
# True

# %%
def val(model, val_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    loss_list = AverageMeter()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            #print("Inside validation");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            loss = criterion(outputs,labels)
            loss_list.update(loss.data, inputs.size(0))
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #print("CORRECT",correct)
            #print("Total",total)
        accuracy = 100 * correct / total
        print(f'Val Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('Validation_LOSS', loss, epoch)
        writer.add_scalar('Validation_ACCURACY', accuracy, epoch)
        return loss,accuracy

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    print("Best Model: ",epoch)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('_LOSS', loss, epoch)
        # writer.add_scalar('TEST_ACC', accuracy, epoch)
        return accuracy

# %%
def visualize(model , data_loader):
    class2idx = {'cat': 0, 'cow': 1, 'dog': 2, 'elephant': 3, 'horse': 4}
    idx2class = { value : key for key,value in  class2idx.items() }
    embeddings = np.array([])
    labels = np.array([])
    model.eval()
    out_features = 1280
    num_categories = 5
    with torch.no_grad(): 
        for i,data in enumerate(data_loader):
            images, labs = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            embeds = model.features["embeddings"].reshape(-1, 1280)
            embeddings = np.append(embeddings , embeds)
            labels = np.append(labels,labs.cpu())
  
    embeddings = embeddings.reshape(-1, 1280)
    
    c_labels = labels.reshape(-1 , 1).ravel()
    tsne = TSNE(n_components=2,perplexity=2).fit_transform(embeddings)
    labels = np.array([ idx2class[ele] for ele in c_labels])
    
    cmap = cm.get_cmap('tab20')
    
    for lab in range(num_categories):
        indices = (c_labels == lab)
        plt.scatter(tsne[indices, 0],tsne[indices, 1],c=np.array(cmap(lab)).reshape(1, 4),label=lab,alpha=1)
        plt.legend(fontsize='large', markerscale=2)
    plt.show()
  
# model = Model((224,224))
# train_loader, val_loader ,test_loader = load_Data()
# visualize(model,test_loader)

# %%
def plotloss():
  plt.figure(figsize=(20,10))
  plt.plot(epochnum, trainloss)
  plt.plot(epochnum, valloss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
class2idx = {'cat': 0, 'cow': 1, 'dog': 2, 'elephant': 3, 'horse': 4}
idx2class = { value : key  for key , value in class2idx.items() }

def plot_confusion_matrix(data, labels, metrics ,output_filename=None):

    [macro_precision , micro_precision , macro_recall , micro_recall] = metrics

    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(10,10))
 
    plt.suptitle("Confusion Matrix")
    plt.title(f"(Macro/Micro) Precision : {round(macro_precision,2)}/{round(micro_precision,2)}   :::::   (Macro/Micro) Recall : {round(macro_recall,2)}/{round(micro_recall,2)}")
 
    seaborn.set(font_scale=1)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu",linewidths=2 , fmt='d' ,cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# %%
def main():
    model = Model((224,224));
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        model = model.cuda()
        print("using gpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    epochs = 30
    train_loader, val_loader ,test_loader = load_Data()
 
    history = open("/content/gdrive/MyDrive/Results/dataset2_MB_history.csv",'w')
    history.write('epochs , trainloss , Train-acc,val_acc , test_acc \n')
    max_accuracy = 0 
    finalepoch  = 0 
    for epoch in range(0,epochs):
        start = time.time()
        train_loss,accuracy = train(model, train_loader, criterion, optimizer, epoch)
        vallosss,val_loss = val(model, val_loader, criterion, optimizer, epoch)
        
        trainloss.append(train_loss.cpu().detach().numpy())
        valloss.append(vallosss.cpu().detach().numpy())
        epochnum.append(epoch)
        print()
        print('-' * 50)
        print('EPOCH {} | LOSS {} | TIME {}'.format(epoch, train_loss, time.time() - start))
        print('-' * 50)
        print()

        if(val_loss > max_accuracy):
          max_accuracy = val_loss
          finalepoch  = epoch
          save_checkpoint({'epoch': epoch,'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),'loss' : train_loss}, "/content/gdrive/MyDrive/Checkpoints/dataset2_MB_checkpoint.ckpt")

        history.write('{},{},{},{}\n'.format(epoch, train_loss,accuracy, val_loss ))
    test_loss = test(model, test_loader, criterion, optimizer, finalepoch)    
    history.close()
    visualize(model,train_loader)

# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    main()
# Out:
# True
# using gpu
# {'cat': 0, 'cow': 1, 'dog': 2, 'elephant': 3, 'horse': 4}
# EPOCH 0 | ITER 0 | AVG_LOSS 1.611883521080017 | Train_ACC 12.5
# EPOCH 0 | ITER 5 | AVG_LOSS 1.577305555343628 | Train_ACC 31.25
# EPOCH 0 | ITER 10 | AVG_LOSS 1.5648683309555054 | Train_ACC 25.0
# EPOCH 0 | ITER 15 | AVG_LOSS 1.5550867319107056 | Train_ACC 46.875
# EPOCH 0 | ITER 20 | AVG_LOSS 1.5499602556228638 | Train_ACC 28.125
# EPOCH 0 | ITER 25 | AVG_LOSS 1.5449261665344238 | Train_ACC 40.625
# EPOCH 0 | ITER 30 | AVG_LOSS 1.541961908340454 | Train_ACC 37.5
# EPOCH 0 | ITER 35 | AVG_LOSS 1.5329740047454834 | Train_ACC 25.0
# EPOCH 0 | ITER 40 | AVG_LOSS 1.5334385633468628 | Train_ACC 25.0
# EPOCH 0 | ITER 45 | AVG_LOSS 1.523186206817627 | Train_ACC 34.375
# EPOCH 0 | ITER 50 | AVG_LOSS 1.515142798423767 | Train_ACC 40.625
# EPOCH 0 | ITER 55 | AVG_LOSS 1.5054786205291748 | Train_ACC 43.75
# EPOCH 0 | ITER 60 | AVG_LOSS 1.4997296333312988 | Train_ACC 31.25
# EPOCH 0 | ITER 65 | AVG_LOSS 1.494497299194336 | Train_ACC 31.25
# EPOCH 0 | ITER 70 | AVG_LOSS 1.4932680130004883 | Train_ACC 28.125
# EPOCH 0 | ITER 75 | AVG_LOSS 1.4934732913970947 | Train_ACC 34.375
# EPOCH 0 | ITER 80 | AVG_LOSS 1.4925659894943237 | Train_ACC 37.5
# EPOCH 0 | ITER 85 | AVG_LOSS 1.489557147026062 | Train_ACC 34.375
# EPOCH 0 | ITER 90 | AVG_LOSS 1.4843944311141968 | Train_ACC 34.375
# EPOCH 0 | ITER 95 | AVG_LOSS 1.4830007553100586 | Train_ACC 40.625
# EPOCH 0 | ITER 100 | AVG_LOSS 1.4763615131378174 | Train_ACC 40.625
# EPOCH 0 | ITER 105 | AVG_LOSS 1.4699060916900635 | Train_ACC 37.5
# EPOCH 0 | ITER 110 | AVG_LOSS 1.4682892560958862 | Train_ACC 34.375
# EPOCH 0 | ITER 115 | AVG_LOSS 1.4635993242263794 | Train_ACC 37.5
# EPOCH 0 | ITER 120 | AVG_LOSS 1.4610942602157593 | Train_ACC 43.75
# EPOCH 0 | ITER 125 | AVG_LOSS 1.4629162549972534 | Train_ACC 34.375
# EPOCH 0 | ITER 130 | AVG_LOSS 1.461167812347412 | Train_ACC 34.375
# EPOCH 0 | ITER 135 | AVG_LOSS 1.4605803489685059 | Train_ACC 34.375
# EPOCH 0 | ITER 140 | AVG_LOSS 1.4598617553710938 | Train_ACC 21.875
# EPOCH 0 | ITER 145 | AVG_LOSS 1.4566560983657837 | Train_ACC 40.625
# EPOCH 0 | ITER 150 | AVG_LOSS 1.4565505981445312 | Train_ACC 31.25
# EPOCH 0 | ITER 155 | AVG_LOSS 1.4555141925811768 | Train_ACC 40.625
# EPOCH 0 | ITER 160 | AVG_LOSS 1.4556447267532349 | Train_ACC 40.625
# EPOCH 0 | ITER 165 | AVG_LOSS 1.4552747011184692 | Train_ACC 25.0
# EPOCH 0 | ITER 170 | AVG_LOSS 1.453598976135254 | Train_ACC 43.75
# EPOCH 0 | ITER 175 | AVG_LOSS 1.4500230550765991 | Train_ACC 50.0
# EPOCH 0 | ITER 180 | AVG_LOSS 1.4481455087661743 | Train_ACC 40.625
# EPOCH 0 | ITER 185 | AVG_LOSS 1.4436458349227905 | Train_ACC 31.25
# EPOCH 0 | ITER 190 | AVG_LOSS 1.4407845735549927 | Train_ACC 31.25
# EPOCH 0 | ITER 195 | AVG_LOSS 1.4388779401779175 | Train_ACC 28.125
# EPOCH 0 | ITER 200 | AVG_LOSS 1.4379527568817139 | Train_ACC 31.25
# EPOCH 0 | ITER 205 | AVG_LOSS 1.4377386569976807 | Train_ACC 34.375
# EPOCH 0 | ITER 210 | AVG_LOSS 1.434281826019287 | Train_ACC 37.5
# EPOCH 0 | ITER 215 | AVG_LOSS 1.4335029125213623 | Train_ACC 31.25
# EPOCH 0 | ITER 220 | AVG_LOSS 1.4329838752746582 | Train_ACC 37.5
# EPOCH 0 | ITER 225 | AVG_LOSS 1.4326022863388062 | Train_ACC 40.625
# EPOCH 0 | ITER 230 | AVG_LOSS 1.430711269378662 | Train_ACC 28.125
# EPOCH 0 | ITER 235 | AVG_LOSS 1.4289597272872925 | Train_ACC 37.5
# EPOCH 0 | ITER 240 | AVG_LOSS 1.4268032312393188 | Train_ACC 31.25
# EPOCH 0 | ITER 245 | AVG_LOSS 1.4244376420974731 | Train_ACC 50.0
# Val Accuracy: 34.47%
#
# --------------------------------------------------
# EPOCH 0 | LOSS 1.3448781967163086 | TIME 273.6891152858734
# --------------------------------------------------
#
# EPOCH 1 | ITER 0 | AVG_LOSS 1.4403878450393677 | Train_ACC 31.25
# EPOCH 1 | ITER 5 | AVG_LOSS 1.3602988719940186 | Train_ACC 40.625
# EPOCH 1 | ITER 10 | AVG_LOSS 1.347391128540039 | Train_ACC 34.375
# EPOCH 1 | ITER 15 | AVG_LOSS 1.335275650024414 | Train_ACC 50.0
# EPOCH 1 | ITER 20 | AVG_LOSS 1.3506085872650146 | Train_ACC 28.125
# EPOCH 1 | ITER 25 | AVG_LOSS 1.3372633457183838 | Train_ACC 43.75
# EPOCH 1 | ITER 30 | AVG_LOSS 1.3324719667434692 | Train_ACC 28.125
# EPOCH 1 | ITER 35 | AVG_LOSS 1.3361190557479858 | Train_ACC 37.5
# EPOCH 1 | ITER 40 | AVG_LOSS 1.3339576721191406 | Train_ACC 46.875
# EPOCH 1 | ITER 45 | AVG_LOSS 1.3408643007278442 | Train_ACC 28.125
# EPOCH 1 | ITER 50 | AVG_LOSS 1.3462564945220947 | Train_ACC 34.375
# EPOCH 1 | ITER 55 | AVG_LOSS 1.3458136320114136 | Train_ACC 40.625
# EPOCH 1 | ITER 60 | AVG_LOSS 1.3462868928909302 | Train_ACC 43.75
# EPOCH 1 | ITER 65 | AVG_LOSS 1.346239447593689 | Train_ACC 50.0
# EPOCH 1 | ITER 70 | AVG_LOSS 1.3472487926483154 | Train_ACC 43.75
# EPOCH 1 | ITER 75 | AVG_LOSS 1.3515938520431519 | Train_ACC 31.25
# EPOCH 1 | ITER 80 | AVG_LOSS 1.3494904041290283 | Train_ACC 37.5
# EPOCH 1 | ITER 85 | AVG_LOSS 1.348733901977539 | Train_ACC 37.5
# EPOCH 1 | ITER 90 | AVG_LOSS 1.3482550382614136 | Train_ACC 40.625
# EPOCH 1 | ITER 95 | AVG_LOSS 1.348061442375183 | Train_ACC 34.375
# EPOCH 1 | ITER 100 | AVG_LOSS 1.343801498413086 | Train_ACC 59.375
# EPOCH 1 | ITER 105 | AVG_LOSS 1.3447941541671753 | Train_ACC 34.375
# EPOCH 1 | ITER 110 | AVG_LOSS 1.3439151048660278 | Train_ACC 21.875
# EPOCH 1 | ITER 115 | AVG_LOSS 1.3426772356033325 | Train_ACC 34.375
# EPOCH 1 | ITER 120 | AVG_LOSS 1.3397653102874756 | Train_ACC 37.5
# EPOCH 1 | ITER 125 | AVG_LOSS 1.336901307106018 | Train_ACC 53.125
# EPOCH 1 | ITER 130 | AVG_LOSS 1.3341768980026245 | Train_ACC 50.0
# EPOCH 1 | ITER 135 | AVG_LOSS 1.3320280313491821 | Train_ACC 37.5
# EPOCH 1 | ITER 140 | AVG_LOSS 1.3318438529968262 | Train_ACC 28.125
# EPOCH 1 | ITER 145 | AVG_LOSS 1.3292407989501953 | Train_ACC 40.625
# EPOCH 1 | ITER 150 | AVG_LOSS 1.3271812200546265 | Train_ACC 40.625
# EPOCH 1 | ITER 155 | AVG_LOSS 1.327163577079773 | Train_ACC 53.125
# EPOCH 1 | ITER 160 | AVG_LOSS 1.3268429040908813 | Train_ACC 34.375
# EPOCH 1 | ITER 165 | AVG_LOSS 1.3231209516525269 | Train_ACC 34.375
# EPOCH 1 | ITER 170 | AVG_LOSS 1.3214131593704224 | Train_ACC 31.25
# EPOCH 1 | ITER 175 | AVG_LOSS 1.3194799423217773 | Train_ACC 46.875
# EPOCH 1 | ITER 180 | AVG_LOSS 1.3187190294265747 | Train_ACC 37.5
# EPOCH 1 | ITER 185 | AVG_LOSS 1.3173753023147583 | Train_ACC 53.125
# EPOCH 1 | ITER 190 | AVG_LOSS 1.3177963495254517 | Train_ACC 37.5
# EPOCH 1 | ITER 195 | AVG_LOSS 1.3179017305374146 | Train_ACC 34.375
# EPOCH 1 | ITER 200 | AVG_LOSS 1.318767786026001 | Train_ACC 40.625
# EPOCH 1 | ITER 205 | AVG_LOSS 1.3165254592895508 | Train_ACC 59.375
# EPOCH 1 | ITER 210 | AVG_LOSS 1.3145314455032349 | Train_ACC 46.875
# EPOCH 1 | ITER 215 | AVG_LOSS 1.3134713172912598 | Train_ACC 31.25
# EPOCH 1 | ITER 220 | AVG_LOSS 1.312467098236084 | Train_ACC 43.75
# EPOCH 1 | ITER 225 | AVG_LOSS 1.3137013912200928 | Train_ACC 31.25
# EPOCH 1 | ITER 230 | AVG_LOSS 1.311139702796936 | Train_ACC 53.125
# EPOCH 1 | ITER 235 | AVG_LOSS 1.3130569458007812 | Train_ACC 37.5
# EPOCH 1 | ITER 240 | AVG_LOSS 1.3122506141662598 | Train_ACC 34.375
# EPOCH 1 | ITER 245 | AVG_LOSS 1.3114094734191895 | Train_ACC 50.0
# Val Accuracy: 42.76%
#
# --------------------------------------------------
# EPOCH 1 | LOSS 1.4614691734313965 | TIME 234.91682696342468
# --------------------------------------------------
#
# EPOCH 2 | ITER 0 | AVG_LOSS 1.1323668956756592 | Train_ACC 59.375
# EPOCH 2 | ITER 5 | AVG_LOSS 1.2274366617202759 | Train_ACC 37.5
# EPOCH 2 | ITER 10 | AVG_LOSS 1.2251861095428467 | Train_ACC 56.25
# EPOCH 2 | ITER 15 | AVG_LOSS 1.2035595178604126 | Train_ACC 62.5
# EPOCH 2 | ITER 20 | AVG_LOSS 1.2070177793502808 | Train_ACC 46.875
# EPOCH 2 | ITER 25 | AVG_LOSS 1.2108039855957031 | Train_ACC 56.25
# EPOCH 2 | ITER 30 | AVG_LOSS 1.2291734218597412 | Train_ACC 46.875
# EPOCH 2 | ITER 35 | AVG_LOSS 1.241570234298706 | Train_ACC 46.875
# EPOCH 2 | ITER 40 | AVG_LOSS 1.2498880624771118 | Train_ACC 31.25
# EPOCH 2 | ITER 45 | AVG_LOSS 1.249024748802185 | Train_ACC 40.625
# EPOCH 2 | ITER 50 | AVG_LOSS 1.2382216453552246 | Train_ACC 40.625
# EPOCH 2 | ITER 55 | AVG_LOSS 1.2353196144104004 | Train_ACC 65.625
# EPOCH 2 | ITER 60 | AVG_LOSS 1.2322479486465454 | Train_ACC 37.5
# EPOCH 2 | ITER 65 | AVG_LOSS 1.2319953441619873 | Train_ACC 46.875
# EPOCH 2 | ITER 70 | AVG_LOSS 1.233217716217041 | Train_ACC 40.625
# EPOCH 2 | ITER 75 | AVG_LOSS 1.2387280464172363 | Train_ACC 40.625
# EPOCH 2 | ITER 80 | AVG_LOSS 1.2424120903015137 | Train_ACC 50.0
# EPOCH 2 | ITER 85 | AVG_LOSS 1.243587851524353 | Train_ACC 28.125
# EPOCH 2 | ITER 90 | AVG_LOSS 1.2420732975006104 | Train_ACC 34.375
# EPOCH 2 | ITER 95 | AVG_LOSS 1.2426731586456299 | Train_ACC 43.75
# EPOCH 2 | ITER 100 | AVG_LOSS 1.247463345527649 | Train_ACC 40.625
# EPOCH 2 | ITER 105 | AVG_LOSS 1.248797059059143 | Train_ACC 40.625
# EPOCH 2 | ITER 110 | AVG_LOSS 1.2495405673980713 | Train_ACC 43.75
# EPOCH 2 | ITER 115 | AVG_LOSS 1.2508490085601807 | Train_ACC 50.0
# EPOCH 2 | ITER 120 | AVG_LOSS 1.2516616582870483 | Train_ACC 37.5
# EPOCH 2 | ITER 125 | AVG_LOSS 1.2522281408309937 | Train_ACC 21.875
# EPOCH 2 | ITER 130 | AVG_LOSS 1.2535027265548706 | Train_ACC 46.875
# EPOCH 2 | ITER 135 | AVG_LOSS 1.253480315208435 | Train_ACC 43.75
# EPOCH 2 | ITER 140 | AVG_LOSS 1.2541767358779907 | Train_ACC 43.75
# EPOCH 2 | ITER 145 | AVG_LOSS 1.254836916923523 | Train_ACC 28.125
# EPOCH 2 | ITER 150 | AVG_LOSS 1.2530096769332886 | Train_ACC 59.375
# EPOCH 2 | ITER 155 | AVG_LOSS 1.255675196647644 | Train_ACC 34.375
# EPOCH 2 | ITER 160 | AVG_LOSS 1.2580773830413818 | Train_ACC 28.125
# EPOCH 2 | ITER 165 | AVG_LOSS 1.2593499422073364 | Train_ACC 46.875
# EPOCH 2 | ITER 170 | AVG_LOSS 1.2573535442352295 | Train_ACC 50.0
# EPOCH 2 | ITER 175 | AVG_LOSS 1.2553157806396484 | Train_ACC 50.0
# EPOCH 2 | ITER 180 | AVG_LOSS 1.2526485919952393 | Train_ACC 46.875
# EPOCH 2 | ITER 185 | AVG_LOSS 1.25706946849823 | Train_ACC 37.5
# EPOCH 2 | ITER 190 | AVG_LOSS 1.2576793432235718 | Train_ACC 40.625
# EPOCH 2 | ITER 195 | AVG_LOSS 1.2583824396133423 | Train_ACC 43.75
# EPOCH 2 | ITER 200 | AVG_LOSS 1.2569639682769775 | Train_ACC 50.0
# EPOCH 2 | ITER 205 | AVG_LOSS 1.2579327821731567 | Train_ACC 43.75
# EPOCH 2 | ITER 210 | AVG_LOSS 1.25968599319458 | Train_ACC 46.875
# EPOCH 2 | ITER 215 | AVG_LOSS 1.2568403482437134 | Train_ACC 59.375
# EPOCH 2 | ITER 220 | AVG_LOSS 1.255204439163208 | Train_ACC 53.125
# EPOCH 2 | ITER 225 | AVG_LOSS 1.2538493871688843 | Train_ACC 59.375
# EPOCH 2 | ITER 230 | AVG_LOSS 1.2527060508728027 | Train_ACC 34.375
# EPOCH 2 | ITER 235 | AVG_LOSS 1.2556843757629395 | Train_ACC 25.0
# EPOCH 2 | ITER 240 | AVG_LOSS 1.2556040287017822 | Train_ACC 40.625
# EPOCH 2 | ITER 245 | AVG_LOSS 1.2561566829681396 | Train_ACC 43.75
# Val Accuracy: 42.36%
#
# --------------------------------------------------
# EPOCH 2 | LOSS 1.3481053113937378 | TIME 235.15519905090332
# --------------------------------------------------
#
# EPOCH 3 | ITER 0 | AVG_LOSS 1.2797627449035645 | Train_ACC 34.375
# EPOCH 3 | ITER 5 | AVG_LOSS 1.2465324401855469 | Train_ACC 40.625
# EPOCH 3 | ITER 10 | AVG_LOSS 1.2291818857192993 | Train_ACC 34.375
# EPOCH 3 | ITER 15 | AVG_LOSS 1.1844455003738403 | Train_ACC 56.25
# EPOCH 3 | ITER 20 | AVG_LOSS 1.1764887571334839 | Train_ACC 46.875
# EPOCH 3 | ITER 25 | AVG_LOSS 1.174497365951538 | Train_ACC 50.0
# EPOCH 3 | ITER 30 | AVG_LOSS 1.1770637035369873 | Train_ACC 59.375
# EPOCH 3 | ITER 35 | AVG_LOSS 1.1787290573120117 | Train_ACC 50.0
# EPOCH 3 | ITER 40 | AVG_LOSS 1.1782745122909546 | Train_ACC 46.875
# EPOCH 3 | ITER 45 | AVG_LOSS 1.176113247871399 | Train_ACC 50.0
# EPOCH 3 | ITER 50 | AVG_LOSS 1.1739068031311035 | Train_ACC 50.0
# EPOCH 3 | ITER 55 | AVG_LOSS 1.1711218357086182 | Train_ACC 37.5
# EPOCH 3 | ITER 60 | AVG_LOSS 1.1758276224136353 | Train_ACC 46.875
# EPOCH 3 | ITER 65 | AVG_LOSS 1.1840802431106567 | Train_ACC 43.75
# EPOCH 3 | ITER 70 | AVG_LOSS 1.180137038230896 | Train_ACC 62.5
# EPOCH 3 | ITER 75 | AVG_LOSS 1.1822633743286133 | Train_ACC 46.875
# EPOCH 3 | ITER 80 | AVG_LOSS 1.179155945777893 | Train_ACC 40.625
# EPOCH 3 | ITER 85 | AVG_LOSS 1.180936574935913 | Train_ACC 46.875
# EPOCH 3 | ITER 90 | AVG_LOSS 1.17827308177948 | Train_ACC 46.875
# EPOCH 3 | ITER 95 | AVG_LOSS 1.175330638885498 | Train_ACC 46.875
# EPOCH 3 | ITER 100 | AVG_LOSS 1.177237868309021 | Train_ACC 56.25
# EPOCH 3 | ITER 105 | AVG_LOSS 1.171717882156372 | Train_ACC 43.75
# EPOCH 3 | ITER 110 | AVG_LOSS 1.1721649169921875 | Train_ACC 40.625
# EPOCH 3 | ITER 115 | AVG_LOSS 1.1704092025756836 | Train_ACC 56.25
# EPOCH 3 | ITER 120 | AVG_LOSS 1.1712630987167358 | Train_ACC 50.0
# EPOCH 3 | ITER 125 | AVG_LOSS 1.1697500944137573 | Train_ACC 56.25
# EPOCH 3 | ITER 130 | AVG_LOSS 1.1679826974868774 | Train_ACC 53.125
# EPOCH 3 | ITER 135 | AVG_LOSS 1.1678695678710938 | Train_ACC 59.375
# EPOCH 3 | ITER 140 | AVG_LOSS 1.168110728263855 | Train_ACC 62.5
# EPOCH 3 | ITER 145 | AVG_LOSS 1.1651393175125122 | Train_ACC 59.375
# EPOCH 3 | ITER 150 | AVG_LOSS 1.162269115447998 | Train_ACC 40.625
# EPOCH 3 | ITER 155 | AVG_LOSS 1.1635122299194336 | Train_ACC 31.25
# EPOCH 3 | ITER 160 | AVG_LOSS 1.1643438339233398 | Train_ACC 56.25
# EPOCH 3 | ITER 165 | AVG_LOSS 1.166895866394043 | Train_ACC 50.0
# EPOCH 3 | ITER 170 | AVG_LOSS 1.1701675653457642 | Train_ACC 53.125
# EPOCH 3 | ITER 175 | AVG_LOSS 1.1707905530929565 | Train_ACC 40.625
# EPOCH 3 | ITER 180 | AVG_LOSS 1.173351764678955 | Train_ACC 46.875
# EPOCH 3 | ITER 185 | AVG_LOSS 1.1743983030319214 | Train_ACC 50.0
# EPOCH 3 | ITER 190 | AVG_LOSS 1.1739600896835327 | Train_ACC 40.625
# EPOCH 3 | ITER 195 | AVG_LOSS 1.1732507944107056 | Train_ACC 50.0
# EPOCH 3 | ITER 200 | AVG_LOSS 1.1750152111053467 | Train_ACC 37.5
# EPOCH 3 | ITER 205 | AVG_LOSS 1.1739689111709595 | Train_ACC 40.625
# EPOCH 3 | ITER 210 | AVG_LOSS 1.1773526668548584 | Train_ACC 40.625
# EPOCH 3 | ITER 215 | AVG_LOSS 1.1772032976150513 | Train_ACC 50.0
# EPOCH 3 | ITER 220 | AVG_LOSS 1.178316593170166 | Train_ACC 50.0
# EPOCH 3 | ITER 225 | AVG_LOSS 1.1786214113235474 | Train_ACC 34.375
# EPOCH 3 | ITER 230 | AVG_LOSS 1.1812922954559326 | Train_ACC 43.75
# EPOCH 3 | ITER 235 | AVG_LOSS 1.177984595298767 | Train_ACC 40.625
# EPOCH 3 | ITER 240 | AVG_LOSS 1.1781924962997437 | Train_ACC 46.875
# EPOCH 3 | ITER 245 | AVG_LOSS 1.1780450344085693 | Train_ACC 56.25
# Val Accuracy: 47.45%
#
# --------------------------------------------------
# EPOCH 3 | LOSS 1.260307788848877 | TIME 234.1886260509491
# --------------------------------------------------
#
# EPOCH 4 | ITER 0 | AVG_LOSS 0.9586650133132935 | Train_ACC 56.25
# EPOCH 4 | ITER 5 | AVG_LOSS 1.051053524017334 | Train_ACC 46.875
# EPOCH 4 | ITER 10 | AVG_LOSS 1.0330719947814941 | Train_ACC 46.875
# EPOCH 4 | ITER 15 | AVG_LOSS 1.065144658088684 | Train_ACC 56.25
# EPOCH 4 | ITER 20 | AVG_LOSS 1.0545228719711304 | Train_ACC 56.25
# EPOCH 4 | ITER 25 | AVG_LOSS 1.0461479425430298 | Train_ACC 59.375
# EPOCH 4 | ITER 30 | AVG_LOSS 1.057582139968872 | Train_ACC 43.75
# EPOCH 4 | ITER 35 | AVG_LOSS 1.0713953971862793 | Train_ACC 46.875
# EPOCH 4 | ITER 40 | AVG_LOSS 1.0803709030151367 | Train_ACC 50.0
# EPOCH 4 | ITER 45 | AVG_LOSS 1.0881744623184204 | Train_ACC 34.375
# EPOCH 4 | ITER 50 | AVG_LOSS 1.0921510457992554 | Train_ACC 68.75
# EPOCH 4 | ITER 55 | AVG_LOSS 1.0903874635696411 | Train_ACC 62.5
# EPOCH 4 | ITER 60 | AVG_LOSS 1.100187063217163 | Train_ACC 46.875
# EPOCH 4 | ITER 65 | AVG_LOSS 1.095786213874817 | Train_ACC 56.25
# EPOCH 4 | ITER 70 | AVG_LOSS 1.0998042821884155 | Train_ACC 34.375
# EPOCH 4 | ITER 75 | AVG_LOSS 1.0944156646728516 | Train_ACC 65.625
# EPOCH 4 | ITER 80 | AVG_LOSS 1.1060105562210083 | Train_ACC 59.375
# EPOCH 4 | ITER 85 | AVG_LOSS 1.1012077331542969 | Train_ACC 40.625
# EPOCH 4 | ITER 90 | AVG_LOSS 1.101096510887146 | Train_ACC 53.125
# EPOCH 4 | ITER 95 | AVG_LOSS 1.0982731580734253 | Train_ACC 65.625
# EPOCH 4 | ITER 100 | AVG_LOSS 1.0949797630310059 | Train_ACC 53.125
# EPOCH 4 | ITER 105 | AVG_LOSS 1.0920525789260864 | Train_ACC 59.375
# EPOCH 4 | ITER 110 | AVG_LOSS 1.0874346494674683 | Train_ACC 65.625
# EPOCH 4 | ITER 115 | AVG_LOSS 1.087276577949524 | Train_ACC 53.125
# EPOCH 4 | ITER 120 | AVG_LOSS 1.0884302854537964 | Train_ACC 56.25
# EPOCH 4 | ITER 125 | AVG_LOSS 1.0881034135818481 | Train_ACC 59.375
# EPOCH 4 | ITER 130 | AVG_LOSS 1.0877714157104492 | Train_ACC 53.125
# EPOCH 4 | ITER 135 | AVG_LOSS 1.0914338827133179 | Train_ACC 50.0
# EPOCH 4 | ITER 140 | AVG_LOSS 1.09141206741333 | Train_ACC 65.625
# EPOCH 4 | ITER 145 | AVG_LOSS 1.0933834314346313 | Train_ACC 46.875
# EPOCH 4 | ITER 150 | AVG_LOSS 1.0881810188293457 | Train_ACC 62.5
# EPOCH 4 | ITER 155 | AVG_LOSS 1.0922162532806396 | Train_ACC 46.875
# EPOCH 4 | ITER 160 | AVG_LOSS 1.0916385650634766 | Train_ACC 62.5
# EPOCH 4 | ITER 165 | AVG_LOSS 1.0908490419387817 | Train_ACC 68.75
# EPOCH 4 | ITER 170 | AVG_LOSS 1.0894025564193726 | Train_ACC 50.0
# EPOCH 4 | ITER 175 | AVG_LOSS 1.0902539491653442 | Train_ACC 40.625
# EPOCH 4 | ITER 180 | AVG_LOSS 1.0918622016906738 | Train_ACC 71.875
# EPOCH 4 | ITER 185 | AVG_LOSS 1.0923659801483154 | Train_ACC 56.25
# EPOCH 4 | ITER 190 | AVG_LOSS 1.0926028490066528 | Train_ACC 50.0
# EPOCH 4 | ITER 195 | AVG_LOSS 1.0934191942214966 | Train_ACC 50.0
# EPOCH 4 | ITER 200 | AVG_LOSS 1.09199857711792 | Train_ACC 59.375
# EPOCH 4 | ITER 205 | AVG_LOSS 1.0907882452011108 | Train_ACC 43.75
# EPOCH 4 | ITER 210 | AVG_LOSS 1.0906444787979126 | Train_ACC 68.75
# EPOCH 4 | ITER 215 | AVG_LOSS 1.0881428718566895 | Train_ACC 65.625
# EPOCH 4 | ITER 220 | AVG_LOSS 1.0882965326309204 | Train_ACC 56.25
# EPOCH 4 | ITER 225 | AVG_LOSS 1.0882236957550049 | Train_ACC 40.625
# EPOCH 4 | ITER 230 | AVG_LOSS 1.0882607698440552 | Train_ACC 56.25
# EPOCH 4 | ITER 235 | AVG_LOSS 1.0894145965576172 | Train_ACC 37.5
# EPOCH 4 | ITER 240 | AVG_LOSS 1.0899912118911743 | Train_ACC 46.875
# EPOCH 4 | ITER 245 | AVG_LOSS 1.089573860168457 | Train_ACC 53.125
# Val Accuracy: 53.15%
#
# --------------------------------------------------
# EPOCH 4 | LOSS 1.2204374074935913 | TIME 237.65030527114868
# --------------------------------------------------
#
# EPOCH 5 | ITER 0 | AVG_LOSS 1.1850389242172241 | Train_ACC 34.375
# EPOCH 5 | ITER 5 | AVG_LOSS 1.08465576171875 | Train_ACC 56.25
# EPOCH 5 | ITER 10 | AVG_LOSS 1.0637637376785278 | Train_ACC 78.125
# EPOCH 5 | ITER 15 | AVG_LOSS 1.02276611328125 | Train_ACC 53.125
# EPOCH 5 | ITER 20 | AVG_LOSS 1.022379755973816 | Train_ACC 56.25
# EPOCH 5 | ITER 25 | AVG_LOSS 0.9948785305023193 | Train_ACC 68.75
# EPOCH 5 | ITER 30 | AVG_LOSS 0.9786641597747803 | Train_ACC 59.375
# EPOCH 5 | ITER 35 | AVG_LOSS 0.9894798398017883 | Train_ACC 56.25
# EPOCH 5 | ITER 40 | AVG_LOSS 1.0020087957382202 | Train_ACC 37.5
# EPOCH 5 | ITER 45 | AVG_LOSS 1.0152654647827148 | Train_ACC 50.0
# EPOCH 5 | ITER 50 | AVG_LOSS 1.0251166820526123 | Train_ACC 68.75
# EPOCH 5 | ITER 55 | AVG_LOSS 1.035552978515625 | Train_ACC 56.25
# EPOCH 5 | ITER 60 | AVG_LOSS 1.035874366760254 | Train_ACC 40.625
# EPOCH 5 | ITER 65 | AVG_LOSS 1.0334583520889282 | Train_ACC 59.375
# EPOCH 5 | ITER 70 | AVG_LOSS 1.0324503183364868 | Train_ACC 59.375
# EPOCH 5 | ITER 75 | AVG_LOSS 1.0411489009857178 | Train_ACC 37.5
# EPOCH 5 | ITER 80 | AVG_LOSS 1.0483477115631104 | Train_ACC 50.0
# EPOCH 5 | ITER 85 | AVG_LOSS 1.0507702827453613 | Train_ACC 50.0
# EPOCH 5 | ITER 90 | AVG_LOSS 1.0522621870040894 | Train_ACC 53.125
# EPOCH 5 | ITER 95 | AVG_LOSS 1.0519812107086182 | Train_ACC 56.25
# EPOCH 5 | ITER 100 | AVG_LOSS 1.0493782758712769 | Train_ACC 53.125
# EPOCH 5 | ITER 105 | AVG_LOSS 1.0427069664001465 | Train_ACC 65.625
# EPOCH 5 | ITER 110 | AVG_LOSS 1.0396370887756348 | Train_ACC 59.375
# EPOCH 5 | ITER 115 | AVG_LOSS 1.0402182340621948 | Train_ACC 65.625
# EPOCH 5 | ITER 120 | AVG_LOSS 1.0422108173370361 | Train_ACC 56.25
# EPOCH 5 | ITER 125 | AVG_LOSS 1.0394543409347534 | Train_ACC 59.375
# EPOCH 5 | ITER 130 | AVG_LOSS 1.0408601760864258 | Train_ACC 46.875
# EPOCH 5 | ITER 135 | AVG_LOSS 1.0453343391418457 | Train_ACC 65.625
# EPOCH 5 | ITER 140 | AVG_LOSS 1.0466032028198242 | Train_ACC 59.375
# EPOCH 5 | ITER 145 | AVG_LOSS 1.046823501586914 | Train_ACC 62.5
# EPOCH 5 | ITER 150 | AVG_LOSS 1.0471187829971313 | Train_ACC 56.25
# EPOCH 5 | ITER 155 | AVG_LOSS 1.0492281913757324 | Train_ACC 46.875
# EPOCH 5 | ITER 160 | AVG_LOSS 1.0498344898223877 | Train_ACC 68.75
# EPOCH 5 | ITER 165 | AVG_LOSS 1.047556757926941 | Train_ACC 62.5
# EPOCH 5 | ITER 170 | AVG_LOSS 1.0434579849243164 | Train_ACC 53.125
# EPOCH 5 | ITER 175 | AVG_LOSS 1.0411665439605713 | Train_ACC 65.625
# EPOCH 5 | ITER 180 | AVG_LOSS 1.0386574268341064 | Train_ACC 62.5
# EPOCH 5 | ITER 185 | AVG_LOSS 1.0370125770568848 | Train_ACC 53.125
# EPOCH 5 | ITER 190 | AVG_LOSS 1.0406367778778076 | Train_ACC 56.25
# EPOCH 5 | ITER 195 | AVG_LOSS 1.0400642156600952 | Train_ACC 59.375
# EPOCH 5 | ITER 200 | AVG_LOSS 1.0376744270324707 | Train_ACC 68.75
# EPOCH 5 | ITER 205 | AVG_LOSS 1.0394017696380615 | Train_ACC 56.25
# EPOCH 5 | ITER 210 | AVG_LOSS 1.0370538234710693 | Train_ACC 50.0
# EPOCH 5 | ITER 215 | AVG_LOSS 1.0359766483306885 | Train_ACC 62.5
# EPOCH 5 | ITER 220 | AVG_LOSS 1.0356950759887695 | Train_ACC 50.0
# EPOCH 5 | ITER 225 | AVG_LOSS 1.0364301204681396 | Train_ACC 59.375
# EPOCH 5 | ITER 230 | AVG_LOSS 1.0349305868148804 | Train_ACC 59.375
# EPOCH 5 | ITER 235 | AVG_LOSS 1.0337023735046387 | Train_ACC 53.125
# EPOCH 5 | ITER 240 | AVG_LOSS 1.0320380926132202 | Train_ACC 65.625
# EPOCH 5 | ITER 245 | AVG_LOSS 1.0270419120788574 | Train_ACC 78.125
# Val Accuracy: 58.04%
#
# --------------------------------------------------
# EPOCH 5 | LOSS 1.2419369220733643 | TIME 234.97569298744202
# --------------------------------------------------
#
# EPOCH 6 | ITER 0 | AVG_LOSS 1.04021155834198 | Train_ACC 62.5
# EPOCH 6 | ITER 5 | AVG_LOSS 0.9296250343322754 | Train_ACC 59.375
# EPOCH 6 | ITER 10 | AVG_LOSS 1.0004123449325562 | Train_ACC 56.25
# EPOCH 6 | ITER 15 | AVG_LOSS 0.9670318365097046 | Train_ACC 53.125
# EPOCH 6 | ITER 20 | AVG_LOSS 0.9591485261917114 | Train_ACC 50.0
# EPOCH 6 | ITER 25 | AVG_LOSS 0.9815053343772888 | Train_ACC 62.5
# EPOCH 6 | ITER 30 | AVG_LOSS 0.9811887741088867 | Train_ACC 56.25
# EPOCH 6 | ITER 35 | AVG_LOSS 0.9904608130455017 | Train_ACC 59.375
# EPOCH 6 | ITER 40 | AVG_LOSS 0.9919324517250061 | Train_ACC 53.125
# EPOCH 6 | ITER 45 | AVG_LOSS 0.9871079325675964 | Train_ACC 53.125
# EPOCH 6 | ITER 50 | AVG_LOSS 0.9847965836524963 | Train_ACC 68.75
# EPOCH 6 | ITER 55 | AVG_LOSS 0.9841680526733398 | Train_ACC 46.875
# EPOCH 6 | ITER 60 | AVG_LOSS 0.9798003435134888 | Train_ACC 59.375
# EPOCH 6 | ITER 65 | AVG_LOSS 0.9868412017822266 | Train_ACC 62.5
# EPOCH 6 | ITER 70 | AVG_LOSS 0.9906615018844604 | Train_ACC 40.625
# EPOCH 6 | ITER 75 | AVG_LOSS 0.9862498044967651 | Train_ACC 59.375
# EPOCH 6 | ITER 80 | AVG_LOSS 0.9861688613891602 | Train_ACC 62.5
# EPOCH 6 | ITER 85 | AVG_LOSS 0.989662766456604 | Train_ACC 56.25
# EPOCH 6 | ITER 90 | AVG_LOSS 0.9919057488441467 | Train_ACC 71.875
# EPOCH 6 | ITER 95 | AVG_LOSS 0.9864208102226257 | Train_ACC 59.375
# EPOCH 6 | ITER 100 | AVG_LOSS 0.987149715423584 | Train_ACC 78.125
# EPOCH 6 | ITER 105 | AVG_LOSS 0.9850268959999084 | Train_ACC 62.5
# EPOCH 6 | ITER 110 | AVG_LOSS 0.9869897365570068 | Train_ACC 46.875
# EPOCH 6 | ITER 115 | AVG_LOSS 0.984425961971283 | Train_ACC 46.875
# EPOCH 6 | ITER 120 | AVG_LOSS 0.9861263036727905 | Train_ACC 59.375
# EPOCH 6 | ITER 125 | AVG_LOSS 0.9815176129341125 | Train_ACC 56.25
# EPOCH 6 | ITER 130 | AVG_LOSS 0.9879778027534485 | Train_ACC 53.125
# EPOCH 6 | ITER 135 | AVG_LOSS 0.9851756691932678 | Train_ACC 56.25
# EPOCH 6 | ITER 140 | AVG_LOSS 0.9828490018844604 | Train_ACC 53.125
# EPOCH 6 | ITER 145 | AVG_LOSS 0.9809351563453674 | Train_ACC 56.25
# EPOCH 6 | ITER 150 | AVG_LOSS 0.978895366191864 | Train_ACC 53.125
# EPOCH 6 | ITER 155 | AVG_LOSS 0.980381190776825 | Train_ACC 56.25
# EPOCH 6 | ITER 160 | AVG_LOSS 0.9818143844604492 | Train_ACC 46.875
# EPOCH 6 | ITER 165 | AVG_LOSS 0.982422947883606 | Train_ACC 43.75
# EPOCH 6 | ITER 170 | AVG_LOSS 0.9821901321411133 | Train_ACC 62.5
# EPOCH 6 | ITER 175 | AVG_LOSS 0.9815257787704468 | Train_ACC 75.0
# EPOCH 6 | ITER 180 | AVG_LOSS 0.9813986420631409 | Train_ACC 62.5
# EPOCH 6 | ITER 185 | AVG_LOSS 0.9815427660942078 | Train_ACC 50.0
# EPOCH 6 | ITER 190 | AVG_LOSS 0.9804225564002991 | Train_ACC 65.625
# EPOCH 6 | ITER 195 | AVG_LOSS 0.9780246615409851 | Train_ACC 68.75
# EPOCH 6 | ITER 200 | AVG_LOSS 0.9803678393363953 | Train_ACC 62.5
# EPOCH 6 | ITER 205 | AVG_LOSS 0.9796618223190308 | Train_ACC 56.25
# EPOCH 6 | ITER 210 | AVG_LOSS 0.9798827767372131 | Train_ACC 53.125
# EPOCH 6 | ITER 215 | AVG_LOSS 0.9780883193016052 | Train_ACC 75.0
# EPOCH 6 | ITER 220 | AVG_LOSS 0.976067304611206 | Train_ACC 65.625
# EPOCH 6 | ITER 225 | AVG_LOSS 0.9768825173377991 | Train_ACC 50.0
# EPOCH 6 | ITER 230 | AVG_LOSS 0.9779521822929382 | Train_ACC 50.0
# EPOCH 6 | ITER 235 | AVG_LOSS 0.9739682674407959 | Train_ACC 62.5
# EPOCH 6 | ITER 240 | AVG_LOSS 0.9750869274139404 | Train_ACC 59.375
# EPOCH 6 | ITER 245 | AVG_LOSS 0.9766433238983154 | Train_ACC 37.5
# Val Accuracy: 56.44%
#
# --------------------------------------------------
# EPOCH 6 | LOSS 1.091135025024414 | TIME 234.0623915195465
# --------------------------------------------------
#
# EPOCH 7 | ITER 0 | AVG_LOSS 0.9656358957290649 | Train_ACC 56.25
# EPOCH 7 | ITER 5 | AVG_LOSS 0.9830791354179382 | Train_ACC 59.375
# EPOCH 7 | ITER 10 | AVG_LOSS 0.9818315505981445 | Train_ACC 65.625
# EPOCH 7 | ITER 15 | AVG_LOSS 0.9922281503677368 | Train_ACC 50.0
# EPOCH 7 | ITER 20 | AVG_LOSS 0.957751989364624 | Train_ACC 68.75
# EPOCH 7 | ITER 25 | AVG_LOSS 0.9379478096961975 | Train_ACC 50.0
# EPOCH 7 | ITER 30 | AVG_LOSS 0.9480533599853516 | Train_ACC 62.5
# EPOCH 7 | ITER 35 | AVG_LOSS 0.9487658739089966 | Train_ACC 75.0
# EPOCH 7 | ITER 40 | AVG_LOSS 0.9479204416275024 | Train_ACC 65.625
# EPOCH 7 | ITER 45 | AVG_LOSS 0.9435686469078064 | Train_ACC 71.875
# EPOCH 7 | ITER 50 | AVG_LOSS 0.9375647306442261 | Train_ACC 65.625
# EPOCH 7 | ITER 55 | AVG_LOSS 0.9413536190986633 | Train_ACC 56.25
# EPOCH 7 | ITER 60 | AVG_LOSS 0.9525400400161743 | Train_ACC 68.75
# EPOCH 7 | ITER 65 | AVG_LOSS 0.9528427124023438 | Train_ACC 65.625
# EPOCH 7 | ITER 70 | AVG_LOSS 0.9502468705177307 | Train_ACC 59.375
# EPOCH 7 | ITER 75 | AVG_LOSS 0.9471357464790344 | Train_ACC 62.5
# EPOCH 7 | ITER 80 | AVG_LOSS 0.9441435933113098 | Train_ACC 62.5
# EPOCH 7 | ITER 85 | AVG_LOSS 0.9438242316246033 | Train_ACC 59.375
# EPOCH 7 | ITER 90 | AVG_LOSS 0.9539860486984253 | Train_ACC 40.625
# EPOCH 7 | ITER 95 | AVG_LOSS 0.9487748146057129 | Train_ACC 56.25
# EPOCH 7 | ITER 100 | AVG_LOSS 0.9511736035346985 | Train_ACC 56.25
# EPOCH 7 | ITER 105 | AVG_LOSS 0.9507536888122559 | Train_ACC 75.0
# EPOCH 7 | ITER 110 | AVG_LOSS 0.9440698027610779 | Train_ACC 59.375
# EPOCH 7 | ITER 115 | AVG_LOSS 0.949398934841156 | Train_ACC 53.125
# EPOCH 7 | ITER 120 | AVG_LOSS 0.9478006958961487 | Train_ACC 81.25
# EPOCH 7 | ITER 125 | AVG_LOSS 0.9422023296356201 | Train_ACC 65.625
# EPOCH 7 | ITER 130 | AVG_LOSS 0.9439637064933777 | Train_ACC 50.0
# EPOCH 7 | ITER 135 | AVG_LOSS 0.9455882906913757 | Train_ACC 53.125
# EPOCH 7 | ITER 140 | AVG_LOSS 0.9466376304626465 | Train_ACC 65.625
# EPOCH 7 | ITER 145 | AVG_LOSS 0.9468884468078613 | Train_ACC 46.875
# EPOCH 7 | ITER 150 | AVG_LOSS 0.9486057758331299 | Train_ACC 62.5
# EPOCH 7 | ITER 155 | AVG_LOSS 0.9488236904144287 | Train_ACC 46.875
# EPOCH 7 | ITER 160 | AVG_LOSS 0.9492635726928711 | Train_ACC 50.0
# EPOCH 7 | ITER 165 | AVG_LOSS 0.9473380446434021 | Train_ACC 65.625
# EPOCH 7 | ITER 170 | AVG_LOSS 0.946533739566803 | Train_ACC 50.0
# EPOCH 7 | ITER 175 | AVG_LOSS 0.9479203224182129 | Train_ACC 53.125
# EPOCH 7 | ITER 180 | AVG_LOSS 0.9489061832427979 | Train_ACC 56.25
# EPOCH 7 | ITER 185 | AVG_LOSS 0.948599636554718 | Train_ACC 62.5
# EPOCH 7 | ITER 190 | AVG_LOSS 0.9503702521324158 | Train_ACC 56.25
# EPOCH 7 | ITER 195 | AVG_LOSS 0.9481196403503418 | Train_ACC 50.0
# EPOCH 7 | ITER 200 | AVG_LOSS 0.9482436776161194 | Train_ACC 65.625
# EPOCH 7 | ITER 205 | AVG_LOSS 0.9474350810050964 | Train_ACC 56.25
# EPOCH 7 | ITER 210 | AVG_LOSS 0.9480961561203003 | Train_ACC 71.875
# EPOCH 7 | ITER 215 | AVG_LOSS 0.9458885192871094 | Train_ACC 59.375
# EPOCH 7 | ITER 220 | AVG_LOSS 0.9454129338264465 | Train_ACC 50.0
# EPOCH 7 | ITER 225 | AVG_LOSS 0.9462957382202148 | Train_ACC 62.5
# EPOCH 7 | ITER 230 | AVG_LOSS 0.9457334280014038 | Train_ACC 50.0
# EPOCH 7 | ITER 235 | AVG_LOSS 0.9459632039070129 | Train_ACC 71.875
# EPOCH 7 | ITER 240 | AVG_LOSS 0.9458585977554321 | Train_ACC 59.375
# EPOCH 7 | ITER 245 | AVG_LOSS 0.944146990776062 | Train_ACC 62.5
# Val Accuracy: 60.34%
#
# --------------------------------------------------
# EPOCH 7 | LOSS 1.0754295587539673 | TIME 234.84081172943115
# --------------------------------------------------
#
# EPOCH 8 | ITER 0 | AVG_LOSS 0.8686715364456177 | Train_ACC 65.625
# EPOCH 8 | ITER 5 | AVG_LOSS 0.9866353869438171 | Train_ACC 65.625
# EPOCH 8 | ITER 10 | AVG_LOSS 0.9367755055427551 | Train_ACC 65.625
# EPOCH 8 | ITER 15 | AVG_LOSS 0.8914779424667358 | Train_ACC 68.75
# EPOCH 8 | ITER 20 | AVG_LOSS 0.8897724151611328 | Train_ACC 68.75
# EPOCH 8 | ITER 25 | AVG_LOSS 0.8885920643806458 | Train_ACC 50.0
# EPOCH 8 | ITER 30 | AVG_LOSS 0.8940969705581665 | Train_ACC 65.625
# EPOCH 8 | ITER 35 | AVG_LOSS 0.8996431827545166 | Train_ACC 68.75
# EPOCH 8 | ITER 40 | AVG_LOSS 0.9100145101547241 | Train_ACC 62.5
# EPOCH 8 | ITER 45 | AVG_LOSS 0.9171801805496216 | Train_ACC 68.75
# EPOCH 8 | ITER 50 | AVG_LOSS 0.9191123843193054 | Train_ACC 62.5
# EPOCH 8 | ITER 55 | AVG_LOSS 0.9141054153442383 | Train_ACC 68.75
# EPOCH 8 | ITER 60 | AVG_LOSS 0.9206666350364685 | Train_ACC 59.375
# EPOCH 8 | ITER 65 | AVG_LOSS 0.9246319532394409 | Train_ACC 53.125
# EPOCH 8 | ITER 70 | AVG_LOSS 0.9281113147735596 | Train_ACC 68.75
# EPOCH 8 | ITER 75 | AVG_LOSS 0.928892970085144 | Train_ACC 59.375
# EPOCH 8 | ITER 80 | AVG_LOSS 0.9265786409378052 | Train_ACC 62.5
# EPOCH 8 | ITER 85 | AVG_LOSS 0.9140339493751526 | Train_ACC 75.0
# EPOCH 8 | ITER 90 | AVG_LOSS 0.912246584892273 | Train_ACC 43.75
# EPOCH 8 | ITER 95 | AVG_LOSS 0.9161137342453003 | Train_ACC 53.125
# EPOCH 8 | ITER 100 | AVG_LOSS 0.9174033999443054 | Train_ACC 65.625
# EPOCH 8 | ITER 105 | AVG_LOSS 0.9158074259757996 | Train_ACC 56.25
# EPOCH 8 | ITER 110 | AVG_LOSS 0.9145132899284363 | Train_ACC 62.5
# EPOCH 8 | ITER 115 | AVG_LOSS 0.9173411130905151 | Train_ACC 43.75
# EPOCH 8 | ITER 120 | AVG_LOSS 0.9167768359184265 | Train_ACC 53.125
# EPOCH 8 | ITER 125 | AVG_LOSS 0.9124791026115417 | Train_ACC 59.375
# EPOCH 8 | ITER 130 | AVG_LOSS 0.9164220094680786 | Train_ACC 56.25
# EPOCH 8 | ITER 135 | AVG_LOSS 0.9167371392250061 | Train_ACC 50.0
# EPOCH 8 | ITER 140 | AVG_LOSS 0.9159476161003113 | Train_ACC 78.125
# EPOCH 8 | ITER 145 | AVG_LOSS 0.9135665893554688 | Train_ACC 75.0
# EPOCH 8 | ITER 150 | AVG_LOSS 0.9138821363449097 | Train_ACC 59.375
# EPOCH 8 | ITER 155 | AVG_LOSS 0.9117744565010071 | Train_ACC 56.25
# EPOCH 8 | ITER 160 | AVG_LOSS 0.9126529097557068 | Train_ACC 43.75
# EPOCH 8 | ITER 165 | AVG_LOSS 0.9091790318489075 | Train_ACC 84.375
# EPOCH 8 | ITER 170 | AVG_LOSS 0.9084160327911377 | Train_ACC 75.0
# EPOCH 8 | ITER 175 | AVG_LOSS 0.9073802828788757 | Train_ACC 65.625
# EPOCH 8 | ITER 180 | AVG_LOSS 0.9071678519248962 | Train_ACC 37.5
# EPOCH 8 | ITER 185 | AVG_LOSS 0.9060453176498413 | Train_ACC 75.0
# EPOCH 8 | ITER 190 | AVG_LOSS 0.9052205085754395 | Train_ACC 65.625
# EPOCH 8 | ITER 195 | AVG_LOSS 0.9076910614967346 | Train_ACC 68.75
# EPOCH 8 | ITER 200 | AVG_LOSS 0.9086072444915771 | Train_ACC 68.75
# EPOCH 8 | ITER 205 | AVG_LOSS 0.9082289338111877 | Train_ACC 56.25
# EPOCH 8 | ITER 210 | AVG_LOSS 0.9083966612815857 | Train_ACC 62.5
# EPOCH 8 | ITER 215 | AVG_LOSS 0.9073951840400696 | Train_ACC 53.125
# EPOCH 8 | ITER 220 | AVG_LOSS 0.9065290689468384 | Train_ACC 50.0
# EPOCH 8 | ITER 225 | AVG_LOSS 0.907814621925354 | Train_ACC 59.375
# EPOCH 8 | ITER 230 | AVG_LOSS 0.9042876958847046 | Train_ACC 65.625
# EPOCH 8 | ITER 235 | AVG_LOSS 0.9046458601951599 | Train_ACC 62.5
# EPOCH 8 | ITER 240 | AVG_LOSS 0.9034246206283569 | Train_ACC 68.75
# EPOCH 8 | ITER 245 | AVG_LOSS 0.9025565385818481 | Train_ACC 62.5
# Val Accuracy: 61.84%
#
# --------------------------------------------------
# EPOCH 8 | LOSS 0.8043319582939148 | TIME 233.88771414756775
# --------------------------------------------------
#
# EPOCH 9 | ITER 0 | AVG_LOSS 0.8110836148262024 | Train_ACC 56.25
# EPOCH 9 | ITER 5 | AVG_LOSS 0.886441707611084 | Train_ACC 56.25
# EPOCH 9 | ITER 10 | AVG_LOSS 0.8637620210647583 | Train_ACC 59.375
# EPOCH 9 | ITER 15 | AVG_LOSS 0.8513119220733643 | Train_ACC 62.5
# EPOCH 9 | ITER 20 | AVG_LOSS 0.8306477069854736 | Train_ACC 62.5
# EPOCH 9 | ITER 25 | AVG_LOSS 0.8191822171211243 | Train_ACC 65.625
# EPOCH 9 | ITER 30 | AVG_LOSS 0.82968670129776 | Train_ACC 65.625
# EPOCH 9 | ITER 35 | AVG_LOSS 0.8237077593803406 | Train_ACC 68.75
# EPOCH 9 | ITER 40 | AVG_LOSS 0.8314100503921509 | Train_ACC 71.875
# EPOCH 9 | ITER 45 | AVG_LOSS 0.8426292538642883 | Train_ACC 59.375
# EPOCH 9 | ITER 50 | AVG_LOSS 0.8416481018066406 | Train_ACC 50.0
# EPOCH 9 | ITER 55 | AVG_LOSS 0.8468946218490601 | Train_ACC 50.0
# EPOCH 9 | ITER 60 | AVG_LOSS 0.8491808772087097 | Train_ACC 59.375
# EPOCH 9 | ITER 65 | AVG_LOSS 0.8567072749137878 | Train_ACC 56.25
# EPOCH 9 | ITER 70 | AVG_LOSS 0.8596049547195435 | Train_ACC 59.375
# EPOCH 9 | ITER 75 | AVG_LOSS 0.8676143288612366 | Train_ACC 62.5
# EPOCH 9 | ITER 80 | AVG_LOSS 0.8683132529258728 | Train_ACC 62.5
# EPOCH 9 | ITER 85 | AVG_LOSS 0.8702666759490967 | Train_ACC 62.5
# EPOCH 9 | ITER 90 | AVG_LOSS 0.8631850481033325 | Train_ACC 71.875
# EPOCH 9 | ITER 95 | AVG_LOSS 0.8619900941848755 | Train_ACC 62.5
# EPOCH 9 | ITER 100 | AVG_LOSS 0.8597362637519836 | Train_ACC 68.75
# EPOCH 9 | ITER 105 | AVG_LOSS 0.8581182956695557 | Train_ACC 56.25
# EPOCH 9 | ITER 110 | AVG_LOSS 0.8589993715286255 | Train_ACC 68.75
# EPOCH 9 | ITER 115 | AVG_LOSS 0.8578150272369385 | Train_ACC 75.0
# EPOCH 9 | ITER 120 | AVG_LOSS 0.8583114147186279 | Train_ACC 59.375
# EPOCH 9 | ITER 125 | AVG_LOSS 0.8601273894309998 | Train_ACC 59.375
# EPOCH 9 | ITER 130 | AVG_LOSS 0.8567152619361877 | Train_ACC 71.875
# EPOCH 9 | ITER 135 | AVG_LOSS 0.855656623840332 | Train_ACC 53.125
# EPOCH 9 | ITER 140 | AVG_LOSS 0.857872486114502 | Train_ACC 65.625
# EPOCH 9 | ITER 145 | AVG_LOSS 0.8589244484901428 | Train_ACC 68.75
# EPOCH 9 | ITER 150 | AVG_LOSS 0.858306884765625 | Train_ACC 59.375
# EPOCH 9 | ITER 155 | AVG_LOSS 0.8577326536178589 | Train_ACC 75.0
# EPOCH 9 | ITER 160 | AVG_LOSS 0.8577349185943604 | Train_ACC 65.625
# EPOCH 9 | ITER 165 | AVG_LOSS 0.8612842559814453 | Train_ACC 68.75
# EPOCH 9 | ITER 170 | AVG_LOSS 0.8631580471992493 | Train_ACC 62.5
# EPOCH 9 | ITER 175 | AVG_LOSS 0.8652330040931702 | Train_ACC 56.25
# EPOCH 9 | ITER 180 | AVG_LOSS 0.8610507845878601 | Train_ACC 78.125
# EPOCH 9 | ITER 185 | AVG_LOSS 0.8618072271347046 | Train_ACC 65.625
# EPOCH 9 | ITER 190 | AVG_LOSS 0.8644974231719971 | Train_ACC 62.5
# EPOCH 9 | ITER 195 | AVG_LOSS 0.860970675945282 | Train_ACC 71.875
# EPOCH 9 | ITER 200 | AVG_LOSS 0.8653016090393066 | Train_ACC 50.0
# EPOCH 9 | ITER 205 | AVG_LOSS 0.8666335344314575 | Train_ACC 56.25
# EPOCH 9 | ITER 210 | AVG_LOSS 0.8674522638320923 | Train_ACC 62.5
# EPOCH 9 | ITER 215 | AVG_LOSS 0.869662344455719 | Train_ACC 68.75
# EPOCH 9 | ITER 220 | AVG_LOSS 0.8709758520126343 | Train_ACC 68.75
# EPOCH 9 | ITER 225 | AVG_LOSS 0.8692901134490967 | Train_ACC 84.375
# EPOCH 9 | ITER 230 | AVG_LOSS 0.8691757917404175 | Train_ACC 78.125
# EPOCH 9 | ITER 235 | AVG_LOSS 0.8686249852180481 | Train_ACC 65.625
# EPOCH 9 | ITER 240 | AVG_LOSS 0.8677091598510742 | Train_ACC 59.375
# EPOCH 9 | ITER 245 | AVG_LOSS 0.8658733367919922 | Train_ACC 81.25
# Val Accuracy: 61.34%
#
# --------------------------------------------------
# EPOCH 9 | LOSS 0.8264940977096558 | TIME 235.25073266029358
# --------------------------------------------------
#
# EPOCH 10 | ITER 0 | AVG_LOSS 1.2433626651763916 | Train_ACC 50.0
# EPOCH 10 | ITER 5 | AVG_LOSS 0.9355985522270203 | Train_ACC 56.25
# EPOCH 10 | ITER 10 | AVG_LOSS 0.8435032963752747 | Train_ACC 71.875
# EPOCH 10 | ITER 15 | AVG_LOSS 0.8175933361053467 | Train_ACC 78.125
# EPOCH 10 | ITER 20 | AVG_LOSS 0.8179454803466797 | Train_ACC 68.75
# EPOCH 10 | ITER 25 | AVG_LOSS 0.8127350807189941 | Train_ACC 65.625
# EPOCH 10 | ITER 30 | AVG_LOSS 0.823529064655304 | Train_ACC 68.75
# EPOCH 10 | ITER 35 | AVG_LOSS 0.8300072550773621 | Train_ACC 65.625
# EPOCH 10 | ITER 40 | AVG_LOSS 0.8364309668540955 | Train_ACC 65.625
# EPOCH 10 | ITER 45 | AVG_LOSS 0.8385464549064636 | Train_ACC 68.75
# EPOCH 10 | ITER 50 | AVG_LOSS 0.8244125843048096 | Train_ACC 68.75
# EPOCH 10 | ITER 55 | AVG_LOSS 0.836943507194519 | Train_ACC 65.625
# EPOCH 10 | ITER 60 | AVG_LOSS 0.8331131935119629 | Train_ACC 62.5
# EPOCH 10 | ITER 65 | AVG_LOSS 0.8284304738044739 | Train_ACC 81.25
# EPOCH 10 | ITER 70 | AVG_LOSS 0.8254687786102295 | Train_ACC 62.5
# EPOCH 10 | ITER 75 | AVG_LOSS 0.836138904094696 | Train_ACC 56.25
# EPOCH 10 | ITER 80 | AVG_LOSS 0.8350114226341248 | Train_ACC 56.25
# EPOCH 10 | ITER 85 | AVG_LOSS 0.8306421637535095 | Train_ACC 59.375
# EPOCH 10 | ITER 90 | AVG_LOSS 0.8294433951377869 | Train_ACC 81.25
# EPOCH 10 | ITER 95 | AVG_LOSS 0.8312990069389343 | Train_ACC 59.375
# EPOCH 10 | ITER 100 | AVG_LOSS 0.8323758244514465 | Train_ACC 62.5
# EPOCH 10 | ITER 105 | AVG_LOSS 0.8306939005851746 | Train_ACC 75.0
# EPOCH 10 | ITER 110 | AVG_LOSS 0.8303163051605225 | Train_ACC 68.75
# EPOCH 10 | ITER 115 | AVG_LOSS 0.8333832025527954 | Train_ACC 78.125
# EPOCH 10 | ITER 120 | AVG_LOSS 0.835538923740387 | Train_ACC 62.5
# EPOCH 10 | ITER 125 | AVG_LOSS 0.834431529045105 | Train_ACC 68.75
# EPOCH 10 | ITER 130 | AVG_LOSS 0.8331473469734192 | Train_ACC 81.25
# EPOCH 10 | ITER 135 | AVG_LOSS 0.837949275970459 | Train_ACC 56.25
# EPOCH 10 | ITER 140 | AVG_LOSS 0.8361590504646301 | Train_ACC 68.75
# EPOCH 10 | ITER 145 | AVG_LOSS 0.839775025844574 | Train_ACC 59.375
# EPOCH 10 | ITER 150 | AVG_LOSS 0.8373530507087708 | Train_ACC 68.75
# EPOCH 10 | ITER 155 | AVG_LOSS 0.8397930860519409 | Train_ACC 59.375
# EPOCH 10 | ITER 160 | AVG_LOSS 0.8375513553619385 | Train_ACC 71.875
# EPOCH 10 | ITER 165 | AVG_LOSS 0.8383125066757202 | Train_ACC 68.75
# EPOCH 10 | ITER 170 | AVG_LOSS 0.8376369476318359 | Train_ACC 50.0
# EPOCH 10 | ITER 175 | AVG_LOSS 0.837002694606781 | Train_ACC 65.625
# EPOCH 10 | ITER 180 | AVG_LOSS 0.839323103427887 | Train_ACC 62.5
# EPOCH 10 | ITER 185 | AVG_LOSS 0.8411075472831726 | Train_ACC 59.375
# EPOCH 10 | ITER 190 | AVG_LOSS 0.8412620425224304 | Train_ACC 65.625
# EPOCH 10 | ITER 195 | AVG_LOSS 0.8380725979804993 | Train_ACC 71.875
# EPOCH 10 | ITER 200 | AVG_LOSS 0.8386209607124329 | Train_ACC 71.875
# EPOCH 10 | ITER 205 | AVG_LOSS 0.8389395475387573 | Train_ACC 68.75
# EPOCH 10 | ITER 210 | AVG_LOSS 0.8407356142997742 | Train_ACC 68.75
# EPOCH 10 | ITER 215 | AVG_LOSS 0.8411505222320557 | Train_ACC 81.25
# EPOCH 10 | ITER 220 | AVG_LOSS 0.8401644229888916 | Train_ACC 78.125
# EPOCH 10 | ITER 225 | AVG_LOSS 0.8396499752998352 | Train_ACC 59.375
# EPOCH 10 | ITER 230 | AVG_LOSS 0.8405013680458069 | Train_ACC 62.5
# EPOCH 10 | ITER 235 | AVG_LOSS 0.8381169438362122 | Train_ACC 68.75
# EPOCH 10 | ITER 240 | AVG_LOSS 0.8376098275184631 | Train_ACC 78.125
# EPOCH 10 | ITER 245 | AVG_LOSS 0.8360754251480103 | Train_ACC 62.5
# Val Accuracy: 65.53%
#
# --------------------------------------------------
# EPOCH 10 | LOSS 0.7457321286201477 | TIME 236.23462510108948
# --------------------------------------------------
#
# EPOCH 11 | ITER 0 | AVG_LOSS 0.8150034546852112 | Train_ACC 65.625
# EPOCH 11 | ITER 5 | AVG_LOSS 0.7398108243942261 | Train_ACC 68.75
# EPOCH 11 | ITER 10 | AVG_LOSS 0.7857739329338074 | Train_ACC 75.0
# EPOCH 11 | ITER 15 | AVG_LOSS 0.7889136075973511 | Train_ACC 78.125
# EPOCH 11 | ITER 20 | AVG_LOSS 0.7913883924484253 | Train_ACC 56.25
# EPOCH 11 | ITER 25 | AVG_LOSS 0.822828471660614 | Train_ACC 71.875
# EPOCH 11 | ITER 30 | AVG_LOSS 0.8165928721427917 | Train_ACC 65.625
# EPOCH 11 | ITER 35 | AVG_LOSS 0.8049672842025757 | Train_ACC 68.75
# EPOCH 11 | ITER 40 | AVG_LOSS 0.8093706369400024 | Train_ACC 71.875
# EPOCH 11 | ITER 45 | AVG_LOSS 0.8145374655723572 | Train_ACC 62.5
# EPOCH 11 | ITER 50 | AVG_LOSS 0.8133877515792847 | Train_ACC 65.625
# EPOCH 11 | ITER 55 | AVG_LOSS 0.8050232529640198 | Train_ACC 87.5
# EPOCH 11 | ITER 60 | AVG_LOSS 0.804688572883606 | Train_ACC 75.0
# EPOCH 11 | ITER 65 | AVG_LOSS 0.814765453338623 | Train_ACC 78.125
# EPOCH 11 | ITER 70 | AVG_LOSS 0.8125218152999878 | Train_ACC 59.375
# EPOCH 11 | ITER 75 | AVG_LOSS 0.8174694180488586 | Train_ACC 71.875
# EPOCH 11 | ITER 80 | AVG_LOSS 0.8133442401885986 | Train_ACC 62.5
# EPOCH 11 | ITER 85 | AVG_LOSS 0.8111814260482788 | Train_ACC 56.25
# EPOCH 11 | ITER 90 | AVG_LOSS 0.8068010210990906 | Train_ACC 81.25
# EPOCH 11 | ITER 95 | AVG_LOSS 0.8079540133476257 | Train_ACC 75.0
# EPOCH 11 | ITER 100 | AVG_LOSS 0.8060855269432068 | Train_ACC 59.375
# EPOCH 11 | ITER 105 | AVG_LOSS 0.8075466156005859 | Train_ACC 65.625
# EPOCH 11 | ITER 110 | AVG_LOSS 0.8095765113830566 | Train_ACC 68.75
# EPOCH 11 | ITER 115 | AVG_LOSS 0.8168778419494629 | Train_ACC 65.625
# EPOCH 11 | ITER 120 | AVG_LOSS 0.8183652758598328 | Train_ACC 71.875
# EPOCH 11 | ITER 125 | AVG_LOSS 0.8204960823059082 | Train_ACC 78.125
# EPOCH 11 | ITER 130 | AVG_LOSS 0.8208622932434082 | Train_ACC 68.75
# EPOCH 11 | ITER 135 | AVG_LOSS 0.8195124864578247 | Train_ACC 65.625
# EPOCH 11 | ITER 140 | AVG_LOSS 0.8163790702819824 | Train_ACC 56.25
# EPOCH 11 | ITER 145 | AVG_LOSS 0.8120189905166626 | Train_ACC 59.375
# EPOCH 11 | ITER 150 | AVG_LOSS 0.813880980014801 | Train_ACC 75.0
# EPOCH 11 | ITER 155 | AVG_LOSS 0.8132803440093994 | Train_ACC 59.375
# EPOCH 11 | ITER 160 | AVG_LOSS 0.8090285062789917 | Train_ACC 81.25
# EPOCH 11 | ITER 165 | AVG_LOSS 0.8101742267608643 | Train_ACC 59.375
# EPOCH 11 | ITER 170 | AVG_LOSS 0.8076335191726685 | Train_ACC 68.75
# EPOCH 11 | ITER 175 | AVG_LOSS 0.810230016708374 | Train_ACC 50.0
# EPOCH 11 | ITER 180 | AVG_LOSS 0.8095431327819824 | Train_ACC 81.25
# EPOCH 11 | ITER 185 | AVG_LOSS 0.8129266500473022 | Train_ACC 84.375
# EPOCH 11 | ITER 190 | AVG_LOSS 0.8149194717407227 | Train_ACC 75.0
# EPOCH 11 | ITER 195 | AVG_LOSS 0.8160738348960876 | Train_ACC 46.875
# EPOCH 11 | ITER 200 | AVG_LOSS 0.8139954209327698 | Train_ACC 84.375
# EPOCH 11 | ITER 205 | AVG_LOSS 0.8124655485153198 | Train_ACC 81.25
# EPOCH 11 | ITER 210 | AVG_LOSS 0.8126598596572876 | Train_ACC 56.25
# EPOCH 11 | ITER 215 | AVG_LOSS 0.8113914728164673 | Train_ACC 68.75
# EPOCH 11 | ITER 220 | AVG_LOSS 0.8103888630867004 | Train_ACC 78.125
# EPOCH 11 | ITER 225 | AVG_LOSS 0.8077704310417175 | Train_ACC 71.875
# EPOCH 11 | ITER 230 | AVG_LOSS 0.809956431388855 | Train_ACC 68.75
# EPOCH 11 | ITER 235 | AVG_LOSS 0.8122003674507141 | Train_ACC 56.25
# EPOCH 11 | ITER 240 | AVG_LOSS 0.8120646476745605 | Train_ACC 71.875
# EPOCH 11 | ITER 245 | AVG_LOSS 0.8107991218566895 | Train_ACC 71.875
# Val Accuracy: 62.44%
#
# --------------------------------------------------
# EPOCH 11 | LOSS 0.7748609185218811 | TIME 233.76792931556702
# --------------------------------------------------
#
# EPOCH 12 | ITER 0 | AVG_LOSS 0.6190400123596191 | Train_ACC 84.375
# EPOCH 12 | ITER 5 | AVG_LOSS 0.8278519511222839 | Train_ACC 68.75
# EPOCH 12 | ITER 10 | AVG_LOSS 0.7391602396965027 | Train_ACC 78.125
# EPOCH 12 | ITER 15 | AVG_LOSS 0.7697579264640808 | Train_ACC 78.125
# EPOCH 12 | ITER 20 | AVG_LOSS 0.7879265546798706 | Train_ACC 56.25
# EPOCH 12 | ITER 25 | AVG_LOSS 0.7978920340538025 | Train_ACC 78.125
# EPOCH 12 | ITER 30 | AVG_LOSS 0.7786964178085327 | Train_ACC 78.125
# EPOCH 12 | ITER 35 | AVG_LOSS 0.7718256115913391 | Train_ACC 62.5
# EPOCH 12 | ITER 40 | AVG_LOSS 0.7753069996833801 | Train_ACC 68.75
# EPOCH 12 | ITER 45 | AVG_LOSS 0.7739726305007935 | Train_ACC 78.125
# EPOCH 12 | ITER 50 | AVG_LOSS 0.764033317565918 | Train_ACC 81.25
# EPOCH 12 | ITER 55 | AVG_LOSS 0.7679382562637329 | Train_ACC 56.25
# EPOCH 12 | ITER 60 | AVG_LOSS 0.7742307186126709 | Train_ACC 53.125
# EPOCH 12 | ITER 65 | AVG_LOSS 0.7660270929336548 | Train_ACC 78.125
# EPOCH 12 | ITER 70 | AVG_LOSS 0.7636644244194031 | Train_ACC 59.375
# EPOCH 12 | ITER 75 | AVG_LOSS 0.7608587741851807 | Train_ACC 71.875
# EPOCH 12 | ITER 80 | AVG_LOSS 0.7676897644996643 | Train_ACC 62.5
# EPOCH 12 | ITER 85 | AVG_LOSS 0.7747045755386353 | Train_ACC 75.0
# EPOCH 12 | ITER 90 | AVG_LOSS 0.777228593826294 | Train_ACC 59.375
# EPOCH 12 | ITER 95 | AVG_LOSS 0.7761303782463074 | Train_ACC 81.25
# EPOCH 12 | ITER 100 | AVG_LOSS 0.7801522612571716 | Train_ACC 62.5
# EPOCH 12 | ITER 105 | AVG_LOSS 0.7798784971237183 | Train_ACC 65.625
# EPOCH 12 | ITER 110 | AVG_LOSS 0.7744883298873901 | Train_ACC 78.125
# EPOCH 12 | ITER 115 | AVG_LOSS 0.7805867791175842 | Train_ACC 68.75
# EPOCH 12 | ITER 120 | AVG_LOSS 0.7833271026611328 | Train_ACC 56.25
# EPOCH 12 | ITER 125 | AVG_LOSS 0.7851163148880005 | Train_ACC 50.0
# EPOCH 12 | ITER 130 | AVG_LOSS 0.785599946975708 | Train_ACC 65.625
# EPOCH 12 | ITER 135 | AVG_LOSS 0.7878499031066895 | Train_ACC 59.375
# EPOCH 12 | ITER 140 | AVG_LOSS 0.7865648865699768 | Train_ACC 75.0
# EPOCH 12 | ITER 145 | AVG_LOSS 0.7838290333747864 | Train_ACC 59.375
# EPOCH 12 | ITER 150 | AVG_LOSS 0.7823601961135864 | Train_ACC 68.75
# EPOCH 12 | ITER 155 | AVG_LOSS 0.7794332504272461 | Train_ACC 75.0
# EPOCH 12 | ITER 160 | AVG_LOSS 0.7791495323181152 | Train_ACC 75.0
# EPOCH 12 | ITER 165 | AVG_LOSS 0.7793489694595337 | Train_ACC 62.5
# EPOCH 12 | ITER 170 | AVG_LOSS 0.7766719460487366 | Train_ACC 71.875
# EPOCH 12 | ITER 175 | AVG_LOSS 0.7763623595237732 | Train_ACC 68.75
# EPOCH 12 | ITER 180 | AVG_LOSS 0.77800452709198 | Train_ACC 50.0
# EPOCH 12 | ITER 185 | AVG_LOSS 0.775368869304657 | Train_ACC 71.875
# EPOCH 12 | ITER 190 | AVG_LOSS 0.7743486166000366 | Train_ACC 81.25
# EPOCH 12 | ITER 195 | AVG_LOSS 0.7758632302284241 | Train_ACC 62.5
# EPOCH 12 | ITER 200 | AVG_LOSS 0.7725303173065186 | Train_ACC 75.0
# EPOCH 12 | ITER 205 | AVG_LOSS 0.7724356055259705 | Train_ACC 65.625
# EPOCH 12 | ITER 210 | AVG_LOSS 0.7725598216056824 | Train_ACC 75.0
# EPOCH 12 | ITER 215 | AVG_LOSS 0.7735539078712463 | Train_ACC 78.125
# EPOCH 12 | ITER 220 | AVG_LOSS 0.7731090188026428 | Train_ACC 90.625
# EPOCH 12 | ITER 225 | AVG_LOSS 0.7721898555755615 | Train_ACC 75.0
# EPOCH 12 | ITER 230 | AVG_LOSS 0.7717543244361877 | Train_ACC 65.625
# EPOCH 12 | ITER 235 | AVG_LOSS 0.770239531993866 | Train_ACC 62.5
# EPOCH 12 | ITER 240 | AVG_LOSS 0.7718053460121155 | Train_ACC 65.625
# EPOCH 12 | ITER 245 | AVG_LOSS 0.7730410695075989 | Train_ACC 62.5
# Val Accuracy: 66.43%
#
# --------------------------------------------------
# EPOCH 12 | LOSS 0.49406522512435913 | TIME 235.05984377861023
# --------------------------------------------------
#
# EPOCH 13 | ITER 0 | AVG_LOSS 0.607197105884552 | Train_ACC 75.0
# EPOCH 13 | ITER 5 | AVG_LOSS 0.6272575855255127 | Train_ACC 84.375
# EPOCH 13 | ITER 10 | AVG_LOSS 0.5792974233627319 | Train_ACC 81.25
# EPOCH 13 | ITER 15 | AVG_LOSS 0.6089718341827393 | Train_ACC 81.25
# EPOCH 13 | ITER 20 | AVG_LOSS 0.608133852481842 | Train_ACC 75.0
# EPOCH 13 | ITER 25 | AVG_LOSS 0.6449996829032898 | Train_ACC 78.125
# EPOCH 13 | ITER 30 | AVG_LOSS 0.643782377243042 | Train_ACC 71.875
# EPOCH 13 | ITER 35 | AVG_LOSS 0.6437718272209167 | Train_ACC 81.25
# EPOCH 13 | ITER 40 | AVG_LOSS 0.65177983045578 | Train_ACC 68.75
# EPOCH 13 | ITER 45 | AVG_LOSS 0.6724180579185486 | Train_ACC 81.25
# EPOCH 13 | ITER 50 | AVG_LOSS 0.6894634962081909 | Train_ACC 65.625
# EPOCH 13 | ITER 55 | AVG_LOSS 0.6887257099151611 | Train_ACC 56.25
# EPOCH 13 | ITER 60 | AVG_LOSS 0.6886274218559265 | Train_ACC 59.375
# EPOCH 13 | ITER 65 | AVG_LOSS 0.6902427673339844 | Train_ACC 68.75
# EPOCH 13 | ITER 70 | AVG_LOSS 0.703602135181427 | Train_ACC 65.625
# EPOCH 13 | ITER 75 | AVG_LOSS 0.710355281829834 | Train_ACC 68.75
# EPOCH 13 | ITER 80 | AVG_LOSS 0.7148371338844299 | Train_ACC 84.375
# EPOCH 13 | ITER 85 | AVG_LOSS 0.7168864011764526 | Train_ACC 71.875
# EPOCH 13 | ITER 90 | AVG_LOSS 0.7174460887908936 | Train_ACC 68.75
# EPOCH 13 | ITER 95 | AVG_LOSS 0.713396430015564 | Train_ACC 71.875
# EPOCH 13 | ITER 100 | AVG_LOSS 0.7090951800346375 | Train_ACC 56.25
# EPOCH 13 | ITER 105 | AVG_LOSS 0.7118483781814575 | Train_ACC 81.25
# EPOCH 13 | ITER 110 | AVG_LOSS 0.7067717909812927 | Train_ACC 71.875
# EPOCH 13 | ITER 115 | AVG_LOSS 0.7068005204200745 | Train_ACC 84.375
# EPOCH 13 | ITER 120 | AVG_LOSS 0.7129204869270325 | Train_ACC 65.625
# EPOCH 13 | ITER 125 | AVG_LOSS 0.7152389287948608 | Train_ACC 56.25
# EPOCH 13 | ITER 130 | AVG_LOSS 0.7205598950386047 | Train_ACC 65.625
# EPOCH 13 | ITER 135 | AVG_LOSS 0.7179641127586365 | Train_ACC 78.125
# EPOCH 13 | ITER 140 | AVG_LOSS 0.7180987000465393 | Train_ACC 53.125
# EPOCH 13 | ITER 145 | AVG_LOSS 0.7183449268341064 | Train_ACC 84.375
# ...
# EPOCH 25 | ITER 175 | AVG_LOSS 0.3837704360485077 | Train_ACC 75.0
# EPOCH 25 | ITER 180 | AVG_LOSS 0.3839055895805359 | Train_ACC 87.5
# EPOCH 25 | ITER 185 | AVG_LOSS 0.3839274048805237 | Train_ACC 87.5
# EPOCH 25 | ITER 190 | AVG_LOSS 0.3840409815311432 | Train_ACC 78.125
# EPOCH 25 | ITER 195 | AVG_LOSS 0.3856946527957916 | Train_ACC 87.5
# EPOCH 25 | ITER 200 | AVG_LOSS 0.3842713236808777 | Train_ACC 93.75
# EPOCH 25 | ITER 205 | AVG_LOSS 0.3847425878047943 | Train_ACC 87.5
# EPOCH 25 | ITER 210 | AVG_LOSS 0.3827550709247589 | Train_ACC 93.75
# EPOCH 25 | ITER 215 | AVG_LOSS 0.3813988268375397 | Train_ACC 87.5
# EPOCH 25 | ITER 220 | AVG_LOSS 0.37902405858039856 | Train_ACC 93.75
# EPOCH 25 | ITER 225 | AVG_LOSS 0.3789292573928833 | Train_ACC 87.5
# EPOCH 25 | ITER 230 | AVG_LOSS 0.3797324597835541 | Train_ACC 75.0
# EPOCH 25 | ITER 235 | AVG_LOSS 0.38186222314834595 | Train_ACC 81.25
# EPOCH 25 | ITER 240 | AVG_LOSS 0.3824232220649719 | Train_ACC 81.25
# EPOCH 25 | ITER 245 | AVG_LOSS 0.382663369178772 | Train_ACC 93.75
# Val Accuracy: 74.73%
#
# --------------------------------------------------
# EPOCH 25 | LOSS 0.2241922914981842 | TIME 231.77400851249695
# --------------------------------------------------
#
# EPOCH 26 | ITER 0 | AVG_LOSS 0.24191613495349884 | Train_ACC 90.625
# EPOCH 26 | ITER 5 | AVG_LOSS 0.2885269820690155 | Train_ACC 96.875
# EPOCH 26 | ITER 10 | AVG_LOSS 0.3102343678474426 | Train_ACC 81.25
# EPOCH 26 | ITER 15 | AVG_LOSS 0.3238990902900696 | Train_ACC 93.75
# EPOCH 26 | ITER 20 | AVG_LOSS 0.34615325927734375 | Train_ACC 84.375
# EPOCH 26 | ITER 25 | AVG_LOSS 0.3257221579551697 | Train_ACC 90.625
# EPOCH 26 | ITER 30 | AVG_LOSS 0.33861973881721497 | Train_ACC 81.25
# EPOCH 26 | ITER 35 | AVG_LOSS 0.33269524574279785 | Train_ACC 90.625
# EPOCH 26 | ITER 40 | AVG_LOSS 0.3355647623538971 | Train_ACC 78.125
# EPOCH 26 | ITER 45 | AVG_LOSS 0.3353886306285858 | Train_ACC 93.75
# EPOCH 26 | ITER 50 | AVG_LOSS 0.33247023820877075 | Train_ACC 90.625
# EPOCH 26 | ITER 55 | AVG_LOSS 0.32436680793762207 | Train_ACC 93.75
# EPOCH 26 | ITER 60 | AVG_LOSS 0.3283306062221527 | Train_ACC 81.25
# EPOCH 26 | ITER 65 | AVG_LOSS 0.33438554406166077 | Train_ACC 71.875
# EPOCH 26 | ITER 70 | AVG_LOSS 0.3315502107143402 | Train_ACC 84.375
# EPOCH 26 | ITER 75 | AVG_LOSS 0.3280892074108124 | Train_ACC 96.875
# EPOCH 26 | ITER 80 | AVG_LOSS 0.33308225870132446 | Train_ACC 75.0
# EPOCH 26 | ITER 85 | AVG_LOSS 0.3381521999835968 | Train_ACC 84.375
# EPOCH 26 | ITER 90 | AVG_LOSS 0.3415415585041046 | Train_ACC 81.25
# EPOCH 26 | ITER 95 | AVG_LOSS 0.34407350420951843 | Train_ACC 87.5
# EPOCH 26 | ITER 100 | AVG_LOSS 0.34644508361816406 | Train_ACC 84.375
# EPOCH 26 | ITER 105 | AVG_LOSS 0.34671249985694885 | Train_ACC 90.625
# EPOCH 26 | ITER 110 | AVG_LOSS 0.34701958298683167 | Train_ACC 87.5
# EPOCH 26 | ITER 115 | AVG_LOSS 0.34637296199798584 | Train_ACC 87.5
# EPOCH 26 | ITER 120 | AVG_LOSS 0.34967198967933655 | Train_ACC 84.375
# EPOCH 26 | ITER 125 | AVG_LOSS 0.3556237518787384 | Train_ACC 78.125
# EPOCH 26 | ITER 130 | AVG_LOSS 0.35755959153175354 | Train_ACC 90.625
# EPOCH 26 | ITER 135 | AVG_LOSS 0.3637872338294983 | Train_ACC 93.75
# EPOCH 26 | ITER 140 | AVG_LOSS 0.3656672239303589 | Train_ACC 90.625
# EPOCH 26 | ITER 145 | AVG_LOSS 0.3670807480812073 | Train_ACC 81.25
# EPOCH 26 | ITER 150 | AVG_LOSS 0.36497002840042114 | Train_ACC 90.625
# EPOCH 26 | ITER 155 | AVG_LOSS 0.36597752571105957 | Train_ACC 87.5
# EPOCH 26 | ITER 160 | AVG_LOSS 0.3646184504032135 | Train_ACC 96.875
# EPOCH 26 | ITER 165 | AVG_LOSS 0.36789384484291077 | Train_ACC 90.625
# EPOCH 26 | ITER 170 | AVG_LOSS 0.370059072971344 | Train_ACC 81.25
# EPOCH 26 | ITER 175 | AVG_LOSS 0.3686861991882324 | Train_ACC 90.625
# EPOCH 26 | ITER 180 | AVG_LOSS 0.3668820858001709 | Train_ACC 87.5
# EPOCH 26 | ITER 185 | AVG_LOSS 0.3684186339378357 | Train_ACC 96.875
# EPOCH 26 | ITER 190 | AVG_LOSS 0.3686560094356537 | Train_ACC 84.375
# EPOCH 26 | ITER 195 | AVG_LOSS 0.3686320185661316 | Train_ACC 84.375
# EPOCH 26 | ITER 200 | AVG_LOSS 0.36887720227241516 | Train_ACC 84.375
# EPOCH 26 | ITER 205 | AVG_LOSS 0.3662530481815338 | Train_ACC 90.625
# EPOCH 26 | ITER 210 | AVG_LOSS 0.365090012550354 | Train_ACC 93.75
# EPOCH 26 | ITER 215 | AVG_LOSS 0.3621978163719177 | Train_ACC 93.75
# EPOCH 26 | ITER 220 | AVG_LOSS 0.36070486903190613 | Train_ACC 87.5
# EPOCH 26 | ITER 225 | AVG_LOSS 0.3585910499095917 | Train_ACC 87.5
# EPOCH 26 | ITER 230 | AVG_LOSS 0.3586606979370117 | Train_ACC 84.375
# EPOCH 26 | ITER 235 | AVG_LOSS 0.3576384484767914 | Train_ACC 93.75
# EPOCH 26 | ITER 240 | AVG_LOSS 0.35809510946273804 | Train_ACC 90.625
# EPOCH 26 | ITER 245 | AVG_LOSS 0.3578386902809143 | Train_ACC 87.5
# Val Accuracy: 74.63%
#
# --------------------------------------------------
# EPOCH 26 | LOSS 0.39699244499206543 | TIME 231.25676250457764
# --------------------------------------------------
#
# EPOCH 27 | ITER 0 | AVG_LOSS 0.3811572194099426 | Train_ACC 84.375
# EPOCH 27 | ITER 5 | AVG_LOSS 0.4012882113456726 | Train_ACC 71.875
# EPOCH 27 | ITER 10 | AVG_LOSS 0.4044647812843323 | Train_ACC 71.875
# EPOCH 27 | ITER 15 | AVG_LOSS 0.3998152017593384 | Train_ACC 84.375
# EPOCH 27 | ITER 20 | AVG_LOSS 0.3877667188644409 | Train_ACC 93.75
# EPOCH 27 | ITER 25 | AVG_LOSS 0.39067479968070984 | Train_ACC 90.625
# EPOCH 27 | ITER 30 | AVG_LOSS 0.3816963732242584 | Train_ACC 87.5
# EPOCH 27 | ITER 35 | AVG_LOSS 0.371486097574234 | Train_ACC 90.625
# EPOCH 27 | ITER 40 | AVG_LOSS 0.36637765169143677 | Train_ACC 87.5
# EPOCH 27 | ITER 45 | AVG_LOSS 0.3647230565547943 | Train_ACC 84.375
# EPOCH 27 | ITER 50 | AVG_LOSS 0.3601791560649872 | Train_ACC 90.625
# EPOCH 27 | ITER 55 | AVG_LOSS 0.3569219708442688 | Train_ACC 90.625
# EPOCH 27 | ITER 60 | AVG_LOSS 0.36068612337112427 | Train_ACC 75.0
# EPOCH 27 | ITER 65 | AVG_LOSS 0.3722909986972809 | Train_ACC 87.5
# EPOCH 27 | ITER 70 | AVG_LOSS 0.3744117021560669 | Train_ACC 81.25
# EPOCH 27 | ITER 75 | AVG_LOSS 0.37442073225975037 | Train_ACC 84.375
# EPOCH 27 | ITER 80 | AVG_LOSS 0.3727603256702423 | Train_ACC 87.5
# EPOCH 27 | ITER 85 | AVG_LOSS 0.3718217611312866 | Train_ACC 93.75
# EPOCH 27 | ITER 90 | AVG_LOSS 0.37340617179870605 | Train_ACC 78.125
# EPOCH 27 | ITER 95 | AVG_LOSS 0.3725632429122925 | Train_ACC 87.5
# EPOCH 27 | ITER 100 | AVG_LOSS 0.3700530529022217 | Train_ACC 87.5
# EPOCH 27 | ITER 105 | AVG_LOSS 0.36521655321121216 | Train_ACC 87.5
# EPOCH 27 | ITER 110 | AVG_LOSS 0.3627581000328064 | Train_ACC 93.75
# EPOCH 27 | ITER 115 | AVG_LOSS 0.3662804961204529 | Train_ACC 81.25
# EPOCH 27 | ITER 120 | AVG_LOSS 0.36366355419158936 | Train_ACC 96.875
# EPOCH 27 | ITER 125 | AVG_LOSS 0.36338022351264954 | Train_ACC 81.25
# EPOCH 27 | ITER 130 | AVG_LOSS 0.3654804825782776 | Train_ACC 90.625
# EPOCH 27 | ITER 135 | AVG_LOSS 0.3638886511325836 | Train_ACC 90.625
# EPOCH 27 | ITER 140 | AVG_LOSS 0.37269774079322815 | Train_ACC 65.625
# EPOCH 27 | ITER 145 | AVG_LOSS 0.3717438876628876 | Train_ACC 81.25
# EPOCH 27 | ITER 150 | AVG_LOSS 0.3723452091217041 | Train_ACC 90.625
# EPOCH 27 | ITER 155 | AVG_LOSS 0.3686155676841736 | Train_ACC 87.5
# EPOCH 27 | ITER 160 | AVG_LOSS 0.3678992986679077 | Train_ACC 87.5
# EPOCH 27 | ITER 165 | AVG_LOSS 0.36704403162002563 | Train_ACC 90.625
# EPOCH 27 | ITER 170 | AVG_LOSS 0.36716893315315247 | Train_ACC 81.25
# EPOCH 27 | ITER 175 | AVG_LOSS 0.3669488728046417 | Train_ACC 90.625
# EPOCH 27 | ITER 180 | AVG_LOSS 0.3668484389781952 | Train_ACC 90.625
# EPOCH 27 | ITER 185 | AVG_LOSS 0.368228942155838 | Train_ACC 87.5
# EPOCH 27 | ITER 190 | AVG_LOSS 0.3697125017642975 | Train_ACC 84.375
# EPOCH 27 | ITER 195 | AVG_LOSS 0.37066495418548584 | Train_ACC 78.125
# EPOCH 27 | ITER 200 | AVG_LOSS 0.3731716573238373 | Train_ACC 90.625
# EPOCH 27 | ITER 205 | AVG_LOSS 0.37511569261550903 | Train_ACC 78.125
# EPOCH 27 | ITER 210 | AVG_LOSS 0.3745764493942261 | Train_ACC 100.0
# EPOCH 27 | ITER 215 | AVG_LOSS 0.37421900033950806 | Train_ACC 81.25
# EPOCH 27 | ITER 220 | AVG_LOSS 0.3746735453605652 | Train_ACC 87.5
# EPOCH 27 | ITER 225 | AVG_LOSS 0.3729207515716553 | Train_ACC 87.5
# EPOCH 27 | ITER 230 | AVG_LOSS 0.37192630767822266 | Train_ACC 90.625
# EPOCH 27 | ITER 235 | AVG_LOSS 0.3731346130371094 | Train_ACC 84.375
# EPOCH 27 | ITER 240 | AVG_LOSS 0.37115049362182617 | Train_ACC 78.125
# EPOCH 27 | ITER 245 | AVG_LOSS 0.3733939230442047 | Train_ACC 84.375
# Val Accuracy: 77.92%
#
# --------------------------------------------------
# EPOCH 27 | LOSS 0.16686993837356567 | TIME 230.0986888408661
# --------------------------------------------------
#
# EPOCH 28 | ITER 0 | AVG_LOSS 0.10256478935480118 | Train_ACC 100.0
# EPOCH 28 | ITER 5 | AVG_LOSS 0.30799251794815063 | Train_ACC 87.5
# EPOCH 28 | ITER 10 | AVG_LOSS 0.34240975975990295 | Train_ACC 81.25
# EPOCH 28 | ITER 15 | AVG_LOSS 0.32389652729034424 | Train_ACC 90.625
# EPOCH 28 | ITER 20 | AVG_LOSS 0.324736624956131 | Train_ACC 87.5
# EPOCH 28 | ITER 25 | AVG_LOSS 0.32459041476249695 | Train_ACC 87.5
# EPOCH 28 | ITER 30 | AVG_LOSS 0.3285919725894928 | Train_ACC 87.5
# EPOCH 28 | ITER 35 | AVG_LOSS 0.3332808017730713 | Train_ACC 81.25
# EPOCH 28 | ITER 40 | AVG_LOSS 0.3273298740386963 | Train_ACC 93.75
# EPOCH 28 | ITER 45 | AVG_LOSS 0.3176734745502472 | Train_ACC 87.5
# EPOCH 28 | ITER 50 | AVG_LOSS 0.32165834307670593 | Train_ACC 90.625
# EPOCH 28 | ITER 55 | AVG_LOSS 0.31802237033843994 | Train_ACC 93.75
# EPOCH 28 | ITER 60 | AVG_LOSS 0.3110915720462799 | Train_ACC 96.875
# EPOCH 28 | ITER 65 | AVG_LOSS 0.3156660199165344 | Train_ACC 100.0
# EPOCH 28 | ITER 70 | AVG_LOSS 0.31112900376319885 | Train_ACC 84.375
# EPOCH 28 | ITER 75 | AVG_LOSS 0.31696823239326477 | Train_ACC 75.0
# EPOCH 28 | ITER 80 | AVG_LOSS 0.3177020847797394 | Train_ACC 93.75
# EPOCH 28 | ITER 85 | AVG_LOSS 0.31897085905075073 | Train_ACC 87.5
# EPOCH 28 | ITER 90 | AVG_LOSS 0.3182900547981262 | Train_ACC 87.5
# EPOCH 28 | ITER 95 | AVG_LOSS 0.3192426562309265 | Train_ACC 90.625
# EPOCH 28 | ITER 100 | AVG_LOSS 0.3158194124698639 | Train_ACC 100.0
# EPOCH 28 | ITER 105 | AVG_LOSS 0.31435370445251465 | Train_ACC 87.5
# EPOCH 28 | ITER 110 | AVG_LOSS 0.3201897442340851 | Train_ACC 81.25
# EPOCH 28 | ITER 115 | AVG_LOSS 0.3203483521938324 | Train_ACC 93.75
# EPOCH 28 | ITER 120 | AVG_LOSS 0.31844496726989746 | Train_ACC 90.625
# EPOCH 28 | ITER 125 | AVG_LOSS 0.32223016023635864 | Train_ACC 90.625
# EPOCH 28 | ITER 130 | AVG_LOSS 0.32150742411613464 | Train_ACC 81.25
# EPOCH 28 | ITER 135 | AVG_LOSS 0.32238852977752686 | Train_ACC 87.5
# EPOCH 28 | ITER 140 | AVG_LOSS 0.32675889134407043 | Train_ACC 81.25
# EPOCH 28 | ITER 145 | AVG_LOSS 0.32572662830352783 | Train_ACC 90.625
# EPOCH 28 | ITER 150 | AVG_LOSS 0.3289456367492676 | Train_ACC 71.875
# EPOCH 28 | ITER 155 | AVG_LOSS 0.32933586835861206 | Train_ACC 84.375
# EPOCH 28 | ITER 160 | AVG_LOSS 0.3314147889614105 | Train_ACC 87.5
# EPOCH 28 | ITER 165 | AVG_LOSS 0.3333982229232788 | Train_ACC 81.25
# EPOCH 28 | ITER 170 | AVG_LOSS 0.33851388096809387 | Train_ACC 81.25
# EPOCH 28 | ITER 175 | AVG_LOSS 0.33775296807289124 | Train_ACC 93.75
# EPOCH 28 | ITER 180 | AVG_LOSS 0.33835601806640625 | Train_ACC 87.5
# EPOCH 28 | ITER 185 | AVG_LOSS 0.3400046229362488 | Train_ACC 87.5
# EPOCH 28 | ITER 190 | AVG_LOSS 0.3391314744949341 | Train_ACC 87.5
# EPOCH 28 | ITER 195 | AVG_LOSS 0.3384121358394623 | Train_ACC 90.625
# EPOCH 28 | ITER 200 | AVG_LOSS 0.3389686048030853 | Train_ACC 81.25
# EPOCH 28 | ITER 205 | AVG_LOSS 0.3389267325401306 | Train_ACC 84.375
# EPOCH 28 | ITER 210 | AVG_LOSS 0.3391914665699005 | Train_ACC 87.5
# EPOCH 28 | ITER 215 | AVG_LOSS 0.3381277620792389 | Train_ACC 87.5
# EPOCH 28 | ITER 220 | AVG_LOSS 0.3388266861438751 | Train_ACC 84.375
# EPOCH 28 | ITER 225 | AVG_LOSS 0.33962303400039673 | Train_ACC 93.75
# EPOCH 28 | ITER 230 | AVG_LOSS 0.3430226743221283 | Train_ACC 84.375
# EPOCH 28 | ITER 235 | AVG_LOSS 0.34133604168891907 | Train_ACC 96.875
# EPOCH 28 | ITER 240 | AVG_LOSS 0.34302395582199097 | Train_ACC 93.75
# EPOCH 28 | ITER 245 | AVG_LOSS 0.3442480266094208 | Train_ACC 81.25
# Val Accuracy: 77.32%
#
# --------------------------------------------------
# EPOCH 28 | LOSS 0.29546862840652466 | TIME 230.9884901046753
# --------------------------------------------------
#
# EPOCH 29 | ITER 0 | AVG_LOSS 0.33317849040031433 | Train_ACC 81.25
# EPOCH 29 | ITER 5 | AVG_LOSS 0.2239639163017273 | Train_ACC 96.875
# EPOCH 29 | ITER 10 | AVG_LOSS 0.27112215757369995 | Train_ACC 84.375
# EPOCH 29 | ITER 15 | AVG_LOSS 0.3020426332950592 | Train_ACC 90.625
# EPOCH 29 | ITER 20 | AVG_LOSS 0.2902095317840576 | Train_ACC 90.625
# EPOCH 29 | ITER 25 | AVG_LOSS 0.29245540499687195 | Train_ACC 90.625
# EPOCH 29 | ITER 30 | AVG_LOSS 0.2938832938671112 | Train_ACC 84.375
# EPOCH 29 | ITER 35 | AVG_LOSS 0.3004090487957001 | Train_ACC 93.75
# EPOCH 29 | ITER 40 | AVG_LOSS 0.3185112774372101 | Train_ACC 84.375
# EPOCH 29 | ITER 45 | AVG_LOSS 0.3159853219985962 | Train_ACC 96.875
# EPOCH 29 | ITER 50 | AVG_LOSS 0.31213149428367615 | Train_ACC 93.75
# EPOCH 29 | ITER 55 | AVG_LOSS 0.31232136487960815 | Train_ACC 87.5
# EPOCH 29 | ITER 60 | AVG_LOSS 0.30960211157798767 | Train_ACC 93.75
# EPOCH 29 | ITER 65 | AVG_LOSS 0.3079931139945984 | Train_ACC 96.875
# EPOCH 29 | ITER 70 | AVG_LOSS 0.2997133433818817 | Train_ACC 93.75
# EPOCH 29 | ITER 75 | AVG_LOSS 0.30366843938827515 | Train_ACC 90.625
# EPOCH 29 | ITER 80 | AVG_LOSS 0.30660536885261536 | Train_ACC 81.25
# EPOCH 29 | ITER 85 | AVG_LOSS 0.30976566672325134 | Train_ACC 84.375
# EPOCH 29 | ITER 90 | AVG_LOSS 0.3158215880393982 | Train_ACC 93.75
# EPOCH 29 | ITER 95 | AVG_LOSS 0.31705838441848755 | Train_ACC 87.5
# EPOCH 29 | ITER 100 | AVG_LOSS 0.3169291913509369 | Train_ACC 93.75
# EPOCH 29 | ITER 105 | AVG_LOSS 0.31277137994766235 | Train_ACC 96.875
# EPOCH 29 | ITER 110 | AVG_LOSS 0.30864381790161133 | Train_ACC 96.875
# EPOCH 29 | ITER 115 | AVG_LOSS 0.30707913637161255 | Train_ACC 100.0
# EPOCH 29 | ITER 120 | AVG_LOSS 0.3058205246925354 | Train_ACC 87.5
# EPOCH 29 | ITER 125 | AVG_LOSS 0.30347326397895813 | Train_ACC 96.875
# EPOCH 29 | ITER 130 | AVG_LOSS 0.3067549169063568 | Train_ACC 96.875
# EPOCH 29 | ITER 135 | AVG_LOSS 0.30537116527557373 | Train_ACC 93.75
# EPOCH 29 | ITER 140 | AVG_LOSS 0.30216723680496216 | Train_ACC 96.875
# EPOCH 29 | ITER 145 | AVG_LOSS 0.3012208640575409 | Train_ACC 96.875
# EPOCH 29 | ITER 150 | AVG_LOSS 0.30075085163116455 | Train_ACC 93.75
# EPOCH 29 | ITER 155 | AVG_LOSS 0.2992212772369385 | Train_ACC 93.75
# EPOCH 29 | ITER 160 | AVG_LOSS 0.29745954275131226 | Train_ACC 96.875
# EPOCH 29 | ITER 165 | AVG_LOSS 0.3025822341442108 | Train_ACC 90.625
# EPOCH 29 | ITER 170 | AVG_LOSS 0.30032992362976074 | Train_ACC 90.625
# EPOCH 29 | ITER 175 | AVG_LOSS 0.29953527450561523 | Train_ACC 93.75
# EPOCH 29 | ITER 180 | AVG_LOSS 0.3032999634742737 | Train_ACC 87.5
# EPOCH 29 | ITER 185 | AVG_LOSS 0.30336669087409973 | Train_ACC 90.625
# EPOCH 29 | ITER 190 | AVG_LOSS 0.30364981293678284 | Train_ACC 93.75
# EPOCH 29 | ITER 195 | AVG_LOSS 0.30562835931777954 | Train_ACC 93.75
# EPOCH 29 | ITER 200 | AVG_LOSS 0.30441656708717346 | Train_ACC 87.5
# EPOCH 29 | ITER 205 | AVG_LOSS 0.3047727644443512 | Train_ACC 93.75
# EPOCH 29 | ITER 210 | AVG_LOSS 0.3075861632823944 | Train_ACC 75.0
# EPOCH 29 | ITER 215 | AVG_LOSS 0.3064268231391907 | Train_ACC 81.25
# EPOCH 29 | ITER 220 | AVG_LOSS 0.30728963017463684 | Train_ACC 96.875
# EPOCH 29 | ITER 225 | AVG_LOSS 0.30608245730400085 | Train_ACC 93.75
# EPOCH 29 | ITER 230 | AVG_LOSS 0.3074752986431122 | Train_ACC 93.75
# EPOCH 29 | ITER 235 | AVG_LOSS 0.3082628548145294 | Train_ACC 90.625
# EPOCH 29 | ITER 240 | AVG_LOSS 0.3088415265083313 | Train_ACC 90.625
# EPOCH 29 | ITER 245 | AVG_LOSS 0.3093632161617279 | Train_ACC 81.25
# Val Accuracy: 80.02%
#
# --------------------------------------------------
# EPOCH 29 | LOSS 0.4082093834877014 | TIME 230.89066910743713
# --------------------------------------------------
#
# Best Model:  29
# ****************************************
# test Accuracy: 80.22%
# <ipython-input-42-1deb41e30bd1>:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
plotloss()

# %%
class2idx = {'cat': 0, 'cow': 1, 'dog': 2, 'elephant': 3, 'horse': 4}

idx2class = { value : key  for key , value in class2idx.items() }
y_true = [idx2class[val.item()] for val in y_expected_test ]
y_pred = [idx2class[val.item()] for val in y_test ]


macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")
f1_score = (2*micro_precision*micro_recall)/(micro_recall + micro_precision)
print("f1 - Score is :--- " ,f1_score)
cnf_matrix = confusion_matrix(y_true , y_pred , labels=['cat','cow','dog','elephant','horse'])
plot_confusion_matrix(cnf_matrix , class2idx.keys() , [macro_precision , micro_precision , macro_recall , micro_recall], output_filename = "cnf_mobilenet_Data2.png")
# Out:
# f1 - Score is :---  0.8021978021978022
