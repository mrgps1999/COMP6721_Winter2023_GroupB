# %%
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
import torchvision.models as models
from torchvision.models import resnet18, ResNet18_Weights
from sklearn.metrics import *
import seaborn as sns
import seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import os.path
import random
import cv2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
writer = SummaryWriter()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


transforms_train = transforms.Compose([
    transforms.Resize((256, 256)),   #must same as here
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(), # data augmentation
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalization
])
transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),   #must same as here
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
def load_Data():
  train_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset3/train"
  test_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset3/test"
  val_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset3/val"
  # train_dir = "/content/gdrive/MyDrive/test/dataset1/train"
  # test_dir = "/content/gdrive/MyDrive/test/dataset1/test"
  # val_dir = "/content/gdrive/MyDrive/test/dataset1/val"
  trainset = datasets.ImageFolder(train_dir, transforms_train)
  testset = datasets.ImageFolder(test_dir, transforms_test)
  valset = datasets.ImageFolder(val_dir, transforms_test)
  trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=8)
  testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=8)
  valloader = torch.utils.data.DataLoader(valset, batch_size=32, shuffle=False, num_workers=8)
  return trainloader,testloader,valloader
load_Data()
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# (<torch.utils.data.dataloader.DataLoader at 0x7feed066a7c0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7feebd9107c0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7feed159ffa0>)

# %%
# def Model():
#   # Define the ResNet-18 model
#   resnet = 
#   # Replace the last fully connected layer with a new one
#   num_ftrs = resnet.fc.in_features
#   print(num_ftrs)
#   resnet.fc = nn.Linear(num_ftrs,2)

#   # Define the loss function and optimizer
#   return resnet
# Model()

# %%
class Resnet18(nn.Module):
    def __init__(self,inputDims) -> None:
        super(Resnet18 , self).__init__()

        self.model = torchvision.models.resnet18(pretrained=False)

        self.fc_layer = nn.Sequential(
            
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),

            nn.Linear(32, 12)
        )
        
        self.model.fc = self.fc_layer
        self.features = {}
        self.model.avgpool.register_forward_hook(self.get_features("embeddings"))

    def get_features(self,name):
        def hook(model, input, output):
            self.features[name] = output.detach().cpu().numpy()
        return hook

    def forward(self, x):
          x = self.model(x)
          return x
model2 = Resnet18((224,224))
print(model2)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Resnet18(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Dropout(p=0.2, inplace=False)
#       (6): Linear(in_features=128, out_features=64, bias=True)
#       (7): ReLU(inplace=True)
#       (8): Dropout(p=0.2, inplace=False)
#       (9): Linear(in_features=64, out_features=32, bias=True)
#       (10): ReLU(inplace=True)
#       (11): Dropout(p=0.2, inplace=False)
#       (12): Linear(in_features=32, out_features=12, bias=True)
#     )
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=64, out_features=32, bias=True)
#     (10): ReLU(inplace=True)
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=32, out_features=12, bias=True)
#   )
# )

# %%
def save_checkpoint(state, filename):
  torch.save(state, filename)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
# datastructure to store all the training testing and validation results.
y_train = []
y_expected_train = []
y_val = []
y_expected_val = []
y_test = []
y_expected_test = []
trainloss = []
valloss =[]
epochnum = []

# %%
print(torch.cuda.is_available())
def train(model, train_loader, criterion, optimizer, epoch, step=5):
    
    model.train()
    loss_list = AverageMeter()
    for i, (images, labels) in enumerate(train_loader):
        #print(torch.cuda.is_available())
        total =0
        correct = 0
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        #print(predicted,type(predicted))
        #print(labels,type(labels))
        output = model(images)
        loss = criterion(output,labels)
        loss_list.update(loss.data, images.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        y_train.extend(predicted.to(torch.device('cpu')))
        y_expected_train.extend(labels.to(torch.device('cpu')))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        #print( f'Training Accuracy: {accuracy:.2f}%')
            
        if i%step==0:
            print('EPOCH {} | ITER {} | AVG_LOSS {} | Train_ACC {}'.format(epoch, i, loss_list.avg,accuracy))
        writer.add_scalar('TRAIN_LOSS', loss, epoch)
        writer.add_scalar('TRAIN_ACC', accuracy, epoch)
        
    return loss ,accuracy
# Out:
# True

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    print("Best Model: ",epoch)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('_LOSS', loss, epoch)
        # writer.add_scalar('TEST_ACC', accuracy, epoch)
        return accuracy

# %%
def val(model, val_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    loss_list = AverageMeter()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            #print("Inside validation");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            loss = criterion(outputs,labels)
            loss_list.update(loss.data, inputs.size(0))
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #print("CORRECT",correct)
            #print("Total",total)
        accuracy = 100 * correct / total
        print(f'Val Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('Validation_LOSS', loss, epoch)
        writer.add_scalar('Validation_ACCURACY', accuracy, epoch)
        return loss,accuracy

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        return accuracy

# %%
def visualize(model , data_loader):
    class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
    idx2class = { value : key for key,value in  class2idx.items() }
    embeddings = np.array([])
    labels = np.array([])
    model.eval()
    out_features = 512
    num_categories = 12
    with torch.no_grad(): 
        for i,data in enumerate(data_loader):
            images, labs = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            embeds = model.features["embeddings"].reshape(-1, 512)
            embeddings = np.append(embeddings , embeds)
            labels = np.append(labels,labs.cpu())
  
    embeddings = embeddings.reshape(-1, 512)
    
    c_labels = labels.reshape(-1 , 1).ravel()
    tsne = TSNE(n_components=2,perplexity=2).fit_transform(embeddings)
    labels = np.array([ idx2class[ele] for ele in c_labels])
    
    cmap = cm.get_cmap('tab20')
    
    for lab in range(num_categories):
        indices = (c_labels == lab)
        plt.scatter(tsne[indices, 0],tsne[indices, 1],c=np.array(cmap(lab)).reshape(1, 4),label=lab,alpha=1)
        plt.legend(fontsize='large', markerscale=2)
    plt.show()
  
# model = Model((224,224))
# train_loader, val_loader ,test_loader = load_Data()
# visualize(model,test_loader)

# %%
def plotloss():
  plt.figure(figsize=(20,10))
  plt.plot(epochnum, trainloss)
  plt.plot(epochnum, valloss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}
idx2class = { value : key  for key , value in class2idx.items() }

def plot_confusion_matrix(data, labels, metrics ,output_filename=None):

    [macro_precision , micro_precision , macro_recall , micro_recall] = metrics

    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(10,10))
 
    plt.suptitle("Confusion Matrix")
    plt.title(f"(Macro/Micro) Precision : {round(macro_precision,2)}/{round(micro_precision,2)}   :::::   (Macro/Micro) Recall : {round(macro_recall,2)}/{round(micro_recall,2)}")
 
    seaborn.set(font_scale=1)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu",linewidths=2 , fmt='d' ,cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# %%
def main():
    model = Resnet18((224,224));
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        model = model.cuda()
        print("using gpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    epochs = 30
    train_loader, val_loader ,test_loader = load_Data()
 
    history = open("/content/gdrive/MyDrive/Results/dataset3_Resnet18_history.csv",'w')
    history.write('epochs , trainloss , Train-acc,val_acc , test_acc \n')
    max_accuracy = 0 
    finalepoch  = 0 
    for epoch in range(0,epochs):
        start = time.time()
        train_loss,accuracy = train(model, train_loader, criterion, optimizer, epoch)
        vallosss,val_loss = val(model, val_loader, criterion, optimizer, epoch)
        
        trainloss.append(train_loss.cpu().detach().numpy())
        valloss.append(vallosss.cpu().detach().numpy())
        epochnum.append(epoch)
        print()
        print('-' * 50)
        print('EPOCH {} | LOSS {} | TIME {}'.format(epoch, train_loss, time.time() - start))
        print('-' * 50)
        print()

        if(val_loss > max_accuracy):
          max_accuracy = val_loss
          finalepoch  = epoch
          save_checkpoint({'epoch': epoch,'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),'loss' : train_loss}, "/content/gdrive/MyDrive/Checkpoints/dataset3_Resnet18_checkpoint.ckpt")

        history.write('{},{},{},{}\n'.format(epoch, train_loss,accuracy, val_loss ))
    test_loss = test(model, test_loader, criterion, optimizer, finalepoch)    
    history.close()
    visualize(model,train_loader)
# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    main()
# Out:
# True
# using gpu
# EPOCH 0 | ITER 0 | AVG_LOSS 2.48771595954895 | Train_ACC 6.25
# EPOCH 0 | ITER 5 | AVG_LOSS 2.4855563640594482 | Train_ACC 6.25
# EPOCH 0 | ITER 10 | AVG_LOSS 2.474365711212158 | Train_ACC 18.75
# EPOCH 0 | ITER 15 | AVG_LOSS 2.4860711097717285 | Train_ACC 9.375
# EPOCH 0 | ITER 20 | AVG_LOSS 2.480078935623169 | Train_ACC 28.125
# EPOCH 0 | ITER 25 | AVG_LOSS 2.475213050842285 | Train_ACC 15.625
# EPOCH 0 | ITER 30 | AVG_LOSS 2.475209951400757 | Train_ACC 12.5
# EPOCH 0 | ITER 35 | AVG_LOSS 2.4763050079345703 | Train_ACC 15.625
# EPOCH 0 | ITER 40 | AVG_LOSS 2.473829984664917 | Train_ACC 12.5
# EPOCH 0 | ITER 45 | AVG_LOSS 2.4742300510406494 | Train_ACC 15.625
# EPOCH 0 | ITER 50 | AVG_LOSS 2.4701249599456787 | Train_ACC 21.875
# EPOCH 0 | ITER 55 | AVG_LOSS 2.4718165397644043 | Train_ACC 6.25
# EPOCH 0 | ITER 60 | AVG_LOSS 2.472515821456909 | Train_ACC 6.25
# EPOCH 0 | ITER 65 | AVG_LOSS 2.4739651679992676 | Train_ACC 3.125
# EPOCH 0 | ITER 70 | AVG_LOSS 2.47469425201416 | Train_ACC 15.625
# EPOCH 0 | ITER 75 | AVG_LOSS 2.472913980484009 | Train_ACC 6.25
# EPOCH 0 | ITER 80 | AVG_LOSS 2.4741158485412598 | Train_ACC 0.0
# EPOCH 0 | ITER 85 | AVG_LOSS 2.4740049839019775 | Train_ACC 12.5
# EPOCH 0 | ITER 90 | AVG_LOSS 2.4736499786376953 | Train_ACC 3.125
# EPOCH 0 | ITER 95 | AVG_LOSS 2.471543312072754 | Train_ACC 12.5
# EPOCH 0 | ITER 100 | AVG_LOSS 2.4723453521728516 | Train_ACC 3.125
# EPOCH 0 | ITER 105 | AVG_LOSS 2.4725353717803955 | Train_ACC 3.125
# EPOCH 0 | ITER 110 | AVG_LOSS 2.4739110469818115 | Train_ACC 3.125
# EPOCH 0 | ITER 115 | AVG_LOSS 2.4731335639953613 | Train_ACC 15.625
# EPOCH 0 | ITER 120 | AVG_LOSS 2.472853660583496 | Train_ACC 15.625
# EPOCH 0 | ITER 125 | AVG_LOSS 2.4727914333343506 | Train_ACC 15.625
# EPOCH 0 | ITER 130 | AVG_LOSS 2.4715940952301025 | Train_ACC 9.375
# EPOCH 0 | ITER 135 | AVG_LOSS 2.469701051712036 | Train_ACC 15.625
# EPOCH 0 | ITER 140 | AVG_LOSS 2.4684195518493652 | Train_ACC 9.375
# EPOCH 0 | ITER 145 | AVG_LOSS 2.4676082134246826 | Train_ACC 15.625
# EPOCH 0 | ITER 150 | AVG_LOSS 2.4672555923461914 | Train_ACC 9.375
# EPOCH 0 | ITER 155 | AVG_LOSS 2.466325283050537 | Train_ACC 18.75
# EPOCH 0 | ITER 160 | AVG_LOSS 2.4640555381774902 | Train_ACC 12.5
# EPOCH 0 | ITER 165 | AVG_LOSS 2.460446834564209 | Train_ACC 6.25
# EPOCH 0 | ITER 170 | AVG_LOSS 2.4613146781921387 | Train_ACC 12.5
# EPOCH 0 | ITER 175 | AVG_LOSS 2.461435317993164 | Train_ACC 15.625
# EPOCH 0 | ITER 180 | AVG_LOSS 2.46043062210083 | Train_ACC 12.5
# EPOCH 0 | ITER 185 | AVG_LOSS 2.46039080619812 | Train_ACC 18.75
# EPOCH 0 | ITER 190 | AVG_LOSS 2.460956335067749 | Train_ACC 6.25
# EPOCH 0 | ITER 195 | AVG_LOSS 2.4603171348571777 | Train_ACC 21.875
# EPOCH 0 | ITER 200 | AVG_LOSS 2.4601240158081055 | Train_ACC 9.375
# EPOCH 0 | ITER 205 | AVG_LOSS 2.4599246978759766 | Train_ACC 18.75
# EPOCH 0 | ITER 210 | AVG_LOSS 2.460341691970825 | Train_ACC 6.25
# EPOCH 0 | ITER 215 | AVG_LOSS 2.45914888381958 | Train_ACC 15.625
# EPOCH 0 | ITER 220 | AVG_LOSS 2.458308696746826 | Train_ACC 15.625
# EPOCH 0 | ITER 225 | AVG_LOSS 2.45747709274292 | Train_ACC 18.75
# EPOCH 0 | ITER 230 | AVG_LOSS 2.455336332321167 | Train_ACC 12.5
# EPOCH 0 | ITER 235 | AVG_LOSS 2.454176902770996 | Train_ACC 12.5
# EPOCH 0 | ITER 240 | AVG_LOSS 2.454634189605713 | Train_ACC 18.75
# EPOCH 0 | ITER 245 | AVG_LOSS 2.4533655643463135 | Train_ACC 6.25
# EPOCH 0 | ITER 250 | AVG_LOSS 2.4516310691833496 | Train_ACC 12.5
# EPOCH 0 | ITER 255 | AVG_LOSS 2.450985908508301 | Train_ACC 18.75
# EPOCH 0 | ITER 260 | AVG_LOSS 2.450343608856201 | Train_ACC 12.5
# EPOCH 0 | ITER 265 | AVG_LOSS 2.4498987197875977 | Train_ACC 6.25
# EPOCH 0 | ITER 270 | AVG_LOSS 2.4482421875 | Train_ACC 15.625
# EPOCH 0 | ITER 275 | AVG_LOSS 2.44827938079834 | Train_ACC 6.25
# EPOCH 0 | ITER 280 | AVG_LOSS 2.4480550289154053 | Train_ACC 9.375
# EPOCH 0 | ITER 285 | AVG_LOSS 2.446796178817749 | Train_ACC 6.25
# EPOCH 0 | ITER 290 | AVG_LOSS 2.4474377632141113 | Train_ACC 12.5
# EPOCH 0 | ITER 295 | AVG_LOSS 2.446791887283325 | Train_ACC 18.75
# EPOCH 0 | ITER 300 | AVG_LOSS 2.446011781692505 | Train_ACC 15.625
# EPOCH 0 | ITER 305 | AVG_LOSS 2.4460058212280273 | Train_ACC 12.5
# EPOCH 0 | ITER 310 | AVG_LOSS 2.445202350616455 | Train_ACC 15.625
# EPOCH 0 | ITER 315 | AVG_LOSS 2.4454638957977295 | Train_ACC 12.5
# EPOCH 0 | ITER 320 | AVG_LOSS 2.445223331451416 | Train_ACC 21.875
# EPOCH 0 | ITER 325 | AVG_LOSS 2.4445528984069824 | Train_ACC 6.25
# EPOCH 0 | ITER 330 | AVG_LOSS 2.443781614303589 | Train_ACC 15.625
# EPOCH 0 | ITER 335 | AVG_LOSS 2.4431378841400146 | Train_ACC 21.875
# EPOCH 0 | ITER 340 | AVG_LOSS 2.442202091217041 | Train_ACC 18.75
# EPOCH 0 | ITER 345 | AVG_LOSS 2.4424378871917725 | Train_ACC 9.375
# EPOCH 0 | ITER 350 | AVG_LOSS 2.4429922103881836 | Train_ACC 18.75
# EPOCH 0 | ITER 355 | AVG_LOSS 2.4425859451293945 | Train_ACC 18.75
# EPOCH 0 | ITER 360 | AVG_LOSS 2.4421792030334473 | Train_ACC 25.0
# EPOCH 0 | ITER 365 | AVG_LOSS 2.441467761993408 | Train_ACC 12.5
# EPOCH 0 | ITER 370 | AVG_LOSS 2.4406397342681885 | Train_ACC 21.875
# Val Accuracy: 12.56%
#
# --------------------------------------------------
# EPOCH 0 | LOSS 2.3561651706695557 | TIME 173.45658493041992
# --------------------------------------------------
#
# EPOCH 1 | ITER 0 | AVG_LOSS 2.473871946334839 | Train_ACC 15.625
# EPOCH 1 | ITER 5 | AVG_LOSS 2.43804931640625 | Train_ACC 15.625
# EPOCH 1 | ITER 10 | AVG_LOSS 2.416929244995117 | Train_ACC 18.75
# EPOCH 1 | ITER 15 | AVG_LOSS 2.39878249168396 | Train_ACC 18.75
# EPOCH 1 | ITER 20 | AVG_LOSS 2.389960765838623 | Train_ACC 28.125
# EPOCH 1 | ITER 25 | AVG_LOSS 2.401846170425415 | Train_ACC 15.625
# EPOCH 1 | ITER 30 | AVG_LOSS 2.401505708694458 | Train_ACC 6.25
# EPOCH 1 | ITER 35 | AVG_LOSS 2.407386064529419 | Train_ACC 15.625
# EPOCH 1 | ITER 40 | AVG_LOSS 2.410043478012085 | Train_ACC 15.625
# EPOCH 1 | ITER 45 | AVG_LOSS 2.407719612121582 | Train_ACC 12.5
# EPOCH 1 | ITER 50 | AVG_LOSS 2.4013099670410156 | Train_ACC 21.875
# EPOCH 1 | ITER 55 | AVG_LOSS 2.3993937969207764 | Train_ACC 21.875
# EPOCH 1 | ITER 60 | AVG_LOSS 2.4053003787994385 | Train_ACC 12.5
# EPOCH 1 | ITER 65 | AVG_LOSS 2.4085042476654053 | Train_ACC 12.5
# EPOCH 1 | ITER 70 | AVG_LOSS 2.405855894088745 | Train_ACC 12.5
# EPOCH 1 | ITER 75 | AVG_LOSS 2.4061853885650635 | Train_ACC 12.5
# EPOCH 1 | ITER 80 | AVG_LOSS 2.4061880111694336 | Train_ACC 21.875
# EPOCH 1 | ITER 85 | AVG_LOSS 2.406120777130127 | Train_ACC 12.5
# EPOCH 1 | ITER 90 | AVG_LOSS 2.4059813022613525 | Train_ACC 28.125
# EPOCH 1 | ITER 95 | AVG_LOSS 2.404336929321289 | Train_ACC 12.5
# EPOCH 1 | ITER 100 | AVG_LOSS 2.4061806201934814 | Train_ACC 15.625
# EPOCH 1 | ITER 105 | AVG_LOSS 2.4051761627197266 | Train_ACC 25.0
# EPOCH 1 | ITER 110 | AVG_LOSS 2.403689384460449 | Train_ACC 15.625
# EPOCH 1 | ITER 115 | AVG_LOSS 2.402107000350952 | Train_ACC 12.5
# EPOCH 1 | ITER 120 | AVG_LOSS 2.4018232822418213 | Train_ACC 15.625
# EPOCH 1 | ITER 125 | AVG_LOSS 2.4005324840545654 | Train_ACC 18.75
# EPOCH 1 | ITER 130 | AVG_LOSS 2.401646614074707 | Train_ACC 6.25
# EPOCH 1 | ITER 135 | AVG_LOSS 2.401010274887085 | Train_ACC 18.75
# EPOCH 1 | ITER 140 | AVG_LOSS 2.399747848510742 | Train_ACC 12.5
# EPOCH 1 | ITER 145 | AVG_LOSS 2.3967254161834717 | Train_ACC 21.875
# EPOCH 1 | ITER 150 | AVG_LOSS 2.39823842048645 | Train_ACC 12.5
# EPOCH 1 | ITER 155 | AVG_LOSS 2.3979368209838867 | Train_ACC 12.5
# EPOCH 1 | ITER 160 | AVG_LOSS 2.396713972091675 | Train_ACC 15.625
# EPOCH 1 | ITER 165 | AVG_LOSS 2.3934192657470703 | Train_ACC 9.375
# EPOCH 1 | ITER 170 | AVG_LOSS 2.392617702484131 | Train_ACC 9.375
# EPOCH 1 | ITER 175 | AVG_LOSS 2.3913700580596924 | Train_ACC 6.25
# EPOCH 1 | ITER 180 | AVG_LOSS 2.3907172679901123 | Train_ACC 15.625
# EPOCH 1 | ITER 185 | AVG_LOSS 2.389000415802002 | Train_ACC 9.375
# EPOCH 1 | ITER 190 | AVG_LOSS 2.3889524936676025 | Train_ACC 18.75
# EPOCH 1 | ITER 195 | AVG_LOSS 2.3892464637756348 | Train_ACC 0.0
# EPOCH 1 | ITER 200 | AVG_LOSS 2.3889143466949463 | Train_ACC 9.375
# EPOCH 1 | ITER 205 | AVG_LOSS 2.3896725177764893 | Train_ACC 6.25
# EPOCH 1 | ITER 210 | AVG_LOSS 2.390331268310547 | Train_ACC 12.5
# EPOCH 1 | ITER 215 | AVG_LOSS 2.390263795852661 | Train_ACC 15.625
# EPOCH 1 | ITER 220 | AVG_LOSS 2.389207601547241 | Train_ACC 12.5
# EPOCH 1 | ITER 225 | AVG_LOSS 2.3902037143707275 | Train_ACC 12.5
# EPOCH 1 | ITER 230 | AVG_LOSS 2.3918890953063965 | Train_ACC 9.375
# EPOCH 1 | ITER 235 | AVG_LOSS 2.3923473358154297 | Train_ACC 9.375
# EPOCH 1 | ITER 240 | AVG_LOSS 2.392902374267578 | Train_ACC 15.625
# EPOCH 1 | ITER 245 | AVG_LOSS 2.3932032585144043 | Train_ACC 18.75
# EPOCH 1 | ITER 250 | AVG_LOSS 2.392130136489868 | Train_ACC 18.75
# EPOCH 1 | ITER 255 | AVG_LOSS 2.3927595615386963 | Train_ACC 9.375
# EPOCH 1 | ITER 260 | AVG_LOSS 2.3920767307281494 | Train_ACC 6.25
# EPOCH 1 | ITER 265 | AVG_LOSS 2.39267897605896 | Train_ACC 12.5
# EPOCH 1 | ITER 270 | AVG_LOSS 2.393231153488159 | Train_ACC 12.5
# EPOCH 1 | ITER 275 | AVG_LOSS 2.394176721572876 | Train_ACC 12.5
# EPOCH 1 | ITER 280 | AVG_LOSS 2.3939077854156494 | Train_ACC 21.875
# EPOCH 1 | ITER 285 | AVG_LOSS 2.3939356803894043 | Train_ACC 12.5
# EPOCH 1 | ITER 290 | AVG_LOSS 2.3937597274780273 | Train_ACC 15.625
# EPOCH 1 | ITER 295 | AVG_LOSS 2.3936216831207275 | Train_ACC 6.25
# EPOCH 1 | ITER 300 | AVG_LOSS 2.3915979862213135 | Train_ACC 18.75
# EPOCH 1 | ITER 305 | AVG_LOSS 2.3930673599243164 | Train_ACC 12.5
# EPOCH 1 | ITER 310 | AVG_LOSS 2.3933846950531006 | Train_ACC 15.625
# EPOCH 1 | ITER 315 | AVG_LOSS 2.3938822746276855 | Train_ACC 25.0
# EPOCH 1 | ITER 320 | AVG_LOSS 2.394026041030884 | Train_ACC 21.875
# EPOCH 1 | ITER 325 | AVG_LOSS 2.393954277038574 | Train_ACC 15.625
# EPOCH 1 | ITER 330 | AVG_LOSS 2.3936972618103027 | Train_ACC 15.625
# EPOCH 1 | ITER 335 | AVG_LOSS 2.394484758377075 | Train_ACC 9.375
# EPOCH 1 | ITER 340 | AVG_LOSS 2.393920660018921 | Train_ACC 25.0
# EPOCH 1 | ITER 345 | AVG_LOSS 2.393359422683716 | Train_ACC 12.5
# EPOCH 1 | ITER 350 | AVG_LOSS 2.393747568130493 | Train_ACC 9.375
# EPOCH 1 | ITER 355 | AVG_LOSS 2.392975330352783 | Train_ACC 12.5
# EPOCH 1 | ITER 360 | AVG_LOSS 2.391148805618286 | Train_ACC 28.125
# EPOCH 1 | ITER 365 | AVG_LOSS 2.3906633853912354 | Train_ACC 9.375
# EPOCH 1 | ITER 370 | AVG_LOSS 2.3907816410064697 | Train_ACC 18.75
# Val Accuracy: 14.88%
#
# --------------------------------------------------
# EPOCH 1 | LOSS 2.3707399368286133 | TIME 171.02946257591248
# --------------------------------------------------
#
# EPOCH 2 | ITER 0 | AVG_LOSS 2.283895969390869 | Train_ACC 25.0
# EPOCH 2 | ITER 5 | AVG_LOSS 2.337583065032959 | Train_ACC 18.75
# EPOCH 2 | ITER 10 | AVG_LOSS 2.336294651031494 | Train_ACC 15.625
# EPOCH 2 | ITER 15 | AVG_LOSS 2.3420257568359375 | Train_ACC 12.5
# EPOCH 2 | ITER 20 | AVG_LOSS 2.331693649291992 | Train_ACC 18.75
# EPOCH 2 | ITER 25 | AVG_LOSS 2.3443431854248047 | Train_ACC 21.875
# EPOCH 2 | ITER 30 | AVG_LOSS 2.3286919593811035 | Train_ACC 21.875
# EPOCH 2 | ITER 35 | AVG_LOSS 2.31901216506958 | Train_ACC 21.875
# EPOCH 2 | ITER 40 | AVG_LOSS 2.317598342895508 | Train_ACC 18.75
# EPOCH 2 | ITER 45 | AVG_LOSS 2.320178747177124 | Train_ACC 15.625
# EPOCH 2 | ITER 50 | AVG_LOSS 2.329275131225586 | Train_ACC 21.875
# EPOCH 2 | ITER 55 | AVG_LOSS 2.329990863800049 | Train_ACC 18.75
# EPOCH 2 | ITER 60 | AVG_LOSS 2.3336145877838135 | Train_ACC 18.75
# EPOCH 2 | ITER 65 | AVG_LOSS 2.3338680267333984 | Train_ACC 25.0
# EPOCH 2 | ITER 70 | AVG_LOSS 2.3334269523620605 | Train_ACC 9.375
# EPOCH 2 | ITER 75 | AVG_LOSS 2.334196090698242 | Train_ACC 21.875
# EPOCH 2 | ITER 80 | AVG_LOSS 2.339050054550171 | Train_ACC 12.5
# EPOCH 2 | ITER 85 | AVG_LOSS 2.3363683223724365 | Train_ACC 25.0
# EPOCH 2 | ITER 90 | AVG_LOSS 2.333594799041748 | Train_ACC 31.25
# EPOCH 2 | ITER 95 | AVG_LOSS 2.330814838409424 | Train_ACC 18.75
# EPOCH 2 | ITER 100 | AVG_LOSS 2.329814910888672 | Train_ACC 31.25
# EPOCH 2 | ITER 105 | AVG_LOSS 2.3306257724761963 | Train_ACC 12.5
# EPOCH 2 | ITER 110 | AVG_LOSS 2.333669662475586 | Train_ACC 21.875
# EPOCH 2 | ITER 115 | AVG_LOSS 2.3359475135803223 | Train_ACC 18.75
# EPOCH 2 | ITER 120 | AVG_LOSS 2.336057186126709 | Train_ACC 15.625
# EPOCH 2 | ITER 125 | AVG_LOSS 2.338186740875244 | Train_ACC 15.625
# EPOCH 2 | ITER 130 | AVG_LOSS 2.3369362354278564 | Train_ACC 15.625
# EPOCH 2 | ITER 135 | AVG_LOSS 2.3414859771728516 | Train_ACC 21.875
# EPOCH 2 | ITER 140 | AVG_LOSS 2.3396265506744385 | Train_ACC 21.875
# EPOCH 2 | ITER 145 | AVG_LOSS 2.3415331840515137 | Train_ACC 9.375
# EPOCH 2 | ITER 150 | AVG_LOSS 2.3420403003692627 | Train_ACC 18.75
# EPOCH 2 | ITER 155 | AVG_LOSS 2.3427600860595703 | Train_ACC 21.875
# EPOCH 2 | ITER 160 | AVG_LOSS 2.343381404876709 | Train_ACC 15.625
# EPOCH 2 | ITER 165 | AVG_LOSS 2.342513084411621 | Train_ACC 18.75
# EPOCH 2 | ITER 170 | AVG_LOSS 2.342972993850708 | Train_ACC 9.375
# EPOCH 2 | ITER 175 | AVG_LOSS 2.343296527862549 | Train_ACC 21.875
# EPOCH 2 | ITER 180 | AVG_LOSS 2.342808485031128 | Train_ACC 21.875
# EPOCH 2 | ITER 185 | AVG_LOSS 2.343000888824463 | Train_ACC 31.25
# EPOCH 2 | ITER 190 | AVG_LOSS 2.344061851501465 | Train_ACC 25.0
# EPOCH 2 | ITER 195 | AVG_LOSS 2.3448047637939453 | Train_ACC 15.625
# EPOCH 2 | ITER 200 | AVG_LOSS 2.342597723007202 | Train_ACC 21.875
# EPOCH 2 | ITER 205 | AVG_LOSS 2.3396713733673096 | Train_ACC 25.0
# EPOCH 2 | ITER 210 | AVG_LOSS 2.338513135910034 | Train_ACC 21.875
# EPOCH 2 | ITER 215 | AVG_LOSS 2.3399548530578613 | Train_ACC 15.625
# EPOCH 2 | ITER 220 | AVG_LOSS 2.339916944503784 | Train_ACC 25.0
# EPOCH 2 | ITER 225 | AVG_LOSS 2.3414225578308105 | Train_ACC 12.5
# EPOCH 2 | ITER 230 | AVG_LOSS 2.3420581817626953 | Train_ACC 12.5
# EPOCH 2 | ITER 235 | AVG_LOSS 2.3421874046325684 | Train_ACC 15.625
# EPOCH 2 | ITER 240 | AVG_LOSS 2.3434207439422607 | Train_ACC 12.5
# EPOCH 2 | ITER 245 | AVG_LOSS 2.342026710510254 | Train_ACC 9.375
# EPOCH 2 | ITER 250 | AVG_LOSS 2.3423056602478027 | Train_ACC 15.625
# EPOCH 2 | ITER 255 | AVG_LOSS 2.341749668121338 | Train_ACC 31.25
# EPOCH 2 | ITER 260 | AVG_LOSS 2.3418564796447754 | Train_ACC 9.375
# EPOCH 2 | ITER 265 | AVG_LOSS 2.3426291942596436 | Train_ACC 18.75
# EPOCH 2 | ITER 270 | AVG_LOSS 2.340484380722046 | Train_ACC 25.0
# EPOCH 2 | ITER 275 | AVG_LOSS 2.3403279781341553 | Train_ACC 21.875
# EPOCH 2 | ITER 280 | AVG_LOSS 2.34096097946167 | Train_ACC 31.25
# EPOCH 2 | ITER 285 | AVG_LOSS 2.3417365550994873 | Train_ACC 9.375
# EPOCH 2 | ITER 290 | AVG_LOSS 2.3426694869995117 | Train_ACC 12.5
# EPOCH 2 | ITER 295 | AVG_LOSS 2.342466354370117 | Train_ACC 15.625
# EPOCH 2 | ITER 300 | AVG_LOSS 2.3426032066345215 | Train_ACC 15.625
# EPOCH 2 | ITER 305 | AVG_LOSS 2.342965602874756 | Train_ACC 21.875
# EPOCH 2 | ITER 310 | AVG_LOSS 2.342026948928833 | Train_ACC 12.5
# EPOCH 2 | ITER 315 | AVG_LOSS 2.342500686645508 | Train_ACC 6.25
# EPOCH 2 | ITER 320 | AVG_LOSS 2.3422560691833496 | Train_ACC 9.375
# EPOCH 2 | ITER 325 | AVG_LOSS 2.341834545135498 | Train_ACC 12.5
# EPOCH 2 | ITER 330 | AVG_LOSS 2.341029644012451 | Train_ACC 40.625
# EPOCH 2 | ITER 335 | AVG_LOSS 2.3399550914764404 | Train_ACC 21.875
# EPOCH 2 | ITER 340 | AVG_LOSS 2.3413376808166504 | Train_ACC 9.375
# EPOCH 2 | ITER 345 | AVG_LOSS 2.3405697345733643 | Train_ACC 9.375
# EPOCH 2 | ITER 350 | AVG_LOSS 2.339364767074585 | Train_ACC 18.75
# EPOCH 2 | ITER 355 | AVG_LOSS 2.3397178649902344 | Train_ACC 21.875
# EPOCH 2 | ITER 360 | AVG_LOSS 2.3396408557891846 | Train_ACC 9.375
# EPOCH 2 | ITER 365 | AVG_LOSS 2.3389859199523926 | Train_ACC 15.625
# EPOCH 2 | ITER 370 | AVG_LOSS 2.339090347290039 | Train_ACC 21.875
# Val Accuracy: 17.81%
#
# --------------------------------------------------
# EPOCH 2 | LOSS 2.3973135948181152 | TIME 170.36534214019775
# --------------------------------------------------
#
# EPOCH 3 | ITER 0 | AVG_LOSS 2.213538885116577 | Train_ACC 18.75
# EPOCH 3 | ITER 5 | AVG_LOSS 2.3095555305480957 | Train_ACC 28.125
# EPOCH 3 | ITER 10 | AVG_LOSS 2.338813066482544 | Train_ACC 9.375
# EPOCH 3 | ITER 15 | AVG_LOSS 2.3130688667297363 | Train_ACC 21.875
# EPOCH 3 | ITER 20 | AVG_LOSS 2.315749406814575 | Train_ACC 12.5
# EPOCH 3 | ITER 25 | AVG_LOSS 2.3080086708068848 | Train_ACC 21.875
# EPOCH 3 | ITER 30 | AVG_LOSS 2.3005707263946533 | Train_ACC 15.625
# EPOCH 3 | ITER 35 | AVG_LOSS 2.314772367477417 | Train_ACC 18.75
# EPOCH 3 | ITER 40 | AVG_LOSS 2.3181636333465576 | Train_ACC 9.375
# EPOCH 3 | ITER 45 | AVG_LOSS 2.314298152923584 | Train_ACC 28.125
# EPOCH 3 | ITER 50 | AVG_LOSS 2.316779851913452 | Train_ACC 15.625
# EPOCH 3 | ITER 55 | AVG_LOSS 2.3132033348083496 | Train_ACC 12.5
# EPOCH 3 | ITER 60 | AVG_LOSS 2.3084168434143066 | Train_ACC 28.125
# EPOCH 3 | ITER 65 | AVG_LOSS 2.3149614334106445 | Train_ACC 6.25
# EPOCH 3 | ITER 70 | AVG_LOSS 2.3171703815460205 | Train_ACC 12.5
# EPOCH 3 | ITER 75 | AVG_LOSS 2.315080404281616 | Train_ACC 28.125
# EPOCH 3 | ITER 80 | AVG_LOSS 2.3156943321228027 | Train_ACC 25.0
# EPOCH 3 | ITER 85 | AVG_LOSS 2.31434965133667 | Train_ACC 34.375
# EPOCH 3 | ITER 90 | AVG_LOSS 2.311107873916626 | Train_ACC 31.25
# EPOCH 3 | ITER 95 | AVG_LOSS 2.3065905570983887 | Train_ACC 15.625
# EPOCH 3 | ITER 100 | AVG_LOSS 2.3139803409576416 | Train_ACC 15.625
# EPOCH 3 | ITER 105 | AVG_LOSS 2.314030408859253 | Train_ACC 34.375
# EPOCH 3 | ITER 110 | AVG_LOSS 2.3166513442993164 | Train_ACC 18.75
# EPOCH 3 | ITER 115 | AVG_LOSS 2.3153934478759766 | Train_ACC 18.75
# EPOCH 3 | ITER 120 | AVG_LOSS 2.313668727874756 | Train_ACC 15.625
# EPOCH 3 | ITER 125 | AVG_LOSS 2.313499927520752 | Train_ACC 9.375
# EPOCH 3 | ITER 130 | AVG_LOSS 2.3152987957000732 | Train_ACC 28.125
# EPOCH 3 | ITER 135 | AVG_LOSS 2.316993236541748 | Train_ACC 9.375
# EPOCH 3 | ITER 140 | AVG_LOSS 2.315464496612549 | Train_ACC 21.875
# EPOCH 3 | ITER 145 | AVG_LOSS 2.3160548210144043 | Train_ACC 12.5
# EPOCH 3 | ITER 150 | AVG_LOSS 2.314495801925659 | Train_ACC 21.875
# EPOCH 3 | ITER 155 | AVG_LOSS 2.314744710922241 | Train_ACC 25.0
# EPOCH 3 | ITER 160 | AVG_LOSS 2.317135810852051 | Train_ACC 25.0
# EPOCH 3 | ITER 165 | AVG_LOSS 2.319206953048706 | Train_ACC 6.25
# EPOCH 3 | ITER 170 | AVG_LOSS 2.3181514739990234 | Train_ACC 28.125
# EPOCH 3 | ITER 175 | AVG_LOSS 2.31567645072937 | Train_ACC 21.875
# EPOCH 3 | ITER 180 | AVG_LOSS 2.3138561248779297 | Train_ACC 18.75
# EPOCH 3 | ITER 185 | AVG_LOSS 2.3118810653686523 | Train_ACC 12.5
# EPOCH 3 | ITER 190 | AVG_LOSS 2.3143417835235596 | Train_ACC 25.0
# EPOCH 3 | ITER 195 | AVG_LOSS 2.3131935596466064 | Train_ACC 18.75
# EPOCH 3 | ITER 200 | AVG_LOSS 2.314669370651245 | Train_ACC 12.5
# EPOCH 3 | ITER 205 | AVG_LOSS 2.312675952911377 | Train_ACC 28.125
# EPOCH 3 | ITER 210 | AVG_LOSS 2.313114881515503 | Train_ACC 18.75
# EPOCH 3 | ITER 215 | AVG_LOSS 2.314272165298462 | Train_ACC 12.5
# EPOCH 3 | ITER 220 | AVG_LOSS 2.3144428730010986 | Train_ACC 28.125
# EPOCH 3 | ITER 225 | AVG_LOSS 2.3148860931396484 | Train_ACC 25.0
# EPOCH 3 | ITER 230 | AVG_LOSS 2.3140969276428223 | Train_ACC 31.25
# EPOCH 3 | ITER 235 | AVG_LOSS 2.313154935836792 | Train_ACC 9.375
# EPOCH 3 | ITER 240 | AVG_LOSS 2.3117008209228516 | Train_ACC 12.5
# EPOCH 3 | ITER 245 | AVG_LOSS 2.3096275329589844 | Train_ACC 21.875
# EPOCH 3 | ITER 250 | AVG_LOSS 2.3100271224975586 | Train_ACC 25.0
# EPOCH 3 | ITER 255 | AVG_LOSS 2.3082094192504883 | Train_ACC 25.0
# EPOCH 3 | ITER 260 | AVG_LOSS 2.306461811065674 | Train_ACC 25.0
# EPOCH 3 | ITER 265 | AVG_LOSS 2.3067679405212402 | Train_ACC 21.875
# EPOCH 3 | ITER 270 | AVG_LOSS 2.307053327560425 | Train_ACC 18.75
# EPOCH 3 | ITER 275 | AVG_LOSS 2.3079495429992676 | Train_ACC 28.125
# EPOCH 3 | ITER 280 | AVG_LOSS 2.305795431137085 | Train_ACC 18.75
# EPOCH 3 | ITER 285 | AVG_LOSS 2.305948495864868 | Train_ACC 31.25
# EPOCH 3 | ITER 290 | AVG_LOSS 2.3057308197021484 | Train_ACC 21.875
# EPOCH 3 | ITER 295 | AVG_LOSS 2.306476354598999 | Train_ACC 25.0
# EPOCH 3 | ITER 300 | AVG_LOSS 2.3056795597076416 | Train_ACC 18.75
# EPOCH 3 | ITER 305 | AVG_LOSS 2.304133415222168 | Train_ACC 37.5
# EPOCH 3 | ITER 310 | AVG_LOSS 2.303943157196045 | Train_ACC 18.75
# EPOCH 3 | ITER 315 | AVG_LOSS 2.303346872329712 | Train_ACC 9.375
# EPOCH 3 | ITER 320 | AVG_LOSS 2.3041508197784424 | Train_ACC 21.875
# EPOCH 3 | ITER 325 | AVG_LOSS 2.303196668624878 | Train_ACC 34.375
# EPOCH 3 | ITER 330 | AVG_LOSS 2.3024563789367676 | Train_ACC 25.0
# EPOCH 3 | ITER 335 | AVG_LOSS 2.3027424812316895 | Train_ACC 15.625
# EPOCH 3 | ITER 340 | AVG_LOSS 2.303255319595337 | Train_ACC 31.25
# EPOCH 3 | ITER 345 | AVG_LOSS 2.3025169372558594 | Train_ACC 28.125
# EPOCH 3 | ITER 350 | AVG_LOSS 2.3009908199310303 | Train_ACC 21.875
# EPOCH 3 | ITER 355 | AVG_LOSS 2.301926612854004 | Train_ACC 15.625
# EPOCH 3 | ITER 360 | AVG_LOSS 2.301994562149048 | Train_ACC 37.5
# EPOCH 3 | ITER 365 | AVG_LOSS 2.30087947845459 | Train_ACC 12.5
# EPOCH 3 | ITER 370 | AVG_LOSS 2.2996666431427 | Train_ACC 18.75
# Val Accuracy: 22.66%
#
# --------------------------------------------------
# EPOCH 3 | LOSS 2.33843994140625 | TIME 168.77055096626282
# --------------------------------------------------
#
# EPOCH 4 | ITER 0 | AVG_LOSS 2.191157579421997 | Train_ACC 25.0
# EPOCH 4 | ITER 5 | AVG_LOSS 2.277534008026123 | Train_ACC 18.75
# EPOCH 4 | ITER 10 | AVG_LOSS 2.254251718521118 | Train_ACC 28.125
# EPOCH 4 | ITER 15 | AVG_LOSS 2.272785186767578 | Train_ACC 15.625
# EPOCH 4 | ITER 20 | AVG_LOSS 2.281219244003296 | Train_ACC 21.875
# EPOCH 4 | ITER 25 | AVG_LOSS 2.261075973510742 | Train_ACC 12.5
# EPOCH 4 | ITER 30 | AVG_LOSS 2.263092279434204 | Train_ACC 25.0
# EPOCH 4 | ITER 35 | AVG_LOSS 2.2572457790374756 | Train_ACC 21.875
# EPOCH 4 | ITER 40 | AVG_LOSS 2.25677752494812 | Train_ACC 37.5
# EPOCH 4 | ITER 45 | AVG_LOSS 2.257112741470337 | Train_ACC 15.625
# EPOCH 4 | ITER 50 | AVG_LOSS 2.2512083053588867 | Train_ACC 15.625
# EPOCH 4 | ITER 55 | AVG_LOSS 2.2478749752044678 | Train_ACC 31.25
# EPOCH 4 | ITER 60 | AVG_LOSS 2.2466585636138916 | Train_ACC 15.625
# EPOCH 4 | ITER 65 | AVG_LOSS 2.249629497528076 | Train_ACC 15.625
# EPOCH 4 | ITER 70 | AVG_LOSS 2.2515809535980225 | Train_ACC 18.75
# EPOCH 4 | ITER 75 | AVG_LOSS 2.2560839653015137 | Train_ACC 9.375
# EPOCH 4 | ITER 80 | AVG_LOSS 2.2543797492980957 | Train_ACC 21.875
# EPOCH 4 | ITER 85 | AVG_LOSS 2.2515616416931152 | Train_ACC 28.125
# EPOCH 4 | ITER 90 | AVG_LOSS 2.2572076320648193 | Train_ACC 25.0
# EPOCH 4 | ITER 95 | AVG_LOSS 2.26470685005188 | Train_ACC 15.625
# EPOCH 4 | ITER 100 | AVG_LOSS 2.265679359436035 | Train_ACC 12.5
# EPOCH 4 | ITER 105 | AVG_LOSS 2.266162157058716 | Train_ACC 18.75
# EPOCH 4 | ITER 110 | AVG_LOSS 2.266570568084717 | Train_ACC 12.5
# EPOCH 4 | ITER 115 | AVG_LOSS 2.2659852504730225 | Train_ACC 15.625
# EPOCH 4 | ITER 120 | AVG_LOSS 2.2651214599609375 | Train_ACC 25.0
# EPOCH 4 | ITER 125 | AVG_LOSS 2.262308120727539 | Train_ACC 25.0
# EPOCH 4 | ITER 130 | AVG_LOSS 2.256248950958252 | Train_ACC 43.75
# EPOCH 4 | ITER 135 | AVG_LOSS 2.2582688331604004 | Train_ACC 9.375
# EPOCH 4 | ITER 140 | AVG_LOSS 2.258693218231201 | Train_ACC 18.75
# EPOCH 4 | ITER 145 | AVG_LOSS 2.257521152496338 | Train_ACC 21.875
# EPOCH 4 | ITER 150 | AVG_LOSS 2.2593796253204346 | Train_ACC 25.0
# EPOCH 4 | ITER 155 | AVG_LOSS 2.262328624725342 | Train_ACC 12.5
# EPOCH 4 | ITER 160 | AVG_LOSS 2.2627763748168945 | Train_ACC 15.625
# EPOCH 4 | ITER 165 | AVG_LOSS 2.2620890140533447 | Train_ACC 25.0
# EPOCH 4 | ITER 170 | AVG_LOSS 2.263378381729126 | Train_ACC 18.75
# EPOCH 4 | ITER 175 | AVG_LOSS 2.2629573345184326 | Train_ACC 28.125
# EPOCH 4 | ITER 180 | AVG_LOSS 2.2641398906707764 | Train_ACC 31.25
# EPOCH 4 | ITER 185 | AVG_LOSS 2.264366865158081 | Train_ACC 18.75
# EPOCH 4 | ITER 190 | AVG_LOSS 2.2652344703674316 | Train_ACC 18.75
# EPOCH 4 | ITER 195 | AVG_LOSS 2.26450777053833 | Train_ACC 15.625
# EPOCH 4 | ITER 200 | AVG_LOSS 2.2643277645111084 | Train_ACC 21.875
# EPOCH 4 | ITER 205 | AVG_LOSS 2.2635560035705566 | Train_ACC 18.75
# EPOCH 4 | ITER 210 | AVG_LOSS 2.2615418434143066 | Train_ACC 12.5
# EPOCH 4 | ITER 215 | AVG_LOSS 2.2616188526153564 | Train_ACC 18.75
# EPOCH 4 | ITER 220 | AVG_LOSS 2.2625906467437744 | Train_ACC 31.25
# EPOCH 4 | ITER 225 | AVG_LOSS 2.262028932571411 | Train_ACC 12.5
# EPOCH 4 | ITER 230 | AVG_LOSS 2.2628276348114014 | Train_ACC 25.0
# EPOCH 4 | ITER 235 | AVG_LOSS 2.262251377105713 | Train_ACC 15.625
# EPOCH 4 | ITER 240 | AVG_LOSS 2.2635650634765625 | Train_ACC 9.375
# EPOCH 4 | ITER 245 | AVG_LOSS 2.2625298500061035 | Train_ACC 34.375
# EPOCH 4 | ITER 250 | AVG_LOSS 2.2606985569000244 | Train_ACC 12.5
# EPOCH 4 | ITER 255 | AVG_LOSS 2.2588164806365967 | Train_ACC 15.625
# EPOCH 4 | ITER 260 | AVG_LOSS 2.258164405822754 | Train_ACC 18.75
# EPOCH 4 | ITER 265 | AVG_LOSS 2.258131742477417 | Train_ACC 15.625
# EPOCH 4 | ITER 270 | AVG_LOSS 2.2584214210510254 | Train_ACC 21.875
# EPOCH 4 | ITER 275 | AVG_LOSS 2.2593696117401123 | Train_ACC 15.625
# EPOCH 4 | ITER 280 | AVG_LOSS 2.258862257003784 | Train_ACC 12.5
# EPOCH 4 | ITER 285 | AVG_LOSS 2.258366584777832 | Train_ACC 15.625
# EPOCH 4 | ITER 290 | AVG_LOSS 2.257017135620117 | Train_ACC 37.5
# EPOCH 4 | ITER 295 | AVG_LOSS 2.2558865547180176 | Train_ACC 21.875
# EPOCH 4 | ITER 300 | AVG_LOSS 2.256732940673828 | Train_ACC 18.75
# EPOCH 4 | ITER 305 | AVG_LOSS 2.2560505867004395 | Train_ACC 18.75
# EPOCH 4 | ITER 310 | AVG_LOSS 2.2563023567199707 | Train_ACC 15.625
# EPOCH 4 | ITER 315 | AVG_LOSS 2.2566096782684326 | Train_ACC 12.5
# EPOCH 4 | ITER 320 | AVG_LOSS 2.256502628326416 | Train_ACC 12.5
# EPOCH 4 | ITER 325 | AVG_LOSS 2.257171630859375 | Train_ACC 21.875
# EPOCH 4 | ITER 330 | AVG_LOSS 2.2568302154541016 | Train_ACC 21.875
# EPOCH 4 | ITER 335 | AVG_LOSS 2.2563772201538086 | Train_ACC 12.5
# EPOCH 4 | ITER 340 | AVG_LOSS 2.25484561920166 | Train_ACC 18.75
# EPOCH 4 | ITER 345 | AVG_LOSS 2.2544941902160645 | Train_ACC 15.625
# EPOCH 4 | ITER 350 | AVG_LOSS 2.2528939247131348 | Train_ACC 18.75
# EPOCH 4 | ITER 355 | AVG_LOSS 2.2527432441711426 | Train_ACC 18.75
# EPOCH 4 | ITER 360 | AVG_LOSS 2.252393960952759 | Train_ACC 31.25
# EPOCH 4 | ITER 365 | AVG_LOSS 2.2514076232910156 | Train_ACC 25.0
# EPOCH 4 | ITER 370 | AVG_LOSS 2.250149965286255 | Train_ACC 31.25
# Val Accuracy: 23.99%
#
# --------------------------------------------------
# EPOCH 4 | LOSS 2.032276153564453 | TIME 169.05544996261597
# --------------------------------------------------
#
# EPOCH 5 | ITER 0 | AVG_LOSS 2.2934508323669434 | Train_ACC 12.5
# EPOCH 5 | ITER 5 | AVG_LOSS 2.3003203868865967 | Train_ACC 18.75
# EPOCH 5 | ITER 10 | AVG_LOSS 2.2554821968078613 | Train_ACC 25.0
# EPOCH 5 | ITER 15 | AVG_LOSS 2.2590749263763428 | Train_ACC 28.125
# EPOCH 5 | ITER 20 | AVG_LOSS 2.2582883834838867 | Train_ACC 18.75
# EPOCH 5 | ITER 25 | AVG_LOSS 2.277745246887207 | Train_ACC 6.25
# EPOCH 5 | ITER 30 | AVG_LOSS 2.2677035331726074 | Train_ACC 12.5
# EPOCH 5 | ITER 35 | AVG_LOSS 2.266780138015747 | Train_ACC 21.875
# EPOCH 5 | ITER 40 | AVG_LOSS 2.268893003463745 | Train_ACC 21.875
# EPOCH 5 | ITER 45 | AVG_LOSS 2.263618230819702 | Train_ACC 21.875
# EPOCH 5 | ITER 50 | AVG_LOSS 2.256040096282959 | Train_ACC 21.875
# EPOCH 5 | ITER 55 | AVG_LOSS 2.2570722103118896 | Train_ACC 34.375
# EPOCH 5 | ITER 60 | AVG_LOSS 2.2545883655548096 | Train_ACC 25.0
# EPOCH 5 | ITER 65 | AVG_LOSS 2.2608883380889893 | Train_ACC 15.625
# EPOCH 5 | ITER 70 | AVG_LOSS 2.257591962814331 | Train_ACC 21.875
# EPOCH 5 | ITER 75 | AVG_LOSS 2.252976655960083 | Train_ACC 28.125
# EPOCH 5 | ITER 80 | AVG_LOSS 2.2574989795684814 | Train_ACC 28.125
# EPOCH 5 | ITER 85 | AVG_LOSS 2.259267807006836 | Train_ACC 9.375
# EPOCH 5 | ITER 90 | AVG_LOSS 2.256190061569214 | Train_ACC 25.0
# EPOCH 5 | ITER 95 | AVG_LOSS 2.250035047531128 | Train_ACC 25.0
# EPOCH 5 | ITER 100 | AVG_LOSS 2.2495996952056885 | Train_ACC 25.0
# EPOCH 5 | ITER 105 | AVG_LOSS 2.248210906982422 | Train_ACC 6.25
# EPOCH 5 | ITER 110 | AVG_LOSS 2.249643564224243 | Train_ACC 12.5
# EPOCH 5 | ITER 115 | AVG_LOSS 2.2483980655670166 | Train_ACC 25.0
# EPOCH 5 | ITER 120 | AVG_LOSS 2.2457287311553955 | Train_ACC 28.125
# EPOCH 5 | ITER 125 | AVG_LOSS 2.2427074909210205 | Train_ACC 15.625
# EPOCH 5 | ITER 130 | AVG_LOSS 2.2443766593933105 | Train_ACC 15.625
# EPOCH 5 | ITER 135 | AVG_LOSS 2.2443125247955322 | Train_ACC 28.125
# EPOCH 5 | ITER 140 | AVG_LOSS 2.2441651821136475 | Train_ACC 21.875
# EPOCH 5 | ITER 145 | AVG_LOSS 2.2408876419067383 | Train_ACC 12.5
# EPOCH 5 | ITER 150 | AVG_LOSS 2.2388551235198975 | Train_ACC 21.875
# EPOCH 5 | ITER 155 | AVG_LOSS 2.238966464996338 | Train_ACC 25.0
# EPOCH 5 | ITER 160 | AVG_LOSS 2.2420754432678223 | Train_ACC 18.75
# EPOCH 5 | ITER 165 | AVG_LOSS 2.2411067485809326 | Train_ACC 18.75
# EPOCH 5 | ITER 170 | AVG_LOSS 2.2391014099121094 | Train_ACC 12.5
# EPOCH 5 | ITER 175 | AVG_LOSS 2.237112522125244 | Train_ACC 25.0
# EPOCH 5 | ITER 180 | AVG_LOSS 2.2369208335876465 | Train_ACC 18.75
# EPOCH 5 | ITER 185 | AVG_LOSS 2.2367303371429443 | Train_ACC 15.625
# EPOCH 5 | ITER 190 | AVG_LOSS 2.237046241760254 | Train_ACC 37.5
# EPOCH 5 | ITER 195 | AVG_LOSS 2.2365221977233887 | Train_ACC 25.0
# EPOCH 5 | ITER 200 | AVG_LOSS 2.2387993335723877 | Train_ACC 18.75
# EPOCH 5 | ITER 205 | AVG_LOSS 2.2383875846862793 | Train_ACC 18.75
# EPOCH 5 | ITER 210 | AVG_LOSS 2.2371647357940674 | Train_ACC 50.0
# EPOCH 5 | ITER 215 | AVG_LOSS 2.237537145614624 | Train_ACC 18.75
# EPOCH 5 | ITER 220 | AVG_LOSS 2.2370471954345703 | Train_ACC 25.0
# EPOCH 5 | ITER 225 | AVG_LOSS 2.2376620769500732 | Train_ACC 25.0
# EPOCH 5 | ITER 230 | AVG_LOSS 2.2366058826446533 | Train_ACC 25.0
# EPOCH 5 | ITER 235 | AVG_LOSS 2.2378530502319336 | Train_ACC 21.875
# EPOCH 5 | ITER 240 | AVG_LOSS 2.2359516620635986 | Train_ACC 15.625
# EPOCH 5 | ITER 245 | AVG_LOSS 2.235398054122925 | Train_ACC 31.25
# EPOCH 5 | ITER 250 | AVG_LOSS 2.233672857284546 | Train_ACC 15.625
# EPOCH 5 | ITER 255 | AVG_LOSS 2.2351977825164795 | Train_ACC 18.75
# EPOCH 5 | ITER 260 | AVG_LOSS 2.2335433959960938 | Train_ACC 25.0
# EPOCH 5 | ITER 265 | AVG_LOSS 2.2346699237823486 | Train_ACC 25.0
# EPOCH 5 | ITER 270 | AVG_LOSS 2.235657215118408 | Train_ACC 31.25
# EPOCH 5 | ITER 275 | AVG_LOSS 2.235623598098755 | Train_ACC 18.75
# EPOCH 5 | ITER 280 | AVG_LOSS 2.2345046997070312 | Train_ACC 18.75
# EPOCH 5 | ITER 285 | AVG_LOSS 2.2338364124298096 | Train_ACC 43.75
# EPOCH 5 | ITER 290 | AVG_LOSS 2.2322378158569336 | Train_ACC 12.5
# EPOCH 5 | ITER 295 | AVG_LOSS 2.2322769165039062 | Train_ACC 28.125
# EPOCH 5 | ITER 300 | AVG_LOSS 2.2331430912017822 | Train_ACC 21.875
# EPOCH 5 | ITER 305 | AVG_LOSS 2.2338287830352783 | Train_ACC 21.875
# EPOCH 5 | ITER 310 | AVG_LOSS 2.2343087196350098 | Train_ACC 28.125
# EPOCH 5 | ITER 315 | AVG_LOSS 2.2345166206359863 | Train_ACC 12.5
# EPOCH 5 | ITER 320 | AVG_LOSS 2.235180616378784 | Train_ACC 12.5
# EPOCH 5 | ITER 325 | AVG_LOSS 2.2338621616363525 | Train_ACC 31.25
# EPOCH 5 | ITER 330 | AVG_LOSS 2.233454942703247 | Train_ACC 28.125
# EPOCH 5 | ITER 335 | AVG_LOSS 2.232358455657959 | Train_ACC 9.375
# EPOCH 5 | ITER 340 | AVG_LOSS 2.2325291633605957 | Train_ACC 21.875
# EPOCH 5 | ITER 345 | AVG_LOSS 2.232177257537842 | Train_ACC 21.875
# EPOCH 5 | ITER 350 | AVG_LOSS 2.2313284873962402 | Train_ACC 31.25
# EPOCH 5 | ITER 355 | AVG_LOSS 2.231525182723999 | Train_ACC 21.875
# EPOCH 5 | ITER 360 | AVG_LOSS 2.2306876182556152 | Train_ACC 21.875
# EPOCH 5 | ITER 365 | AVG_LOSS 2.2296009063720703 | Train_ACC 21.875
# EPOCH 5 | ITER 370 | AVG_LOSS 2.2298521995544434 | Train_ACC 15.625
# Val Accuracy: 22.72%
#
# --------------------------------------------------
# EPOCH 5 | LOSS 2.160579204559326 | TIME 170.04869961738586
# --------------------------------------------------
#
# EPOCH 6 | ITER 0 | AVG_LOSS 2.2825443744659424 | Train_ACC 25.0
# EPOCH 6 | ITER 5 | AVG_LOSS 2.1713614463806152 | Train_ACC 15.625
# EPOCH 6 | ITER 10 | AVG_LOSS 2.178270101547241 | Train_ACC 25.0
# EPOCH 6 | ITER 15 | AVG_LOSS 2.17264986038208 | Train_ACC 18.75
# EPOCH 6 | ITER 20 | AVG_LOSS 2.1699252128601074 | Train_ACC 34.375
# EPOCH 6 | ITER 25 | AVG_LOSS 2.1852753162384033 | Train_ACC 31.25
# EPOCH 6 | ITER 30 | AVG_LOSS 2.1932904720306396 | Train_ACC 28.125
# EPOCH 6 | ITER 35 | AVG_LOSS 2.1912953853607178 | Train_ACC 25.0
# EPOCH 6 | ITER 40 | AVG_LOSS 2.2057390213012695 | Train_ACC 18.75
# EPOCH 6 | ITER 45 | AVG_LOSS 2.2088687419891357 | Train_ACC 18.75
# EPOCH 6 | ITER 50 | AVG_LOSS 2.2002174854278564 | Train_ACC 31.25
# EPOCH 6 | ITER 55 | AVG_LOSS 2.2011802196502686 | Train_ACC 25.0
# EPOCH 6 | ITER 60 | AVG_LOSS 2.2028024196624756 | Train_ACC 31.25
# EPOCH 6 | ITER 65 | AVG_LOSS 2.1984024047851562 | Train_ACC 34.375
# EPOCH 6 | ITER 70 | AVG_LOSS 2.200610399246216 | Train_ACC 9.375
# EPOCH 6 | ITER 75 | AVG_LOSS 2.2048754692077637 | Train_ACC 25.0
# EPOCH 6 | ITER 80 | AVG_LOSS 2.2033402919769287 | Train_ACC 28.125
# EPOCH 6 | ITER 85 | AVG_LOSS 2.1997272968292236 | Train_ACC 15.625
# EPOCH 6 | ITER 90 | AVG_LOSS 2.2039523124694824 | Train_ACC 21.875
# EPOCH 6 | ITER 95 | AVG_LOSS 2.200377941131592 | Train_ACC 25.0
# EPOCH 6 | ITER 100 | AVG_LOSS 2.204267978668213 | Train_ACC 12.5
# EPOCH 6 | ITER 105 | AVG_LOSS 2.206620931625366 | Train_ACC 34.375
# EPOCH 6 | ITER 110 | AVG_LOSS 2.2020835876464844 | Train_ACC 21.875
# EPOCH 6 | ITER 115 | AVG_LOSS 2.200744390487671 | Train_ACC 6.25
# EPOCH 6 | ITER 120 | AVG_LOSS 2.1942217350006104 | Train_ACC 34.375
# EPOCH 6 | ITER 125 | AVG_LOSS 2.1904380321502686 | Train_ACC 21.875
# EPOCH 6 | ITER 130 | AVG_LOSS 2.1961045265197754 | Train_ACC 15.625
# EPOCH 6 | ITER 135 | AVG_LOSS 2.1962709426879883 | Train_ACC 25.0
# EPOCH 6 | ITER 140 | AVG_LOSS 2.1965150833129883 | Train_ACC 18.75
# EPOCH 6 | ITER 145 | AVG_LOSS 2.1988439559936523 | Train_ACC 21.875
# EPOCH 6 | ITER 150 | AVG_LOSS 2.1991429328918457 | Train_ACC 21.875
# EPOCH 6 | ITER 155 | AVG_LOSS 2.1970908641815186 | Train_ACC 31.25
# EPOCH 6 | ITER 160 | AVG_LOSS 2.196007013320923 | Train_ACC 18.75
# EPOCH 6 | ITER 165 | AVG_LOSS 2.1963093280792236 | Train_ACC 15.625
# EPOCH 6 | ITER 170 | AVG_LOSS 2.1966803073883057 | Train_ACC 25.0
# EPOCH 6 | ITER 175 | AVG_LOSS 2.2003884315490723 | Train_ACC 37.5
# EPOCH 6 | ITER 180 | AVG_LOSS 2.2013790607452393 | Train_ACC 18.75
# EPOCH 6 | ITER 185 | AVG_LOSS 2.202972412109375 | Train_ACC 34.375
# EPOCH 6 | ITER 190 | AVG_LOSS 2.20184063911438 | Train_ACC 37.5
# EPOCH 6 | ITER 195 | AVG_LOSS 2.202021598815918 | Train_ACC 12.5
# EPOCH 6 | ITER 200 | AVG_LOSS 2.2000653743743896 | Train_ACC 28.125
# EPOCH 6 | ITER 205 | AVG_LOSS 2.1993825435638428 | Train_ACC 31.25
# EPOCH 6 | ITER 210 | AVG_LOSS 2.2016689777374268 | Train_ACC 28.125
# EPOCH 6 | ITER 215 | AVG_LOSS 2.201460361480713 | Train_ACC 25.0
# EPOCH 6 | ITER 220 | AVG_LOSS 2.20147705078125 | Train_ACC 21.875
# EPOCH 6 | ITER 225 | AVG_LOSS 2.202165365219116 | Train_ACC 15.625
# EPOCH 6 | ITER 230 | AVG_LOSS 2.200948715209961 | Train_ACC 25.0
# EPOCH 6 | ITER 235 | AVG_LOSS 2.1995348930358887 | Train_ACC 12.5
# EPOCH 6 | ITER 240 | AVG_LOSS 2.199929714202881 | Train_ACC 25.0
# EPOCH 6 | ITER 245 | AVG_LOSS 2.199110269546509 | Train_ACC 28.125
# EPOCH 6 | ITER 250 | AVG_LOSS 2.198826551437378 | Train_ACC 28.125
# EPOCH 6 | ITER 255 | AVG_LOSS 2.198509454727173 | Train_ACC 21.875
# EPOCH 6 | ITER 260 | AVG_LOSS 2.198042154312134 | Train_ACC 21.875
# EPOCH 6 | ITER 265 | AVG_LOSS 2.197655439376831 | Train_ACC 12.5
# EPOCH 6 | ITER 270 | AVG_LOSS 2.1974923610687256 | Train_ACC 28.125
# EPOCH 6 | ITER 275 | AVG_LOSS 2.1968495845794678 | Train_ACC 18.75
# EPOCH 6 | ITER 280 | AVG_LOSS 2.1973373889923096 | Train_ACC 18.75
# EPOCH 6 | ITER 285 | AVG_LOSS 2.197948694229126 | Train_ACC 21.875
# EPOCH 6 | ITER 290 | AVG_LOSS 2.195969343185425 | Train_ACC 31.25
# EPOCH 6 | ITER 295 | AVG_LOSS 2.1966426372528076 | Train_ACC 12.5
# EPOCH 6 | ITER 300 | AVG_LOSS 2.1978342533111572 | Train_ACC 15.625
# EPOCH 6 | ITER 305 | AVG_LOSS 2.1986007690429688 | Train_ACC 21.875
# EPOCH 6 | ITER 310 | AVG_LOSS 2.197934627532959 | Train_ACC 28.125
# EPOCH 6 | ITER 315 | AVG_LOSS 2.198462724685669 | Train_ACC 21.875
# EPOCH 6 | ITER 320 | AVG_LOSS 2.1966609954833984 | Train_ACC 28.125
# EPOCH 6 | ITER 325 | AVG_LOSS 2.1971826553344727 | Train_ACC 21.875
# EPOCH 6 | ITER 330 | AVG_LOSS 2.1978251934051514 | Train_ACC 21.875
# EPOCH 6 | ITER 335 | AVG_LOSS 2.197535514831543 | Train_ACC 28.125
# EPOCH 6 | ITER 340 | AVG_LOSS 2.1983983516693115 | Train_ACC 34.375
# EPOCH 6 | ITER 345 | AVG_LOSS 2.196303606033325 | Train_ACC 31.25
# EPOCH 6 | ITER 350 | AVG_LOSS 2.1965057849884033 | Train_ACC 18.75
# EPOCH 6 | ITER 355 | AVG_LOSS 2.196270704269409 | Train_ACC 15.625
# EPOCH 6 | ITER 360 | AVG_LOSS 2.1971192359924316 | Train_ACC 15.625
# EPOCH 6 | ITER 365 | AVG_LOSS 2.1969799995422363 | Train_ACC 12.5
# EPOCH 6 | ITER 370 | AVG_LOSS 2.196232795715332 | Train_ACC 15.625
# Val Accuracy: 18.14%
#
# --------------------------------------------------
# EPOCH 6 | LOSS 2.1008565425872803 | TIME 167.84864401817322
# --------------------------------------------------
#
# EPOCH 7 | ITER 0 | AVG_LOSS 2.2586722373962402 | Train_ACC 25.0
# EPOCH 7 | ITER 5 | AVG_LOSS 2.227180004119873 | Train_ACC 15.625
# EPOCH 7 | ITER 10 | AVG_LOSS 2.255035400390625 | Train_ACC 12.5
# EPOCH 7 | ITER 15 | AVG_LOSS 2.2472493648529053 | Train_ACC 25.0
# EPOCH 7 | ITER 20 | AVG_LOSS 2.234837055206299 | Train_ACC 21.875
# EPOCH 7 | ITER 25 | AVG_LOSS 2.22772216796875 | Train_ACC 31.25
# EPOCH 7 | ITER 30 | AVG_LOSS 2.230454206466675 | Train_ACC 15.625
# EPOCH 7 | ITER 35 | AVG_LOSS 2.21321964263916 | Train_ACC 28.125
# EPOCH 7 | ITER 40 | AVG_LOSS 2.2090134620666504 | Train_ACC 18.75
# EPOCH 7 | ITER 45 | AVG_LOSS 2.1955819129943848 | Train_ACC 31.25
# EPOCH 7 | ITER 50 | AVG_LOSS 2.196772813796997 | Train_ACC 25.0
# EPOCH 7 | ITER 55 | AVG_LOSS 2.1884536743164062 | Train_ACC 40.625
# EPOCH 7 | ITER 60 | AVG_LOSS 2.1864280700683594 | Train_ACC 21.875
# EPOCH 7 | ITER 65 | AVG_LOSS 2.1801693439483643 | Train_ACC 43.75
# EPOCH 7 | ITER 70 | AVG_LOSS 2.1843652725219727 | Train_ACC 18.75
# EPOCH 7 | ITER 75 | AVG_LOSS 2.187833070755005 | Train_ACC 6.25
# EPOCH 7 | ITER 80 | AVG_LOSS 2.188009262084961 | Train_ACC 12.5
# EPOCH 7 | ITER 85 | AVG_LOSS 2.1842267513275146 | Train_ACC 34.375
# EPOCH 7 | ITER 90 | AVG_LOSS 2.1852664947509766 | Train_ACC 15.625
# EPOCH 7 | ITER 95 | AVG_LOSS 2.1873576641082764 | Train_ACC 18.75
# EPOCH 7 | ITER 100 | AVG_LOSS 2.1798717975616455 | Train_ACC 18.75
# EPOCH 7 | ITER 105 | AVG_LOSS 2.181675672531128 | Train_ACC 21.875
# EPOCH 7 | ITER 110 | AVG_LOSS 2.182460069656372 | Train_ACC 25.0
# EPOCH 7 | ITER 115 | AVG_LOSS 2.1808626651763916 | Train_ACC 31.25
# EPOCH 7 | ITER 120 | AVG_LOSS 2.176638126373291 | Train_ACC 37.5
# EPOCH 7 | ITER 125 | AVG_LOSS 2.175997018814087 | Train_ACC 21.875
# EPOCH 7 | ITER 130 | AVG_LOSS 2.1756742000579834 | Train_ACC 18.75
# EPOCH 7 | ITER 135 | AVG_LOSS 2.173705577850342 | Train_ACC 21.875
# EPOCH 7 | ITER 140 | AVG_LOSS 2.173017740249634 | Train_ACC 18.75
# EPOCH 7 | ITER 145 | AVG_LOSS 2.177022933959961 | Train_ACC 25.0
# EPOCH 7 | ITER 150 | AVG_LOSS 2.1793909072875977 | Train_ACC 18.75
# EPOCH 7 | ITER 155 | AVG_LOSS 2.1816117763519287 | Train_ACC 28.125
# EPOCH 7 | ITER 160 | AVG_LOSS 2.1802825927734375 | Train_ACC 25.0
# EPOCH 7 | ITER 165 | AVG_LOSS 2.179828405380249 | Train_ACC 12.5
# EPOCH 7 | ITER 170 | AVG_LOSS 2.180382013320923 | Train_ACC 43.75
# EPOCH 7 | ITER 175 | AVG_LOSS 2.1800599098205566 | Train_ACC 28.125
# EPOCH 7 | ITER 180 | AVG_LOSS 2.180176258087158 | Train_ACC 25.0
# EPOCH 7 | ITER 185 | AVG_LOSS 2.18125319480896 | Train_ACC 25.0
# EPOCH 7 | ITER 190 | AVG_LOSS 2.179753065109253 | Train_ACC 34.375
# EPOCH 7 | ITER 195 | AVG_LOSS 2.173815965652466 | Train_ACC 34.375
# EPOCH 7 | ITER 200 | AVG_LOSS 2.1768014430999756 | Train_ACC 21.875
# EPOCH 7 | ITER 205 | AVG_LOSS 2.17622709274292 | Train_ACC 15.625
# EPOCH 7 | ITER 210 | AVG_LOSS 2.176037549972534 | Train_ACC 18.75
# EPOCH 7 | ITER 215 | AVG_LOSS 2.1730618476867676 | Train_ACC 28.125
# EPOCH 7 | ITER 220 | AVG_LOSS 2.1735117435455322 | Train_ACC 25.0
# EPOCH 7 | ITER 225 | AVG_LOSS 2.1748528480529785 | Train_ACC 12.5
# EPOCH 7 | ITER 230 | AVG_LOSS 2.1730329990386963 | Train_ACC 37.5
# EPOCH 7 | ITER 235 | AVG_LOSS 2.175225257873535 | Train_ACC 18.75
# EPOCH 7 | ITER 240 | AVG_LOSS 2.1758289337158203 | Train_ACC 21.875
# EPOCH 7 | ITER 245 | AVG_LOSS 2.1755518913269043 | Train_ACC 37.5
# EPOCH 7 | ITER 250 | AVG_LOSS 2.175551652908325 | Train_ACC 31.25
# EPOCH 7 | ITER 255 | AVG_LOSS 2.179124593734741 | Train_ACC 25.0
# EPOCH 7 | ITER 260 | AVG_LOSS 2.178864002227783 | Train_ACC 31.25
# EPOCH 7 | ITER 265 | AVG_LOSS 2.178313732147217 | Train_ACC 31.25
# EPOCH 7 | ITER 270 | AVG_LOSS 2.17834210395813 | Train_ACC 28.125
# EPOCH 7 | ITER 275 | AVG_LOSS 2.1772258281707764 | Train_ACC 15.625
# EPOCH 7 | ITER 280 | AVG_LOSS 2.174992799758911 | Train_ACC 18.75
# EPOCH 7 | ITER 285 | AVG_LOSS 2.174448251724243 | Train_ACC 18.75
# EPOCH 7 | ITER 290 | AVG_LOSS 2.1724140644073486 | Train_ACC 18.75
# EPOCH 7 | ITER 295 | AVG_LOSS 2.1720798015594482 | Train_ACC 9.375
# EPOCH 7 | ITER 300 | AVG_LOSS 2.171391010284424 | Train_ACC 31.25
# EPOCH 7 | ITER 305 | AVG_LOSS 2.1702840328216553 | Train_ACC 21.875
# EPOCH 7 | ITER 310 | AVG_LOSS 2.1715855598449707 | Train_ACC 12.5
# EPOCH 7 | ITER 315 | AVG_LOSS 2.1711299419403076 | Train_ACC 3.125
# EPOCH 7 | ITER 320 | AVG_LOSS 2.168949842453003 | Train_ACC 25.0
# EPOCH 7 | ITER 325 | AVG_LOSS 2.1694910526275635 | Train_ACC 18.75
# EPOCH 7 | ITER 330 | AVG_LOSS 2.169706106185913 | Train_ACC 15.625
# EPOCH 7 | ITER 335 | AVG_LOSS 2.16827654838562 | Train_ACC 43.75
# EPOCH 7 | ITER 340 | AVG_LOSS 2.1678578853607178 | Train_ACC 28.125
# EPOCH 7 | ITER 345 | AVG_LOSS 2.167656183242798 | Train_ACC 18.75
# EPOCH 7 | ITER 350 | AVG_LOSS 2.166163682937622 | Train_ACC 15.625
# EPOCH 7 | ITER 355 | AVG_LOSS 2.1667580604553223 | Train_ACC 21.875
# EPOCH 7 | ITER 360 | AVG_LOSS 2.1657838821411133 | Train_ACC 25.0
# EPOCH 7 | ITER 365 | AVG_LOSS 2.1648504734039307 | Train_ACC 21.875
# EPOCH 7 | ITER 370 | AVG_LOSS 2.1642513275146484 | Train_ACC 28.125
# Val Accuracy: 27.11%
#
# --------------------------------------------------
# EPOCH 7 | LOSS 2.3538215160369873 | TIME 166.86173343658447
# --------------------------------------------------
#
# EPOCH 8 | ITER 0 | AVG_LOSS 1.827156662940979 | Train_ACC 43.75
# EPOCH 8 | ITER 5 | AVG_LOSS 2.0781214237213135 | Train_ACC 21.875
# EPOCH 8 | ITER 10 | AVG_LOSS 2.1304149627685547 | Train_ACC 25.0
# EPOCH 8 | ITER 15 | AVG_LOSS 2.147026777267456 | Train_ACC 31.25
# EPOCH 8 | ITER 20 | AVG_LOSS 2.145772695541382 | Train_ACC 21.875
# EPOCH 8 | ITER 25 | AVG_LOSS 2.141664505004883 | Train_ACC 25.0
# EPOCH 8 | ITER 30 | AVG_LOSS 2.1435422897338867 | Train_ACC 25.0
# EPOCH 8 | ITER 35 | AVG_LOSS 2.14862322807312 | Train_ACC 9.375
# EPOCH 8 | ITER 40 | AVG_LOSS 2.14997935295105 | Train_ACC 15.625
# EPOCH 8 | ITER 45 | AVG_LOSS 2.154219150543213 | Train_ACC 25.0
# EPOCH 8 | ITER 50 | AVG_LOSS 2.149580240249634 | Train_ACC 28.125
# EPOCH 8 | ITER 55 | AVG_LOSS 2.1518144607543945 | Train_ACC 18.75
# EPOCH 8 | ITER 60 | AVG_LOSS 2.149010181427002 | Train_ACC 12.5
# EPOCH 8 | ITER 65 | AVG_LOSS 2.152749538421631 | Train_ACC 25.0
# EPOCH 8 | ITER 70 | AVG_LOSS 2.148616313934326 | Train_ACC 31.25
# EPOCH 8 | ITER 75 | AVG_LOSS 2.1479220390319824 | Train_ACC 34.375
# EPOCH 8 | ITER 80 | AVG_LOSS 2.145123243331909 | Train_ACC 28.125
# EPOCH 8 | ITER 85 | AVG_LOSS 2.145139455795288 | Train_ACC 28.125
# EPOCH 8 | ITER 90 | AVG_LOSS 2.144637107849121 | Train_ACC 15.625
# EPOCH 8 | ITER 95 | AVG_LOSS 2.1479368209838867 | Train_ACC 18.75
# EPOCH 8 | ITER 100 | AVG_LOSS 2.1490368843078613 | Train_ACC 12.5
# EPOCH 8 | ITER 105 | AVG_LOSS 2.1471526622772217 | Train_ACC 34.375
# EPOCH 8 | ITER 110 | AVG_LOSS 2.1447925567626953 | Train_ACC 21.875
# EPOCH 8 | ITER 115 | AVG_LOSS 2.1410133838653564 | Train_ACC 34.375
# EPOCH 8 | ITER 120 | AVG_LOSS 2.141181230545044 | Train_ACC 15.625
# EPOCH 8 | ITER 125 | AVG_LOSS 2.1362385749816895 | Train_ACC 34.375
# EPOCH 8 | ITER 130 | AVG_LOSS 2.131939649581909 | Train_ACC 34.375
# EPOCH 8 | ITER 135 | AVG_LOSS 2.133876323699951 | Train_ACC 25.0
# EPOCH 8 | ITER 140 | AVG_LOSS 2.1327431201934814 | Train_ACC 25.0
# EPOCH 8 | ITER 145 | AVG_LOSS 2.1300456523895264 | Train_ACC 18.75
# EPOCH 8 | ITER 150 | AVG_LOSS 2.1288955211639404 | Train_ACC 31.25
# EPOCH 8 | ITER 155 | AVG_LOSS 2.1322007179260254 | Train_ACC 18.75
# EPOCH 8 | ITER 160 | AVG_LOSS 2.1317355632781982 | Train_ACC 37.5
# EPOCH 8 | ITER 165 | AVG_LOSS 2.1306753158569336 | Train_ACC 21.875
# EPOCH 8 | ITER 170 | AVG_LOSS 2.1296465396881104 | Train_ACC 25.0
# EPOCH 8 | ITER 175 | AVG_LOSS 2.1321442127227783 | Train_ACC 28.125
# EPOCH 8 | ITER 180 | AVG_LOSS 2.1299638748168945 | Train_ACC 46.875
# EPOCH 8 | ITER 185 | AVG_LOSS 2.1287755966186523 | Train_ACC 18.75
# EPOCH 8 | ITER 190 | AVG_LOSS 2.128960371017456 | Train_ACC 15.625
# EPOCH 8 | ITER 195 | AVG_LOSS 2.127915859222412 | Train_ACC 25.0
# EPOCH 8 | ITER 200 | AVG_LOSS 2.1285669803619385 | Train_ACC 25.0
# EPOCH 8 | ITER 205 | AVG_LOSS 2.1292638778686523 | Train_ACC 15.625
# EPOCH 8 | ITER 210 | AVG_LOSS 2.130733013153076 | Train_ACC 18.75
# EPOCH 8 | ITER 215 | AVG_LOSS 2.130156993865967 | Train_ACC 43.75
# EPOCH 8 | ITER 220 | AVG_LOSS 2.1305627822875977 | Train_ACC 21.875
# EPOCH 8 | ITER 225 | AVG_LOSS 2.134042978286743 | Train_ACC 12.5
# EPOCH 8 | ITER 230 | AVG_LOSS 2.133484125137329 | Train_ACC 25.0
# EPOCH 8 | ITER 235 | AVG_LOSS 2.1347978115081787 | Train_ACC 21.875
# EPOCH 8 | ITER 240 | AVG_LOSS 2.1338160037994385 | Train_ACC 28.125
# EPOCH 8 | ITER 245 | AVG_LOSS 2.1299219131469727 | Train_ACC 28.125
# EPOCH 8 | ITER 250 | AVG_LOSS 2.128746509552002 | Train_ACC 15.625
# EPOCH 8 | ITER 255 | AVG_LOSS 2.12783145904541 | Train_ACC 37.5
# EPOCH 8 | ITER 260 | AVG_LOSS 2.1290194988250732 | Train_ACC 12.5
# EPOCH 8 | ITER 265 | AVG_LOSS 2.1278574466705322 | Train_ACC 21.875
# EPOCH 8 | ITER 270 | AVG_LOSS 2.1257755756378174 | Train_ACC 37.5
# EPOCH 8 | ITER 275 | AVG_LOSS 2.1269891262054443 | Train_ACC 15.625
# EPOCH 8 | ITER 280 | AVG_LOSS 2.127166509628296 | Train_ACC 31.25
# EPOCH 8 | ITER 285 | AVG_LOSS 2.1258013248443604 | Train_ACC 15.625
# EPOCH 8 | ITER 290 | AVG_LOSS 2.1260182857513428 | Train_ACC 21.875
# EPOCH 8 | ITER 295 | AVG_LOSS 2.12664794921875 | Train_ACC 21.875
# EPOCH 8 | ITER 300 | AVG_LOSS 2.127894878387451 | Train_ACC 25.0
# EPOCH 8 | ITER 305 | AVG_LOSS 2.127885341644287 | Train_ACC 37.5
# EPOCH 8 | ITER 310 | AVG_LOSS 2.127300977706909 | Train_ACC 25.0
# EPOCH 8 | ITER 315 | AVG_LOSS 2.1268537044525146 | Train_ACC 43.75
# EPOCH 8 | ITER 320 | AVG_LOSS 2.1273303031921387 | Train_ACC 25.0
# EPOCH 8 | ITER 325 | AVG_LOSS 2.1264278888702393 | Train_ACC 34.375
# EPOCH 8 | ITER 330 | AVG_LOSS 2.124457597732544 | Train_ACC 31.25
# EPOCH 8 | ITER 335 | AVG_LOSS 2.1248135566711426 | Train_ACC 25.0
# EPOCH 8 | ITER 340 | AVG_LOSS 2.123492479324341 | Train_ACC 21.875
# EPOCH 8 | ITER 345 | AVG_LOSS 2.126312494277954 | Train_ACC 15.625
# EPOCH 8 | ITER 350 | AVG_LOSS 2.126986265182495 | Train_ACC 37.5
# EPOCH 8 | ITER 355 | AVG_LOSS 2.1275386810302734 | Train_ACC 21.875
# EPOCH 8 | ITER 360 | AVG_LOSS 2.1274001598358154 | Train_ACC 21.875
# EPOCH 8 | ITER 365 | AVG_LOSS 2.1270251274108887 | Train_ACC 21.875
# EPOCH 8 | ITER 370 | AVG_LOSS 2.1259267330169678 | Train_ACC 25.0
# Val Accuracy: 25.38%
#
# --------------------------------------------------
# EPOCH 8 | LOSS 2.0839152336120605 | TIME 168.35195469856262
# --------------------------------------------------
#
# EPOCH 9 | ITER 0 | AVG_LOSS 2.1501641273498535 | Train_ACC 28.125
# EPOCH 9 | ITER 5 | AVG_LOSS 2.123547077178955 | Train_ACC 21.875
# EPOCH 9 | ITER 10 | AVG_LOSS 2.0952250957489014 | Train_ACC 34.375
# EPOCH 9 | ITER 15 | AVG_LOSS 2.1120171546936035 | Train_ACC 40.625
# EPOCH 9 | ITER 20 | AVG_LOSS 2.096651792526245 | Train_ACC 46.875
# EPOCH 9 | ITER 25 | AVG_LOSS 2.1044018268585205 | Train_ACC 15.625
# EPOCH 9 | ITER 30 | AVG_LOSS 2.1264140605926514 | Train_ACC 28.125
# EPOCH 9 | ITER 35 | AVG_LOSS 2.118037462234497 | Train_ACC 25.0
# EPOCH 9 | ITER 40 | AVG_LOSS 2.1323444843292236 | Train_ACC 15.625
# EPOCH 9 | ITER 45 | AVG_LOSS 2.1273179054260254 | Train_ACC 34.375
# EPOCH 9 | ITER 50 | AVG_LOSS 2.120913505554199 | Train_ACC 40.625
# EPOCH 9 | ITER 55 | AVG_LOSS 2.1145806312561035 | Train_ACC 18.75
# EPOCH 9 | ITER 60 | AVG_LOSS 2.121563673019409 | Train_ACC 18.75
# EPOCH 9 | ITER 65 | AVG_LOSS 2.109813690185547 | Train_ACC 28.125
# EPOCH 9 | ITER 70 | AVG_LOSS 2.1131227016448975 | Train_ACC 18.75
# EPOCH 9 | ITER 75 | AVG_LOSS 2.109678030014038 | Train_ACC 34.375
# EPOCH 9 | ITER 80 | AVG_LOSS 2.099220037460327 | Train_ACC 34.375
# EPOCH 9 | ITER 85 | AVG_LOSS 2.0949020385742188 | Train_ACC 34.375
# EPOCH 9 | ITER 90 | AVG_LOSS 2.096532106399536 | Train_ACC 28.125
# EPOCH 9 | ITER 95 | AVG_LOSS 2.0979180335998535 | Train_ACC 25.0
# EPOCH 9 | ITER 100 | AVG_LOSS 2.0980424880981445 | Train_ACC 31.25
# EPOCH 9 | ITER 105 | AVG_LOSS 2.0956664085388184 | Train_ACC 31.25
# EPOCH 9 | ITER 110 | AVG_LOSS 2.0920052528381348 | Train_ACC 25.0
# EPOCH 9 | ITER 115 | AVG_LOSS 2.094708204269409 | Train_ACC 21.875
# ...
# EPOCH 27 | ITER 15 | AVG_LOSS 1.5252748727798462 | Train_ACC 43.75
# EPOCH 27 | ITER 20 | AVG_LOSS 1.5608139038085938 | Train_ACC 43.75
# EPOCH 27 | ITER 25 | AVG_LOSS 1.5908645391464233 | Train_ACC 43.75
# EPOCH 27 | ITER 30 | AVG_LOSS 1.5583655834197998 | Train_ACC 59.375
# EPOCH 27 | ITER 35 | AVG_LOSS 1.5516767501831055 | Train_ACC 62.5
# EPOCH 27 | ITER 40 | AVG_LOSS 1.547279953956604 | Train_ACC 43.75
# EPOCH 27 | ITER 45 | AVG_LOSS 1.5312752723693848 | Train_ACC 50.0
# EPOCH 27 | ITER 50 | AVG_LOSS 1.5228056907653809 | Train_ACC 43.75
# EPOCH 27 | ITER 55 | AVG_LOSS 1.5268645286560059 | Train_ACC 37.5
# EPOCH 27 | ITER 60 | AVG_LOSS 1.5262984037399292 | Train_ACC 43.75
# EPOCH 27 | ITER 65 | AVG_LOSS 1.5348498821258545 | Train_ACC 46.875
# EPOCH 27 | ITER 70 | AVG_LOSS 1.5329700708389282 | Train_ACC 53.125
# EPOCH 27 | ITER 75 | AVG_LOSS 1.5207960605621338 | Train_ACC 65.625
# EPOCH 27 | ITER 80 | AVG_LOSS 1.528102993965149 | Train_ACC 46.875
# EPOCH 27 | ITER 85 | AVG_LOSS 1.520869255065918 | Train_ACC 56.25
# EPOCH 27 | ITER 90 | AVG_LOSS 1.5153557062149048 | Train_ACC 43.75
# EPOCH 27 | ITER 95 | AVG_LOSS 1.5091578960418701 | Train_ACC 53.125
# EPOCH 27 | ITER 100 | AVG_LOSS 1.5116130113601685 | Train_ACC 62.5
# EPOCH 27 | ITER 105 | AVG_LOSS 1.511500597000122 | Train_ACC 46.875
# EPOCH 27 | ITER 110 | AVG_LOSS 1.513041377067566 | Train_ACC 56.25
# EPOCH 27 | ITER 115 | AVG_LOSS 1.5094919204711914 | Train_ACC 59.375
# EPOCH 27 | ITER 120 | AVG_LOSS 1.5090619325637817 | Train_ACC 56.25
# EPOCH 27 | ITER 125 | AVG_LOSS 1.5087062120437622 | Train_ACC 46.875
# EPOCH 27 | ITER 130 | AVG_LOSS 1.5107780694961548 | Train_ACC 43.75
# EPOCH 27 | ITER 135 | AVG_LOSS 1.508512258529663 | Train_ACC 50.0
# EPOCH 27 | ITER 140 | AVG_LOSS 1.5054486989974976 | Train_ACC 37.5
# EPOCH 27 | ITER 145 | AVG_LOSS 1.502358078956604 | Train_ACC 50.0
# EPOCH 27 | ITER 150 | AVG_LOSS 1.4973033666610718 | Train_ACC 40.625
# EPOCH 27 | ITER 155 | AVG_LOSS 1.497910499572754 | Train_ACC 40.625
# EPOCH 27 | ITER 160 | AVG_LOSS 1.4993499517440796 | Train_ACC 46.875
# EPOCH 27 | ITER 165 | AVG_LOSS 1.499800682067871 | Train_ACC 53.125
# EPOCH 27 | ITER 170 | AVG_LOSS 1.5003783702850342 | Train_ACC 43.75
# EPOCH 27 | ITER 175 | AVG_LOSS 1.5025686025619507 | Train_ACC 56.25
# EPOCH 27 | ITER 180 | AVG_LOSS 1.50005042552948 | Train_ACC 59.375
# EPOCH 27 | ITER 185 | AVG_LOSS 1.499237060546875 | Train_ACC 53.125
# EPOCH 27 | ITER 190 | AVG_LOSS 1.498197078704834 | Train_ACC 59.375
# EPOCH 27 | ITER 195 | AVG_LOSS 1.4996010065078735 | Train_ACC 40.625
# EPOCH 27 | ITER 200 | AVG_LOSS 1.5002449750900269 | Train_ACC 43.75
# EPOCH 27 | ITER 205 | AVG_LOSS 1.4990695714950562 | Train_ACC 40.625
# EPOCH 27 | ITER 210 | AVG_LOSS 1.4962198734283447 | Train_ACC 68.75
# EPOCH 27 | ITER 215 | AVG_LOSS 1.4936869144439697 | Train_ACC 53.125
# EPOCH 27 | ITER 220 | AVG_LOSS 1.4910343885421753 | Train_ACC 71.875
# EPOCH 27 | ITER 225 | AVG_LOSS 1.4932050704956055 | Train_ACC 53.125
# EPOCH 27 | ITER 230 | AVG_LOSS 1.4890966415405273 | Train_ACC 59.375
# EPOCH 27 | ITER 235 | AVG_LOSS 1.490505337715149 | Train_ACC 43.75
# EPOCH 27 | ITER 240 | AVG_LOSS 1.4882049560546875 | Train_ACC 59.375
# EPOCH 27 | ITER 245 | AVG_LOSS 1.4843820333480835 | Train_ACC 59.375
# EPOCH 27 | ITER 250 | AVG_LOSS 1.481278419494629 | Train_ACC 56.25
# EPOCH 27 | ITER 255 | AVG_LOSS 1.4780601263046265 | Train_ACC 53.125
# EPOCH 27 | ITER 260 | AVG_LOSS 1.4803799390792847 | Train_ACC 46.875
# EPOCH 27 | ITER 265 | AVG_LOSS 1.4815689325332642 | Train_ACC 53.125
# EPOCH 27 | ITER 270 | AVG_LOSS 1.4825177192687988 | Train_ACC 43.75
# EPOCH 27 | ITER 275 | AVG_LOSS 1.483978509902954 | Train_ACC 50.0
# EPOCH 27 | ITER 280 | AVG_LOSS 1.4855351448059082 | Train_ACC 53.125
# EPOCH 27 | ITER 285 | AVG_LOSS 1.4836437702178955 | Train_ACC 50.0
# EPOCH 27 | ITER 290 | AVG_LOSS 1.4826074838638306 | Train_ACC 53.125
# EPOCH 27 | ITER 295 | AVG_LOSS 1.4818907976150513 | Train_ACC 46.875
# EPOCH 27 | ITER 300 | AVG_LOSS 1.4774377346038818 | Train_ACC 71.875
# EPOCH 27 | ITER 305 | AVG_LOSS 1.4795582294464111 | Train_ACC 53.125
# EPOCH 27 | ITER 310 | AVG_LOSS 1.4799185991287231 | Train_ACC 37.5
# EPOCH 27 | ITER 315 | AVG_LOSS 1.481036901473999 | Train_ACC 25.0
# EPOCH 27 | ITER 320 | AVG_LOSS 1.4789373874664307 | Train_ACC 62.5
# EPOCH 27 | ITER 325 | AVG_LOSS 1.4793466329574585 | Train_ACC 40.625
# EPOCH 27 | ITER 330 | AVG_LOSS 1.4809150695800781 | Train_ACC 43.75
# EPOCH 27 | ITER 335 | AVG_LOSS 1.4796150922775269 | Train_ACC 50.0
# EPOCH 27 | ITER 340 | AVG_LOSS 1.4792051315307617 | Train_ACC 43.75
# EPOCH 27 | ITER 345 | AVG_LOSS 1.4767347574234009 | Train_ACC 56.25
# EPOCH 27 | ITER 350 | AVG_LOSS 1.4792616367340088 | Train_ACC 40.625
# EPOCH 27 | ITER 355 | AVG_LOSS 1.4773242473602295 | Train_ACC 59.375
# EPOCH 27 | ITER 360 | AVG_LOSS 1.4789519309997559 | Train_ACC 34.375
# EPOCH 27 | ITER 365 | AVG_LOSS 1.479243516921997 | Train_ACC 56.25
# EPOCH 27 | ITER 370 | AVG_LOSS 1.4791170358657837 | Train_ACC 40.625
# Val Accuracy: 53.69%
#
# --------------------------------------------------
# EPOCH 27 | LOSS 1.5632272958755493 | TIME 158.7213637828827
# --------------------------------------------------
#
# EPOCH 28 | ITER 0 | AVG_LOSS 1.4565719366073608 | Train_ACC 53.125
# EPOCH 28 | ITER 5 | AVG_LOSS 1.32170569896698 | Train_ACC 53.125
# EPOCH 28 | ITER 10 | AVG_LOSS 1.4237178564071655 | Train_ACC 50.0
# EPOCH 28 | ITER 15 | AVG_LOSS 1.4185091257095337 | Train_ACC 59.375
# EPOCH 28 | ITER 20 | AVG_LOSS 1.40933096408844 | Train_ACC 40.625
# EPOCH 28 | ITER 25 | AVG_LOSS 1.3882648944854736 | Train_ACC 46.875
# EPOCH 28 | ITER 30 | AVG_LOSS 1.3877066373825073 | Train_ACC 62.5
# EPOCH 28 | ITER 35 | AVG_LOSS 1.3842260837554932 | Train_ACC 50.0
# EPOCH 28 | ITER 40 | AVG_LOSS 1.3908653259277344 | Train_ACC 59.375
# EPOCH 28 | ITER 45 | AVG_LOSS 1.3722645044326782 | Train_ACC 56.25
# EPOCH 28 | ITER 50 | AVG_LOSS 1.3712782859802246 | Train_ACC 43.75
# EPOCH 28 | ITER 55 | AVG_LOSS 1.3897461891174316 | Train_ACC 50.0
# EPOCH 28 | ITER 60 | AVG_LOSS 1.3978135585784912 | Train_ACC 40.625
# EPOCH 28 | ITER 65 | AVG_LOSS 1.4126194715499878 | Train_ACC 53.125
# EPOCH 28 | ITER 70 | AVG_LOSS 1.4325450658798218 | Train_ACC 56.25
# EPOCH 28 | ITER 75 | AVG_LOSS 1.4344905614852905 | Train_ACC 34.375
# EPOCH 28 | ITER 80 | AVG_LOSS 1.432339072227478 | Train_ACC 59.375
# EPOCH 28 | ITER 85 | AVG_LOSS 1.4327199459075928 | Train_ACC 46.875
# EPOCH 28 | ITER 90 | AVG_LOSS 1.4310059547424316 | Train_ACC 56.25
# EPOCH 28 | ITER 95 | AVG_LOSS 1.4299683570861816 | Train_ACC 50.0
# EPOCH 28 | ITER 100 | AVG_LOSS 1.4307529926300049 | Train_ACC 50.0
# EPOCH 28 | ITER 105 | AVG_LOSS 1.424996256828308 | Train_ACC 59.375
# EPOCH 28 | ITER 110 | AVG_LOSS 1.4287291765213013 | Train_ACC 40.625
# EPOCH 28 | ITER 115 | AVG_LOSS 1.4346426725387573 | Train_ACC 50.0
# EPOCH 28 | ITER 120 | AVG_LOSS 1.4354326725006104 | Train_ACC 56.25
# EPOCH 28 | ITER 125 | AVG_LOSS 1.4334545135498047 | Train_ACC 59.375
# EPOCH 28 | ITER 130 | AVG_LOSS 1.432839035987854 | Train_ACC 40.625
# EPOCH 28 | ITER 135 | AVG_LOSS 1.4339088201522827 | Train_ACC 50.0
# EPOCH 28 | ITER 140 | AVG_LOSS 1.4361584186553955 | Train_ACC 43.75
# EPOCH 28 | ITER 145 | AVG_LOSS 1.4364984035491943 | Train_ACC 46.875
# EPOCH 28 | ITER 150 | AVG_LOSS 1.4385981559753418 | Train_ACC 40.625
# EPOCH 28 | ITER 155 | AVG_LOSS 1.4361201524734497 | Train_ACC 59.375
# EPOCH 28 | ITER 160 | AVG_LOSS 1.43868088722229 | Train_ACC 28.125
# EPOCH 28 | ITER 165 | AVG_LOSS 1.4392400979995728 | Train_ACC 46.875
# EPOCH 28 | ITER 170 | AVG_LOSS 1.4387602806091309 | Train_ACC 59.375
# EPOCH 28 | ITER 175 | AVG_LOSS 1.4370561838150024 | Train_ACC 53.125
# EPOCH 28 | ITER 180 | AVG_LOSS 1.4351065158843994 | Train_ACC 50.0
# EPOCH 28 | ITER 185 | AVG_LOSS 1.4401651620864868 | Train_ACC 40.625
# EPOCH 28 | ITER 190 | AVG_LOSS 1.4412784576416016 | Train_ACC 56.25
# EPOCH 28 | ITER 195 | AVG_LOSS 1.4453154802322388 | Train_ACC 65.625
# EPOCH 28 | ITER 200 | AVG_LOSS 1.4428789615631104 | Train_ACC 56.25
# EPOCH 28 | ITER 205 | AVG_LOSS 1.4450092315673828 | Train_ACC 65.625
# EPOCH 28 | ITER 210 | AVG_LOSS 1.4456267356872559 | Train_ACC 59.375
# EPOCH 28 | ITER 215 | AVG_LOSS 1.4475303888320923 | Train_ACC 43.75
# EPOCH 28 | ITER 220 | AVG_LOSS 1.44926118850708 | Train_ACC 37.5
# EPOCH 28 | ITER 225 | AVG_LOSS 1.4487327337265015 | Train_ACC 53.125
# EPOCH 28 | ITER 230 | AVG_LOSS 1.4473084211349487 | Train_ACC 56.25
# EPOCH 28 | ITER 235 | AVG_LOSS 1.4465100765228271 | Train_ACC 56.25
# EPOCH 28 | ITER 240 | AVG_LOSS 1.4457910060882568 | Train_ACC 53.125
# EPOCH 28 | ITER 245 | AVG_LOSS 1.4442763328552246 | Train_ACC 37.5
# EPOCH 28 | ITER 250 | AVG_LOSS 1.444547176361084 | Train_ACC 50.0
# EPOCH 28 | ITER 255 | AVG_LOSS 1.4457226991653442 | Train_ACC 59.375
# EPOCH 28 | ITER 260 | AVG_LOSS 1.4434689283370972 | Train_ACC 46.875
# EPOCH 28 | ITER 265 | AVG_LOSS 1.441375970840454 | Train_ACC 46.875
# EPOCH 28 | ITER 270 | AVG_LOSS 1.4422743320465088 | Train_ACC 50.0
# EPOCH 28 | ITER 275 | AVG_LOSS 1.4422218799591064 | Train_ACC 46.875
# EPOCH 28 | ITER 280 | AVG_LOSS 1.4418973922729492 | Train_ACC 46.875
# EPOCH 28 | ITER 285 | AVG_LOSS 1.4425573348999023 | Train_ACC 56.25
# EPOCH 28 | ITER 290 | AVG_LOSS 1.4420922994613647 | Train_ACC 50.0
# EPOCH 28 | ITER 295 | AVG_LOSS 1.4426387548446655 | Train_ACC 46.875
# EPOCH 28 | ITER 300 | AVG_LOSS 1.4437692165374756 | Train_ACC 40.625
# EPOCH 28 | ITER 305 | AVG_LOSS 1.444941759109497 | Train_ACC 46.875
# EPOCH 28 | ITER 310 | AVG_LOSS 1.4435354471206665 | Train_ACC 59.375
# EPOCH 28 | ITER 315 | AVG_LOSS 1.4431705474853516 | Train_ACC 68.75
# EPOCH 28 | ITER 320 | AVG_LOSS 1.4427677392959595 | Train_ACC 50.0
# EPOCH 28 | ITER 325 | AVG_LOSS 1.4419026374816895 | Train_ACC 43.75
# EPOCH 28 | ITER 330 | AVG_LOSS 1.4424136877059937 | Train_ACC 43.75
# EPOCH 28 | ITER 335 | AVG_LOSS 1.4408496618270874 | Train_ACC 46.875
# EPOCH 28 | ITER 340 | AVG_LOSS 1.440536618232727 | Train_ACC 56.25
# EPOCH 28 | ITER 345 | AVG_LOSS 1.443717122077942 | Train_ACC 56.25
# EPOCH 28 | ITER 350 | AVG_LOSS 1.4430252313613892 | Train_ACC 53.125
# EPOCH 28 | ITER 355 | AVG_LOSS 1.4424901008605957 | Train_ACC 43.75
# EPOCH 28 | ITER 360 | AVG_LOSS 1.4424331188201904 | Train_ACC 59.375
# EPOCH 28 | ITER 365 | AVG_LOSS 1.443993091583252 | Train_ACC 40.625
# EPOCH 28 | ITER 370 | AVG_LOSS 1.4445551633834839 | Train_ACC 68.75
# Val Accuracy: 55.95%
#
# --------------------------------------------------
# EPOCH 28 | LOSS 1.270015001296997 | TIME 157.31694626808167
# --------------------------------------------------
#
# EPOCH 29 | ITER 0 | AVG_LOSS 1.6421624422073364 | Train_ACC 40.625
# EPOCH 29 | ITER 5 | AVG_LOSS 1.4648703336715698 | Train_ACC 65.625
# EPOCH 29 | ITER 10 | AVG_LOSS 1.4549673795700073 | Train_ACC 46.875
# EPOCH 29 | ITER 15 | AVG_LOSS 1.4253815412521362 | Train_ACC 56.25
# EPOCH 29 | ITER 20 | AVG_LOSS 1.416723370552063 | Train_ACC 40.625
# EPOCH 29 | ITER 25 | AVG_LOSS 1.4275280237197876 | Train_ACC 68.75
# EPOCH 29 | ITER 30 | AVG_LOSS 1.4549461603164673 | Train_ACC 59.375
# EPOCH 29 | ITER 35 | AVG_LOSS 1.4773356914520264 | Train_ACC 37.5
# EPOCH 29 | ITER 40 | AVG_LOSS 1.453329086303711 | Train_ACC 65.625
# EPOCH 29 | ITER 45 | AVG_LOSS 1.4444735050201416 | Train_ACC 59.375
# EPOCH 29 | ITER 50 | AVG_LOSS 1.4372320175170898 | Train_ACC 56.25
# EPOCH 29 | ITER 55 | AVG_LOSS 1.4407708644866943 | Train_ACC 71.875
# EPOCH 29 | ITER 60 | AVG_LOSS 1.4322463274002075 | Train_ACC 59.375
# EPOCH 29 | ITER 65 | AVG_LOSS 1.4327454566955566 | Train_ACC 34.375
# EPOCH 29 | ITER 70 | AVG_LOSS 1.4341750144958496 | Train_ACC 62.5
# EPOCH 29 | ITER 75 | AVG_LOSS 1.420179843902588 | Train_ACC 62.5
# EPOCH 29 | ITER 80 | AVG_LOSS 1.413488745689392 | Train_ACC 56.25
# EPOCH 29 | ITER 85 | AVG_LOSS 1.4076311588287354 | Train_ACC 50.0
# EPOCH 29 | ITER 90 | AVG_LOSS 1.4096438884735107 | Train_ACC 50.0
# EPOCH 29 | ITER 95 | AVG_LOSS 1.4031450748443604 | Train_ACC 50.0
# EPOCH 29 | ITER 100 | AVG_LOSS 1.4174550771713257 | Train_ACC 46.875
# EPOCH 29 | ITER 105 | AVG_LOSS 1.4170318841934204 | Train_ACC 56.25
# EPOCH 29 | ITER 110 | AVG_LOSS 1.4146171808242798 | Train_ACC 50.0
# EPOCH 29 | ITER 115 | AVG_LOSS 1.4118831157684326 | Train_ACC 53.125
# EPOCH 29 | ITER 120 | AVG_LOSS 1.4133881330490112 | Train_ACC 46.875
# EPOCH 29 | ITER 125 | AVG_LOSS 1.4046262502670288 | Train_ACC 53.125
# EPOCH 29 | ITER 130 | AVG_LOSS 1.4040945768356323 | Train_ACC 50.0
# EPOCH 29 | ITER 135 | AVG_LOSS 1.4096508026123047 | Train_ACC 56.25
# EPOCH 29 | ITER 140 | AVG_LOSS 1.4100515842437744 | Train_ACC 53.125
# EPOCH 29 | ITER 145 | AVG_LOSS 1.4129090309143066 | Train_ACC 53.125
# EPOCH 29 | ITER 150 | AVG_LOSS 1.4123141765594482 | Train_ACC 50.0
# EPOCH 29 | ITER 155 | AVG_LOSS 1.415067195892334 | Train_ACC 31.25
# EPOCH 29 | ITER 160 | AVG_LOSS 1.4128339290618896 | Train_ACC 56.25
# EPOCH 29 | ITER 165 | AVG_LOSS 1.4131238460540771 | Train_ACC 31.25
# EPOCH 29 | ITER 170 | AVG_LOSS 1.4130364656448364 | Train_ACC 62.5
# EPOCH 29 | ITER 175 | AVG_LOSS 1.4139126539230347 | Train_ACC 50.0
# EPOCH 29 | ITER 180 | AVG_LOSS 1.4106886386871338 | Train_ACC 56.25
# EPOCH 29 | ITER 185 | AVG_LOSS 1.416422724723816 | Train_ACC 46.875
# EPOCH 29 | ITER 190 | AVG_LOSS 1.414318323135376 | Train_ACC 56.25
# EPOCH 29 | ITER 195 | AVG_LOSS 1.4124760627746582 | Train_ACC 75.0
# EPOCH 29 | ITER 200 | AVG_LOSS 1.4111695289611816 | Train_ACC 46.875
# EPOCH 29 | ITER 205 | AVG_LOSS 1.4124987125396729 | Train_ACC 43.75
# EPOCH 29 | ITER 210 | AVG_LOSS 1.4143967628479004 | Train_ACC 53.125
# EPOCH 29 | ITER 215 | AVG_LOSS 1.4182968139648438 | Train_ACC 53.125
# EPOCH 29 | ITER 220 | AVG_LOSS 1.4175727367401123 | Train_ACC 53.125
# EPOCH 29 | ITER 225 | AVG_LOSS 1.4160889387130737 | Train_ACC 53.125
# EPOCH 29 | ITER 230 | AVG_LOSS 1.4159640073776245 | Train_ACC 59.375
# EPOCH 29 | ITER 235 | AVG_LOSS 1.4138473272323608 | Train_ACC 46.875
# EPOCH 29 | ITER 240 | AVG_LOSS 1.4124938249588013 | Train_ACC 53.125
# EPOCH 29 | ITER 245 | AVG_LOSS 1.4156516790390015 | Train_ACC 34.375
# EPOCH 29 | ITER 250 | AVG_LOSS 1.4164758920669556 | Train_ACC 50.0
# EPOCH 29 | ITER 255 | AVG_LOSS 1.4154998064041138 | Train_ACC 40.625
# EPOCH 29 | ITER 260 | AVG_LOSS 1.4149737358093262 | Train_ACC 50.0
# EPOCH 29 | ITER 265 | AVG_LOSS 1.4165472984313965 | Train_ACC 53.125
# EPOCH 29 | ITER 270 | AVG_LOSS 1.4173210859298706 | Train_ACC 62.5
# EPOCH 29 | ITER 275 | AVG_LOSS 1.4193766117095947 | Train_ACC 53.125
# EPOCH 29 | ITER 280 | AVG_LOSS 1.4190582036972046 | Train_ACC 50.0
# EPOCH 29 | ITER 285 | AVG_LOSS 1.4187169075012207 | Train_ACC 46.875
# EPOCH 29 | ITER 290 | AVG_LOSS 1.4205915927886963 | Train_ACC 34.375
# EPOCH 29 | ITER 295 | AVG_LOSS 1.424499273300171 | Train_ACC 56.25
# EPOCH 29 | ITER 300 | AVG_LOSS 1.4266234636306763 | Train_ACC 53.125
# EPOCH 29 | ITER 305 | AVG_LOSS 1.425599217414856 | Train_ACC 59.375
# EPOCH 29 | ITER 310 | AVG_LOSS 1.4255856275558472 | Train_ACC 50.0
# EPOCH 29 | ITER 315 | AVG_LOSS 1.4263509511947632 | Train_ACC 56.25
# EPOCH 29 | ITER 320 | AVG_LOSS 1.4263756275177002 | Train_ACC 59.375
# EPOCH 29 | ITER 325 | AVG_LOSS 1.4249159097671509 | Train_ACC 59.375
# EPOCH 29 | ITER 330 | AVG_LOSS 1.424316167831421 | Train_ACC 68.75
# EPOCH 29 | ITER 335 | AVG_LOSS 1.426946997642517 | Train_ACC 34.375
# EPOCH 29 | ITER 340 | AVG_LOSS 1.4242497682571411 | Train_ACC 68.75
# EPOCH 29 | ITER 345 | AVG_LOSS 1.4274415969848633 | Train_ACC 37.5
# EPOCH 29 | ITER 350 | AVG_LOSS 1.4299218654632568 | Train_ACC 50.0
# EPOCH 29 | ITER 355 | AVG_LOSS 1.4296376705169678 | Train_ACC 50.0
# EPOCH 29 | ITER 360 | AVG_LOSS 1.4286632537841797 | Train_ACC 75.0
# EPOCH 29 | ITER 365 | AVG_LOSS 1.4280706644058228 | Train_ACC 50.0
# EPOCH 29 | ITER 370 | AVG_LOSS 1.4285746812820435 | Train_ACC 46.875
# Val Accuracy: 53.16%
#
# --------------------------------------------------
# EPOCH 29 | LOSS 1.2820563316345215 | TIME 156.8979058265686
# --------------------------------------------------
#
# ****************************************
# test Accuracy: 53.50%
# <ipython-input-70-000cc153af2f>:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
plotloss()

# %%
class2idx = {'butterfly': 0, 'cats': 1, 'cow': 2, 'dogs': 3, 'elephant': 4, 'hen': 5, 'horse': 6, 'monkey': 7, 'panda': 8, 'sheep': 9, 'spider': 10, 'squirrel': 11}

idx2class = { value : key  for key , value in class2idx.items() }
y_true = [idx2class[val.item()] for val in y_expected_test ]
y_pred = [idx2class[val.item()] for val in y_test ]

macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")
f1_score = (2*micro_precision*micro_recall)/(micro_recall + micro_precision)

print("f1 - Score is :--- " ,f1_score)
cnf_matrix = confusion_matrix(y_true , y_pred , labels=['butterfly','cats','cow','dogs','elephant','hen','horse','monkey','panda','sheep', 'spider', 'squirrel'])
plot_confusion_matrix(cnf_matrix , class2idx.keys() , [macro_precision , micro_precision , macro_recall , micro_recall], output_filename = "cnf_resnet_Data3.png")
# Out:
# f1 - Score is :---  0.5350233488992662
