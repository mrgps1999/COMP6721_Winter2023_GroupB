# %%
import time
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.decomposition import PCA
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix
import torchvision.models as models
from torchvision.models import resnet18, ResNet18_Weights
from sklearn.metrics import *
import seaborn as sns
import seaborn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import os.path
import random
import cv2

# %%
writer = SummaryWriter()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from google.colab import drive
drive.mount('/content/gdrive/');

transforms_train = transforms.Compose([
    transforms.Resize((256, 256)),   #must same as here
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(), # data augmentation
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalization
])
transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),   #must same as here
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# Out:
# Mounted at /content/gdrive/

# %%
def load_Data():
  train_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset1/train/"
  test_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset1/val/"
  val_dir = "/content/gdrive/MyDrive/Final_Dataset/dataset1/test/"

  trainset = datasets.ImageFolder(train_dir, transforms_train)
  testset = datasets.ImageFolder(test_dir, transforms_test)
  valset = datasets.ImageFolder(val_dir, transforms_test)
  trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True, num_workers=8)
  testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=8)
  valloader = torch.utils.data.DataLoader(valset, batch_size=32, shuffle=False, num_workers=8)
  return trainloader,testloader,valloader
load_Data()
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# (<torch.utils.data.dataloader.DataLoader at 0x7eff8051a2e0>,
#  <torch.utils.data.dataloader.DataLoader at 0x7eff8051a910>,
#  <torch.utils.data.dataloader.DataLoader at 0x7eff8051a700>)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
# def Model():
#   # Define the ResNet-18 model
#   resnet = 
#   # Replace the last fully connected layer with a new one
#   num_ftrs = resnet.fc.in_features
#   print(num_ftrs)
#   resnet.fc = nn.Linear(num_ftrs,2)

#   # Define the loss function and optimizer
#   return resnet
# Model()

# %%
class Resnet18(nn.Module):
    def __init__(self,input) -> None:
        super(Resnet18 , self).__init__()

        self.resnet18 = torchvision.models.resnet18(pretrained=True)

        # Freeze all the layers in the ResNet18 model except the final fully connected layer
        for param in self.resnet18.parameters():
            param.requires_grad = False
        self.resnet18.fc.requires_grad = True

        # Replace the final fully connected layer with a new fully connected layer that matches the number of classes in your dataset
        self.resnet18.fc = nn.Linear(self.resnet18.fc.in_features, 2)
        
        
        self.features = {}
        self.resnet18.avgpool.register_forward_hook(self.get_features("embeddings"))

    def get_features(self,name):
        def hook(model, input, output):
            self.features[name] = output.detach().cpu().numpy()
        return hook

    def forward(self, x):
          x = self.resnet18(x)
          return x
model2 = Resnet18((224,224))
print(model2)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 164MB/s]
# Resnet18(
#   (resnet18): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %%
def save_checkpoint(state, filename):
  torch.save(state, filename)

# %%
# datastructure to store all the training testing and validation results.
y_train = []
y_expected_train = []
y_val = []
y_expected_val = []
y_test = []
y_expected_test = []
trainloss = []
valloss =[]
epochnum = []

# %%
print(torch.cuda.is_available())
def train(model, train_loader, criterion, optimizer, epoch, step=5):
    
    model.train()
    loss_list = AverageMeter()
    for i, (images, labels) in enumerate(train_loader):
        #print(torch.cuda.is_available())
        total =0
        correct = 0
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        #print(predicted,type(predicted))
        #print(labels,type(labels))
        output = model(images)
        loss = criterion(output,labels)
        loss_list.update(loss.data, images.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(output.data, 1)
        y_train.extend(predicted.to(torch.device('cpu')))
        y_expected_train.extend(labels.to(torch.device('cpu')))
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        #print( f'Training Accuracy: {accuracy:.2f}%')
            
        if i%step==0:
            print('EPOCH {} | ITER {} | AVG_LOSS {} | Train_ACC {}'.format(epoch, i, loss_list.avg,accuracy))
        writer.add_scalar('TRAIN_LOSS', loss, epoch)
        writer.add_scalar('TRAIN_ACC', accuracy, epoch)
        
    return loss ,accuracy
# Out:
# True

# %%
def test(model, test_loader, criterion, optimizer, epoch, step=5):
    print("Best Model: ",epoch)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        print("*"*40)
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            
            #print("Inside test");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            y_test.extend(predicted.to(torch.device('cpu')))
            y_expected_test.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f'test Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('_LOSS', loss, epoch)
        # writer.add_scalar('TEST_ACC', accuracy, epoch)
        return accuracy

# %%
def val(model, val_loader, criterion, optimizer, epoch, step=5):
    model.eval()
    loss_list = AverageMeter()
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            #print("Inside validation");
            #print(inputs.shape)
            #print(labels.shape)
            labels = labels.to(device)
            outputs = model(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            #print(predicted,type(predicted))
            #print(labels,type(labels))
            loss = criterion(outputs,labels)
            loss_list.update(loss.data, inputs.size(0))
            y_val.extend(predicted.to(torch.device('cpu')))
            y_expected_val.extend(labels.to(torch.device('cpu')))
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #print("CORRECT",correct)
            #print("Total",total)
        accuracy = 100 * correct / total
        print(f'Val Accuracy: {accuracy:.2f}%')
        # writer.add_scalar('Validation_LOSS', loss, epoch)
        writer.add_scalar('Validation_ACCURACY', accuracy, epoch)
        return loss,accuracy

# %%
def visualize(model , data_loader):
    class2idx = {'Cat': 0, 'Dog': 1}
    idx2class = { value : key for key,value in  class2idx.items() }
    embeddings = np.array([])
    labels = np.array([])
    model.eval()
    out_features = 512
    num_categories = 2
    with torch.no_grad(): 
        for i,data in enumerate(data_loader):
            images, labs = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            embeds = model.features["embeddings"].reshape(-1, 1024)
            embeddings = np.append(embeddings , embeds)
            labels = np.append(labels,labs.cpu())
  
    embeddings = embeddings.reshape(-1, 512)
    
    c_labels = labels.reshape(-1 , 1).ravel()
    tsne = TSNE(n_components=2,perplexity=2).fit_transform(embeddings)
    labels = np.array([ idx2class[ele] for ele in c_labels])
    
    cmap = cm.get_cmap('tab20')
    
    for lab in range(num_categories):
        indices = (c_labels == lab)
        plt.scatter(tsne[indices, 0],tsne[indices, 1],c=np.array(cmap(lab)).reshape(1, 4),label=lab,alpha=1)
        plt.legend(fontsize='large', markerscale=2)
    plt.show()
  
# model = Model((224,224))
# train_loader, val_loader ,test_loader = load_Data()
# visualize(model,test_loader)

# %%
def plotloss():
  plt.figure(figsize=(20,10))
  plt.plot(epochnum, trainloss)
  plt.plot(epochnum, valloss)
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['training', 'validation'], loc='upper right')
  plt.show()

# %%
class2idx = {'Cat':0,'Dog':1}
idx2class = { value : key  for key , value in class2idx.items() }

def plot_confusion_matrix(data, labels, metrics ,output_filename=None):

    [macro_precision , micro_precision , macro_recall , micro_recall] = metrics

    seaborn.set(color_codes=True)
    plt.figure(1, figsize=(10,10))
 
    plt.suptitle("Confusion Matrix")
    plt.title(f"(Macro/Micro) Precision : {round(macro_precision,2)}/{round(micro_precision,2)}   :::::   (Macro/Micro) Recall : {round(macro_recall,2)}/{round(micro_recall,2)}")
 
    seaborn.set(font_scale=1)
    ax = seaborn.heatmap(data, annot=True, cmap="YlGnBu",linewidths=2 , fmt='d' ,cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
    
    plt.savefig(output_filename, bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# %%
def main():
    model = Resnet18((224,224));
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        model = model.cuda()
        print("using gpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    epochs = 30
    train_loader, val_loader ,test_loader = load_Data()
 
    history = open("/content/gdrive/MyDrive/Results/deeptunedataset1_Resnet18_history.csv",'w')
    history.write('epochs , trainloss , Train-acc,val_acc , test_acc \n')
    max_accuracy = 0 
    finalepoch  = 0 
    for epoch in range(0,epochs):
        start = time.time()
        train_loss,accuracy = train(model, train_loader, criterion, optimizer, epoch)
        vallosss,val_loss = val(model, val_loader, criterion, optimizer, epoch)
        
        trainloss.append(train_loss.cpu().detach().numpy())
        valloss.append(vallosss.cpu().detach().numpy())
        epochnum.append(epoch)
        print()
        print('-' * 50)
        print('EPOCH {} | LOSS {} | TIME {}'.format(epoch, train_loss, time.time() - start))
        print('-' * 50)
        print()

        if(val_loss > max_accuracy):
          max_accuracy = val_loss
          finalepoch  = epoch
          save_checkpoint({'epoch': epoch,'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),'loss' : train_loss}, "/content/gdrive/MyDrive/Checkpoints/deeptunedataset1_Resnet18_checkpoint.ckpt")

        history.write('{},{},{},{}\n'.format(epoch, train_loss,accuracy, val_loss ))
    test_loss = test(model, test_loader, criterion, optimizer, finalepoch)    
    history.close()
    visualize(model,train_loader)

# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    main()
# Out:
# True
# using gpu
# EPOCH 0 | ITER 0 | AVG_LOSS 0.9328950047492981 | Train_ACC 40.625
# EPOCH 0 | ITER 5 | AVG_LOSS 0.8504385352134705 | Train_ACC 40.625
# EPOCH 0 | ITER 10 | AVG_LOSS 0.7437493801116943 | Train_ACC 59.375
# EPOCH 0 | ITER 15 | AVG_LOSS 0.6767184734344482 | Train_ACC 87.5
# EPOCH 0 | ITER 20 | AVG_LOSS 0.6206586956977844 | Train_ACC 78.125
# EPOCH 0 | ITER 25 | AVG_LOSS 0.5704285502433777 | Train_ACC 87.5
# EPOCH 0 | ITER 30 | AVG_LOSS 0.5298849940299988 | Train_ACC 90.625
# EPOCH 0 | ITER 35 | AVG_LOSS 0.4933573305606842 | Train_ACC 84.375
# EPOCH 0 | ITER 40 | AVG_LOSS 0.46340250968933105 | Train_ACC 93.75
# EPOCH 0 | ITER 45 | AVG_LOSS 0.4398047924041748 | Train_ACC 87.5
# EPOCH 0 | ITER 50 | AVG_LOSS 0.4164782166481018 | Train_ACC 87.5
# EPOCH 0 | ITER 55 | AVG_LOSS 0.3992294669151306 | Train_ACC 87.5
# EPOCH 0 | ITER 60 | AVG_LOSS 0.38372087478637695 | Train_ACC 93.75
# EPOCH 0 | ITER 65 | AVG_LOSS 0.37154486775398254 | Train_ACC 90.625
# EPOCH 0 | ITER 70 | AVG_LOSS 0.35756000876426697 | Train_ACC 93.75
# EPOCH 0 | ITER 75 | AVG_LOSS 0.35024693608283997 | Train_ACC 93.75
# EPOCH 0 | ITER 80 | AVG_LOSS 0.3416370153427124 | Train_ACC 87.5
# EPOCH 0 | ITER 85 | AVG_LOSS 0.3330378532409668 | Train_ACC 93.75
# EPOCH 0 | ITER 90 | AVG_LOSS 0.3234671652317047 | Train_ACC 96.875
# EPOCH 0 | ITER 95 | AVG_LOSS 0.3147813379764557 | Train_ACC 93.75
# EPOCH 0 | ITER 100 | AVG_LOSS 0.3092266917228699 | Train_ACC 84.375
# EPOCH 0 | ITER 105 | AVG_LOSS 0.304347425699234 | Train_ACC 84.375
# EPOCH 0 | ITER 110 | AVG_LOSS 0.29877328872680664 | Train_ACC 96.875
# EPOCH 0 | ITER 115 | AVG_LOSS 0.2922801673412323 | Train_ACC 96.875
# EPOCH 0 | ITER 120 | AVG_LOSS 0.2884507477283478 | Train_ACC 100.0
# Val Accuracy: 97.60%
#
# --------------------------------------------------
# EPOCH 0 | LOSS 0.12387155741453171 | TIME 104.00133872032166
# --------------------------------------------------
#
# EPOCH 1 | ITER 0 | AVG_LOSS 0.11944672465324402 | Train_ACC 96.875
# EPOCH 1 | ITER 5 | AVG_LOSS 0.1810288429260254 | Train_ACC 90.625
# EPOCH 1 | ITER 10 | AVG_LOSS 0.18341143429279327 | Train_ACC 81.25
# EPOCH 1 | ITER 15 | AVG_LOSS 0.19420239329338074 | Train_ACC 87.5
# EPOCH 1 | ITER 20 | AVG_LOSS 0.19990330934524536 | Train_ACC 81.25
# EPOCH 1 | ITER 25 | AVG_LOSS 0.1985587626695633 | Train_ACC 93.75
# EPOCH 1 | ITER 30 | AVG_LOSS 0.1959044188261032 | Train_ACC 90.625
# EPOCH 1 | ITER 35 | AVG_LOSS 0.19125884771347046 | Train_ACC 93.75
# EPOCH 1 | ITER 40 | AVG_LOSS 0.1871473342180252 | Train_ACC 93.75
# EPOCH 1 | ITER 45 | AVG_LOSS 0.18573246896266937 | Train_ACC 93.75
# EPOCH 1 | ITER 50 | AVG_LOSS 0.1850546896457672 | Train_ACC 87.5
# EPOCH 1 | ITER 55 | AVG_LOSS 0.18466618657112122 | Train_ACC 93.75
# EPOCH 1 | ITER 60 | AVG_LOSS 0.18337902426719666 | Train_ACC 90.625
# EPOCH 1 | ITER 65 | AVG_LOSS 0.18291927874088287 | Train_ACC 93.75
# EPOCH 1 | ITER 70 | AVG_LOSS 0.18424375355243683 | Train_ACC 84.375
# EPOCH 1 | ITER 75 | AVG_LOSS 0.18247279524803162 | Train_ACC 93.75
# EPOCH 1 | ITER 80 | AVG_LOSS 0.18303650617599487 | Train_ACC 93.75
# EPOCH 1 | ITER 85 | AVG_LOSS 0.18065962195396423 | Train_ACC 93.75
# EPOCH 1 | ITER 90 | AVG_LOSS 0.180598646402359 | Train_ACC 90.625
# EPOCH 1 | ITER 95 | AVG_LOSS 0.18221211433410645 | Train_ACC 84.375
# EPOCH 1 | ITER 100 | AVG_LOSS 0.1828700304031372 | Train_ACC 87.5
# EPOCH 1 | ITER 105 | AVG_LOSS 0.18399858474731445 | Train_ACC 90.625
# EPOCH 1 | ITER 110 | AVG_LOSS 0.1845197081565857 | Train_ACC 93.75
# EPOCH 1 | ITER 115 | AVG_LOSS 0.18188844621181488 | Train_ACC 93.75
# EPOCH 1 | ITER 120 | AVG_LOSS 0.1793757677078247 | Train_ACC 100.0
# Val Accuracy: 98.40%
#
# --------------------------------------------------
# EPOCH 1 | LOSS 0.20404267311096191 | TIME 35.62621855735779
# --------------------------------------------------
#
# EPOCH 2 | ITER 0 | AVG_LOSS 0.10985657572746277 | Train_ACC 96.875
# EPOCH 2 | ITER 5 | AVG_LOSS 0.13213053345680237 | Train_ACC 96.875
# EPOCH 2 | ITER 10 | AVG_LOSS 0.1490587592124939 | Train_ACC 100.0
# EPOCH 2 | ITER 15 | AVG_LOSS 0.14273439347743988 | Train_ACC 96.875
# EPOCH 2 | ITER 20 | AVG_LOSS 0.16069310903549194 | Train_ACC 96.875
# EPOCH 2 | ITER 25 | AVG_LOSS 0.1541345864534378 | Train_ACC 100.0
# EPOCH 2 | ITER 30 | AVG_LOSS 0.1560349315404892 | Train_ACC 93.75
# EPOCH 2 | ITER 35 | AVG_LOSS 0.1542540341615677 | Train_ACC 96.875
# EPOCH 2 | ITER 40 | AVG_LOSS 0.15138059854507446 | Train_ACC 87.5
# EPOCH 2 | ITER 45 | AVG_LOSS 0.14543592929840088 | Train_ACC 100.0
# EPOCH 2 | ITER 50 | AVG_LOSS 0.14752766489982605 | Train_ACC 93.75
# EPOCH 2 | ITER 55 | AVG_LOSS 0.1478208303451538 | Train_ACC 90.625
# EPOCH 2 | ITER 60 | AVG_LOSS 0.1463754028081894 | Train_ACC 90.625
# EPOCH 2 | ITER 65 | AVG_LOSS 0.1421152651309967 | Train_ACC 96.875
# EPOCH 2 | ITER 70 | AVG_LOSS 0.14379091560840607 | Train_ACC 100.0
# EPOCH 2 | ITER 75 | AVG_LOSS 0.1434369683265686 | Train_ACC 93.75
# EPOCH 2 | ITER 80 | AVG_LOSS 0.14528369903564453 | Train_ACC 90.625
# EPOCH 2 | ITER 85 | AVG_LOSS 0.1428569257259369 | Train_ACC 96.875
# EPOCH 2 | ITER 90 | AVG_LOSS 0.1414373815059662 | Train_ACC 100.0
# EPOCH 2 | ITER 95 | AVG_LOSS 0.14021240174770355 | Train_ACC 100.0
# EPOCH 2 | ITER 100 | AVG_LOSS 0.13977359235286713 | Train_ACC 100.0
# EPOCH 2 | ITER 105 | AVG_LOSS 0.1410290002822876 | Train_ACC 93.75
# EPOCH 2 | ITER 110 | AVG_LOSS 0.1402769535779953 | Train_ACC 96.875
# EPOCH 2 | ITER 115 | AVG_LOSS 0.14194203913211823 | Train_ACC 96.875
# EPOCH 2 | ITER 120 | AVG_LOSS 0.14033523201942444 | Train_ACC 93.75
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 2 | LOSS 0.09545782953500748 | TIME 33.48019504547119
# --------------------------------------------------
#
# EPOCH 3 | ITER 0 | AVG_LOSS 0.0995546206831932 | Train_ACC 93.75
# EPOCH 3 | ITER 5 | AVG_LOSS 0.128697007894516 | Train_ACC 96.875
# EPOCH 3 | ITER 10 | AVG_LOSS 0.1762043833732605 | Train_ACC 90.625
# EPOCH 3 | ITER 15 | AVG_LOSS 0.1431029587984085 | Train_ACC 96.875
# EPOCH 3 | ITER 20 | AVG_LOSS 0.14506950974464417 | Train_ACC 93.75
# EPOCH 3 | ITER 25 | AVG_LOSS 0.1410675048828125 | Train_ACC 93.75
# EPOCH 3 | ITER 30 | AVG_LOSS 0.13382484018802643 | Train_ACC 96.875
# EPOCH 3 | ITER 35 | AVG_LOSS 0.1381206214427948 | Train_ACC 90.625
# EPOCH 3 | ITER 40 | AVG_LOSS 0.1383400410413742 | Train_ACC 93.75
# EPOCH 3 | ITER 45 | AVG_LOSS 0.14234891533851624 | Train_ACC 87.5
# EPOCH 3 | ITER 50 | AVG_LOSS 0.14556832611560822 | Train_ACC 96.875
# EPOCH 3 | ITER 55 | AVG_LOSS 0.14308863878250122 | Train_ACC 93.75
# EPOCH 3 | ITER 60 | AVG_LOSS 0.13947328925132751 | Train_ACC 100.0
# EPOCH 3 | ITER 65 | AVG_LOSS 0.14025555551052094 | Train_ACC 93.75
# EPOCH 3 | ITER 70 | AVG_LOSS 0.1374136060476303 | Train_ACC 96.875
# EPOCH 3 | ITER 75 | AVG_LOSS 0.13689814507961273 | Train_ACC 87.5
# EPOCH 3 | ITER 80 | AVG_LOSS 0.13465498387813568 | Train_ACC 87.5
# EPOCH 3 | ITER 85 | AVG_LOSS 0.13390125334262848 | Train_ACC 93.75
# EPOCH 3 | ITER 90 | AVG_LOSS 0.13409991562366486 | Train_ACC 90.625
# EPOCH 3 | ITER 95 | AVG_LOSS 0.13689099252223969 | Train_ACC 96.875
# EPOCH 3 | ITER 100 | AVG_LOSS 0.13616123795509338 | Train_ACC 100.0
# EPOCH 3 | ITER 105 | AVG_LOSS 0.1381223350763321 | Train_ACC 96.875
# EPOCH 3 | ITER 110 | AVG_LOSS 0.13926132023334503 | Train_ACC 93.75
# EPOCH 3 | ITER 115 | AVG_LOSS 0.13951724767684937 | Train_ACC 90.625
# EPOCH 3 | ITER 120 | AVG_LOSS 0.13959839940071106 | Train_ACC 96.875
# Val Accuracy: 98.60%
#
# --------------------------------------------------
# EPOCH 3 | LOSS 0.08832446485757828 | TIME 37.124112606048584
# --------------------------------------------------
#
# EPOCH 4 | ITER 0 | AVG_LOSS 0.11746792495250702 | Train_ACC 96.875
# EPOCH 4 | ITER 5 | AVG_LOSS 0.11436247080564499 | Train_ACC 90.625
# EPOCH 4 | ITER 10 | AVG_LOSS 0.12370221316814423 | Train_ACC 93.75
# EPOCH 4 | ITER 15 | AVG_LOSS 0.14624294638633728 | Train_ACC 84.375
# EPOCH 4 | ITER 20 | AVG_LOSS 0.13587690889835358 | Train_ACC 93.75
# EPOCH 4 | ITER 25 | AVG_LOSS 0.1452455371618271 | Train_ACC 93.75
# EPOCH 4 | ITER 30 | AVG_LOSS 0.14478687942028046 | Train_ACC 87.5
# EPOCH 4 | ITER 35 | AVG_LOSS 0.15750181674957275 | Train_ACC 100.0
# EPOCH 4 | ITER 40 | AVG_LOSS 0.16494588553905487 | Train_ACC 78.125
# EPOCH 4 | ITER 45 | AVG_LOSS 0.16062374413013458 | Train_ACC 93.75
# EPOCH 4 | ITER 50 | AVG_LOSS 0.1569366455078125 | Train_ACC 87.5
# EPOCH 4 | ITER 55 | AVG_LOSS 0.15495535731315613 | Train_ACC 84.375
# EPOCH 4 | ITER 60 | AVG_LOSS 0.1519903987646103 | Train_ACC 93.75
# EPOCH 4 | ITER 65 | AVG_LOSS 0.1528075635433197 | Train_ACC 100.0
# EPOCH 4 | ITER 70 | AVG_LOSS 0.15017758309841156 | Train_ACC 90.625
# EPOCH 4 | ITER 75 | AVG_LOSS 0.1520245224237442 | Train_ACC 90.625
# EPOCH 4 | ITER 80 | AVG_LOSS 0.15129968523979187 | Train_ACC 96.875
# EPOCH 4 | ITER 85 | AVG_LOSS 0.15086111426353455 | Train_ACC 87.5
# EPOCH 4 | ITER 90 | AVG_LOSS 0.15087315440177917 | Train_ACC 96.875
# EPOCH 4 | ITER 95 | AVG_LOSS 0.1491757333278656 | Train_ACC 96.875
# EPOCH 4 | ITER 100 | AVG_LOSS 0.1491604894399643 | Train_ACC 96.875
# EPOCH 4 | ITER 105 | AVG_LOSS 0.14680759608745575 | Train_ACC 100.0
# EPOCH 4 | ITER 110 | AVG_LOSS 0.14421476423740387 | Train_ACC 93.75
# EPOCH 4 | ITER 115 | AVG_LOSS 0.14398163557052612 | Train_ACC 93.75
# EPOCH 4 | ITER 120 | AVG_LOSS 0.14319027960300446 | Train_ACC 100.0
# Val Accuracy: 98.80%
#
# --------------------------------------------------
# EPOCH 4 | LOSS 0.12924404442310333 | TIME 33.56007170677185
# --------------------------------------------------
#
# EPOCH 5 | ITER 0 | AVG_LOSS 0.13117066025733948 | Train_ACC 93.75
# EPOCH 5 | ITER 5 | AVG_LOSS 0.1048218160867691 | Train_ACC 100.0
# EPOCH 5 | ITER 10 | AVG_LOSS 0.09700164198875427 | Train_ACC 90.625
# EPOCH 5 | ITER 15 | AVG_LOSS 0.11026688665151596 | Train_ACC 87.5
# EPOCH 5 | ITER 20 | AVG_LOSS 0.12766428291797638 | Train_ACC 96.875
# EPOCH 5 | ITER 25 | AVG_LOSS 0.12093513458967209 | Train_ACC 100.0
# EPOCH 5 | ITER 30 | AVG_LOSS 0.1265513151884079 | Train_ACC 90.625
# EPOCH 5 | ITER 35 | AVG_LOSS 0.13113315403461456 | Train_ACC 93.75
# EPOCH 5 | ITER 40 | AVG_LOSS 0.13379399478435516 | Train_ACC 96.875
# EPOCH 5 | ITER 45 | AVG_LOSS 0.1320972740650177 | Train_ACC 100.0
# EPOCH 5 | ITER 50 | AVG_LOSS 0.12875497341156006 | Train_ACC 90.625
# EPOCH 5 | ITER 55 | AVG_LOSS 0.12914273142814636 | Train_ACC 93.75
# EPOCH 5 | ITER 60 | AVG_LOSS 0.12929730117321014 | Train_ACC 96.875
# EPOCH 5 | ITER 65 | AVG_LOSS 0.12782146036624908 | Train_ACC 100.0
# EPOCH 5 | ITER 70 | AVG_LOSS 0.12837055325508118 | Train_ACC 90.625
# EPOCH 5 | ITER 75 | AVG_LOSS 0.13157685101032257 | Train_ACC 87.5
# EPOCH 5 | ITER 80 | AVG_LOSS 0.12882530689239502 | Train_ACC 100.0
# EPOCH 5 | ITER 85 | AVG_LOSS 0.12909430265426636 | Train_ACC 90.625
# EPOCH 5 | ITER 90 | AVG_LOSS 0.1298951953649521 | Train_ACC 93.75
# EPOCH 5 | ITER 95 | AVG_LOSS 0.12912961840629578 | Train_ACC 96.875
# EPOCH 5 | ITER 100 | AVG_LOSS 0.12920869886875153 | Train_ACC 93.75
# EPOCH 5 | ITER 105 | AVG_LOSS 0.129172220826149 | Train_ACC 90.625
# EPOCH 5 | ITER 110 | AVG_LOSS 0.1269114911556244 | Train_ACC 93.75
# EPOCH 5 | ITER 115 | AVG_LOSS 0.128568634390831 | Train_ACC 96.875
# EPOCH 5 | ITER 120 | AVG_LOSS 0.13019873201847076 | Train_ACC 93.75
# Val Accuracy: 97.80%
#
# --------------------------------------------------
# EPOCH 5 | LOSS 0.20506398379802704 | TIME 34.868000507354736
# --------------------------------------------------
#
# EPOCH 6 | ITER 0 | AVG_LOSS 0.060249365866184235 | Train_ACC 100.0
# EPOCH 6 | ITER 5 | AVG_LOSS 0.16554099321365356 | Train_ACC 93.75
# EPOCH 6 | ITER 10 | AVG_LOSS 0.1511552333831787 | Train_ACC 93.75
# EPOCH 6 | ITER 15 | AVG_LOSS 0.14254145324230194 | Train_ACC 96.875
# EPOCH 6 | ITER 20 | AVG_LOSS 0.13059619069099426 | Train_ACC 93.75
# EPOCH 6 | ITER 25 | AVG_LOSS 0.12059243023395538 | Train_ACC 100.0
# EPOCH 6 | ITER 30 | AVG_LOSS 0.12069804221391678 | Train_ACC 100.0
# EPOCH 6 | ITER 35 | AVG_LOSS 0.12158747762441635 | Train_ACC 87.5
# EPOCH 6 | ITER 40 | AVG_LOSS 0.12299633771181107 | Train_ACC 90.625
# EPOCH 6 | ITER 45 | AVG_LOSS 0.12308667600154877 | Train_ACC 87.5
# EPOCH 6 | ITER 50 | AVG_LOSS 0.13017141819000244 | Train_ACC 90.625
# EPOCH 6 | ITER 55 | AVG_LOSS 0.1320774257183075 | Train_ACC 93.75
# EPOCH 6 | ITER 60 | AVG_LOSS 0.13327185809612274 | Train_ACC 93.75
# EPOCH 6 | ITER 65 | AVG_LOSS 0.1370166689157486 | Train_ACC 96.875
# EPOCH 6 | ITER 70 | AVG_LOSS 0.14019431173801422 | Train_ACC 96.875
# EPOCH 6 | ITER 75 | AVG_LOSS 0.14611539244651794 | Train_ACC 90.625
# EPOCH 6 | ITER 80 | AVG_LOSS 0.14712949097156525 | Train_ACC 93.75
# EPOCH 6 | ITER 85 | AVG_LOSS 0.14634251594543457 | Train_ACC 93.75
# EPOCH 6 | ITER 90 | AVG_LOSS 0.1452944278717041 | Train_ACC 96.875
# EPOCH 6 | ITER 95 | AVG_LOSS 0.1465558260679245 | Train_ACC 84.375
# EPOCH 6 | ITER 100 | AVG_LOSS 0.1450517624616623 | Train_ACC 93.75
# EPOCH 6 | ITER 105 | AVG_LOSS 0.14609958231449127 | Train_ACC 96.875
# EPOCH 6 | ITER 110 | AVG_LOSS 0.150665283203125 | Train_ACC 81.25
# EPOCH 6 | ITER 115 | AVG_LOSS 0.15000846982002258 | Train_ACC 96.875
# EPOCH 6 | ITER 120 | AVG_LOSS 0.15447627007961273 | Train_ACC 84.375
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 6 | LOSS 0.23738938570022583 | TIME 36.63247585296631
# --------------------------------------------------
#
# EPOCH 7 | ITER 0 | AVG_LOSS 0.16623610258102417 | Train_ACC 93.75
# EPOCH 7 | ITER 5 | AVG_LOSS 0.10522200912237167 | Train_ACC 93.75
# EPOCH 7 | ITER 10 | AVG_LOSS 0.10046078264713287 | Train_ACC 90.625
# EPOCH 7 | ITER 15 | AVG_LOSS 0.11819710582494736 | Train_ACC 96.875
# EPOCH 7 | ITER 20 | AVG_LOSS 0.12105124443769455 | Train_ACC 100.0
# EPOCH 7 | ITER 25 | AVG_LOSS 0.12324203550815582 | Train_ACC 93.75
# EPOCH 7 | ITER 30 | AVG_LOSS 0.1245659664273262 | Train_ACC 96.875
# EPOCH 7 | ITER 35 | AVG_LOSS 0.12760691344738007 | Train_ACC 93.75
# EPOCH 7 | ITER 40 | AVG_LOSS 0.13210095465183258 | Train_ACC 96.875
# EPOCH 7 | ITER 45 | AVG_LOSS 0.13682067394256592 | Train_ACC 96.875
# EPOCH 7 | ITER 50 | AVG_LOSS 0.13718536496162415 | Train_ACC 100.0
# EPOCH 7 | ITER 55 | AVG_LOSS 0.13864019513130188 | Train_ACC 96.875
# EPOCH 7 | ITER 60 | AVG_LOSS 0.1411282867193222 | Train_ACC 90.625
# EPOCH 7 | ITER 65 | AVG_LOSS 0.14229384064674377 | Train_ACC 96.875
# EPOCH 7 | ITER 70 | AVG_LOSS 0.1390560120344162 | Train_ACC 100.0
# EPOCH 7 | ITER 75 | AVG_LOSS 0.1393667757511139 | Train_ACC 100.0
# EPOCH 7 | ITER 80 | AVG_LOSS 0.1396539956331253 | Train_ACC 87.5
# EPOCH 7 | ITER 85 | AVG_LOSS 0.1380990743637085 | Train_ACC 96.875
# EPOCH 7 | ITER 90 | AVG_LOSS 0.13582345843315125 | Train_ACC 93.75
# EPOCH 7 | ITER 95 | AVG_LOSS 0.1344633400440216 | Train_ACC 93.75
# EPOCH 7 | ITER 100 | AVG_LOSS 0.13304194808006287 | Train_ACC 96.875
# EPOCH 7 | ITER 105 | AVG_LOSS 0.13397246599197388 | Train_ACC 96.875
# EPOCH 7 | ITER 110 | AVG_LOSS 0.13422483205795288 | Train_ACC 96.875
# EPOCH 7 | ITER 115 | AVG_LOSS 0.13191770017147064 | Train_ACC 96.875
# EPOCH 7 | ITER 120 | AVG_LOSS 0.13179540634155273 | Train_ACC 93.75
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 7 | LOSS 0.09991799294948578 | TIME 33.14939212799072
# --------------------------------------------------
#
# EPOCH 8 | ITER 0 | AVG_LOSS 0.12323661148548126 | Train_ACC 93.75
# EPOCH 8 | ITER 5 | AVG_LOSS 0.11636736243963242 | Train_ACC 96.875
# EPOCH 8 | ITER 10 | AVG_LOSS 0.14682792127132416 | Train_ACC 90.625
# EPOCH 8 | ITER 15 | AVG_LOSS 0.14438976347446442 | Train_ACC 100.0
# EPOCH 8 | ITER 20 | AVG_LOSS 0.14383983612060547 | Train_ACC 93.75
# EPOCH 8 | ITER 25 | AVG_LOSS 0.1367371678352356 | Train_ACC 100.0
# EPOCH 8 | ITER 30 | AVG_LOSS 0.1380775421857834 | Train_ACC 93.75
# EPOCH 8 | ITER 35 | AVG_LOSS 0.14144720137119293 | Train_ACC 87.5
# EPOCH 8 | ITER 40 | AVG_LOSS 0.1460082232952118 | Train_ACC 90.625
# EPOCH 8 | ITER 45 | AVG_LOSS 0.13974086940288544 | Train_ACC 90.625
# EPOCH 8 | ITER 50 | AVG_LOSS 0.13817958533763885 | Train_ACC 96.875
# EPOCH 8 | ITER 55 | AVG_LOSS 0.1360560804605484 | Train_ACC 93.75
# EPOCH 8 | ITER 60 | AVG_LOSS 0.13386790454387665 | Train_ACC 96.875
# EPOCH 8 | ITER 65 | AVG_LOSS 0.13127152621746063 | Train_ACC 87.5
# EPOCH 8 | ITER 70 | AVG_LOSS 0.1338137835264206 | Train_ACC 93.75
# EPOCH 8 | ITER 75 | AVG_LOSS 0.13498836755752563 | Train_ACC 90.625
# EPOCH 8 | ITER 80 | AVG_LOSS 0.13326679170131683 | Train_ACC 93.75
# EPOCH 8 | ITER 85 | AVG_LOSS 0.1325637400150299 | Train_ACC 93.75
# EPOCH 8 | ITER 90 | AVG_LOSS 0.13286451995372772 | Train_ACC 100.0
# EPOCH 8 | ITER 95 | AVG_LOSS 0.13531234860420227 | Train_ACC 100.0
# EPOCH 8 | ITER 100 | AVG_LOSS 0.13538363575935364 | Train_ACC 87.5
# EPOCH 8 | ITER 105 | AVG_LOSS 0.13301250338554382 | Train_ACC 96.875
# EPOCH 8 | ITER 110 | AVG_LOSS 0.13669626414775848 | Train_ACC 93.75
# EPOCH 8 | ITER 115 | AVG_LOSS 0.1345415562391281 | Train_ACC 93.75
# EPOCH 8 | ITER 120 | AVG_LOSS 0.13552187383174896 | Train_ACC 96.875
# Val Accuracy: 98.40%
#
# --------------------------------------------------
# EPOCH 8 | LOSS 0.10969340801239014 | TIME 37.02490258216858
# --------------------------------------------------
#
# EPOCH 9 | ITER 0 | AVG_LOSS 0.12846091389656067 | Train_ACC 93.75
# EPOCH 9 | ITER 5 | AVG_LOSS 0.15314984321594238 | Train_ACC 93.75
# EPOCH 9 | ITER 10 | AVG_LOSS 0.20403163135051727 | Train_ACC 68.75
# EPOCH 9 | ITER 15 | AVG_LOSS 0.171406090259552 | Train_ACC 100.0
# EPOCH 9 | ITER 20 | AVG_LOSS 0.15269678831100464 | Train_ACC 100.0
# EPOCH 9 | ITER 25 | AVG_LOSS 0.15639802813529968 | Train_ACC 90.625
# EPOCH 9 | ITER 30 | AVG_LOSS 0.15213125944137573 | Train_ACC 93.75
# EPOCH 9 | ITER 35 | AVG_LOSS 0.142684206366539 | Train_ACC 96.875
# EPOCH 9 | ITER 40 | AVG_LOSS 0.15765886008739471 | Train_ACC 84.375
# EPOCH 9 | ITER 45 | AVG_LOSS 0.1531347632408142 | Train_ACC 96.875
# EPOCH 9 | ITER 50 | AVG_LOSS 0.14786605536937714 | Train_ACC 96.875
# EPOCH 9 | ITER 55 | AVG_LOSS 0.14882415533065796 | Train_ACC 96.875
# EPOCH 9 | ITER 60 | AVG_LOSS 0.14538519084453583 | Train_ACC 96.875
# EPOCH 9 | ITER 65 | AVG_LOSS 0.14891919493675232 | Train_ACC 87.5
# EPOCH 9 | ITER 70 | AVG_LOSS 0.14478209614753723 | Train_ACC 90.625
# EPOCH 9 | ITER 75 | AVG_LOSS 0.14401142299175262 | Train_ACC 90.625
# EPOCH 9 | ITER 80 | AVG_LOSS 0.14198589324951172 | Train_ACC 93.75
# EPOCH 9 | ITER 85 | AVG_LOSS 0.13818569481372833 | Train_ACC 96.875
# EPOCH 9 | ITER 90 | AVG_LOSS 0.13723327219486237 | Train_ACC 96.875
# EPOCH 9 | ITER 95 | AVG_LOSS 0.13867849111557007 | Train_ACC 96.875
# EPOCH 9 | ITER 100 | AVG_LOSS 0.13613037765026093 | Train_ACC 93.75
# EPOCH 9 | ITER 105 | AVG_LOSS 0.133671373128891 | Train_ACC 100.0
# EPOCH 9 | ITER 110 | AVG_LOSS 0.13326720893383026 | Train_ACC 93.75
# EPOCH 9 | ITER 115 | AVG_LOSS 0.13334833085536957 | Train_ACC 96.875
# EPOCH 9 | ITER 120 | AVG_LOSS 0.13309653103351593 | Train_ACC 100.0
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 9 | LOSS 0.22225996851921082 | TIME 33.183666467666626
# --------------------------------------------------
#
# EPOCH 10 | ITER 0 | AVG_LOSS 0.15985941886901855 | Train_ACC 90.625
# EPOCH 10 | ITER 5 | AVG_LOSS 0.10440009832382202 | Train_ACC 93.75
# EPOCH 10 | ITER 10 | AVG_LOSS 0.12907513976097107 | Train_ACC 84.375
# EPOCH 10 | ITER 15 | AVG_LOSS 0.12164220958948135 | Train_ACC 100.0
# EPOCH 10 | ITER 20 | AVG_LOSS 0.14028538763523102 | Train_ACC 96.875
# EPOCH 10 | ITER 25 | AVG_LOSS 0.14590366184711456 | Train_ACC 96.875
# EPOCH 10 | ITER 30 | AVG_LOSS 0.14061783254146576 | Train_ACC 93.75
# EPOCH 10 | ITER 35 | AVG_LOSS 0.13936808705329895 | Train_ACC 96.875
# EPOCH 10 | ITER 40 | AVG_LOSS 0.13429714739322662 | Train_ACC 96.875
# EPOCH 10 | ITER 45 | AVG_LOSS 0.1387694627046585 | Train_ACC 96.875
# EPOCH 10 | ITER 50 | AVG_LOSS 0.13573072850704193 | Train_ACC 96.875
# EPOCH 10 | ITER 55 | AVG_LOSS 0.1406373679637909 | Train_ACC 93.75
# EPOCH 10 | ITER 60 | AVG_LOSS 0.13534341752529144 | Train_ACC 100.0
# EPOCH 10 | ITER 65 | AVG_LOSS 0.134989932179451 | Train_ACC 96.875
# EPOCH 10 | ITER 70 | AVG_LOSS 0.1340530514717102 | Train_ACC 96.875
# EPOCH 10 | ITER 75 | AVG_LOSS 0.13744093477725983 | Train_ACC 93.75
# EPOCH 10 | ITER 80 | AVG_LOSS 0.1355663239955902 | Train_ACC 100.0
# EPOCH 10 | ITER 85 | AVG_LOSS 0.14200998842716217 | Train_ACC 90.625
# EPOCH 10 | ITER 90 | AVG_LOSS 0.1438084989786148 | Train_ACC 90.625
# EPOCH 10 | ITER 95 | AVG_LOSS 0.14427703619003296 | Train_ACC 87.5
# EPOCH 10 | ITER 100 | AVG_LOSS 0.1413959264755249 | Train_ACC 100.0
# EPOCH 10 | ITER 105 | AVG_LOSS 0.1399780809879303 | Train_ACC 100.0
# EPOCH 10 | ITER 110 | AVG_LOSS 0.13861139118671417 | Train_ACC 96.875
# EPOCH 10 | ITER 115 | AVG_LOSS 0.13609273731708527 | Train_ACC 100.0
# EPOCH 10 | ITER 120 | AVG_LOSS 0.1329813152551651 | Train_ACC 93.75
# Val Accuracy: 98.60%
#
# --------------------------------------------------
# EPOCH 10 | LOSS 0.133255735039711 | TIME 33.61043453216553
# --------------------------------------------------
#
# EPOCH 11 | ITER 0 | AVG_LOSS 0.10459315031766891 | Train_ACC 93.75
# EPOCH 11 | ITER 5 | AVG_LOSS 0.1240624189376831 | Train_ACC 96.875
# EPOCH 11 | ITER 10 | AVG_LOSS 0.11983884871006012 | Train_ACC 93.75
# EPOCH 11 | ITER 15 | AVG_LOSS 0.11480259895324707 | Train_ACC 96.875
# EPOCH 11 | ITER 20 | AVG_LOSS 0.11619257181882858 | Train_ACC 96.875
# EPOCH 11 | ITER 25 | AVG_LOSS 0.11773807555437088 | Train_ACC 93.75
# EPOCH 11 | ITER 30 | AVG_LOSS 0.12166756391525269 | Train_ACC 90.625
# EPOCH 11 | ITER 35 | AVG_LOSS 0.12449399381875992 | Train_ACC 100.0
# EPOCH 11 | ITER 40 | AVG_LOSS 0.12068718671798706 | Train_ACC 96.875
# EPOCH 11 | ITER 45 | AVG_LOSS 0.12189413607120514 | Train_ACC 93.75
# EPOCH 11 | ITER 50 | AVG_LOSS 0.12598514556884766 | Train_ACC 96.875
# EPOCH 11 | ITER 55 | AVG_LOSS 0.1334991306066513 | Train_ACC 93.75
# EPOCH 11 | ITER 60 | AVG_LOSS 0.13281868398189545 | Train_ACC 100.0
# EPOCH 11 | ITER 65 | AVG_LOSS 0.13199441134929657 | Train_ACC 90.625
# EPOCH 11 | ITER 70 | AVG_LOSS 0.13140790164470673 | Train_ACC 96.875
# EPOCH 11 | ITER 75 | AVG_LOSS 0.13554155826568604 | Train_ACC 93.75
# EPOCH 11 | ITER 80 | AVG_LOSS 0.13560666143894196 | Train_ACC 90.625
# EPOCH 11 | ITER 85 | AVG_LOSS 0.13689571619033813 | Train_ACC 87.5
# EPOCH 11 | ITER 90 | AVG_LOSS 0.13619975745677948 | Train_ACC 100.0
# EPOCH 11 | ITER 95 | AVG_LOSS 0.13653571903705597 | Train_ACC 93.75
# EPOCH 11 | ITER 100 | AVG_LOSS 0.13953447341918945 | Train_ACC 93.75
# EPOCH 11 | ITER 105 | AVG_LOSS 0.13944405317306519 | Train_ACC 96.875
# EPOCH 11 | ITER 110 | AVG_LOSS 0.14509586989879608 | Train_ACC 87.5
# EPOCH 11 | ITER 115 | AVG_LOSS 0.14386799931526184 | Train_ACC 93.75
# EPOCH 11 | ITER 120 | AVG_LOSS 0.14455562829971313 | Train_ACC 100.0
# Val Accuracy: 97.40%
#
# --------------------------------------------------
# EPOCH 11 | LOSS 0.09570102393627167 | TIME 36.92220950126648
# --------------------------------------------------
#
# EPOCH 12 | ITER 0 | AVG_LOSS 0.017339980229735374 | Train_ACC 100.0
# EPOCH 12 | ITER 5 | AVG_LOSS 0.11178957670927048 | Train_ACC 96.875
# EPOCH 12 | ITER 10 | AVG_LOSS 0.09899497032165527 | Train_ACC 96.875
# EPOCH 12 | ITER 15 | AVG_LOSS 0.10249165445566177 | Train_ACC 96.875
# EPOCH 12 | ITER 20 | AVG_LOSS 0.11562509834766388 | Train_ACC 96.875
# EPOCH 12 | ITER 25 | AVG_LOSS 0.1119854524731636 | Train_ACC 93.75
# EPOCH 12 | ITER 30 | AVG_LOSS 0.10729604214429855 | Train_ACC 96.875
# EPOCH 12 | ITER 35 | AVG_LOSS 0.1113620325922966 | Train_ACC 93.75
# EPOCH 12 | ITER 40 | AVG_LOSS 0.1239546611905098 | Train_ACC 81.25
# EPOCH 12 | ITER 45 | AVG_LOSS 0.12294818460941315 | Train_ACC 84.375
# EPOCH 12 | ITER 50 | AVG_LOSS 0.12278842180967331 | Train_ACC 90.625
# EPOCH 12 | ITER 55 | AVG_LOSS 0.12910562753677368 | Train_ACC 100.0
# EPOCH 12 | ITER 60 | AVG_LOSS 0.12612807750701904 | Train_ACC 96.875
# EPOCH 12 | ITER 65 | AVG_LOSS 0.12318921089172363 | Train_ACC 96.875
# EPOCH 12 | ITER 70 | AVG_LOSS 0.12039069086313248 | Train_ACC 96.875
# EPOCH 12 | ITER 75 | AVG_LOSS 0.12208685278892517 | Train_ACC 100.0
# EPOCH 12 | ITER 80 | AVG_LOSS 0.12308425456285477 | Train_ACC 100.0
# EPOCH 12 | ITER 85 | AVG_LOSS 0.1288388967514038 | Train_ACC 90.625
# EPOCH 12 | ITER 90 | AVG_LOSS 0.128468856215477 | Train_ACC 78.125
# EPOCH 12 | ITER 95 | AVG_LOSS 0.12533245980739594 | Train_ACC 96.875
# EPOCH 12 | ITER 100 | AVG_LOSS 0.12436243146657944 | Train_ACC 87.5
# EPOCH 12 | ITER 105 | AVG_LOSS 0.12311668694019318 | Train_ACC 93.75
# EPOCH 12 | ITER 110 | AVG_LOSS 0.12593117356300354 | Train_ACC 96.875
# EPOCH 12 | ITER 115 | AVG_LOSS 0.1244155690073967 | Train_ACC 90.625
# EPOCH 12 | ITER 120 | AVG_LOSS 0.12439008802175522 | Train_ACC 90.625
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 12 | LOSS 0.14137980341911316 | TIME 33.29796814918518
# --------------------------------------------------
#
# EPOCH 13 | ITER 0 | AVG_LOSS 0.951050877571106 | Train_ACC 71.875
# EPOCH 13 | ITER 5 | AVG_LOSS 0.2753421664237976 | Train_ACC 96.875
# EPOCH 13 | ITER 10 | AVG_LOSS 0.18454274535179138 | Train_ACC 96.875
# EPOCH 13 | ITER 15 | AVG_LOSS 0.17133000493049622 | Train_ACC 87.5
# EPOCH 13 | ITER 20 | AVG_LOSS 0.15941713750362396 | Train_ACC 90.625
# EPOCH 13 | ITER 25 | AVG_LOSS 0.15634939074516296 | Train_ACC 96.875
# EPOCH 13 | ITER 30 | AVG_LOSS 0.15002775192260742 | Train_ACC 96.875
# EPOCH 13 | ITER 35 | AVG_LOSS 0.14728708565235138 | Train_ACC 96.875
# EPOCH 13 | ITER 40 | AVG_LOSS 0.14947442710399628 | Train_ACC 96.875
# EPOCH 13 | ITER 45 | AVG_LOSS 0.140934556722641 | Train_ACC 100.0
# EPOCH 13 | ITER 50 | AVG_LOSS 0.14318804442882538 | Train_ACC 96.875
# EPOCH 13 | ITER 55 | AVG_LOSS 0.14273472130298615 | Train_ACC 93.75
# EPOCH 13 | ITER 60 | AVG_LOSS 0.14717704057693481 | Train_ACC 96.875
# EPOCH 13 | ITER 65 | AVG_LOSS 0.14291426539421082 | Train_ACC 93.75
# EPOCH 13 | ITER 70 | AVG_LOSS 0.14503660798072815 | Train_ACC 96.875
# EPOCH 13 | ITER 75 | AVG_LOSS 0.14675171673297882 | Train_ACC 90.625
# EPOCH 13 | ITER 80 | AVG_LOSS 0.14345073699951172 | Train_ACC 96.875
# EPOCH 13 | ITER 85 | AVG_LOSS 0.1404140442609787 | Train_ACC 100.0
# EPOCH 13 | ITER 90 | AVG_LOSS 0.13875915110111237 | Train_ACC 96.875
# EPOCH 13 | ITER 95 | AVG_LOSS 0.1346224695444107 | Train_ACC 100.0
# EPOCH 13 | ITER 100 | AVG_LOSS 0.13268432021141052 | Train_ACC 90.625
# EPOCH 13 | ITER 105 | AVG_LOSS 0.13354811072349548 | Train_ACC 87.5
# EPOCH 13 | ITER 110 | AVG_LOSS 0.1340850442647934 | Train_ACC 93.75
# EPOCH 13 | ITER 115 | AVG_LOSS 0.13369759917259216 | Train_ACC 100.0
# EPOCH 13 | ITER 120 | AVG_LOSS 0.13506054878234863 | Train_ACC 100.0
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 13 | LOSS 0.12189784646034241 | TIME 35.3976891040802
# --------------------------------------------------
#
# EPOCH 14 | ITER 0 | AVG_LOSS 0.19709402322769165 | Train_ACC 93.75
# EPOCH 14 | ITER 5 | AVG_LOSS 0.10187429189682007 | Train_ACC 96.875
# EPOCH 14 | ITER 10 | AVG_LOSS 0.1058836430311203 | Train_ACC 93.75
# EPOCH 14 | ITER 15 | AVG_LOSS 0.10947953909635544 | Train_ACC 96.875
# EPOCH 14 | ITER 20 | AVG_LOSS 0.09861007332801819 | Train_ACC 96.875
# EPOCH 14 | ITER 25 | AVG_LOSS 0.1016986295580864 | Train_ACC 87.5
# EPOCH 14 | ITER 30 | AVG_LOSS 0.09926538169384003 | Train_ACC 100.0
# EPOCH 14 | ITER 35 | AVG_LOSS 0.09492083638906479 | Train_ACC 100.0
# EPOCH 14 | ITER 40 | AVG_LOSS 0.10145409405231476 | Train_ACC 84.375
# EPOCH 14 | ITER 45 | AVG_LOSS 0.10042976588010788 | Train_ACC 96.875
# EPOCH 14 | ITER 50 | AVG_LOSS 0.1026649922132492 | Train_ACC 96.875
# EPOCH 14 | ITER 55 | AVG_LOSS 0.10402855277061462 | Train_ACC 87.5
# EPOCH 14 | ITER 60 | AVG_LOSS 0.10353697091341019 | Train_ACC 93.75
# EPOCH 14 | ITER 65 | AVG_LOSS 0.10263608396053314 | Train_ACC 87.5
# EPOCH 14 | ITER 70 | AVG_LOSS 0.10609788447618484 | Train_ACC 100.0
# EPOCH 14 | ITER 75 | AVG_LOSS 0.10985836386680603 | Train_ACC 87.5
# EPOCH 14 | ITER 80 | AVG_LOSS 0.11041005700826645 | Train_ACC 90.625
# EPOCH 14 | ITER 85 | AVG_LOSS 0.11204084008932114 | Train_ACC 100.0
# EPOCH 14 | ITER 90 | AVG_LOSS 0.11264689266681671 | Train_ACC 96.875
# EPOCH 14 | ITER 95 | AVG_LOSS 0.11114484071731567 | Train_ACC 93.75
# EPOCH 14 | ITER 100 | AVG_LOSS 0.11446092277765274 | Train_ACC 90.625
# EPOCH 14 | ITER 105 | AVG_LOSS 0.11702454090118408 | Train_ACC 93.75
# EPOCH 14 | ITER 110 | AVG_LOSS 0.11733588576316833 | Train_ACC 96.875
# EPOCH 14 | ITER 115 | AVG_LOSS 0.11913349479436874 | Train_ACC 90.625
# EPOCH 14 | ITER 120 | AVG_LOSS 0.11750459671020508 | Train_ACC 90.625
# Val Accuracy: 98.00%
#
# --------------------------------------------------
# EPOCH 14 | LOSS 0.10899603366851807 | TIME 37.63988661766052
# --------------------------------------------------
#
# EPOCH 15 | ITER 0 | AVG_LOSS 0.20298495888710022 | Train_ACC 84.375
# EPOCH 15 | ITER 5 | AVG_LOSS 0.07440804690122604 | Train_ACC 100.0
# EPOCH 15 | ITER 10 | AVG_LOSS 0.11073250323534012 | Train_ACC 96.875
# EPOCH 15 | ITER 15 | AVG_LOSS 0.12085817754268646 | Train_ACC 96.875
# EPOCH 15 | ITER 20 | AVG_LOSS 0.11702379584312439 | Train_ACC 93.75
# EPOCH 15 | ITER 25 | AVG_LOSS 0.11251496523618698 | Train_ACC 96.875
# EPOCH 15 | ITER 30 | AVG_LOSS 0.10707607120275497 | Train_ACC 100.0
# EPOCH 15 | ITER 35 | AVG_LOSS 0.10581627488136292 | Train_ACC 96.875
# EPOCH 15 | ITER 40 | AVG_LOSS 0.10904043167829514 | Train_ACC 93.75
# EPOCH 15 | ITER 45 | AVG_LOSS 0.1113409474492073 | Train_ACC 93.75
# EPOCH 15 | ITER 50 | AVG_LOSS 0.1094200611114502 | Train_ACC 93.75
# EPOCH 15 | ITER 55 | AVG_LOSS 0.11598671227693558 | Train_ACC 100.0
# EPOCH 15 | ITER 60 | AVG_LOSS 0.11668836325407028 | Train_ACC 100.0
# EPOCH 15 | ITER 65 | AVG_LOSS 0.11387969553470612 | Train_ACC 100.0
# EPOCH 15 | ITER 70 | AVG_LOSS 0.12012632936239243 | Train_ACC 87.5
# EPOCH 15 | ITER 75 | AVG_LOSS 0.11888208240270615 | Train_ACC 100.0
# EPOCH 15 | ITER 80 | AVG_LOSS 0.11853780597448349 | Train_ACC 93.75
# EPOCH 15 | ITER 85 | AVG_LOSS 0.11991576105356216 | Train_ACC 93.75
# EPOCH 15 | ITER 90 | AVG_LOSS 0.11978017538785934 | Train_ACC 93.75
# EPOCH 15 | ITER 95 | AVG_LOSS 0.12087585777044296 | Train_ACC 93.75
# EPOCH 15 | ITER 100 | AVG_LOSS 0.12265638262033463 | Train_ACC 90.625
# EPOCH 15 | ITER 105 | AVG_LOSS 0.12300656735897064 | Train_ACC 84.375
# EPOCH 15 | ITER 110 | AVG_LOSS 0.12519533932209015 | Train_ACC 87.5
# EPOCH 15 | ITER 115 | AVG_LOSS 0.12692072987556458 | Train_ACC 93.75
# EPOCH 15 | ITER 120 | AVG_LOSS 0.13079805672168732 | Train_ACC 93.75
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 15 | LOSS 0.09418019652366638 | TIME 33.79757881164551
# --------------------------------------------------
#
# EPOCH 16 | ITER 0 | AVG_LOSS 0.015726007521152496 | Train_ACC 100.0
# EPOCH 16 | ITER 5 | AVG_LOSS 0.10102638602256775 | Train_ACC 90.625
# EPOCH 16 | ITER 10 | AVG_LOSS 0.14667367935180664 | Train_ACC 96.875
# EPOCH 16 | ITER 15 | AVG_LOSS 0.1305665522813797 | Train_ACC 100.0
# EPOCH 16 | ITER 20 | AVG_LOSS 0.14235280454158783 | Train_ACC 96.875
# EPOCH 16 | ITER 25 | AVG_LOSS 0.13255195319652557 | Train_ACC 93.75
# EPOCH 16 | ITER 30 | AVG_LOSS 0.13652773201465607 | Train_ACC 100.0
# EPOCH 16 | ITER 35 | AVG_LOSS 0.1367122083902359 | Train_ACC 100.0
# EPOCH 16 | ITER 40 | AVG_LOSS 0.12934653460979462 | Train_ACC 100.0
# EPOCH 16 | ITER 45 | AVG_LOSS 0.12838369607925415 | Train_ACC 96.875
# EPOCH 16 | ITER 50 | AVG_LOSS 0.127640038728714 | Train_ACC 90.625
# EPOCH 16 | ITER 55 | AVG_LOSS 0.12966419756412506 | Train_ACC 93.75
# EPOCH 16 | ITER 60 | AVG_LOSS 0.1273464411497116 | Train_ACC 96.875
# EPOCH 16 | ITER 65 | AVG_LOSS 0.1263214349746704 | Train_ACC 90.625
# EPOCH 16 | ITER 70 | AVG_LOSS 0.12438558787107468 | Train_ACC 96.875
# EPOCH 16 | ITER 75 | AVG_LOSS 0.1263139545917511 | Train_ACC 87.5
# EPOCH 16 | ITER 80 | AVG_LOSS 0.1270606368780136 | Train_ACC 93.75
# EPOCH 16 | ITER 85 | AVG_LOSS 0.12570686638355255 | Train_ACC 100.0
# EPOCH 16 | ITER 90 | AVG_LOSS 0.12326698005199432 | Train_ACC 96.875
# EPOCH 16 | ITER 95 | AVG_LOSS 0.12294311821460724 | Train_ACC 90.625
# EPOCH 16 | ITER 100 | AVG_LOSS 0.12426024675369263 | Train_ACC 100.0
# EPOCH 16 | ITER 105 | AVG_LOSS 0.12675659358501434 | Train_ACC 93.75
# EPOCH 16 | ITER 110 | AVG_LOSS 0.1261415183544159 | Train_ACC 90.625
# EPOCH 16 | ITER 115 | AVG_LOSS 0.126461461186409 | Train_ACC 96.875
# EPOCH 16 | ITER 120 | AVG_LOSS 0.12740786373615265 | Train_ACC 90.625
# Val Accuracy: 98.40%
#
# --------------------------------------------------
# EPOCH 16 | LOSS 0.135837584733963 | TIME 35.69627857208252
# --------------------------------------------------
#
# EPOCH 17 | ITER 0 | AVG_LOSS 0.14470095932483673 | Train_ACC 96.875
# EPOCH 17 | ITER 5 | AVG_LOSS 0.13871543109416962 | Train_ACC 81.25
# EPOCH 17 | ITER 10 | AVG_LOSS 0.12305180728435516 | Train_ACC 93.75
# EPOCH 17 | ITER 15 | AVG_LOSS 0.12707513570785522 | Train_ACC 93.75
# EPOCH 17 | ITER 20 | AVG_LOSS 0.11276017129421234 | Train_ACC 100.0
# EPOCH 17 | ITER 25 | AVG_LOSS 0.11751224845647812 | Train_ACC 96.875
# EPOCH 17 | ITER 30 | AVG_LOSS 0.11627516150474548 | Train_ACC 96.875
# EPOCH 17 | ITER 35 | AVG_LOSS 0.11428225040435791 | Train_ACC 100.0
# EPOCH 17 | ITER 40 | AVG_LOSS 0.11037109792232513 | Train_ACC 100.0
# EPOCH 17 | ITER 45 | AVG_LOSS 0.10425852984189987 | Train_ACC 100.0
# EPOCH 17 | ITER 50 | AVG_LOSS 0.10726211965084076 | Train_ACC 90.625
# EPOCH 17 | ITER 55 | AVG_LOSS 0.11427110433578491 | Train_ACC 90.625
# EPOCH 17 | ITER 60 | AVG_LOSS 0.11918449401855469 | Train_ACC 96.875
# EPOCH 17 | ITER 65 | AVG_LOSS 0.12528666853904724 | Train_ACC 84.375
# EPOCH 17 | ITER 70 | AVG_LOSS 0.12564146518707275 | Train_ACC 90.625
# EPOCH 17 | ITER 75 | AVG_LOSS 0.12360118329524994 | Train_ACC 93.75
# EPOCH 17 | ITER 80 | AVG_LOSS 0.12378156930208206 | Train_ACC 100.0
# EPOCH 17 | ITER 85 | AVG_LOSS 0.12249527126550674 | Train_ACC 93.75
# EPOCH 17 | ITER 90 | AVG_LOSS 0.12025723606348038 | Train_ACC 96.875
# EPOCH 17 | ITER 95 | AVG_LOSS 0.12301145493984222 | Train_ACC 93.75
# EPOCH 17 | ITER 100 | AVG_LOSS 0.1234937533736229 | Train_ACC 87.5
# EPOCH 17 | ITER 105 | AVG_LOSS 0.13157255947589874 | Train_ACC 71.875
# EPOCH 17 | ITER 110 | AVG_LOSS 0.13413700461387634 | Train_ACC 96.875
# EPOCH 17 | ITER 115 | AVG_LOSS 0.13258548080921173 | Train_ACC 96.875
# EPOCH 17 | ITER 120 | AVG_LOSS 0.1327284425497055 | Train_ACC 87.5
# Val Accuracy: 98.20%
#
# --------------------------------------------------
# EPOCH 17 | LOSS 0.10181210935115814 | TIME 35.03330159187317
# --------------------------------------------------
#
# EPOCH 18 | ITER 0 | AVG_LOSS 0.06643164902925491 | Train_ACC 96.875
# EPOCH 18 | ITER 5 | AVG_LOSS 0.10631108283996582 | Train_ACC 90.625
# EPOCH 18 | ITER 10 | AVG_LOSS 0.1407383680343628 | Train_ACC 100.0
# EPOCH 18 | ITER 15 | AVG_LOSS 0.12106533348560333 | Train_ACC 96.875
# EPOCH 18 | ITER 20 | AVG_LOSS 0.14180976152420044 | Train_ACC 100.0
# EPOCH 18 | ITER 25 | AVG_LOSS 0.14261889457702637 | Train_ACC 90.625
# EPOCH 18 | ITER 30 | AVG_LOSS 0.146372988820076 | Train_ACC 93.75
# EPOCH 18 | ITER 35 | AVG_LOSS 0.1483413130044937 | Train_ACC 87.5
# EPOCH 18 | ITER 40 | AVG_LOSS 0.14132320880889893 | Train_ACC 93.75
# EPOCH 18 | ITER 45 | AVG_LOSS 0.13924451172351837 | Train_ACC 96.875
# EPOCH 18 | ITER 50 | AVG_LOSS 0.13971008360385895 | Train_ACC 96.875
# EPOCH 18 | ITER 55 | AVG_LOSS 0.13669516146183014 | Train_ACC 93.75
# EPOCH 18 | ITER 60 | AVG_LOSS 0.13667729496955872 | Train_ACC 87.5
# EPOCH 18 | ITER 65 | AVG_LOSS 0.1343947798013687 | Train_ACC 96.875
# EPOCH 18 | ITER 70 | AVG_LOSS 0.1327037811279297 | Train_ACC 96.875
# EPOCH 18 | ITER 75 | AVG_LOSS 0.13193903863430023 | Train_ACC 96.875
# EPOCH 18 | ITER 80 | AVG_LOSS 0.12935523688793182 | Train_ACC 93.75
# EPOCH 18 | ITER 85 | AVG_LOSS 0.12953998148441315 | Train_ACC 93.75
# EPOCH 18 | ITER 90 | AVG_LOSS 0.12845736742019653 | Train_ACC 96.875
# EPOCH 18 | ITER 95 | AVG_LOSS 0.1311897337436676 | Train_ACC 84.375
# EPOCH 18 | ITER 100 | AVG_LOSS 0.12852467596530914 | Train_ACC 90.625
# EPOCH 18 | ITER 105 | AVG_LOSS 0.12589582800865173 | Train_ACC 90.625
# EPOCH 18 | ITER 110 | AVG_LOSS 0.12293514609336853 | Train_ACC 96.875
# EPOCH 18 | ITER 115 | AVG_LOSS 0.12221883982419968 | Train_ACC 96.875
# EPOCH 18 | ITER 120 | AVG_LOSS 0.12410426139831543 | Train_ACC 93.75
# Val Accuracy: 99.00%
#
# --------------------------------------------------
# EPOCH 18 | LOSS 0.12257461994886398 | TIME 35.27870774269104
# --------------------------------------------------
#
# EPOCH 19 | ITER 0 | AVG_LOSS 0.11693894118070602 | Train_ACC 93.75
# EPOCH 19 | ITER 5 | AVG_LOSS 0.19079282879829407 | Train_ACC 90.625
# EPOCH 19 | ITER 10 | AVG_LOSS 0.15851342678070068 | Train_ACC 93.75
# EPOCH 19 | ITER 15 | AVG_LOSS 0.12924683094024658 | Train_ACC 93.75
# EPOCH 19 | ITER 20 | AVG_LOSS 0.12235671281814575 | Train_ACC 90.625
# EPOCH 19 | ITER 25 | AVG_LOSS 0.12975512444972992 | Train_ACC 96.875
# EPOCH 19 | ITER 30 | AVG_LOSS 0.11889929324388504 | Train_ACC 100.0
# EPOCH 19 | ITER 35 | AVG_LOSS 0.11617127060890198 | Train_ACC 96.875
# EPOCH 19 | ITER 40 | AVG_LOSS 0.11358708143234253 | Train_ACC 96.875
# EPOCH 19 | ITER 45 | AVG_LOSS 0.10942350327968597 | Train_ACC 96.875
# EPOCH 19 | ITER 50 | AVG_LOSS 0.11362841725349426 | Train_ACC 93.75
# EPOCH 19 | ITER 55 | AVG_LOSS 0.11375139653682709 | Train_ACC 93.75
# EPOCH 19 | ITER 60 | AVG_LOSS 0.11182277649641037 | Train_ACC 96.875
# EPOCH 19 | ITER 65 | AVG_LOSS 0.1130591407418251 | Train_ACC 93.75
# EPOCH 19 | ITER 70 | AVG_LOSS 0.11059413105249405 | Train_ACC 96.875
# EPOCH 19 | ITER 75 | AVG_LOSS 0.11170167475938797 | Train_ACC 100.0
# EPOCH 19 | ITER 80 | AVG_LOSS 0.11287244409322739 | Train_ACC 90.625
# EPOCH 19 | ITER 85 | AVG_LOSS 0.11259610205888748 | Train_ACC 96.875
# EPOCH 19 | ITER 90 | AVG_LOSS 0.11108218133449554 | Train_ACC 93.75
# EPOCH 19 | ITER 95 | AVG_LOSS 0.11171373724937439 | Train_ACC 96.875
# EPOCH 19 | ITER 100 | AVG_LOSS 0.1125611960887909 | Train_ACC 96.875
# EPOCH 19 | ITER 105 | AVG_LOSS 0.11256768554449081 | Train_ACC 100.0
# EPOCH 19 | ITER 110 | AVG_LOSS 0.11429786682128906 | Train_ACC 96.875
# EPOCH 19 | ITER 115 | AVG_LOSS 0.11481484770774841 | Train_ACC 96.875
# EPOCH 19 | ITER 120 | AVG_LOSS 0.11805453151464462 | Train_ACC 96.875
# Val Accuracy: 99.00%
#
# --------------------------------------------------
# EPOCH 19 | LOSS 0.21595892310142517 | TIME 34.70342230796814
# --------------------------------------------------
#
# EPOCH 20 | ITER 0 | AVG_LOSS 0.10630623996257782 | Train_ACC 96.875
# EPOCH 20 | ITER 5 | AVG_LOSS 0.13063126802444458 | Train_ACC 93.75
# EPOCH 20 | ITER 10 | AVG_LOSS 0.13129077851772308 | Train_ACC 90.625
# EPOCH 20 | ITER 15 | AVG_LOSS 0.14367376267910004 | Train_ACC 93.75
# EPOCH 20 | ITER 20 | AVG_LOSS 0.13134492933750153 | Train_ACC 93.75
# EPOCH 20 | ITER 25 | AVG_LOSS 0.12951332330703735 | Train_ACC 96.875
# EPOCH 20 | ITER 30 | AVG_LOSS 0.1183273047208786 | Train_ACC 100.0
# EPOCH 20 | ITER 35 | AVG_LOSS 0.11225313693284988 | Train_ACC 93.75
# EPOCH 20 | ITER 40 | AVG_LOSS 0.10904841870069504 | Train_ACC 96.875
# EPOCH 20 | ITER 45 | AVG_LOSS 0.10917258262634277 | Train_ACC 96.875
# EPOCH 20 | ITER 50 | AVG_LOSS 0.11028794944286346 | Train_ACC 96.875
# EPOCH 20 | ITER 55 | AVG_LOSS 0.11128725111484528 | Train_ACC 90.625
# EPOCH 20 | ITER 60 | AVG_LOSS 0.11452865600585938 | Train_ACC 93.75
# EPOCH 20 | ITER 65 | AVG_LOSS 0.11198015511035919 | Train_ACC 100.0
# EPOCH 20 | ITER 70 | AVG_LOSS 0.1143462210893631 | Train_ACC 93.75
# EPOCH 20 | ITER 75 | AVG_LOSS 0.11433346569538116 | Train_ACC 96.875
# EPOCH 20 | ITER 80 | AVG_LOSS 0.11209502071142197 | Train_ACC 96.875
# EPOCH 20 | ITER 85 | AVG_LOSS 0.11447054892778397 | Train_ACC 93.75
# EPOCH 20 | ITER 90 | AVG_LOSS 0.11751218140125275 | Train_ACC 93.75
# EPOCH 20 | ITER 95 | AVG_LOSS 0.115585558116436 | Train_ACC 90.625
# EPOCH 20 | ITER 100 | AVG_LOSS 0.11430278420448303 | Train_ACC 100.0
# EPOCH 20 | ITER 105 | AVG_LOSS 0.11510346084833145 | Train_ACC 96.875
# EPOCH 20 | ITER 110 | AVG_LOSS 0.11669902503490448 | Train_ACC 90.625
# EPOCH 20 | ITER 115 | AVG_LOSS 0.11885227262973785 | Train_ACC 96.875
# EPOCH 20 | ITER 120 | AVG_LOSS 0.12147402763366699 | Train_ACC 93.75
# Val Accuracy: 97.40%
#
# --------------------------------------------------
# EPOCH 20 | LOSS 0.03961450606584549 | TIME 33.96273446083069
# --------------------------------------------------
#
# EPOCH 21 | ITER 0 | AVG_LOSS 0.43870845437049866 | Train_ACC 87.5
# EPOCH 21 | ITER 5 | AVG_LOSS 0.23322342336177826 | Train_ACC 96.875
# EPOCH 21 | ITER 10 | AVG_LOSS 0.21176213026046753 | Train_ACC 90.625
# EPOCH 21 | ITER 15 | AVG_LOSS 0.1762917935848236 | Train_ACC 93.75
# EPOCH 21 | ITER 20 | AVG_LOSS 0.16333365440368652 | Train_ACC 93.75
# EPOCH 21 | ITER 25 | AVG_LOSS 0.18108977377414703 | Train_ACC 100.0
# EPOCH 21 | ITER 30 | AVG_LOSS 0.17413277924060822 | Train_ACC 90.625
# EPOCH 21 | ITER 35 | AVG_LOSS 0.16258873045444489 | Train_ACC 96.875
# EPOCH 21 | ITER 40 | AVG_LOSS 0.15492130815982819 | Train_ACC 96.875
# EPOCH 21 | ITER 45 | AVG_LOSS 0.14879974722862244 | Train_ACC 100.0
# EPOCH 21 | ITER 50 | AVG_LOSS 0.14085038006305695 | Train_ACC 93.75
# EPOCH 21 | ITER 55 | AVG_LOSS 0.13541445136070251 | Train_ACC 93.75
# EPOCH 21 | ITER 60 | AVG_LOSS 0.133121058344841 | Train_ACC 100.0
# EPOCH 21 | ITER 65 | AVG_LOSS 0.1295614242553711 | Train_ACC 100.0
# EPOCH 21 | ITER 70 | AVG_LOSS 0.1342296302318573 | Train_ACC 84.375
# EPOCH 21 | ITER 75 | AVG_LOSS 0.13428136706352234 | Train_ACC 93.75
# EPOCH 21 | ITER 80 | AVG_LOSS 0.13409385085105896 | Train_ACC 93.75
# EPOCH 21 | ITER 85 | AVG_LOSS 0.13329419493675232 | Train_ACC 96.875
# EPOCH 21 | ITER 90 | AVG_LOSS 0.13628457486629486 | Train_ACC 81.25
# EPOCH 21 | ITER 95 | AVG_LOSS 0.13580621778964996 | Train_ACC 93.75
# EPOCH 21 | ITER 100 | AVG_LOSS 0.1349959373474121 | Train_ACC 93.75
# EPOCH 21 | ITER 105 | AVG_LOSS 0.13583748042583466 | Train_ACC 93.75
# EPOCH 21 | ITER 110 | AVG_LOSS 0.13658855855464935 | Train_ACC 93.75
# EPOCH 21 | ITER 115 | AVG_LOSS 0.13784117996692657 | Train_ACC 90.625
# EPOCH 21 | ITER 120 | AVG_LOSS 0.1374925673007965 | Train_ACC 93.75
# Val Accuracy: 98.00%
#
# --------------------------------------------------
# EPOCH 21 | LOSS 0.06227141618728638 | TIME 35.007317781448364
# --------------------------------------------------
#
# EPOCH 22 | ITER 0 | AVG_LOSS 0.09075494855642319 | Train_ACC 96.875
# EPOCH 22 | ITER 5 | AVG_LOSS 0.11265355348587036 | Train_ACC 90.625
# EPOCH 22 | ITER 10 | AVG_LOSS 0.11244823783636093 | Train_ACC 100.0
# EPOCH 22 | ITER 15 | AVG_LOSS 0.10409845411777496 | Train_ACC 96.875
# EPOCH 22 | ITER 20 | AVG_LOSS 0.10980408638715744 | Train_ACC 93.75
# EPOCH 22 | ITER 25 | AVG_LOSS 0.1250758022069931 | Train_ACC 96.875
# EPOCH 22 | ITER 30 | AVG_LOSS 0.12047900259494781 | Train_ACC 93.75
# EPOCH 22 | ITER 35 | AVG_LOSS 0.12085571885108948 | Train_ACC 93.75
# EPOCH 22 | ITER 40 | AVG_LOSS 0.12576450407505035 | Train_ACC 81.25
# EPOCH 22 | ITER 45 | AVG_LOSS 0.1388401985168457 | Train_ACC 78.125
# EPOCH 22 | ITER 50 | AVG_LOSS 0.1338651180267334 | Train_ACC 100.0
# EPOCH 22 | ITER 55 | AVG_LOSS 0.13159731030464172 | Train_ACC 93.75
# EPOCH 22 | ITER 60 | AVG_LOSS 0.13184425234794617 | Train_ACC 100.0
# EPOCH 22 | ITER 65 | AVG_LOSS 0.1307562291622162 | Train_ACC 93.75
# EPOCH 22 | ITER 70 | AVG_LOSS 0.13509659469127655 | Train_ACC 90.625
# EPOCH 22 | ITER 75 | AVG_LOSS 0.1401556134223938 | Train_ACC 84.375
# EPOCH 22 | ITER 80 | AVG_LOSS 0.13858945667743683 | Train_ACC 84.375
# EPOCH 22 | ITER 85 | AVG_LOSS 0.13550855219364166 | Train_ACC 100.0
# EPOCH 22 | ITER 90 | AVG_LOSS 0.13666802644729614 | Train_ACC 87.5
# EPOCH 22 | ITER 95 | AVG_LOSS 0.13517072796821594 | Train_ACC 96.875
# EPOCH 22 | ITER 100 | AVG_LOSS 0.1378164291381836 | Train_ACC 96.875
# EPOCH 22 | ITER 105 | AVG_LOSS 0.1360083967447281 | Train_ACC 96.875
# EPOCH 22 | ITER 110 | AVG_LOSS 0.1344018578529358 | Train_ACC 93.75
# EPOCH 22 | ITER 115 | AVG_LOSS 0.13353003561496735 | Train_ACC 93.75
# EPOCH 22 | ITER 120 | AVG_LOSS 0.1338711380958557 | Train_ACC 96.875
# Val Accuracy: 98.60%
#
# --------------------------------------------------
# EPOCH 22 | LOSS 0.11219093203544617 | TIME 35.56152701377869
# --------------------------------------------------
#
# EPOCH 23 | ITER 0 | AVG_LOSS 0.13150613009929657 | Train_ACC 93.75
# EPOCH 23 | ITER 5 | AVG_LOSS 0.13406923413276672 | Train_ACC 100.0
# EPOCH 23 | ITER 10 | AVG_LOSS 0.1089145839214325 | Train_ACC 100.0
# EPOCH 23 | ITER 15 | AVG_LOSS 0.11641126871109009 | Train_ACC 96.875
# EPOCH 23 | ITER 20 | AVG_LOSS 0.11944574862718582 | Train_ACC 96.875
# EPOCH 23 | ITER 25 | AVG_LOSS 0.11287429928779602 | Train_ACC 93.75
# EPOCH 23 | ITER 30 | AVG_LOSS 0.11363914608955383 | Train_ACC 96.875
# EPOCH 23 | ITER 35 | AVG_LOSS 0.1193103939294815 | Train_ACC 78.125
# EPOCH 23 | ITER 40 | AVG_LOSS 0.11614532768726349 | Train_ACC 96.875
# EPOCH 23 | ITER 45 | AVG_LOSS 0.11656766384840012 | Train_ACC 96.875
# EPOCH 23 | ITER 50 | AVG_LOSS 0.1205403059720993 | Train_ACC 100.0
# EPOCH 23 | ITER 55 | AVG_LOSS 0.11614298820495605 | Train_ACC 93.75
# EPOCH 23 | ITER 60 | AVG_LOSS 0.11376827955245972 | Train_ACC 93.75
# EPOCH 23 | ITER 65 | AVG_LOSS 0.11011812835931778 | Train_ACC 96.875
# EPOCH 23 | ITER 70 | AVG_LOSS 0.10873974114656448 | Train_ACC 93.75
# EPOCH 23 | ITER 75 | AVG_LOSS 0.10921256244182587 | Train_ACC 93.75
# EPOCH 23 | ITER 80 | AVG_LOSS 0.11435460299253464 | Train_ACC 87.5
# EPOCH 23 | ITER 85 | AVG_LOSS 0.11554575711488724 | Train_ACC 87.5
# EPOCH 23 | ITER 90 | AVG_LOSS 0.1159805878996849 | Train_ACC 87.5
# EPOCH 23 | ITER 95 | AVG_LOSS 0.11507414281368256 | Train_ACC 93.75
# EPOCH 23 | ITER 100 | AVG_LOSS 0.11460788547992706 | Train_ACC 96.875
# EPOCH 23 | ITER 105 | AVG_LOSS 0.11668676137924194 | Train_ACC 100.0
# EPOCH 23 | ITER 110 | AVG_LOSS 0.11697390675544739 | Train_ACC 93.75
# EPOCH 23 | ITER 115 | AVG_LOSS 0.1193590834736824 | Train_ACC 84.375
# EPOCH 23 | ITER 120 | AVG_LOSS 0.1173974871635437 | Train_ACC 100.0
# Val Accuracy: 98.80%
#
# --------------------------------------------------
# EPOCH 23 | LOSS 0.057493530213832855 | TIME 36.10256576538086
# --------------------------------------------------
#
# EPOCH 24 | ITER 0 | AVG_LOSS 0.32486626505851746 | Train_ACC 84.375
# EPOCH 24 | ITER 5 | AVG_LOSS 0.26442664861679077 | Train_ACC 93.75
# EPOCH 24 | ITER 10 | AVG_LOSS 0.18499010801315308 | Train_ACC 100.0
# EPOCH 24 | ITER 15 | AVG_LOSS 0.18598799407482147 | Train_ACC 93.75
# EPOCH 24 | ITER 20 | AVG_LOSS 0.17323707044124603 | Train_ACC 100.0
# EPOCH 24 | ITER 25 | AVG_LOSS 0.1642995923757553 | Train_ACC 96.875
# EPOCH 24 | ITER 30 | AVG_LOSS 0.15274423360824585 | Train_ACC 96.875
# EPOCH 24 | ITER 35 | AVG_LOSS 0.14975601434707642 | Train_ACC 93.75
# EPOCH 24 | ITER 40 | AVG_LOSS 0.14959992468357086 | Train_ACC 90.625
# EPOCH 24 | ITER 45 | AVG_LOSS 0.14745987951755524 | Train_ACC 90.625
# EPOCH 24 | ITER 50 | AVG_LOSS 0.14984145760536194 | Train_ACC 87.5
# EPOCH 24 | ITER 55 | AVG_LOSS 0.14480410516262054 | Train_ACC 100.0
# EPOCH 24 | ITER 60 | AVG_LOSS 0.13988187909126282 | Train_ACC 93.75
# EPOCH 24 | ITER 65 | AVG_LOSS 0.1406897008419037 | Train_ACC 100.0
# EPOCH 24 | ITER 70 | AVG_LOSS 0.1443951576948166 | Train_ACC 96.875
# EPOCH 24 | ITER 75 | AVG_LOSS 0.1417902559041977 | Train_ACC 93.75
# EPOCH 24 | ITER 80 | AVG_LOSS 0.14119482040405273 | Train_ACC 93.75
# EPOCH 24 | ITER 85 | AVG_LOSS 0.1383952498435974 | Train_ACC 93.75
# EPOCH 24 | ITER 90 | AVG_LOSS 0.14087150990962982 | Train_ACC 96.875
# EPOCH 24 | ITER 95 | AVG_LOSS 0.13678935170173645 | Train_ACC 100.0
# EPOCH 24 | ITER 100 | AVG_LOSS 0.1428961455821991 | Train_ACC 96.875
# EPOCH 24 | ITER 105 | AVG_LOSS 0.14074118435382843 | Train_ACC 100.0
# EPOCH 24 | ITER 110 | AVG_LOSS 0.1389162838459015 | Train_ACC 96.875
# EPOCH 24 | ITER 115 | AVG_LOSS 0.13841959834098816 | Train_ACC 93.75
# EPOCH 24 | ITER 120 | AVG_LOSS 0.13941465318202972 | Train_ACC 90.625
# Val Accuracy: 97.60%
#
# --------------------------------------------------
# EPOCH 24 | LOSS 0.023786911740899086 | TIME 33.62708377838135
# --------------------------------------------------
#
# EPOCH 25 | ITER 0 | AVG_LOSS 0.05100677162408829 | Train_ACC 96.875
# EPOCH 25 | ITER 5 | AVG_LOSS 0.14975732564926147 | Train_ACC 96.875
# EPOCH 25 | ITER 10 | AVG_LOSS 0.15440607070922852 | Train_ACC 96.875
# EPOCH 25 | ITER 15 | AVG_LOSS 0.14544937014579773 | Train_ACC 90.625
# EPOCH 25 | ITER 20 | AVG_LOSS 0.1381773054599762 | Train_ACC 87.5
# EPOCH 25 | ITER 25 | AVG_LOSS 0.12810899317264557 | Train_ACC 96.875
# EPOCH 25 | ITER 30 | AVG_LOSS 0.12501543760299683 | Train_ACC 100.0
# EPOCH 25 | ITER 35 | AVG_LOSS 0.12171884626150131 | Train_ACC 96.875
# EPOCH 25 | ITER 40 | AVG_LOSS 0.12680870294570923 | Train_ACC 90.625
# EPOCH 25 | ITER 45 | AVG_LOSS 0.12911388278007507 | Train_ACC 93.75
# EPOCH 25 | ITER 50 | AVG_LOSS 0.12938392162322998 | Train_ACC 100.0
# EPOCH 25 | ITER 55 | AVG_LOSS 0.12506906688213348 | Train_ACC 100.0
# EPOCH 25 | ITER 60 | AVG_LOSS 0.13289162516593933 | Train_ACC 78.125
# EPOCH 25 | ITER 65 | AVG_LOSS 0.13011707365512848 | Train_ACC 93.75
# EPOCH 25 | ITER 70 | AVG_LOSS 0.1290055811405182 | Train_ACC 90.625
# EPOCH 25 | ITER 75 | AVG_LOSS 0.1293618381023407 | Train_ACC 90.625
# EPOCH 25 | ITER 80 | AVG_LOSS 0.13073892891407013 | Train_ACC 96.875
# EPOCH 25 | ITER 85 | AVG_LOSS 0.12638992071151733 | Train_ACC 96.875
# EPOCH 25 | ITER 90 | AVG_LOSS 0.12326865643262863 | Train_ACC 96.875
# EPOCH 25 | ITER 95 | AVG_LOSS 0.12351074814796448 | Train_ACC 87.5
# EPOCH 25 | ITER 100 | AVG_LOSS 0.12379086762666702 | Train_ACC 90.625
# EPOCH 25 | ITER 105 | AVG_LOSS 0.12385021150112152 | Train_ACC 100.0
# EPOCH 25 | ITER 110 | AVG_LOSS 0.1224122866988182 | Train_ACC 90.625
# EPOCH 25 | ITER 115 | AVG_LOSS 0.1202249526977539 | Train_ACC 100.0
# EPOCH 25 | ITER 120 | AVG_LOSS 0.12178008258342743 | Train_ACC 93.75
# Val Accuracy: 98.40%
#
# --------------------------------------------------
# EPOCH 25 | LOSS 0.02911573089659214 | TIME 35.51534724235535
# --------------------------------------------------
#
# EPOCH 26 | ITER 0 | AVG_LOSS 0.1403195559978485 | Train_ACC 90.625
# EPOCH 26 | ITER 5 | AVG_LOSS 0.19269394874572754 | Train_ACC 93.75
# EPOCH 26 | ITER 10 | AVG_LOSS 0.19298319518566132 | Train_ACC 93.75
# EPOCH 26 | ITER 15 | AVG_LOSS 0.17197425663471222 | Train_ACC 81.25
# EPOCH 26 | ITER 20 | AVG_LOSS 0.16394443809986115 | Train_ACC 90.625
# EPOCH 26 | ITER 25 | AVG_LOSS 0.14664840698242188 | Train_ACC 100.0
# EPOCH 26 | ITER 30 | AVG_LOSS 0.1462017446756363 | Train_ACC 100.0
# EPOCH 26 | ITER 35 | AVG_LOSS 0.14061462879180908 | Train_ACC 100.0
# EPOCH 26 | ITER 40 | AVG_LOSS 0.13830940425395966 | Train_ACC 100.0
# EPOCH 26 | ITER 45 | AVG_LOSS 0.13170240819454193 | Train_ACC 96.875
# EPOCH 26 | ITER 50 | AVG_LOSS 0.13536013662815094 | Train_ACC 93.75
# EPOCH 26 | ITER 55 | AVG_LOSS 0.1363627016544342 | Train_ACC 93.75
# EPOCH 26 | ITER 60 | AVG_LOSS 0.1327180564403534 | Train_ACC 90.625
# EPOCH 26 | ITER 65 | AVG_LOSS 0.13251663744449615 | Train_ACC 96.875
# EPOCH 26 | ITER 70 | AVG_LOSS 0.1331513375043869 | Train_ACC 93.75
# EPOCH 26 | ITER 75 | AVG_LOSS 0.13385970890522003 | Train_ACC 96.875
# EPOCH 26 | ITER 80 | AVG_LOSS 0.13095693290233612 | Train_ACC 96.875
# EPOCH 26 | ITER 85 | AVG_LOSS 0.12995199859142303 | Train_ACC 87.5
# EPOCH 26 | ITER 90 | AVG_LOSS 0.12768377363681793 | Train_ACC 100.0
# EPOCH 26 | ITER 95 | AVG_LOSS 0.12587080895900726 | Train_ACC 93.75
# EPOCH 26 | ITER 100 | AVG_LOSS 0.12703660130500793 | Train_ACC 93.75
# EPOCH 26 | ITER 105 | AVG_LOSS 0.12569528818130493 | Train_ACC 90.625
# EPOCH 26 | ITER 110 | AVG_LOSS 0.12677007913589478 | Train_ACC 96.875
# EPOCH 26 | ITER 115 | AVG_LOSS 0.12485040724277496 | Train_ACC 100.0
# EPOCH 26 | ITER 120 | AVG_LOSS 0.12896844744682312 | Train_ACC 96.875
# Val Accuracy: 98.00%
#
# --------------------------------------------------
# EPOCH 26 | LOSS 0.6233689188957214 | TIME 34.69729495048523
# --------------------------------------------------
#
# EPOCH 27 | ITER 0 | AVG_LOSS 0.19241885840892792 | Train_ACC 96.875
# EPOCH 27 | ITER 5 | AVG_LOSS 0.15210571885108948 | Train_ACC 100.0
# EPOCH 27 | ITER 10 | AVG_LOSS 0.12012653052806854 | Train_ACC 100.0
# EPOCH 27 | ITER 15 | AVG_LOSS 0.1228250190615654 | Train_ACC 90.625
# EPOCH 27 | ITER 20 | AVG_LOSS 0.11652322113513947 | Train_ACC 100.0
# EPOCH 27 | ITER 25 | AVG_LOSS 0.11585087329149246 | Train_ACC 100.0
# EPOCH 27 | ITER 30 | AVG_LOSS 0.1151658147573471 | Train_ACC 90.625
# EPOCH 27 | ITER 35 | AVG_LOSS 0.1108187586069107 | Train_ACC 96.875
# EPOCH 27 | ITER 40 | AVG_LOSS 0.11013653874397278 | Train_ACC 100.0
# EPOCH 27 | ITER 45 | AVG_LOSS 0.12000525742769241 | Train_ACC 93.75
# EPOCH 27 | ITER 50 | AVG_LOSS 0.12374749034643173 | Train_ACC 90.625
# EPOCH 27 | ITER 55 | AVG_LOSS 0.12230689823627472 | Train_ACC 90.625
# EPOCH 27 | ITER 60 | AVG_LOSS 0.11857699602842331 | Train_ACC 96.875
# EPOCH 27 | ITER 65 | AVG_LOSS 0.11827059835195541 | Train_ACC 96.875
# EPOCH 27 | ITER 70 | AVG_LOSS 0.1145445704460144 | Train_ACC 100.0
# EPOCH 27 | ITER 75 | AVG_LOSS 0.11362822353839874 | Train_ACC 96.875
# EPOCH 27 | ITER 80 | AVG_LOSS 0.11053437739610672 | Train_ACC 100.0
# EPOCH 27 | ITER 85 | AVG_LOSS 0.10892220586538315 | Train_ACC 100.0
# EPOCH 27 | ITER 90 | AVG_LOSS 0.11213169991970062 | Train_ACC 96.875
# EPOCH 27 | ITER 95 | AVG_LOSS 0.11605604737997055 | Train_ACC 84.375
# EPOCH 27 | ITER 100 | AVG_LOSS 0.11437135189771652 | Train_ACC 96.875
# EPOCH 27 | ITER 105 | AVG_LOSS 0.11513982713222504 | Train_ACC 96.875
# EPOCH 27 | ITER 110 | AVG_LOSS 0.11488843709230423 | Train_ACC 93.75
# EPOCH 27 | ITER 115 | AVG_LOSS 0.11303626000881195 | Train_ACC 100.0
# EPOCH 27 | ITER 120 | AVG_LOSS 0.11401547491550446 | Train_ACC 93.75
# Val Accuracy: 97.40%
#
# --------------------------------------------------
# EPOCH 27 | LOSS 0.12161476165056229 | TIME 33.60326361656189
# --------------------------------------------------
#
# EPOCH 28 | ITER 0 | AVG_LOSS 0.06596194952726364 | Train_ACC 100.0
# EPOCH 28 | ITER 5 | AVG_LOSS 0.11726073920726776 | Train_ACC 90.625
# EPOCH 28 | ITER 10 | AVG_LOSS 0.10284517705440521 | Train_ACC 100.0
# EPOCH 28 | ITER 15 | AVG_LOSS 0.10721362382173538 | Train_ACC 90.625
# EPOCH 28 | ITER 20 | AVG_LOSS 0.0965869128704071 | Train_ACC 100.0
# EPOCH 28 | ITER 25 | AVG_LOSS 0.09754780679941177 | Train_ACC 96.875
# EPOCH 28 | ITER 30 | AVG_LOSS 0.10382378101348877 | Train_ACC 90.625
# EPOCH 28 | ITER 35 | AVG_LOSS 0.11291570216417313 | Train_ACC 90.625
# EPOCH 28 | ITER 40 | AVG_LOSS 0.11033868044614792 | Train_ACC 100.0
# EPOCH 28 | ITER 45 | AVG_LOSS 0.11289032548666 | Train_ACC 96.875
# EPOCH 28 | ITER 50 | AVG_LOSS 0.11559395492076874 | Train_ACC 93.75
# EPOCH 28 | ITER 55 | AVG_LOSS 0.12249433994293213 | Train_ACC 90.625
# EPOCH 28 | ITER 60 | AVG_LOSS 0.13088589906692505 | Train_ACC 100.0
# EPOCH 28 | ITER 65 | AVG_LOSS 0.12826423346996307 | Train_ACC 93.75
# EPOCH 28 | ITER 70 | AVG_LOSS 0.1301938146352768 | Train_ACC 93.75
# EPOCH 28 | ITER 75 | AVG_LOSS 0.13043028116226196 | Train_ACC 100.0
# EPOCH 28 | ITER 80 | AVG_LOSS 0.13066068291664124 | Train_ACC 90.625
# EPOCH 28 | ITER 85 | AVG_LOSS 0.13197486102581024 | Train_ACC 96.875
# EPOCH 28 | ITER 90 | AVG_LOSS 0.1316264420747757 | Train_ACC 93.75
# EPOCH 28 | ITER 95 | AVG_LOSS 0.13032466173171997 | Train_ACC 100.0
# EPOCH 28 | ITER 100 | AVG_LOSS 0.13198328018188477 | Train_ACC 93.75
# EPOCH 28 | ITER 105 | AVG_LOSS 0.13272786140441895 | Train_ACC 84.375
# EPOCH 28 | ITER 110 | AVG_LOSS 0.1311711072921753 | Train_ACC 96.875
# EPOCH 28 | ITER 115 | AVG_LOSS 0.13090303540229797 | Train_ACC 90.625
# EPOCH 28 | ITER 120 | AVG_LOSS 0.13010144233703613 | Train_ACC 96.875
# Val Accuracy: 98.40%
#
# --------------------------------------------------
# EPOCH 28 | LOSS 0.09465139359235764 | TIME 36.81298637390137
# --------------------------------------------------
#
# EPOCH 29 | ITER 0 | AVG_LOSS 0.11155755817890167 | Train_ACC 93.75
# EPOCH 29 | ITER 5 | AVG_LOSS 0.08319269120693207 | Train_ACC 100.0
# EPOCH 29 | ITER 10 | AVG_LOSS 0.10213898867368698 | Train_ACC 90.625
# EPOCH 29 | ITER 15 | AVG_LOSS 0.10604935884475708 | Train_ACC 93.75
# EPOCH 29 | ITER 20 | AVG_LOSS 0.10247041285037994 | Train_ACC 96.875
# EPOCH 29 | ITER 25 | AVG_LOSS 0.10639728605747223 | Train_ACC 100.0
# EPOCH 29 | ITER 30 | AVG_LOSS 0.11026843637228012 | Train_ACC 93.75
# EPOCH 29 | ITER 35 | AVG_LOSS 0.11830486357212067 | Train_ACC 100.0
# EPOCH 29 | ITER 40 | AVG_LOSS 0.13720552623271942 | Train_ACC 87.5
# EPOCH 29 | ITER 45 | AVG_LOSS 0.1355752795934677 | Train_ACC 93.75
# EPOCH 29 | ITER 50 | AVG_LOSS 0.1328987181186676 | Train_ACC 100.0
# EPOCH 29 | ITER 55 | AVG_LOSS 0.13097912073135376 | Train_ACC 87.5
# EPOCH 29 | ITER 60 | AVG_LOSS 0.1320105344057083 | Train_ACC 100.0
# EPOCH 29 | ITER 65 | AVG_LOSS 0.1344311535358429 | Train_ACC 93.75
# EPOCH 29 | ITER 70 | AVG_LOSS 0.13340900838375092 | Train_ACC 96.875
# EPOCH 29 | ITER 75 | AVG_LOSS 0.12946408987045288 | Train_ACC 93.75
# EPOCH 29 | ITER 80 | AVG_LOSS 0.12885308265686035 | Train_ACC 87.5
# EPOCH 29 | ITER 85 | AVG_LOSS 0.1277264803647995 | Train_ACC 96.875
# EPOCH 29 | ITER 90 | AVG_LOSS 0.12693040072917938 | Train_ACC 96.875
# EPOCH 29 | ITER 95 | AVG_LOSS 0.12910570204257965 | Train_ACC 96.875
# EPOCH 29 | ITER 100 | AVG_LOSS 0.12880268692970276 | Train_ACC 90.625
# EPOCH 29 | ITER 105 | AVG_LOSS 0.13346019387245178 | Train_ACC 87.5
# EPOCH 29 | ITER 110 | AVG_LOSS 0.13150331377983093 | Train_ACC 96.875
# EPOCH 29 | ITER 115 | AVG_LOSS 0.13024719059467316 | Train_ACC 100.0
# EPOCH 29 | ITER 120 | AVG_LOSS 0.1282891482114792 | Train_ACC 93.75
# Val Accuracy: 98.80%
#
# --------------------------------------------------
# EPOCH 29 | LOSS 0.09405533224344254 | TIME 33.8908793926239
# --------------------------------------------------
#
# Best Model:  18
# ****************************************
# test Accuracy: 98.20%
# <ipython-input-12-21ea961f37fa>:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab20')

# %%
plotloss()

# %%
class2idx = {'Cat': 0, 'Dog': 1}

idx2class = { value : key  for key , value in class2idx.items() }
y_true = [idx2class[val.item()] for val in y_expected_test ]
y_pred = [idx2class[val.item()] for val in y_test ]

macro_precision = precision_score(y_true, y_pred, average="macro")
macro_recall = recall_score(y_true, y_pred, average="macro")
micro_precision = precision_score(y_true, y_pred, average="micro")
micro_recall = recall_score(y_true, y_pred, average="micro")
f1_score = (2*micro_precision*micro_recall)/(micro_recall + micro_precision)

print("f1 - Score is :--- " ,f1_score)
cnf_matrix = confusion_matrix(y_true , y_pred , labels=['Cat','Dog'])
plot_confusion_matrix(cnf_matrix , class2idx.keys() , [macro_precision , micro_precision , macro_recall , micro_recall], output_filename = "cnf_resnet_Data1.png")
# Out:
# f1 - Score is :---  0.982
